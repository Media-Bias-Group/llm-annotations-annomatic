# %%
import random
from datasets import load_dataset
import nltk

nltk.download("punkt")

def _fix_sentences(sentences):
    merged_sentences = []

    for i, sentence in enumerate(sentences):
        if i > 0 and sentence.startswith(("'", '"', "“", "!", "—")):
            merged_sentences[-1] += " " + sentence
        else:
            merged_sentences.append(sentence)

    return merged_sentences


def count_sentences(text):
    sentences = nltk.sent_tokenize(text)
    return len(_fix_sentences(sentences=sentences))


def split_sentences(text):
    sentences = nltk.sent_tokenize(text)
    merged_sentences = _fix_sentences(sentences)
    
    if len(merged_sentences) < 2:
        return text, ""
    if len(merged_sentences) == 2:
        return merged_sentences[0], merged_sentences[1]
    else:
        split_index = random.randint(1, len(merged_sentences) - 1)
        first_piece = " ".join(merged_sentences[:split_index]).strip()
        second_piece = " ".join(merged_sentences[split_index:]).strip()

        return first_piece, second_piece
# Out:
# [nltk_data] Downloading package punkt to /Users/mandlc/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = load_dataset("mediabiasgroup/BABE")['train'].to_pandas()
icl_pool = load_dataset("mediabiasgroup/BABE-icl-pool")['train'].to_pandas()

df = df.merge(icl_pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)

# %%
df['sentence_count'] = df['text'].apply(lambda x: count_sentences(x))
df_sentences = df[df['sentence_count'] > 1].reset_index(drop=True)

min_sentence_count = df['sentence_count'].min()
max_sentence_count = df['sentence_count'].max()
mean_sentence_count = df['sentence_count'].mean()

print("Minimum sentence count:", min_sentence_count)
print("Maximum sentence count:", max_sentence_count)
print("Mean sentence count:", mean_sentence_count)
# Out:
# Minimum sentence count: 1
# Maximum sentence count: 5
# Mean sentence count: 1.101952995696789

# %%
import pandas as pd


df_new = df_sentences[["text",'label']].copy()
df_new[["first_piece", "second_piece"]] = df_new["text"].apply(lambda x: pd.Series(split_sentences(x)))
df_new = df_new.groupby('label').sample(10, random_state=42)

# map label (same as in their paper)
df_new['label'] = df_new['label'].replace({0: '0 (not biased)', 1: '1 (biased)'})
df_new.to_csv("babe_contamination.csv", index=False)

# %%
df_new
# Out:
#                                                   text           label  \
# 107  In California, where personal income taxes acc...  0 (not biased)
# 191  Victims of the violence endured potentially li...  0 (not biased)
# 230  But last Wednesday, when the Heritage Clinic f...  0 (not biased)
# 66   President Donald Trump and Congress are taking...  0 (not biased)
# 194  The protestors reportedly are demanding that  ...  0 (not biased)
# 23   Before we get to work dispensing these argumen...  0 (not biased)
# 101  President Donald Trump says that voting by mai...  0 (not biased)
# 241  Two years ago, America’s white nationalist mov...  0 (not biased)
# 20   Two Democrats -- state Sens. Creigh Deeds and ...  0 (not biased)
# 156  Japan is facing a major challenge, with the pu...  0 (not biased)
# 82   That the Secret Service takes precautions to p...      1 (biased)
# 56   For that matter, Christianity is equally anti-...      1 (biased)
# 12   The same goes for Govs. Gavin Newsom, Andrew C...      1 (biased)
# 89   The backlash by health-care professionals and ...      1 (biased)
# 172  Yet the drumbeat for censorship goes on as the...      1 (biased)
# 127  During the campaign, it was clear that much of...      1 (biased)
# 26   The bureaucrats and local would-be dictators c...      1 (biased)
# 22   The president has failed miserably at handling...      1 (biased)
# 158  Yes Trump and the right are embracing and cele...      1 (biased)
# 132  President Donald Trump clearly wasn’t pleased ...      1 (biased)
#
#                                            first_piece  \
# 107  In California, where personal income taxes acc...
# 191  Victims of the violence endured potentially li...
# 230  But last Wednesday, when the Heritage Clinic f...
# 66   President Donald Trump and Congress are taking...
# 194  The protestors reportedly are demanding that  ...
# 23   Before we get to work dispensing these argumen...
# 101  President Donald Trump says that voting by mai...
# 241  Two years ago, America’s white nationalist mov...
# 20                        Two Democrats -- state Sens.
# 156  Japan is facing a major challenge, with the pu...
# 82   That the Secret Service takes precautions to p...
# 56   For that matter, Christianity is equally anti-...
# 12                             The same goes for Govs.
# 89   The backlash by health-care professionals and ...
# 172  Yet the drumbeat for censorship goes on as the...
# 127  During the campaign, it was clear that much of...
# 26   The bureaucrats and local would-be dictators c...
# 22   The president has failed miserably at handling...
# 158  Yes Trump and the right are embracing and cele...
# 132  President Donald Trump clearly wasn’t pleased ...
#
#                                           second_piece
# 107  Palmer, a spokesman for the state’s finance de...
# 191  D.C. Police Chief Peter Newsham told protester...
# 230  Ignoring the no-trespassing signs, they began ...
# 66   Billy Graham last Wednesday, through a preside...
# 194  Andrew Cuomo hike taxes on the state’s billion...
# 23   A lot of Americans, especially those who got t...
# 101  But county-level election supervisors in his h...
# 241  Neo-Nazi demonstrations in Charlottesville, Vi...
# 20   Creigh Deeds and Chap Petersen -- joined with ...
# 156  Japan has already invested billions, and the d...
# 82   Unsurprisingly, a lot of people made fun of hi...
# 56   And yet, the Christian Right and many of Presi...
# 12   Gavin Newsom, Andrew Cuomo, Jay Inslee, and ev...
# 89                                And for good reason.
# 172  Today it will be about money, but only because...
# 127  NeverTrump gambled on a Hillary Clinton victor...
# 26   So how did we get here, and how do we reclaim ...
# 22   They have not only revealed the incompetence o...
# 158  It is also one more illustration that the Age ...
# 132  So the president responded in his usual and pr...
