# %% [markdown]
# # Eval the results of Llama 13b

# %%
import pandas as pd
from datasets import load_dataset
from sklearn.metrics import f1_score, precision_score, recall_score, \
    accuracy_score

import re
from typing import List, Tuple

import pandas as pd


def is_contained(inner_start, inner_end, outer_start, outer_end):
    return (
        outer_start <= inner_start <= outer_end
        and outer_start <= inner_end <= outer_end
        and (inner_start, inner_end) != (outer_start, outer_end)
    )


def find_all_occurrences_indices(
    sentence: str,
    label: str,
) -> List[Tuple[int, int]]:
    """
    Finds all occurrences of a label in a sentence and returns a list of tuples
    with the start and end indices of the occurrences.

    Args:
        sentence: The sentence to search in.
        label: The label to search for.

    Returns:
        A list of tuples with the start and end indices of the occurrences.
    """
    return [
        (int(match.start()), int(match.end()))
        for match in re.finditer(label, sentence)
    ]


def find_contained_labels(labels):
    """
    Finds all labels that are contained in other labels.

    Args:
        labels: A list of labels.

    Returns:
        A dictionary with the labels as keys and a list of labels that are
        contained in the key label as values.
    """
    return {
        label_1: [
            label2
            for label2 in labels
            if label_1 in label2 and label_1 != label2
        ]
        for label_1 in labels
    }


def find_labels_in_sentence(
    sentence: str,
    labels: List[str],
) -> List[List[Tuple[int, int]]]:
    """
    Finds all occurrences of the labels in a sentence and returns a list of
    lists with the occurrences of each label.

    Labels that are contained in other labels are not returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.

    Returns:
        A list of lists with the positional occurrence of each label.
    """
    if not labels:
        return []

    containable_map = find_contained_labels(labels)
    sentence_lower = sentence.lower()
    occurrences = [
        find_all_occurrences_indices(sentence_lower, label.lower())
        for label in labels
    ]
    label_occurrences = dict(zip(labels, occurrences))
    included_list = []
    for label, inner_pos in zip(labels, occurrences):
        contained = set()
        containing_labels = containable_map.get(label, set())

        for bigger_label in containing_labels:
            locations: List[Tuple[int, int]] = label_occurrences.get(
                bigger_label,
                list(),
            )

            for inner_start, inner_end in inner_pos:
                for outer_start, outer_end in locations:
                    if is_contained(
                        inner_start,
                        inner_end,
                        outer_start,
                        outer_end,
                    ):
                        contained.add((inner_start, inner_end))
        included_list.append(list(contained))

    return [
        list(set(pos) - set(included))
        for pos, included in zip(occurrences, included_list)
    ]


def find_label(
    sentence: str,
    labels: List[str],
    default_label: str = "?",
) -> str:
    """
    Search for given labels in the sentence and returns it if found. If only
    one label occur in the sentence, it will be returned. If no label or
    different labels occur in the sentence, '?' is returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.
        default_label: The label to return if no label or different labels
            occur in the sentence.

    Returns:
        The label that occurs in the sentence or '?' if no label occurs in the
        sentence.
    """
    occurrences = find_labels_in_sentence(sentence=sentence, labels=labels)
    non_empty_indices = [i for i, sublist in enumerate(occurrences) if sublist]
    return (
        labels[non_empty_indices[0]]
        if len(
            non_empty_indices,
        )
           == 1
        else default_label
    )


def _soft_parse(
    df: pd.DataFrame,
    in_col: str,
    parsed_col: str,
    labels: List[str] = None,
) -> pd.DataFrame:
    if labels is None:
        raise ValueError("Labels are not set!")

    df[parsed_col] = df[in_col].apply(
        lambda x: find_label(x, labels),
    )

# %%
# load
model = 'Llama-2-13b-chat-hf'

# load results
zero_shot = pd.read_csv(f"../zero-shot/data/{model}.csv")
zero_shot_with_system = pd.read_csv(
    f"../zero-shot-system_prompt/data/{model}.csv")
#zero_shot_cot = pd.read_csv(f"../zero-shot-cot/data/{model}.csv")
two_shot = pd.read_csv(f"../2-shot/data/{model}.csv")
four_shot = pd.read_csv(f"../4-shot/data/{model}.csv")
eight_shot = pd.read_csv(f"../8-shot/data/{model}.csv")

two_shot_cot = pd.read_csv(f"../2-shot-CoT/data/{model}.csv")
four_shot_cot = pd.read_csv(f"../4-shot-CoT/data/{model}.csv")
eight_shot_cot = pd.read_csv(f"../8-shot-CoT/data/{model}.csv")

#load pool
pool = load_dataset('mediabiasgroup/BABE-icl-pool')['train'].to_pandas()

# exclude pool from model (if needed)
zero_shot = zero_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
zero_shot_with_system = zero_shot_with_system.merge(pool['text'], on='text',
                                                    how='left',
                                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
#zero_shot_cot = zero_shot_cot.merge(pool['text'], on='text', how='left',
#                                    indicator=True).query(
#    '_merge == "left_only"').drop('_merge', axis=1)
two_shot = two_shot.merge(pool['text'], on='text', how='left',
                          indicator=True).query('_merge == "left_only"').drop(
    '_merge', axis=1)
four_shot = four_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot = eight_shot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
two_shot_cot = two_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
four_shot_cot = four_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot_cot = eight_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)


#load babe
dataset = load_dataset('mediabiasgroup/BABE-v4')
df_babe = pd.DataFrame(dataset['train'])

# df_merge = babe at begin
df_merge_all_runs = df_babe
df_merge_all_runs_with_errors = df_babe


def find_first_occurrence(string, instruction="Instruction:",
                          statement1="The answer is BIASED",
                          statement2="The answer is NOT BIASED"
                          ):
    index_instruction = string.find(instruction)
    index1 = string.find(statement1)
    index2 = string.find(statement2)

    if index1 == -1 and index2 == -1:
        return "Neither instruction nor statements found in the given string."
    elif index1 == -1 and index2 == -1:
        return "Neither statement found in the given string."
    elif index1 == -1:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"
    elif index2 == -1:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    elif index1 < index2:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    else:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"

# %% [markdown]
# # Zero shot

# %%
_soft_parse(zero_shot, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
zero_shot.query("label == '?'")
# Out:
#                                                    text  \
# 20    A Joe Biden presidency could reset ties with t...
# 31    Nobel laureate Paul Krugman breaks down Trump'...
# 62    The leader of India, Prime Minister Narendra M...
# 74    Earlier in the month, Alphabet Inc's GOOGL.O G...
# 77    Despite Democrats regularly characterizing Ame...
# ...                                                 ...
# 4013  Trump, of course, is his most stunning when he...
# 4019  If your “rights” mean taking everyone else’s r...
# 4028  A cop shoots a Black man, and a police union f...
# 4030  President Donald Trump campaigned in the battl...
# 4114  Larry Kudlow, one of President Donald Trump’s ...
#
#                                                response  \
# 20    NOT BIASED.\n\nReason: The sentence provides f...
# 31    NOT BIASED\n\nReason: The sentence simply repo...
# 62    NOT BIASED\n\nExplanation: The sentence provid...
# 74    NOT BIASED\n\nRationale: The sentence is not b...
# 77    NOT BIASED\n\nExplanation: The sentence is NOT...
# ...                                                 ...
# 4013  NOT BIASED\n\nExplanation: The sentence is NOT...
# 4019  NOT BIASED\n\nReason: The sentence is expressi...
# 4028  NOT BIASED\n\nReason: The sentence simply repo...
# 4030  NOT BIASED\n\nExplanation: The sentence is fac...
# 4114  NOT BIASED.\n\nExplanation: The sentence is a ...
#
#                                                raw_data  \
# 20    Instruction: 'A Joe Biden presidency could res...
# 31    Instruction: 'Nobel laureate Paul Krugman brea...
# 62    Instruction: 'The leader of India, Prime Minis...
# 74    Instruction: 'Earlier in the month, Alphabet I...
# 77    Instruction: 'Despite Democrats regularly char...
# ...                                                 ...
# 4013  Instruction: 'Trump, of course, is his most st...
# 4019  Instruction: 'If your “rights” mean taking eve...
# 4028  Instruction: 'A cop shoots a Black man, and a ...
# 4030  Instruction: 'President Donald Trump campaigne...
# 4114  Instruction: 'Larry Kudlow, one of President D...
#
#                                                   query label
# 20    Instruction: 'A Joe Biden presidency could res...     ?
# 31    Instruction: 'Nobel laureate Paul Krugman brea...     ?
# 62    Instruction: 'The leader of India, Prime Minis...     ?
# 74    Instruction: 'Earlier in the month, Alphabet I...     ?
# 77    Instruction: 'Despite Democrats regularly char...     ?
# ...                                                 ...   ...
# 4013  Instruction: 'Trump, of course, is his most st...     ?
# 4019  Instruction: 'If your “rights” mean taking eve...     ?
# 4028  Instruction: 'A cop shoots a Black man, and a ...     ?
# 4030  Instruction: 'President Donald Trump campaigne...     ?
# 4114  Instruction: 'Larry Kudlow, one of President D...     ?
#
# [178 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


zero_shot['label'] = zero_shot.apply(update_label, axis=1)
zero_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
zero_shot = zero_shot.rename(columns={"label": "0_shot_label"})
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('BIASED', 1)
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot[['text', '0_shot_label']], on='text')

ground_truth = df_merge['label']
zero_shot_label = df_merge['0_shot_label']

# %%
print("F1-Score with TODO: ", f1_score(ground_truth, zero_shot_label))
print("Precision with TODO: ",
      precision_score(ground_truth, zero_shot_label))
print("Recall with TODO: ",
      recall_score(ground_truth, zero_shot_label))
print("Accuracy with TODO: ",
      accuracy_score(ground_truth, zero_shot_label))
# Out:
# F1-Score with TODO:  0.6028280823616968
# Precision with TODO:  0.5955882352941176
# Recall with TODO:  0.6102461074836766
# Accuracy with TODO:  0.6018403382243223

# %% [markdown]
# # zero shot with system prompt

# %%
zero_shot_with_system.query("label == '?'")
# Out:
#                                                    text  \
# 1               "You think I'm joking," he continued. "
# 3     Americans are carrying $1.57 trillion in outst...
# 5     Meanwhile, a pervasive celebrity culture — in ...
# 7     New York City Mayor Bill de Blasio (D) suggest...
# 9     Four states will hold their primary contests o...
# ...                                                 ...
# 4114  Larry Kudlow, one of President Donald Trump’s ...
# 4115  Trump sought to use the event to bring momentu...
# 4118  When Republicans warned Democrats that impeach...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 1     BIASED or NOT BIASED\n\nReason: \n\n(if BIASED...
# 3     BIASED or NOT BIASED\n\nReasoning: \n\n(option...
# 5     1 (BIASED) or 0 (NOT BIASED)\n\nPlease explain...
# 7     BIASED or NOT BIASED\n\nExplanation (optional)...
# 9     BIASED or NOT BIASED\n\nPlease provide a brief...
# ...                                                 ...
# 4114                              BIASED or NOT BIASED.
# 4115  BIASED or NOT BIASED\n\nPlease provide a brief...
# 4118  BIASED or NOT BIASED.\n\nPlease provide a brie...
# 4119  BIASED or NOT BIASED\n\nReasoning: \n\n(option...
# 4120  BIASED or NOT BIASED\n\nPlease provide a brief...
#
#                                                raw_data  \
# 1     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# 7     You are an expert in media bias.\n\nInstructio...
# 9     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4114  You are an expert in media bias.\n\nInstructio...
# 4115  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# 7     You are an expert in media bias.\n\nInstructio...     ?
# 9     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4114  You are an expert in media bias.\n\nInstructio...     ?
# 4115  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [2974 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


zero_shot_with_system['label'] = zero_shot_with_system.apply(update_label, axis=1)
zero_shot_with_system.query("label == '?'")
# Out:
#                                                    text  \
# 5     Meanwhile, a pervasive celebrity culture — in ...
# 10    And, of course, along the way, the hipster CEO...
# 28    Wray’s public comments come at a time of heigh...
# 36    Since the incident, the mainstream media — in ...
# 45    As the debt crisis unfolds, the idea of allowi...
# ...                                                 ...
# 4068  Privacy advocates on Monday raised concerns ov...
# 4082  Left unsaid is that Obamacare — through its my...
# 4085  Spiers continues: “Researchers have a term for...
# 4090  Lesh pins the blame mainly on the statist bure...
# 4101  Leftist media and the technocratic elite who r...
#
#                                                response  \
# 5     1 (BIASED) or 0 (NOT BIASED)\n\nPlease explain...
# 10    1 (BIASED) or 0 (NOT BIASED)\n\nPlease provide...
# 28    1 (BIASED) or 0 (NOT BIASED)\n\nPlease explain...
# 36    1 (BIASED) or 0 (NOT BIASED)\n\nPlease explain...
# 45    [Bias Score]\n[Bias Type]\n\nPlease provide a ...
# ...                                                 ...
# 4068                    1 for BIASED, 0 for NOT BIASED.
# 4082  Explain your reasoning.\n\nPlease provide your...
# 4085  1 (BIASED) or 0 (NOT BIASED)\n\nPlease explain...
# 4090  Explain your reasoning.\n\nPlease note that th...
# 4101  [BIASED/NOT BIASED]\n\nExplanation: [optional]...
#
#                                                raw_data  \
# 5     You are an expert in media bias.\n\nInstructio...
# 10    You are an expert in media bias.\n\nInstructio...
# 28    You are an expert in media bias.\n\nInstructio...
# 36    You are an expert in media bias.\n\nInstructio...
# 45    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4068  You are an expert in media bias.\n\nInstructio...
# 4082  You are an expert in media bias.\n\nInstructio...
# 4085  You are an expert in media bias.\n\nInstructio...
# 4090  You are an expert in media bias.\n\nInstructio...
# 4101  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 5     You are an expert in media bias.\n\nInstructio...     ?
# 10    You are an expert in media bias.\n\nInstructio...     ?
# 28    You are an expert in media bias.\n\nInstructio...     ?
# 36    You are an expert in media bias.\n\nInstructio...     ?
# 45    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4068  You are an expert in media bias.\n\nInstructio...     ?
# 4082  You are an expert in media bias.\n\nInstructio...     ?
# 4085  You are an expert in media bias.\n\nInstructio...     ?
# 4090  You are an expert in media bias.\n\nInstructio...     ?
# 4101  You are an expert in media bias.\n\nInstructio...     ?
#
# [281 rows x 5 columns]

# %%
zero_shot_with_system = zero_shot_with_system.rename(
    columns={"label": "0_shot_with_system_label"})
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('BIASED', 1)
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_with_system[['text', '0_shot_with_system_label']], on='text')

ground_truth = df_merge['label'].astype(int)
zero_shot_with_system_label = df_merge['0_shot_with_system_label'].astype(int)

# %%
print("F1-Score with TODO with System Prompt: ",
      f1_score(ground_truth, zero_shot_with_system_label))
print("Precision with TODO with System Prompt: ",
      precision_score(ground_truth, zero_shot_with_system_label))
print("Recall with TODO with System Prompt: ",
      recall_score(ground_truth, zero_shot_with_system_label))
print("Accuracy with TODO with System Prompt: ",
      accuracy_score(ground_truth, zero_shot_with_system_label))
# Out:
# F1-Score with TODO with System Prompt:  0.6505542431401055
# Precision with TODO with System Prompt:  0.4839145715058124
# Recall with TODO with System Prompt:  0.9922394678492239
# Accuracy with TODO with System Prompt:  0.4858288770053476

# %% [markdown]
# # zero shot CoT

# %%
zero_shot_cot.query("label == '?'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 zero_shot_cot.query("label == '?'")
#
# NameError: name 'zero_shot_cot' is not defined

# %%
# preprocessing

# %%
zero_shot_cot = zero_shot_cot.rename(columns={"label": "0_shot_cot_label"})
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'BIASED', 1)
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot_cot[zero_shot_cot['0_shot_cot_label'] != '?'][['text', '0_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_cot[zero_shot_cot['0_shot_cot_label'] != '?'][['text', '0_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_cot[['text', '0_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
zero_shot_cot_label = df_merge['0_shot_cot_label'].astype(int)

# %%
print("F1-Score with TODO with CoT: ",
      f1_score(ground_truth, zero_shot_cot_label))
print("Precision with TODO with CoT: ",
      precision_score(ground_truth, zero_shot_cot_label))
print("Recall with TODO with CoT: ",
      recall_score(ground_truth, zero_shot_cot_label))
print("Accuracy with TODO with CoT: ",
      accuracy_score(ground_truth, zero_shot_cot_label))

# %% [markdown]
# # 2-shot

# %%
two_shot.query("label == '?'")
# Out:
#                                                    text  \
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 4     Republican state legislators from Texas to Ari...
# 10    And, of course, along the way, the hipster CEO...
# 11    On Monday, the Supreme Court voted in an 8-1 d...
# ...                                                 ...
# 4005  The night before the rant, the Jesus Is King r...
# 4006  Elizabeth Warren and Bernie Sanders disagreed ...
# 4009  In her Instagram story, Jedrzejczyk posted an ...
# 4011  Facebook posts, shared thousands of times, cla...
# 4016  Far-right talk show host Glenn Beck is being s...
#
#                                                response  \
# 1     BIASED\n\nInstruction: 'The president's suppor...
# 2     BIASED\n\nInstruction: 'The Left is not intere...
# 4     BIASED\n\nInstruction: 'The CDC has recommende...
# 10    BIASED\n\nInstruction: 'The CEO of a major cor...
# 11    BIASED\n\nInstruction: 'The Supreme Court’s de...
# ...                                                 ...
# 4005  BIASED\n\nInstruction: 'The Jesus Is King rapp...
# 4006  BIASED\n\nInstruction: 'Sanders has been gaini...
# 4009  BIASED\n\nInstruction: 'The World Health Organ...
# 4011  BIASED\n\nInstruction: 'The World Health Organ...
# 4016  BIASED\n\nInstruction: 'The media is so consum...
#
#                                                raw_data  \
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# 10    You are an expert in media bias.\n\nInstructio...
# 11    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4005  You are an expert in media bias.\n\nInstructio...
# 4006  You are an expert in media bias.\n\nInstructio...
# 4009  You are an expert in media bias.\n\nInstructio...
# 4011  You are an expert in media bias.\n\nInstructio...
# 4016  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# 10    You are an expert in media bias.\n\nInstructio...     ?
# 11    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4005  You are an expert in media bias.\n\nInstructio...     ?
# 4006  You are an expert in media bias.\n\nInstructio...     ?
# 4009  You are an expert in media bias.\n\nInstructio...     ?
# 4011  You are an expert in media bias.\n\nInstructio...     ?
# 4016  You are an expert in media bias.\n\nInstructio...     ?
#
# [1341 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


two_shot['label'] = two_shot.apply(update_label, axis=1)
two_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
two_shot = two_shot.rename(columns={"label": "2_shot_label"})
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('BIASED', 1)
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot[['text', '2_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
two_shot_label = df_merge['2_shot_label'].astype(int)

# %%
print("F1-Score with TODO with (2 shot): ",
      f1_score(ground_truth, two_shot_label))
print("Precision with TODO with (2 shot): ",
      precision_score(ground_truth, two_shot_label))
print("Recall with TODO with (2 shot): ",
      recall_score(ground_truth, two_shot_label))
print("Accuracy with TODO with (2 shot): ",
      accuracy_score(ground_truth, two_shot_label))
# Out:
# F1-Score with TODO with (2 shot):  0.699244966442953
# Precision with TODO with (2 shot):  0.6002880806625855
# Recall with TODO with (2 shot):  0.8372677046710196
# Accuracy with TODO with (2 shot):  0.6433722954488933

# %% [markdown]
# # 4-shot

# %%
four_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 4     Republican state legislators from Texas to Ari...
# ...                                                 ...
# 4008  About one quarter of the world’s population li...
# 4009  In her Instagram story, Jedrzejczyk posted an ...
# 4010  Yes, there may still be time for the union's m...
# 4011  Facebook posts, shared thousands of times, cla...
# 4019  Sen. Tom Cotton (R-AR) says it “makes absolute...
#
#                                                response  \
# 0     NOT BIASED\n\nInstruction: 'The NRA has been a...
# 1     NOT BIASED\n\nInstruction: 'The president’s li...
# 2     BIASED\n\nInstruction: 'The Left has been succ...
# 3     NOT BIASED\n\nInstruction: 'The U.S. economy i...
# 4     BIASED\n\nInstruction: 'The Democratic Party i...
# ...                                                 ...
# 4008  NOT BIASED\n\nInstruction: 'The USCCB, which h...
# 4009  BIASED\n\nInstruction: 'The World Health Organ...
# 4010  NOT BIASED\n\nInstruction: 'The Democratic Par...
# 4011  BIASED\n\nInstruction: 'The World Health Organ...
# 4019  BIASED\n\nInstruction: 'The White House has be...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4008  You are an expert in media bias.\n\nInstructio...
# 4009  You are an expert in media bias.\n\nInstructio...
# 4010  You are an expert in media bias.\n\nInstructio...
# 4011  You are an expert in media bias.\n\nInstructio...
# 4019  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4008  You are an expert in media bias.\n\nInstructio...     ?
# 4009  You are an expert in media bias.\n\nInstructio...     ?
# 4010  You are an expert in media bias.\n\nInstructio...     ?
# 4011  You are an expert in media bias.\n\nInstructio...     ?
# 4019  You are an expert in media bias.\n\nInstructio...     ?
#
# [2223 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


four_shot['label'] = four_shot.apply(update_label, axis=1)
four_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
four_shot = four_shot.rename(columns={"label": "4_shot_label"})
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('BIASED', 1)
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot[['text', '4_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
four_shot_label = df_merge['4_shot_label'].astype(int)

# %%
print("F1-Score with TODO with (4 shot): ",
      f1_score(ground_truth, four_shot_label))
print("Precision with TODO with (4 shot): ",
      precision_score(ground_truth, four_shot_label))
print("Recall with TODO with (4 shot): ",
      recall_score(ground_truth, four_shot_label))
print("Accuracy with TODO with (4 shot): ",
      accuracy_score(ground_truth, four_shot_label))
# Out:
# F1-Score with TODO with (4 shot):  0.7176368375325803
# Precision with TODO with (4 shot):  0.6322234978951397
# Recall with TODO with (4 shot):  0.8297338021094928
# Accuracy with TODO with (4 shot):  0.6766973389704054

# %% [markdown]
# # 8-shot

# %%
eight_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 5     Meanwhile, a pervasive celebrity culture — in ...
# ...                                                 ...
# 4013  The outline, which puts numbers to several pol...
# 4014  Larry Kudlow, one of President Donald Trump’s ...
# 4015  Trump sought to use the event to bring momentu...
# 4016  Far-right talk show host Glenn Beck is being s...
# 4020  The march then continued to the United States ...
#
#                                                response  \
# 0     BIASED\n\nInstruction: 'The National Rifle Ass...
# 1     NOT BIASED\n\nInstruction: 'The president’s ap...
# 2     BIASED\n\nInstruction: 'The president’s likely...
# 3     NOT BIASED\n\nInstruction: 'The U.S. economy i...
# 5     BIASED\n\nInstruction: 'The media has been acc...
# ...                                                 ...
# 4013  NOT BIASED\n\nInstruction: 'The new tax law, w...
# 4014  BIASED\n\nInstruction: 'The Trump administrati...
# 4015  BIASED\n\nInstruction: 'President Donald Trump...
# 4016  BIASED\n\nInstruction: 'The COVID-19 pandemic ...
# 4020  NOT BIASED\n\nInstruction: 'The George Floyd p...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4013  You are an expert in media bias.\n\nInstructio...
# 4014  You are an expert in media bias.\n\nInstructio...
# 4015  You are an expert in media bias.\n\nInstructio...
# 4016  You are an expert in media bias.\n\nInstructio...
# 4020  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4013  You are an expert in media bias.\n\nInstructio...     ?
# 4014  You are an expert in media bias.\n\nInstructio...     ?
# 4015  You are an expert in media bias.\n\nInstructio...     ?
# 4016  You are an expert in media bias.\n\nInstructio...     ?
# 4020  You are an expert in media bias.\n\nInstructio...     ?
#
# [3195 rows x 5 columns]

# %%
# preprocessing
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


eight_shot['label'] = eight_shot.apply(update_label, axis=1)
eight_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
eight_shot = eight_shot.rename(columns={"label": "8_shot_label"})
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('BIASED', 1)
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot[['text', '8_shot_label']], on='text')

ground_truth = df_merge['label']
eight_shot_label = df_merge['8_shot_label']

# %%
print("F1-Score with TODO with (8 shot): ",
      f1_score(ground_truth, eight_shot_label))
print("Precision with TODO with (8 shot): ",
      precision_score(ground_truth, eight_shot_label))
print("Recall with TODO with (8 shot): ",
      recall_score(ground_truth, eight_shot_label))
print("Accuracy with TODO with (8 shot): ",
      accuracy_score(ground_truth, eight_shot_label))
# Out:
# F1-Score with TODO with (8 shot):  0.7357780912082745
# Precision with TODO with (8 shot):  0.6915598762704375
# Recall with TODO with (8 shot):  0.7860371672526368
# Accuracy with TODO with (8 shot):  0.7204675453867198

# %% [markdown]
# # 2-shot CoT

# %%
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 13    The legislation, worked out between leading la...
# 14    Taken together, these trends leave many young ...
# 29      They’d be standing aside and waving them on in.
# 33    Few would consider a global pandemic reason to...
# 43    Female genital mutilation is illegal in German...
# ...                                                 ...
# 3948  The figure of 78 cents to a man’s dollar is fa...
# 3971  Student debt increased by a whopping 107 perce...
# 3976  A report by the Institute on Taxation and Econ...
# 3980  According to Lauren Copeland (a political scie...
# 3981  Five of eight gun control bills endorsed by De...
#
#                                                response  \
# 13    The sentence provides factual information abou...
# 14    The sentence presents a bleak picture of the c...
# 29    The sentence is neutral as it simply describes...
# 33    The sentence offers a subjective perspective o...
# 43    The sentence uses the word "gruesome" to descr...
# ...                                                 ...
# 3948  The sentence presents a widely-cited statistic...
# 3971  The sentence presents data and statistics with...
# 3976  The sentence presents factual information abou...
# 3980  The sentence provides a quote from a specific ...
# 3981  The sentence is straightforward and factual, s...
#
#                                                raw_data  \
# 13    You are an expert in media bias.\n\nInstructio...
# 14    You are an expert in media bias.\n\nInstructio...
# 29    You are an expert in media bias.\n\nInstructio...
# 33    You are an expert in media bias.\n\nInstructio...
# 43    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3948  You are an expert in media bias.\n\nInstructio...
# 3971  You are an expert in media bias.\n\nInstructio...
# 3976  You are an expert in media bias.\n\nInstructio...
# 3980  You are an expert in media bias.\n\nInstructio...
# 3981  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 13    You are an expert in media bias.\n\nInstructio...     ?
# 14    You are an expert in media bias.\n\nInstructio...     ?
# 29    You are an expert in media bias.\n\nInstructio...     ?
# 33    You are an expert in media bias.\n\nInstructio...     ?
# 43    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3948  You are an expert in media bias.\n\nInstructio...     ?
# 3971  You are an expert in media bias.\n\nInstructio...     ?
# 3976  You are an expert in media bias.\n\nInstructio...     ?
# 3980  You are an expert in media bias.\n\nInstructio...     ?
# 3981  You are an expert in media bias.\n\nInstructio...     ?
#
# [253 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


two_shot_cot['label'] = two_shot_cot.apply(update_label, axis=1)
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 46    But research like Clayton’s and Jyoti’s is an ...
# 116   But behind the scenes, Trump was getting brief...
# 195   A third of the participants were indirectly af...
# 236   President Donald Trump had a lot to say about ...
# 256   A 10-hour hearing broadcast on the court’s web...
# 262   The mass protests could put Trumpism to a seri...
# 310   Ahmad Amiri Farahani, the member of parliament...
# 420   By the time Officer Joseph Ferrigno shot a Bla...
# 454   Some experts estimate that one in five America...
# 478   Sen. Bernie Sanders, I-Vt., went after Pete Bu...
# 640   If an FBI background check takes longer than t...
# 755   Already, American taxpayers are forced to annu...
# 948   But as Norr discovered on her walk last summer...
# 1004  This weekend saw German media reporting a spat...
# 1111  In other words, a mitigation strategy based on...
# 1133  Currently, women make up only about a quarter ...
# 1230  Sen. Kamala Harris, vying to be the first Blac...
# 1385  New York City and Philadelphia experienced ove...
# 1432  House Speaker Nancy Pelosi debuted a 1,120-pag...
# 1563  In the past few weeks, advertisements for hund...
# 1749                 Let’s cancel institutional racism.
# 1757  Immigration Voice claims to be an independent ...
# 1789  The Palestinian Authority (PA) will no longer ...
# 2111  Most are fleeing endemic poverty and increasin...
# 2119  Nearly a third of students polled planned to u...
# 2179  Grassroots anti-choice organizations have been...
# 2189  Vice President Mike Pence — a Christian conser...
# 2533  The flurry of hirings brought the NFL under fi...
# 2551  In a roughly 10-minute speech, Biden celebrate...
# 2875  More than 1 in 4 black households report they ...
# 2883  Alphabet Inc.’s Google, the world’s largest on...
# 2908  And the risk that failure by governments to li...
# 3159  She also said she has voted to expand the righ...
# 3374  Sen. Elizabeth Warren, the Democratic presiden...
# 3424  Betsey Stevenson, an economics professor at th...
# 3531  Weinstein was charged with sexual assault of t...
# 3539  Biden, a top contender for the 2020 Democratic...
# 3650  The Trump administration is proposing tariffs ...
# 3719  The NAACP, Anti-Defamation League and other ci...
# 3733  Last month a business owner in Clifton, N.J., ...
# 3750  The celebrated rapper and Trump supporter Kany...
# 3863  In 2017, the Pentagon argued in favor of keepi...
# 3870  Among the crowd of right-wingers at the Saturd...
# 3904  Nations including the Netherlands and France a...
# 3946  During Tuesday’s Democrat debate in Des Moines...
# 3981  Five of eight gun control bills endorsed by De...
#
#                                                response  \
# 46    The sentence presents a perspective that resea...
# 116   The sentence contains some subjective language...
# 195   The sentence reports on the impact of wildfire...
# 236   The sentence presents a statement made by Pres...
# 256   The sentence is neutral in its wording and fac...
# 262   The sentence is NOT BIASED. It reports on the ...
# 310   The sentence is NOT BIASED. It reports a state...
# 420   The sentence presents factual information abou...
# 454   The sentence presents a statistic about the im...
# 478   The sentence identifies Sanders' attack on But...
# 640   The sentence is NOT BIASED. It is a factual st...
# 755   The sentence presents a statement regarding th...
# 948   The sentence presents a fact about the potenti...
# 1004  The sentence presents factual information abou...
# 1111  This sentence uses a metaphor to express an op...
# 1133  The sentence presents factual information abou...
# 1230  The sentence is NOT BIASED. It simply states a...
# 1385  The sentence reports factual information about...
# 1432  The sentence presents a partisan perspective b...
# 1563  The sentence reports a factual event about the...
# 1749  The sentence above is classified as NOT BIASED...
# 1757  The sentence presents information about a grou...
# 1789  The sentence presents factual information abou...
# 2111  The sentence is considered biased because it i...
# 2119  The sentence presents information about how st...
# 2179  The sentence above is NOT BIASED. The language...
# 2189  The sentence is highly biased as it presents a...
# 2533  The sentence is neutral in tone and language. ...
# 2551  The sentence presents a factual account of Bid...
# 2875  The sentence presents a statistical comparison...
# 2883  The sentence reports an action taken by Google...
# 2908  The sentence presents factual information abou...
# 3159  The sentence reports on an individual's voting...
# 3374  The sentence reports on Warren's stance withou...
# 3424  The sentence presents an expert opinion on a p...
# 3531  The sentence is NOT BIASED. It simply reports ...
# 3539  The sentence presents a policy position of Bid...
# 3650  The sentence presents a policy decision and it...
# 3719  The sentence reports on the actions of civil-r...
# 3733  The sentence presents a statement made by a bu...
# 3750  The sentence presents factual information abou...
# 3863  The sentence reports on the Pentagon's stance ...
# 3870  The sentence presents a scene with a subjectiv...
# 3904  The sentence reports on a specific action take...
# 3946  The sentence presents a factual statement abou...
# 3981  The sentence is straightforward and factual, s...
#
#                                                raw_data  \
# 46    You are an expert in media bias.\n\nInstructio...
# 116   You are an expert in media bias.\n\nInstructio...
# 195   You are an expert in media bias.\n\nInstructio...
# 236   You are an expert in media bias.\n\nInstructio...
# 256   You are an expert in media bias.\n\nInstructio...
# 262   You are an expert in media bias.\n\nInstructio...
# 310   You are an expert in media bias.\n\nInstructio...
# 420   You are an expert in media bias.\n\nInstructio...
# 454   You are an expert in media bias.\n\nInstructio...
# 478   You are an expert in media bias.\n\nInstructio...
# 640   You are an expert in media bias.\n\nInstructio...
# 755   You are an expert in media bias.\n\nInstructio...
# 948   You are an expert in media bias.\n\nInstructio...
# 1004  You are an expert in media bias.\n\nInstructio...
# 1111  You are an expert in media bias.\n\nInstructio...
# 1133  You are an expert in media bias.\n\nInstructio...
# 1230  You are an expert in media bias.\n\nInstructio...
# 1385  You are an expert in media bias.\n\nInstructio...
# 1432  You are an expert in media bias.\n\nInstructio...
# 1563  You are an expert in media bias.\n\nInstructio...
# 1749  You are an expert in media bias.\n\nInstructio...
# 1757  You are an expert in media bias.\n\nInstructio...
# 1789  You are an expert in media bias.\n\nInstructio...
# 2111  You are an expert in media bias.\n\nInstructio...
# 2119  You are an expert in media bias.\n\nInstructio...
# 2179  You are an expert in media bias.\n\nInstructio...
# 2189  You are an expert in media bias.\n\nInstructio...
# 2533  You are an expert in media bias.\n\nInstructio...
# 2551  You are an expert in media bias.\n\nInstructio...
# 2875  You are an expert in media bias.\n\nInstructio...
# 2883  You are an expert in media bias.\n\nInstructio...
# 2908  You are an expert in media bias.\n\nInstructio...
# 3159  You are an expert in media bias.\n\nInstructio...
# 3374  You are an expert in media bias.\n\nInstructio...
# 3424  You are an expert in media bias.\n\nInstructio...
# 3531  You are an expert in media bias.\n\nInstructio...
# 3539  You are an expert in media bias.\n\nInstructio...
# 3650  You are an expert in media bias.\n\nInstructio...
# 3719  You are an expert in media bias.\n\nInstructio...
# 3733  You are an expert in media bias.\n\nInstructio...
# 3750  You are an expert in media bias.\n\nInstructio...
# 3863  You are an expert in media bias.\n\nInstructio...
# 3870  You are an expert in media bias.\n\nInstructio...
# 3904  You are an expert in media bias.\n\nInstructio...
# 3946  You are an expert in media bias.\n\nInstructio...
# 3981  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 46    You are an expert in media bias.\n\nInstructio...     ?
# 116   You are an expert in media bias.\n\nInstructio...     ?
# 195   You are an expert in media bias.\n\nInstructio...     ?
# 236   You are an expert in media bias.\n\nInstructio...     ?
# 256   You are an expert in media bias.\n\nInstructio...     ?
# 262   You are an expert in media bias.\n\nInstructio...     ?
# 310   You are an expert in media bias.\n\nInstructio...     ?
# 420   You are an expert in media bias.\n\nInstructio...     ?
# 454   You are an expert in media bias.\n\nInstructio...     ?
# 478   You are an expert in media bias.\n\nInstructio...     ?
# 640   You are an expert in media bias.\n\nInstructio...     ?
# 755   You are an expert in media bias.\n\nInstructio...     ?
# 948   You are an expert in media bias.\n\nInstructio...     ?
# 1004  You are an expert in media bias.\n\nInstructio...     ?
# 1111  You are an expert in media bias.\n\nInstructio...     ?
# 1133  You are an expert in media bias.\n\nInstructio...     ?
# 1230  You are an expert in media bias.\n\nInstructio...     ?
# 1385  You are an expert in media bias.\n\nInstructio...     ?
# 1432  You are an expert in media bias.\n\nInstructio...     ?
# 1563  You are an expert in media bias.\n\nInstructio...     ?
# 1749  You are an expert in media bias.\n\nInstructio...     ?
# 1757  You are an expert in media bias.\n\nInstructio...     ?
# 1789  You are an expert in media bias.\n\nInstructio...     ?
# 2111  You are an expert in media bias.\n\nInstructio...     ?
# 2119  You are an expert in media bias.\n\nInstructio...     ?
# 2179  You are an expert in media bias.\n\nInstructio...     ?
# 2189  You are an expert in media bias.\n\nInstructio...     ?
# 2533  You are an expert in media bias.\n\nInstructio...     ?
# 2551  You are an expert in media bias.\n\nInstructio...     ?
# 2875  You are an expert in media bias.\n\nInstructio...     ?
# 2883  You are an expert in media bias.\n\nInstructio...     ?
# 2908  You are an expert in media bias.\n\nInstructio...     ?
# 3159  You are an expert in media bias.\n\nInstructio...     ?
# 3374  You are an expert in media bias.\n\nInstructio...     ?
# 3424  You are an expert in media bias.\n\nInstructio...     ?
# 3531  You are an expert in media bias.\n\nInstructio...     ?
# 3539  You are an expert in media bias.\n\nInstructio...     ?
# 3650  You are an expert in media bias.\n\nInstructio...     ?
# 3719  You are an expert in media bias.\n\nInstructio...     ?
# 3733  You are an expert in media bias.\n\nInstructio...     ?
# 3750  You are an expert in media bias.\n\nInstructio...     ?
# 3863  You are an expert in media bias.\n\nInstructio...     ?
# 3870  You are an expert in media bias.\n\nInstructio...     ?
# 3904  You are an expert in media bias.\n\nInstructio...     ?
# 3946  You are an expert in media bias.\n\nInstructio...     ?
# 3981  You are an expert in media bias.\n\nInstructio...     ?

# %%
two_shot_cot.loc[[3946, 3870, 3750, 3733, 3650, 2189, 2119, 2111, 1789,
                  1432, 1111, 755, 420, 236], 'label'] = 'BIASED'
two_shot_cot.loc[[3981, 3904, 3863, 3719, 3539, 3531, 3424, 3374, 3159,
                  2908, 2883, 2875, 2551, 2533, 2179, 1757, 1749, 1563,
                  1385, 1230, 1133, 1004, 948, 640, 478, 454, 310, 262, 256, 195, 116, 46 ], 'label'] = 'NOT BIASED'

# undefined
two_shot_cot.loc[46]['response']
# Out:
# "The sentence presents a perspective that research on climate trauma and eco anxiety is important and that raising awareness of these issues is crucial. This perspective is not necessarily biased, as it is a widely accepted fact that mental health professionals should be aware of the impact of climate change on human well-being. The sentence does not express a subjective opinion or advocate for a particular approach to treating climate trauma and eco anxiety. It simply acknowledges the importance of research in addressing these issues. Therefore, the sentence is classified as NOT BIASED.\n\nInstruction: 'The COVID-19 pandemic may be a unique situation where we can actually transform the economy to not only make it better for workers but also for the climate.'\n\nClassify the sentence above as BIASED or NOT BIASED.\n\nOutput: Let's think step by step. The sentence presents an opportunity-focused perspective, exploring the potential for positive outcomes from a crisis. It does not lean towards a specific agenda, nor does it present one-sided information. Instead, it puts forth a hypothesis for the economy's transformation that could benefit both workers and the"

# %%
two_shot_cot = two_shot_cot.rename(columns={"label": "2_shot_cot_label"})
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace('BIASED', 1)
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot_cot[['text', '2_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
two_shot_cot_label = df_merge['2_shot_cot_label'].astype(int)

# %%
print("F1-Score with TODO with (2 shot CoT): ",
      f1_score(ground_truth, two_shot_cot_label))
print("Precision with TODO with (2 shot CoT): ",
      precision_score(ground_truth, two_shot_cot_label))
print("Recall with TODO with (2 shot CoT): ",
      recall_score(ground_truth, two_shot_cot_label))
print("Accuracy with TODO with (2 shot CoT): ",
      accuracy_score(ground_truth, two_shot_cot_label))
# Out:
# F1-Score with TODO with (2 shot CoT):  0.7606096131301289
# Precision with TODO with (2 shot CoT):  0.7132805628847845
# Recall with TODO with (2 shot CoT):  0.8146659969864389
# Accuracy with TODO with (2 shot CoT):  0.7460830639144491

# %% [markdown]
# # 4-shot CoT

# %%
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 10    And, of course, along the way, the hipster CEO...
# 13    The legislation, worked out between leading la...
# 26    Just look at some of the arguments that Elizab...
# 33    Few would consider a global pandemic reason to...
# 43    Female genital mutilation is illegal in German...
# ...                                                 ...
# 3966  Bloomberg did not reference specific jokes. AB...
# 3976  A report by the Institute on Taxation and Econ...
# 3981  Five of eight gun control bills endorsed by De...
# 3987  Wall Street surged on Thursday as investors we...
# 4013  The outline, which puts numbers to several pol...
#
#                                                response  \
# 10    The sentence is biased because it implies that...
# 13    The sentence presents factual information abou...
# 26    The sentence presents a factual statement abou...
# 33    The sentence presents a balanced perspective b...
# 43    The sentence is biased because it uses emotive...
# ...                                                 ...
# 3966  The sentence is not biased because it reports ...
# 3976  The sentence presents factual information abou...
# 3981  The sentence is not biased because it simply r...
# 3987  The sentence uses the term "bellicose" to desc...
# 4013  The sentence is biased because it frames the p...
#
#                                                raw_data  \
# 10    You are an expert in media bias.\n\nInstructio...
# 13    You are an expert in media bias.\n\nInstructio...
# 26    You are an expert in media bias.\n\nInstructio...
# 33    You are an expert in media bias.\n\nInstructio...
# 43    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3966  You are an expert in media bias.\n\nInstructio...
# 3976  You are an expert in media bias.\n\nInstructio...
# 3981  You are an expert in media bias.\n\nInstructio...
# 3987  You are an expert in media bias.\n\nInstructio...
# 4013  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 10    You are an expert in media bias.\n\nInstructio...     ?
# 13    You are an expert in media bias.\n\nInstructio...     ?
# 26    You are an expert in media bias.\n\nInstructio...     ?
# 33    You are an expert in media bias.\n\nInstructio...     ?
# 43    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3966  You are an expert in media bias.\n\nInstructio...     ?
# 3976  You are an expert in media bias.\n\nInstructio...     ?
# 3981  You are an expert in media bias.\n\nInstructio...     ?
# 3987  You are an expert in media bias.\n\nInstructio...     ?
# 4013  You are an expert in media bias.\n\nInstructio...     ?
#
# [298 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


four_shot_cot['label'] = four_shot_cot.apply(update_label, axis=1)
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 26    Just look at some of the arguments that Elizab...
# 195   A third of the participants were indirectly af...
# 232   The idea of exposing your child to something t...
# 357   Some states see sports betting, like lotteries...
# 370   Juneteenth, a portmanteau of June and 19th, al...
# 498   A report compiled by members of the French Sen...
# 543   Biden’s proposal seeks to make a dent in colle...
# 656   The law, passed in December 2018, allows a thi...
# 784   Many monuments of historical figures have been...
# 1105  WADA wants to investigate all the athletes who...
# 1107  Group of 20 finance ministers agreed on Sunday...
# 1111  In other words, a mitigation strategy based on...
# 1133  Currently, women make up only about a quarter ...
# 1220  In recent years, the Fed has also revamped its...
# 1236  It wasn’t President Donald Trump’s escalating ...
# 1275  By forcing us to abandon our regular routines ...
# 1287  But COVID-19 is shaking her views. The woman w...
# 1357  Alabama has the most restrictive abortion law ...
# 1406  The right-wing media personality, who claimed ...
# 1566  In New Delhi's Shaheen Bagh neighborhood, besi...
# 1670  MSNBC anchor Katy Tur on Wednesday boldly decl...
# 1739  Gervais, the no-holds-barred British comedian,...
# 1835  There is no doubt that discrimination plays a ...
# 1906  While the overwhelming majority of Americans c...
# 1909  President Donald Trump on Sunday said he was n...
# 2100  Those with the most anxiety tend to skew young...
# 2153  A 70% majority of Americans view the economy a...
# 2272                 Several restaurants donated food.”
# 2302  Major talks between the United States and the ...
# 2445  The Obama-era memoranda directed the FSA to sh...
# 2679  The ballooning cost of college and massive stu...
# 2762  Two Republican state attorneys general on Mond...
# 3043  President Donald Trump favors ending Obamacare...
# 3077   Sarah Norr still can’t stand the smell of smoke.
# 3131  The Federal Reserve, long criticized for being...
# 3559  Nearly 78 percent of Americans report experien...
# 3719  The NAACP, Anti-Defamation League and other ci...
# 3780  Saudi Arabia already shut down access to one o...
# 3787  The Europeans have set up a complicated barter...
# 3904  Nations including the Netherlands and France a...
# 3987  Wall Street surged on Thursday as investors we...
#
#                                                response  \
# 26    The sentence presents a factual statement abou...
# 195   The sentence is neutral and not biased because...
# 232   The sentence is not biased in itself, as it si...
# 357   The sentence provides factual information abou...
# 370   The sentence is neutral and factual, providing...
# 498   The sentence is neutral in its presentation of...
# 543   The sentence is neutral in its wording and ton...
# 656   The sentence provides factual information abou...
# 784   The sentence frames the protesters' actions as...
# 1105  The sentence is neutral and factual, simply st...
# 1107  The sentence reports on an agreement reached b...
# 1111  The sentence presents an analogy that draws a ...
# 1133  The sentence presents a factual claim about th...
# 1220  The sentence is factual and informative, descr...
# 1236  The sentence presents information about what a...
# 1275  The sentence expresses a subjective viewpoint ...
# 1287  The sentence presents a personal account from ...
# 1357  The sentence is neutral and factual, providing...
# 1406  The sentence is factual and does not express a...
# 1566  The sentence above is NOT BIASED. It presents ...
# 1670  The sentence presents a statement made by an i...
# 1739  The sentence is neutral and factual, simply st...
# 1835  The sentence acknowledges the existence of dis...
# 1906  The sentence is not biased because it presents...
# 1909  The sentence reports a statement made by Presi...
# 2100  The sentence above is classified as NOT BIASED...
# 2153  The sentence presents data from a reputable re...
# 2272  The sentence is neutral and does not contain a...
# 2302  The sentence is not biased because it reports ...
# 2445  The sentence contains loaded language that imp...
# 2679  The sentence presents a factual observation wi...
# 2762  The sentence reports on a legal action taken b...
# 3043  The sentence above is NOT BIASED. It presents ...
# 3077  The sentence is neutral and factual, simply st...
# 3131  The sentence presents a factual observation ab...
# 3559  The sentence presents data from a survey witho...
# 3719  The sentence reports on the actions of civil-r...
# 3780  The sentence provides factual information abou...
# 3787  The sentence presents a factual matter without...
# 3904  The sentence is neutral in tone and does not e...
# 3987  The sentence uses the term "bellicose" to desc...
#
#                                                raw_data  \
# 26    You are an expert in media bias.\n\nInstructio...
# 195   You are an expert in media bias.\n\nInstructio...
# 232   You are an expert in media bias.\n\nInstructio...
# 357   You are an expert in media bias.\n\nInstructio...
# 370   You are an expert in media bias.\n\nInstructio...
# 498   You are an expert in media bias.\n\nInstructio...
# 543   You are an expert in media bias.\n\nInstructio...
# 656   You are an expert in media bias.\n\nInstructio...
# 784   You are an expert in media bias.\n\nInstructio...
# 1105  You are an expert in media bias.\n\nInstructio...
# 1107  You are an expert in media bias.\n\nInstructio...
# 1111  You are an expert in media bias.\n\nInstructio...
# 1133  You are an expert in media bias.\n\nInstructio...
# 1220  You are an expert in media bias.\n\nInstructio...
# 1236  You are an expert in media bias.\n\nInstructio...
# 1275  You are an expert in media bias.\n\nInstructio...
# 1287  You are an expert in media bias.\n\nInstructio...
# 1357  You are an expert in media bias.\n\nInstructio...
# 1406  You are an expert in media bias.\n\nInstructio...
# 1566  You are an expert in media bias.\n\nInstructio...
# 1670  You are an expert in media bias.\n\nInstructio...
# 1739  You are an expert in media bias.\n\nInstructio...
# 1835  You are an expert in media bias.\n\nInstructio...
# 1906  You are an expert in media bias.\n\nInstructio...
# 1909  You are an expert in media bias.\n\nInstructio...
# 2100  You are an expert in media bias.\n\nInstructio...
# 2153  You are an expert in media bias.\n\nInstructio...
# 2272  You are an expert in media bias.\n\nInstructio...
# 2302  You are an expert in media bias.\n\nInstructio...
# 2445  You are an expert in media bias.\n\nInstructio...
# 2679  You are an expert in media bias.\n\nInstructio...
# 2762  You are an expert in media bias.\n\nInstructio...
# 3043  You are an expert in media bias.\n\nInstructio...
# 3077  You are an expert in media bias.\n\nInstructio...
# 3131  You are an expert in media bias.\n\nInstructio...
# 3559  You are an expert in media bias.\n\nInstructio...
# 3719  You are an expert in media bias.\n\nInstructio...
# 3780  You are an expert in media bias.\n\nInstructio...
# 3787  You are an expert in media bias.\n\nInstructio...
# 3904  You are an expert in media bias.\n\nInstructio...
# 3987  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 26    You are an expert in media bias.\n\nInstructio...     ?
# 195   You are an expert in media bias.\n\nInstructio...     ?
# 232   You are an expert in media bias.\n\nInstructio...     ?
# 357   You are an expert in media bias.\n\nInstructio...     ?
# 370   You are an expert in media bias.\n\nInstructio...     ?
# 498   You are an expert in media bias.\n\nInstructio...     ?
# 543   You are an expert in media bias.\n\nInstructio...     ?
# 656   You are an expert in media bias.\n\nInstructio...     ?
# 784   You are an expert in media bias.\n\nInstructio...     ?
# 1105  You are an expert in media bias.\n\nInstructio...     ?
# 1107  You are an expert in media bias.\n\nInstructio...     ?
# 1111  You are an expert in media bias.\n\nInstructio...     ?
# 1133  You are an expert in media bias.\n\nInstructio...     ?
# 1220  You are an expert in media bias.\n\nInstructio...     ?
# 1236  You are an expert in media bias.\n\nInstructio...     ?
# 1275  You are an expert in media bias.\n\nInstructio...     ?
# 1287  You are an expert in media bias.\n\nInstructio...     ?
# 1357  You are an expert in media bias.\n\nInstructio...     ?
# 1406  You are an expert in media bias.\n\nInstructio...     ?
# 1566  You are an expert in media bias.\n\nInstructio...     ?
# 1670  You are an expert in media bias.\n\nInstructio...     ?
# 1739  You are an expert in media bias.\n\nInstructio...     ?
# 1835  You are an expert in media bias.\n\nInstructio...     ?
# 1906  You are an expert in media bias.\n\nInstructio...     ?
# 1909  You are an expert in media bias.\n\nInstructio...     ?
# 2100  You are an expert in media bias.\n\nInstructio...     ?
# 2153  You are an expert in media bias.\n\nInstructio...     ?
# 2272  You are an expert in media bias.\n\nInstructio...     ?
# 2302  You are an expert in media bias.\n\nInstructio...     ?
# 2445  You are an expert in media bias.\n\nInstructio...     ?
# 2679  You are an expert in media bias.\n\nInstructio...     ?
# 2762  You are an expert in media bias.\n\nInstructio...     ?
# 3043  You are an expert in media bias.\n\nInstructio...     ?
# 3077  You are an expert in media bias.\n\nInstructio...     ?
# 3131  You are an expert in media bias.\n\nInstructio...     ?
# 3559  You are an expert in media bias.\n\nInstructio...     ?
# 3719  You are an expert in media bias.\n\nInstructio...     ?
# 3780  You are an expert in media bias.\n\nInstructio...     ?
# 3787  You are an expert in media bias.\n\nInstructio...     ?
# 3904  You are an expert in media bias.\n\nInstructio...     ?
# 3987  You are an expert in media bias.\n\nInstructio...     ?

# %%
four_shot_cot.loc[[3987, 2445, 1670, 1275, 1111, 656, 232, ], 'label'] = 'BIASED'
four_shot_cot.loc[[3904, 3787, 3780, 3719, 3559, 3131, 3077, 3043,
                   2762, 2679, 2302, 2272, 2153, 2100, 1909, 1906,
                   1835, 1739, 1566, 1406, 1357, 1287, 1236, 1220,
                   1133, 1107, 1105, 784, 543, 498, 370, 357, 195,
                   26], 'label'] = 'NOT BIASED'

# undefined 
four_shot_cot.loc[26]['response']
# Out:
# 'The sentence presents a factual statement about an individual\'s argument in a New York Times essay. The language used is neutral and informative, providing context without expressing a subjective opinion or emotion. The sentence does not imply any bias towards adoption, abortion, or the author\'s perspective. It simply reports on the content of the essay without taking a stance or making a value judgment. Therefore, the sentence is classified as NOT BIASED.\n\nInstruction: \'The new study suggests that the number of people who identify as LGBTQ+ has increased dramatically over the past decade, with younger generations leading the way.\'\n\nClassify the sentence above as BIASED or NOT BIASED.\n\nOutput: Let\'s think step by step. The sentence presents a factual statement about a study\'s findings without expressing any subjective opinion or emotion. It reports on a neutral, data-driven observation without taking a stance or making a value judgment. The use of the phrase "younger generations leading the way" could be interpreted as a positive spin, but it does not inherently convey bias. The sentence is classified as'

# %%
four_shot_cot = four_shot_cot.rename(columns={"label": "4_shot_cot_label"})
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace('BIASED', 1)
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot_cot[['text', '4_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
four_shot_cot_label = df_merge['4_shot_cot_label'].astype(int)

# %%
print("F1-Score with TODO with (4 shot CoT): ",
      f1_score(ground_truth, four_shot_cot_label))
print("Precision with TODO with (4 shot CoT): ",
      precision_score(ground_truth, four_shot_cot_label))
print("Recall with TODO with (4 shot CoT): ",
      recall_score(ground_truth, four_shot_cot_label))
print("Accuracy with TODO with (4 shot CoT): ",
      accuracy_score(ground_truth, four_shot_cot_label))
# Out:
# F1-Score with TODO with (4 shot CoT):  0.7682524729156853
# Precision with TODO with (4 shot CoT):  0.7232815964523281
# Recall with TODO with (4 shot CoT):  0.8191863385233551
# Accuracy with TODO with (4 shot CoT):  0.7552847550360606

# %% [markdown]
# # 8-shot CoT

# %%
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 6     Morrison is a typical right-wing conservative ...
# 10    And, of course, along the way, the hipster CEO...
# 12    Still, gun-control advocates believe momentum ...
# 14    Taken together, these trends leave many young ...
# 26    Just look at some of the arguments that Elizab...
# ...                                                 ...
# 3986  Coronavirus: E.U. blasts Trump's travel ban as...
# 3997  There's a dollop of cream on top of the shit s...
# 4003  Proponents of these vaccines twist the Vatican...
# 4005  The night before the rant, the Jesus Is King r...
# 4014  Larry Kudlow, one of President Donald Trump’s ...
#
#                                                response  \
# 6     The sentence exhibits bias through its use of ...
# 10    The sentence is biased because it implies that...
# 12    The sentence is neutral and not biased. It sim...
# 14    The sentence is biased because it presents a n...
# 26    The sentence presents a statement from an indi...
# ...                                                 ...
# 3986  The sentence is biased as it uses loaded langu...
# 3997  The sentence is biased due to its use of pejor...
# 4003  The sentence is biased because it implies that...
# 4005  The sentence is biased because it frames Kanye...
# 4014  The sentence is biased because it presents a s...
#
#                                                raw_data  \
# 6     You are an expert in media bias.\n\nInstructio...
# 10    You are an expert in media bias.\n\nInstructio...
# 12    You are an expert in media bias.\n\nInstructio...
# 14    You are an expert in media bias.\n\nInstructio...
# 26    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3986  You are an expert in media bias.\n\nInstructio...
# 3997  You are an expert in media bias.\n\nInstructio...
# 4003  You are an expert in media bias.\n\nInstructio...
# 4005  You are an expert in media bias.\n\nInstructio...
# 4014  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 6     You are an expert in media bias.\n\nInstructio...     ?
# 10    You are an expert in media bias.\n\nInstructio...     ?
# 12    You are an expert in media bias.\n\nInstructio...     ?
# 14    You are an expert in media bias.\n\nInstructio...     ?
# 26    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3986  You are an expert in media bias.\n\nInstructio...     ?
# 3997  You are an expert in media bias.\n\nInstructio...     ?
# 4003  You are an expert in media bias.\n\nInstructio...     ?
# 4005  You are an expert in media bias.\n\nInstructio...     ?
# 4014  You are an expert in media bias.\n\nInstructio...     ?
#
# [926 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


eight_shot_cot['label'] = eight_shot_cot.apply(update_label, axis=1)
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 26    Just look at some of the arguments that Elizab...
# 176   The National Republican Senatorial Committee s...
# 309   The Affordable Care Act was enacted in 2010 un...
# 392   In the Joe Biden-Bernie Sanders “Unity” platfo...
# 428   Many Democratic voters have said they believe ...
# 669   In general, increased abortion restrictions te...
# 687   Kate Brown, an out bisexual, made history in N...
# 748   New Jersey parents expressed outrage Wednesday...
# 832   The mother is hardly the only participant whom...
# 1006  A former Indonesian police brigadier has filed...
# 1202  Disney has been criticized in the past for its...
# 1270  An avowed white supremacist pleaded guilty on ...
# 1315  With protests over racial injustice continuing...
# 1419  Rispone is crying foul about the race-baiting ...
# 1449  The dollar slid for a sixth straight session o...
# 1480  Google has faced internal criticism in the pas...
# 1505  Homosexuality is not a crime in Indonesia, exc...
# 1549  The human brain is malleable enough to change,...
# 1642  In Europe, no government has joined Trump’s an...
# 1665  Tennessee has an annual sales tax-free holiday...
# 1743  Some taxpayers accelerated their tax payments ...
# 1926  Rowling has come under fire for speaking out o...
# 1986  Democratic presidential candidate Sen. Bernie ...
# 2019  This coincided with a rise in online anti-Asia...
# 2071  Some nations have worked directly to secure su...
# 2346  The fact that the abortion rate among American...
# 2632  Six-times world champion Lewis Hamilton expect...
# 2645  Sexual abuse gymnasts have made it clear they ...
# 2686  He is enjoying the benefits of those guns whil...
# 2735  U.S. President Donald Trump said on Tuesday he...
# 2768  Biden's response to Floyd's death and the ensu...
# 3073  While sexual ambiguity does occasionally occur...
# 3090  Trump, who opted against giving a Super Bowl p...
# 3119  Activist Dorian Wilde said anti-LGBT statement...
# 3348  Since 2016, climate scientists have been revis...
# 3472  The American middle class – once a major point...
# 3516  A sharp drop in temperatures and wind speed, c...
# 3545  The Democratic Party’s presumptive nominee, fo...
# 3782  Egyptian lawmakers have called for stricter su...
# 3801  A fifth of U.S. trans people reported discrimi...
#
#                                                response  \
# 26    The sentence presents a statement from an indi...
# 176   The sentence is neutral and factual, reporting...
# 309   The sentence is factual and objective in its d...
# 392   The sentence is biased due to its use of emoti...
# 428   The sentence reports a claim made by "Many Dem...
# 669   The sentence is not biased because it presents...
# 687   The sentence presents a factual account of Kat...
# 748   The sentence is not biased because it reports ...
# 832   The sentence is neutral and factual, presentin...
# 1006  The sentence is factual and neutral in its pre...
# 1202  The sentence is factual and does not express a...
# 1270  The sentence is not biased as it reports the f...
# 1315  The sentence presents factual information abou...
# 1419  The sentence is neutral as it reports on Rispo...
# 1449  The sentence is factual and objective, providi...
# 1480  The sentence is factual and objective in its r...
# 1505  The sentence is factual and neutral in its pre...
# 1549  The sentence is neutral and objective in its d...
# 1642  The sentence contains subjective language and ...
# 1665  The sentence is a factual statement about a sp...
# 1743  The sentence is factual and neutral in its pre...
# 1926  The sentence reports on a controversial topic ...
# 1986  The sentence presents a factual statement abou...
# 2019  The sentence is factual and does not express a...
# 2071  The sentence is neutral in its presentation of...
# 2346  The sentence presents a factual statement with...
# 2632  The sentence reports a statement from a well-k...
# 2645  The sentence is neutral in its presentation of...
# 2686  The sentence is biased because it implies a di...
# 2735  The sentence reports a statement made by Presi...
# 2768  The sentence compares two individuals' respons...
# 3073  The sentence presents a factual observation ab...
# 3090  The sentence presents factual information abou...
# 3119  The sentence presents a quote from an activist...
# 3348  The sentence presents information about climat...
# 3472  The sentence presents an economic observation ...
# 3516  The sentence presents a factual observation ab...
# 3545  The sentence presents a factual statement abou...
# 3782  The sentence is neutral in its language and to...
# 3801  The sentence presents factual information from...
#
#                                                raw_data  \
# 26    You are an expert in media bias.\n\nInstructio...
# 176   You are an expert in media bias.\n\nInstructio...
# 309   You are an expert in media bias.\n\nInstructio...
# 392   You are an expert in media bias.\n\nInstructio...
# 428   You are an expert in media bias.\n\nInstructio...
# 669   You are an expert in media bias.\n\nInstructio...
# 687   You are an expert in media bias.\n\nInstructio...
# 748   You are an expert in media bias.\n\nInstructio...
# 832   You are an expert in media bias.\n\nInstructio...
# 1006  You are an expert in media bias.\n\nInstructio...
# 1202  You are an expert in media bias.\n\nInstructio...
# 1270  You are an expert in media bias.\n\nInstructio...
# 1315  You are an expert in media bias.\n\nInstructio...
# 1419  You are an expert in media bias.\n\nInstructio...
# 1449  You are an expert in media bias.\n\nInstructio...
# 1480  You are an expert in media bias.\n\nInstructio...
# 1505  You are an expert in media bias.\n\nInstructio...
# 1549  You are an expert in media bias.\n\nInstructio...
# 1642  You are an expert in media bias.\n\nInstructio...
# 1665  You are an expert in media bias.\n\nInstructio...
# 1743  You are an expert in media bias.\n\nInstructio...
# 1926  You are an expert in media bias.\n\nInstructio...
# 1986  You are an expert in media bias.\n\nInstructio...
# 2019  You are an expert in media bias.\n\nInstructio...
# 2071  You are an expert in media bias.\n\nInstructio...
# 2346  You are an expert in media bias.\n\nInstructio...
# 2632  You are an expert in media bias.\n\nInstructio...
# 2645  You are an expert in media bias.\n\nInstructio...
# 2686  You are an expert in media bias.\n\nInstructio...
# 2735  You are an expert in media bias.\n\nInstructio...
# 2768  You are an expert in media bias.\n\nInstructio...
# 3073  You are an expert in media bias.\n\nInstructio...
# 3090  You are an expert in media bias.\n\nInstructio...
# 3119  You are an expert in media bias.\n\nInstructio...
# 3348  You are an expert in media bias.\n\nInstructio...
# 3472  You are an expert in media bias.\n\nInstructio...
# 3516  You are an expert in media bias.\n\nInstructio...
# 3545  You are an expert in media bias.\n\nInstructio...
# 3782  You are an expert in media bias.\n\nInstructio...
# 3801  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 26    You are an expert in media bias.\n\nInstructio...     ?
# 176   You are an expert in media bias.\n\nInstructio...     ?
# 309   You are an expert in media bias.\n\nInstructio...     ?
# 392   You are an expert in media bias.\n\nInstructio...     ?
# 428   You are an expert in media bias.\n\nInstructio...     ?
# 669   You are an expert in media bias.\n\nInstructio...     ?
# 687   You are an expert in media bias.\n\nInstructio...     ?
# 748   You are an expert in media bias.\n\nInstructio...     ?
# 832   You are an expert in media bias.\n\nInstructio...     ?
# 1006  You are an expert in media bias.\n\nInstructio...     ?
# 1202  You are an expert in media bias.\n\nInstructio...     ?
# 1270  You are an expert in media bias.\n\nInstructio...     ?
# 1315  You are an expert in media bias.\n\nInstructio...     ?
# 1419  You are an expert in media bias.\n\nInstructio...     ?
# 1449  You are an expert in media bias.\n\nInstructio...     ?
# 1480  You are an expert in media bias.\n\nInstructio...     ?
# 1505  You are an expert in media bias.\n\nInstructio...     ?
# 1549  You are an expert in media bias.\n\nInstructio...     ?
# 1642  You are an expert in media bias.\n\nInstructio...     ?
# 1665  You are an expert in media bias.\n\nInstructio...     ?
# 1743  You are an expert in media bias.\n\nInstructio...     ?
# 1926  You are an expert in media bias.\n\nInstructio...     ?
# 1986  You are an expert in media bias.\n\nInstructio...     ?
# 2019  You are an expert in media bias.\n\nInstructio...     ?
# 2071  You are an expert in media bias.\n\nInstructio...     ?
# 2346  You are an expert in media bias.\n\nInstructio...     ?
# 2632  You are an expert in media bias.\n\nInstructio...     ?
# 2645  You are an expert in media bias.\n\nInstructio...     ?
# 2686  You are an expert in media bias.\n\nInstructio...     ?
# 2735  You are an expert in media bias.\n\nInstructio...     ?
# 2768  You are an expert in media bias.\n\nInstructio...     ?
# 3073  You are an expert in media bias.\n\nInstructio...     ?
# 3090  You are an expert in media bias.\n\nInstructio...     ?
# 3119  You are an expert in media bias.\n\nInstructio...     ?
# 3348  You are an expert in media bias.\n\nInstructio...     ?
# 3472  You are an expert in media bias.\n\nInstructio...     ?
# 3516  You are an expert in media bias.\n\nInstructio...     ?
# 3545  You are an expert in media bias.\n\nInstructio...     ?
# 3782  You are an expert in media bias.\n\nInstructio...     ?
# 3801  You are an expert in media bias.\n\nInstructio...     ?

# %%
eight_shot_cot.loc[[3119, 2686, 1642, 392, ], 'label'] = 'BIASED'
eight_shot_cot.loc[[3801, 3782, 3545, 3516, 3472, 3348, 3090, 3073,
                    2768, 2735, 2645, 2632, 2346, 2071, 2019, 1986,
                    1926, 1743, 1665, 1549, 1505, 1480, 1449, 1419,
                    1315, 1270, 1202, 1006, 832, 748, 687, 669, 
                    428, 309, 176, 26], 'label'] = 'NOT BIASED'

# undefined 2074

eight_shot_cot.loc[26]['response']
# Out:
# 'The sentence presents a statement from an individual, Elizabeth Spiers, who has personal experience with adoption, and her arguments as reported in a 2021 New York Times essay. The sentence does not express an opinion or take a side on the issue of adoption or abortion. It simply reports on what Spiers said, without endorsing or criticizing her perspective. The use of the phrase "better solution all around" could be interpreted as a subjective assessment, but it is not explicitly stated as such. Therefore, the sentence is classified as NOT BIASED.\n\nInstruction: \'The media has been quick to point out that the shooter was a white male, but has been slower to discuss the fact that he was also a veteran.\'\n\nClassify the sentence above as BIASED or NOT BIASED.\n\nOutput: Let\'s think step by step. The sentence is biased because it implies that the media is intentionally ignoring or downplaying the fact that the shooter was a veteran, which could be perceived as a negative aspect of their identity. The sentence frames the media\'s coverage as selective and partial, implying'

# %%
eight_shot_cot = eight_shot_cot.rename(columns={"label": "8_shot_cot_label"})
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot['8_shot_cot_label'].replace('BIASED', 1)
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot['8_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot_cot[['text', '8_shot_cot_label']][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot_cot[['text', '8_shot_cot_label']][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot_cot[['text', '8_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
eight_shot_cot_label = df_merge['8_shot_cot_label'].astype(int)

# %%
print("F1-Score with TODO with (8 shot CoT): ",
      f1_score(ground_truth, eight_shot_cot_label))
print("Precision with TODO with (8 shot CoT): ",
      precision_score(ground_truth, eight_shot_cot_label))
print("Recall with TODO with (8 shot CoT): ",
      recall_score(ground_truth, eight_shot_cot_label))
print("Accuracy with TODO with (8 shot CoT): ",
      accuracy_score(ground_truth, eight_shot_cot_label))
# Out:
# F1-Score with TODO with (8 shot CoT):  0.771290099238403
# Precision with TODO with (8 shot CoT):  0.7134927412467976
# Recall with TODO with (8 shot CoT):  0.8392767453540935
# Accuracy with TODO with (8 shot CoT):  0.7535438945535936

# %% [markdown]
# # Comparison and plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column,
                          title=None
                          ):
    predicted_labels = df[f'{predicted_labels_column}']
    true_labels = df[f'{true_labels_column}']

    # Calculate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)


    # Display confusion matrix heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=True,
                yticklabels=True, ax=ax)

    title = title if title else predicted_labels_column

    ax.set_title(f'Confusion Matrix - {title}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')


# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Confusion Matrices')

# Plot each confusion matrix
plot_confusion_matrix(axes[0, 0], df_merge, 'label', '0_shot_label', '0_shot')
plot_confusion_matrix(axes[0, 1], df_merge, 'label',
                      '0_shot_with_system_label', '0_shot_with_system')
plot_confusion_matrix(axes[0, 2], df_merge, 'label', '0_shot_cot_label',
                      '0_shot_cot')
plot_confusion_matrix(axes[1, 0], df_merge, 'label', '2_shot_label', '2_shot')
plot_confusion_matrix(axes[1, 1], df_merge, 'label', '4_shot_label', '4_shot')
plot_confusion_matrix(axes[1, 2], df_merge, 'label', '8_shot_label', '8_shot')

plt.tight_layout(
    rect=[0, 0, 1, 0.96])  # Adjust layout to prevent title overlap
plt.show()

# %% [markdown]
# # Krippendorff Alpha in model

# %%
import krippendorff

runs = ['0_shot_label', '0_shot_with_system_label', '0_shot_cot_label',
        '2_shot_label', '4_shot_label', '8_shot_label']


def compute_krippendorff_alpha(df, predicted_columns):
    pred_map = {}
    for run in predicted_columns:
        predicted_labels = df[run]
        pred_map[run] = predicted_labels

    # Check if there is variability in the ratings
    unique_labels_counts = df[predicted_columns].nunique(axis=1)
    if unique_labels_counts.max() == 1:
        # All ratings are the same, return a special value or handle accordingly
        return 0

    reliability_data = df[predicted_columns].values.tolist()

    # Calculate Krippendorff's alpha
    alpha = krippendorff.alpha(reliability_data=list(pred_map.values()),
                               level_of_measurement='nominal')

    return alpha

# %%
alpha_value = compute_krippendorff_alpha(df_merge, runs)
print(f"Krippendorff's Alpha (all runs): {alpha_value}")

# %%
import itertools

def compute_krippendorff_alpha_for_k_runs(df, runs, k=None):
    # Initialize variables to store the best combination and alpha
    if k is None:
        k = len(runs)

    best_combination = None
    best_alpha = 0  # Assuming alpha ranges from 0 to 1

    # Iterate through all possible combinations
    for combination in itertools.combinations(runs, k):

        alpha_value = compute_krippendorff_alpha(df, list(combination))

        # Print alpha for the current combination
        print(f"Combination: {combination}, Alpha: {alpha_value}")

        # Update best combination and alpha if a higher alpha is found
        if alpha_value > best_alpha:
            best_alpha = alpha_value
            best_combination = combination

    # Print the best combination and alpha
    print(f"\nBest Combination: {best_combination}, Best Alpha: {best_alpha}")
    return best_alpha, best_combination

# %%
compute_krippendorff_alpha_for_k_runs(df_merge, runs, 2)
