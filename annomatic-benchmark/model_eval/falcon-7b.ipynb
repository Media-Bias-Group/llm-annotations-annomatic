# %% [markdown]
# # Eval the results of falcon 7b

# %%
import pandas as pd
from datasets import load_dataset
from sklearn.metrics import f1_score, precision_score, recall_score, \
    accuracy_score

import re
from typing import List, Tuple

import pandas as pd


def is_contained(inner_start, inner_end, outer_start, outer_end):
    return (
        outer_start <= inner_start <= outer_end
        and outer_start <= inner_end <= outer_end
        and (inner_start, inner_end) != (outer_start, outer_end)
    )


def find_all_occurrences_indices(
    sentence: str,
    label: str,
) -> List[Tuple[int, int]]:
    """
    Finds all occurrences of a label in a sentence and returns a list of tuples
    with the start and end indices of the occurrences.

    Args:
        sentence: The sentence to search in.
        label: The label to search for.

    Returns:
        A list of tuples with the start and end indices of the occurrences.
    """
    return [
        (int(match.start()), int(match.end()))
        for match in re.finditer(label, sentence)
    ]


def find_contained_labels(labels):
    """
    Finds all labels that are contained in other labels.

    Args:
        labels: A list of labels.

    Returns:
        A dictionary with the labels as keys and a list of labels that are
        contained in the key label as values.
    """
    return {
        label_1: [
            label2
            for label2 in labels
            if label_1 in label2 and label_1 != label2
        ]
        for label_1 in labels
    }


def find_labels_in_sentence(
    sentence: str,
    labels: List[str],
) -> List[List[Tuple[int, int]]]:
    """
    Finds all occurrences of the labels in a sentence and returns a list of
    lists with the occurrences of each label.

    Labels that are contained in other labels are not returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.

    Returns:
        A list of lists with the positional occurrence of each label.
    """
    if not labels:
        return []

    containable_map = find_contained_labels(labels)
    sentence_lower = sentence.lower()
    occurrences = [
        find_all_occurrences_indices(sentence_lower, label.lower())
        for label in labels
    ]
    label_occurrences = dict(zip(labels, occurrences))
    included_list = []
    for label, inner_pos in zip(labels, occurrences):
        contained = set()
        containing_labels = containable_map.get(label, set())

        for bigger_label in containing_labels:
            locations: List[Tuple[int, int]] = label_occurrences.get(
                bigger_label,
                list(),
            )

            for inner_start, inner_end in inner_pos:
                for outer_start, outer_end in locations:
                    if is_contained(
                        inner_start,
                        inner_end,
                        outer_start,
                        outer_end,
                    ):
                        contained.add((inner_start, inner_end))
        included_list.append(list(contained))

    return [
        list(set(pos) - set(included))
        for pos, included in zip(occurrences, included_list)
    ]


def find_label(
    sentence: str,
    labels: List[str],
    default_label: str = "?",
) -> str:
    """
    Search for given labels in the sentence and returns it if found. If only
    one label occur in the sentence, it will be returned. If no label or
    different labels occur in the sentence, '?' is returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.
        default_label: The label to return if no label or different labels
            occur in the sentence.

    Returns:
        The label that occurs in the sentence or '?' if no label occurs in the
        sentence.
    """
    occurrences = find_labels_in_sentence(sentence=sentence, labels=labels)
    non_empty_indices = [i for i, sublist in enumerate(occurrences) if sublist]
    return (
        labels[non_empty_indices[0]]
        if len(
            non_empty_indices,
        )
           == 1
        else default_label
    )


def _soft_parse(
    df: pd.DataFrame,
    in_col: str,
    parsed_col: str,
    labels: List[str] = None,
) -> pd.DataFrame:
    if labels is None:
        raise ValueError("Labels are not set!")

    df[parsed_col] = df[in_col].apply(
        lambda x: find_label(x, labels),
    )

# %%
# load
model = 'falcon-7b-instruct'

# load results
zero_shot = pd.read_csv(f"../zero-shot/data/{model}.csv")
zero_shot_with_system = pd.read_csv(
    f"../zero-shot-system_prompt/data/{model}.csv")
zero_shot_cot = pd.read_csv(f"../zero-shot-cot/data/{model}.csv")
two_shot = pd.read_csv(f"../2-shot/data/{model}.csv")
four_shot = pd.read_csv(f"../4-shot/data/{model}.csv")
eight_shot = pd.read_csv(f"../8-shot/data/{model}.csv")

two_shot_cot = pd.read_csv(f"../2-shot-CoT/data/{model}.csv")
four_shot_cot = pd.read_csv(f"../4-shot-CoT/data/{model}.csv")
eight_shot_cot = pd.read_csv(f"../8-shot-CoT/data/{model}.csv")

#load pool
pool = load_dataset('mediabiasgroup/BABE-icl-pool')['train'].to_pandas()

# exclude pool from model (if needed)
zero_shot = zero_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
zero_shot_with_system = zero_shot_with_system.merge(pool['text'], on='text',
                                                    how='left',
                                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
zero_shot_cot = zero_shot_cot.merge(pool['text'], on='text', how='left',
                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
two_shot = two_shot.merge(pool['text'], on='text', how='left',
                          indicator=True).query('_merge == "left_only"').drop(
    '_merge', axis=1)
four_shot = four_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot = eight_shot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
two_shot_cot = two_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
four_shot_cot = four_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot_cot = eight_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)


#load babe
dataset = load_dataset('mediabiasgroup/BABE-v4')
df_babe = pd.DataFrame(dataset['train'])

# df_merge = babe at begin
df_merge_all_runs = df_babe
df_merge_all_runs_with_errors = df_babe

def find_first_occurrence(string, instruction="Instruction:",
                          statement1="The answer is BIASED",
                          statement2="The answer is NOT BIASED"
                          ):
    index_instruction = string.find(instruction)
    index1 = string.find(statement1)
    index2 = string.find(statement2)

    if index1 == -1 and index2 == -1:
        return "Neither instruction nor statements found in the given string."
    elif index1 == -1 and index2 == -1:
        return "Neither statement found in the given string."
    elif index1 == -1:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"
    elif index2 == -1:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    elif index1 < index2:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    else:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"

# %% [markdown]
# # Zero shot

# %%
_soft_parse(zero_shot, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
zero_shot.query("label == '?'")
# Out:
#                                                    text  \
# 10    And, of course, along the way, the hipster CEO...
# 36    Since the incident, the mainstream media — in ...
# 51    As leading 2020 Dems advocate spending big on ...
# 211   His confidence in his sense of humor is the sa...
# 258   Father Horan was one of the many voices from t...
# ...                                                 ...
# 3588  Wealthy American corporations are using their ...
# 3618  While falling short of calling half the nation...
# 3812  Chicago Police Superintendent David Brown desc...
# 3872  It's not immediately clear what Biden was tryi...
# 4111  Facebook posts, shared thousands of times, cla...
#
#                                                response  \
# 10    'NOT BIASED'\n\nExplanation: The sentence port...
# 36    'NOT BIASED'\n\nExplanation: The sentence is n...
# 51    'NOT BIASED'\n\nExplanation: The sentence does...
# 211   'NOT BIASED'\n\nExplanation: The sentence is n...
# 258   'NOT BIASED'\n\nExplanation: The sentence is n...
# ...                                                 ...
# 3588  'NOT BIASED'\n\nExplanation: The sentence pres...
# 3618  'NOT BIASED'\n\nExplanation: The sentence is n...
# 3812  'NOT BIASED'\n\nExplanation: The sentence desc...
# 3872  'Not Biased'\n\nExplanation: The sentence is n...
# 4111  'NOT BIASED'\n\nExplanation: The sentence clai...
#
#                                                raw_data  \
# 10    Instruction: 'And, of course, along the way, t...
# 36    Instruction: 'Since the incident, the mainstre...
# 51    Instruction: 'As leading 2020 Dems advocate sp...
# 211   Instruction: 'His confidence in his sense of h...
# 258   Instruction: 'Father Horan was one of the many...
# ...                                                 ...
# 3588  Instruction: 'Wealthy American corporations ar...
# 3618  Instruction: 'While falling short of calling h...
# 3812  Instruction: 'Chicago Police Superintendent Da...
# 3872  Instruction: 'It's not immediately clear what ...
# 4111  Instruction: 'Facebook posts, shared thousands...
#
#                                                   query label
# 10    Instruction: 'And, of course, along the way, t...     ?
# 36    Instruction: 'Since the incident, the mainstre...     ?
# 51    Instruction: 'As leading 2020 Dems advocate sp...     ?
# 211   Instruction: 'His confidence in his sense of h...     ?
# 258   Instruction: 'Father Horan was one of the many...     ?
# ...                                                 ...   ...
# 3588  Instruction: 'Wealthy American corporations ar...     ?
# 3618  Instruction: 'While falling short of calling h...     ?
# 3812  Instruction: 'Chicago Police Superintendent Da...     ?
# 3872  Instruction: 'It's not immediately clear what ...     ?
# 4111  Instruction: 'Facebook posts, shared thousands...     ?
#
# [67 rows x 5 columns]

# %%
# preprocessing
# preprocessing
def update_label(row):
    if row['response'].startswith("'BIASED'") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("'Biased'") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("1") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("'NOT BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith("'Not BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith("'Not Biased'") and row[
        'label'] == '?':
        return 'NOT BIASED'

    else:
        return row['label']


zero_shot['label'] = zero_shot.apply(update_label, axis=1)
zero_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
zero_shot = zero_shot.rename(columns={"label": "0_shot_label"})
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('BIASED', 1)
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('NOT BIASED', 0)

df_merge = pd.merge(df_babe, zero_shot[['text', '0_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot[['text', '0_shot_label']], on='text')


ground_truth = df_merge['label']
zero_shot_label = df_merge['0_shot_label']

# %%
print("F1-Score with TODO: ", f1_score(ground_truth, zero_shot_label))
print("Precision with TODO: ",
      precision_score(ground_truth, zero_shot_label))
print("Recall with TODO: ",
      recall_score(ground_truth, zero_shot_label))
print("Accuracy with TODO: ",
      accuracy_score(ground_truth, zero_shot_label))
# Out:
# F1-Score with TODO:  0.5398627868464633
# Precision with TODO:  0.5102862254025045
# Recall with TODO:  0.5730788548468106
# Accuracy with TODO:  0.5162894802287988

# %% [markdown]
# # zero shot with system prompt

# %%
_soft_parse(zero_shot_with_system, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
zero_shot_with_system.query("label == '?'")
# Out:
#                                                    text  \
# 20    A Joe Biden presidency could reset ties with t...
# 95    The head of the World Health Organization said...
# 196   With radical feminists and extremist trans act...
# 297   This is why Donald Trump is awake at 2:30 a.m....
# 383   While the stupid Democrats who vote for Democr...
# ...                                                 ...
# 3658  acked by Virginia’s first Democratic-controlle...
# 3837  It amazes me that even intelligent people – in...
# 3845  The movement’s hysteric leader proceeded to hu...
# 3851  A leading economist who vouched for Democratic...
# 4084  Posting on Twitter, the former stripper turned...
#
#                                                response  \
# 20    'NOT BIASED'\n\nExplanation: The sentence pres...
# 95    'NOT BIASED'\n\nExplanation: The sentence does...
# 196   'NOT BIASED'\n\nExplanation: The sentence port...
# 297   'NOT BIASED'\n\nExplanation: The sentence pres...
# 383   'NOT BIASED'\n\nExplanation: The sentence cont...
# ...                                                 ...
# 3658  'NOT BIASED'\n\nExplanation: The sentence pres...
# 3837  'NOT BIASED'\n\nExplanation: The sentence is n...
# 3845  'Hysteric' (BIASED), 'leader' (NOT BIASED),'mo...
# 3851  'NOT BIASED'\n\nExplanation: The sentence pres...
# 4084  'NOT BIASED'\n\nExplanation: The sentence is n...
#
#                                                raw_data  \
# 20    You are an expert in media bias.\n\nInstructio...
# 95    You are an expert in media bias.\n\nInstructio...
# 196   You are an expert in media bias.\n\nInstructio...
# 297   You are an expert in media bias.\n\nInstructio...
# 383   You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3658  You are an expert in media bias.\n\nInstructio...
# 3837  You are an expert in media bias.\n\nInstructio...
# 3845  You are an expert in media bias.\n\nInstructio...
# 3851  You are an expert in media bias.\n\nInstructio...
# 4084  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 20    You are an expert in media bias.\n\nInstructio...     ?
# 95    You are an expert in media bias.\n\nInstructio...     ?
# 196   You are an expert in media bias.\n\nInstructio...     ?
# 297   You are an expert in media bias.\n\nInstructio...     ?
# 383   You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3658  You are an expert in media bias.\n\nInstructio...     ?
# 3837  You are an expert in media bias.\n\nInstructio...     ?
# 3845  You are an expert in media bias.\n\nInstructio...     ?
# 3851  You are an expert in media bias.\n\nInstructio...     ?
# 4084  You are an expert in media bias.\n\nInstructio...     ?
#
# [82 rows x 5 columns]

# %%
# preprocessing
# preprocessing
def update_label(row):
    if row['response'].startswith("'BIASED'") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("'Biased'") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("1") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("'NOT BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith("'Not BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith("'Not Biased'") and row[
        'label'] == '?':
        return 'NOT BIASED'

    else:
        return row['label']


zero_shot_with_system['label'] = zero_shot_with_system.apply(update_label, axis=1)
zero_shot_with_system.query("label == '?'")
# Out:
#                                                    text  \
# 2062  'Pandemic Apprentice': Deprived of rallies to ...
# 3845  The movement’s hysteric leader proceeded to hu...
#
#                                                response  \
# 2062  'Pandemic Apprentice': Deprived of rallies to ...
# 3845  'Hysteric' (BIASED), 'leader' (NOT BIASED),'mo...
#
#                                                raw_data  \
# 2062  You are an expert in media bias.\n\nInstructio...
# 3845  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 2062  You are an expert in media bias.\n\nInstructio...     ?
# 3845  You are an expert in media bias.\n\nInstructio...     ?

# %%
zero_shot_with_system = zero_shot_with_system.rename(
    columns={"label": "0_shot_with_system_label"})
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('BIASED', 1)
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('NOT BIASED', 0)


df_merge = df_babe.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_with_system[['text', '0_shot_with_system_label']], on='text')


ground_truth = df_merge['label'].astype(int)
zero_shot_with_system_label = df_merge['0_shot_with_system_label'].astype(int)

# %%
print("F1-Score with TODO with System Prompt: ",
      f1_score(ground_truth, zero_shot_with_system_label))
print("Precision with TODO with System Prompt: ",
      precision_score(ground_truth, zero_shot_with_system_label))
print("Recall with TODO with System Prompt: ",
      recall_score(ground_truth, zero_shot_with_system_label))
print("Accuracy with TODO with System Prompt: ",
      accuracy_score(ground_truth, zero_shot_with_system_label))
# Out:
# F1-Score with TODO with System Prompt:  0.5074925074925075
# Precision with TODO with System Prompt:  0.5042183622828784
# Recall with TODO with System Prompt:  0.5108094519859225
# Accuracy with TODO with System Prompt:  0.5093306792734511

# %% [markdown]
# # zero shot CoT

# %%
zero_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 4     Republican state legislators from Texas to Ari...
# 10    And, of course, along the way, the hipster CEO...
# 16    TrumpWorld also reflects the horrible surreali...
# 17    The American Psychological Association has sai...
# 22    irearms kill almost 1,300 American youngsters ...
# ...                                                 ...
# 4108  About one quarter of the world’s population li...
# 4109  In her Instagram story, Jedrzejczyk posted an ...
# 4111  Facebook posts, shared thousands of times, cla...
# 4112  U.S. President Donald Trump’s former personal ...
# 4118  When Republicans warned Democrats that impeach...
#
#                                                response  \
# 4     1. The sentence is about Republican state legi...
# 10    First, we need to define the term 'bias'. Bias...
# 16    1. The sentence contains a reference to a spec...
# 17    1. The sentence is about a statement made by t...
# 22    1. The sentence is about firearms and children...
# ...                                                 ...
# 4108  1. The sentence is about a specific type of la...
# 4109  1. The sentence is about a public figure, spec...
# 4111  1. The sentence claims that Melinda Gates has ...
# 4112  1. The sentence is about Michael Cohen, a pers...
# 4118  1. The sentence contains an opinion, as it is ...
#
#                                                raw_data  \
# 4     You are an expert in media bias.\n\nInstructio...
# 10    You are an expert in media bias.\n\nInstructio...
# 16    You are an expert in media bias.\n\nInstructio...
# 17    You are an expert in media bias.\n\nInstructio...
# 22    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4108  You are an expert in media bias.\n\nInstructio...
# 4109  You are an expert in media bias.\n\nInstructio...
# 4111  You are an expert in media bias.\n\nInstructio...
# 4112  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 4     You are an expert in media bias.\n\nInstructio...     ?
# 10    You are an expert in media bias.\n\nInstructio...     ?
# 16    You are an expert in media bias.\n\nInstructio...     ?
# 17    You are an expert in media bias.\n\nInstructio...     ?
# 22    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4108  You are an expert in media bias.\n\nInstructio...     ?
# 4109  You are an expert in media bias.\n\nInstructio...     ?
# 4111  You are an expert in media bias.\n\nInstructio...     ?
# 4112  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
#
# [901 rows x 5 columns]

# %%
# preprocessing

# %%
zero_shot_cot = zero_shot_cot.rename(columns={"label": "0_shot_cot_label"})
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'BIASED', 1)
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot_cot[zero_shot_cot['0_shot_cot_label'] != '?'], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_cot[zero_shot_cot['0_shot_cot_label'] != '?'][['text', '0_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_cot[['text', '0_shot_cot_label']], on='text')


ground_truth = df_merge['label'].astype(int)
zero_shot_cot_label = df_merge['0_shot_cot_label'].astype(int)

# %%
print("F1-Score with TODO with CoT: ",
      f1_score(ground_truth, zero_shot_cot_label))
print("Precision with TODO with CoT: ",
      precision_score(ground_truth, zero_shot_cot_label))
print("Recall with TODO with CoT: ",
      recall_score(ground_truth, zero_shot_cot_label))
print("Accuracy with TODO with CoT: ",
      accuracy_score(ground_truth, zero_shot_cot_label))
# Out:
# F1-Score with TODO with CoT:  0.6558500914076784
# Precision with TODO with CoT:  0.4996518105849582
# Recall with TODO with CoT:  0.9541223404255319
# Accuracy with TODO with CoT:  0.5173076923076924

# %% [markdown]
# # 2-shot

# %%
two_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 4     Republican state legislators from Texas to Ari...
# ...                                                 ...
# 4115  Trump sought to use the event to bring momentu...
# 4116  Far-right talk show host Glenn Beck is being s...
# 4117  After President Donald Trump’s news conference...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 0                                                   NaN
# 1     'BIASED'\n\nInstruction: 'The media has been k...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4115                                                NaN
# 4116                                                NaN
# 4117                                                NaN
# 4119                                                NaN
# 4120                                                NaN
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4115  You are an expert in media bias.\n\nInstructio...
# 4116  You are an expert in media bias.\n\nInstructio...
# 4117  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4115  You are an expert in media bias.\n\nInstructio...     ?
# 4116  You are an expert in media bias.\n\nInstructio...     ?
# 4117  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [2747 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if str(row['response']).startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith("'BIASED'") and row['label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith("'NOT BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif pd.isna(row['response']):
        return '!'
    else:
        return row['label']

two_shot['label'] = two_shot.apply(update_label, axis=1)
two_shot.query("label == '?'")
# Out:
#                                                    text  \
# 87    "You are under oath before this committee, and...
# 130                                                 may
# 642   "Mr. Chairman, I have to tell you, this is the...
# 1032  As an appellate judge, Barrett has staked out ...
# 1242  How a 'constitutionalist' Oregon sheriff rules...
# 1757  "I mean, this is unbelievable, and you want to...
# 1895  A Minnesota man in his 60s who attended the St...
# 2316  Barrett argued in a 38-page opinion that the F...
# 3116  Last year, the number of people who signed up ...
# 3124  Sen. Amy Klobuchar (D-MN) boasted that she wor...
# 3444  If we want to explain what has happened to the...
# 3853  Overall, four million young Americans enter th...
#
#                                                response  \
# 87                                                ASED'
# 130   not) BIASED\n\nInstruction: 'The 2010s saw the...
# 642                                               ASED'
# 1032                                              ASED'
# 1242                                              ASED'
# 1757                                              ASED'
# 1895  (NOT BIASED)\n\nInstruction: 'The Republican-c...
# 2316  T BIASED'\n\nInstruction: 'The media has been ...
# 3116  (BIASED)\n\nInstruction: 'The Trump administra...
# 3124  (NOT BIASED)\n\nInstruction: 'The New York Tim...
# 3444  (not) BIASED\n\nInstruction: 'The media has a ...
# 3853  (NOT BIASED)\n\nInstruction: 'The U.S. economy...
#
#                                                raw_data  \
# 87    You are an expert in media bias.\n\nInstructio...
# 130   You are an expert in media bias.\n\nInstructio...
# 642   You are an expert in media bias.\n\nInstructio...
# 1032  You are an expert in media bias.\n\nInstructio...
# 1242  You are an expert in media bias.\n\nInstructio...
# 1757  You are an expert in media bias.\n\nInstructio...
# 1895  You are an expert in media bias.\n\nInstructio...
# 2316  You are an expert in media bias.\n\nInstructio...
# 3116  You are an expert in media bias.\n\nInstructio...
# 3124  You are an expert in media bias.\n\nInstructio...
# 3444  You are an expert in media bias.\n\nInstructio...
# 3853  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 87    You are an expert in media bias.\n\nInstructio...     ?
# 130   You are an expert in media bias.\n\nInstructio...     ?
# 642   You are an expert in media bias.\n\nInstructio...     ?
# 1032  You are an expert in media bias.\n\nInstructio...     ?
# 1242  You are an expert in media bias.\n\nInstructio...     ?
# 1757  You are an expert in media bias.\n\nInstructio...     ?
# 1895  You are an expert in media bias.\n\nInstructio...     ?
# 2316  You are an expert in media bias.\n\nInstructio...     ?
# 3116  You are an expert in media bias.\n\nInstructio...     ?
# 3124  You are an expert in media bias.\n\nInstructio...     ?
# 3444  You are an expert in media bias.\n\nInstructio...     ?
# 3853  You are an expert in media bias.\n\nInstructio...     ?

# %%
two_shot.loc[[87, 642, 1032, 1242, 1757, 3116, ], 'label'] = 'BIASED'
two_shot.loc[[1895, 2316, 3124, 3444, 3853], 'label'] = 'NOT BIASED'

two_shot.loc[[130], 'label'] = '!'


# best answer: , which makes it NOT BIASED. The answer is correct.'

two_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
# map "!" flag back to "?"
two_shot['label'] = two_shot['label'].replace('!', '?')

two_shot = two_shot.rename(columns={"label": "2_shot_label"})
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('BIASED', 1)
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot[['text', '2_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
two_shot_label = df_merge['2_shot_label'].astype(int)

# %%
print("F1-Score with TODO with (2 shot): ",
      f1_score(ground_truth, two_shot_label))
print("Precision with TODO with (2 shot): ",
      precision_score(ground_truth, two_shot_label))
print("Recall with TODO with (2 shot): ",
      recall_score(ground_truth, two_shot_label))
print("Accuracy with TODO with (2 shot): ",
      accuracy_score(ground_truth, two_shot_label))
# Out:
# F1-Score with TODO with (2 shot):  0.5921450151057402
# Precision with TODO with (2 shot):  0.539647577092511
# Recall with TODO with (2 shot):  0.6559571619812584
# Accuracy with TODO with (2 shot):  0.5697896749521989

# %% [markdown]
# # 4-shot

# %%
four_shot.query("label == '?'")
# Out:
#                                                    text response  \
# 0     But instead of closing loopholes that allow cr...      NaN
# 4     Republican state legislators from Texas to Ari...      NaN
# 5     Meanwhile, a pervasive celebrity culture — in ...      NaN
# 6     Morrison is a typical right-wing conservative ...      NaN
# 7     New York City Mayor Bill de Blasio (D) suggest...      NaN
# ...                                                 ...      ...
# 4115  Trump sought to use the event to bring momentu...      NaN
# 4117  After President Donald Trump’s news conference...      NaN
# 4118  When Republicans warned Democrats that impeach...      NaN
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...      NaN
# 4120  The march then continued to the United States ...      NaN
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# 6     You are an expert in media bias.\n\nInstructio...
# 7     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4115  You are an expert in media bias.\n\nInstructio...
# 4117  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# 6     You are an expert in media bias.\n\nInstructio...     ?
# 7     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4115  You are an expert in media bias.\n\nInstructio...     ?
# 4117  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [2922 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if str(row['response']).startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith("'BIASED'") and row['label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith("'NOT BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif pd.isna(row['response']):
        return '!'
    else:
        return row['label']

four_shot['label'] = four_shot.apply(update_label, axis=1)
four_shot.query("label == '?'")
# Out:
#                                                    text  \
# 87    "You are under oath before this committee, and...
# 103   Mack’s organization—which has a long history o...
# 388   It probably has something to do with Pitlyk be...
# 575   The hearing was halted briefly after an uniden...
# 1032  As an appellate judge, Barrett has staked out ...
# 1268  Instagram and TikTok influencer Haneen Hossam,...
# 1675  Witness, for instance, the wacky nonsense New ...
# 1757  "I mean, this is unbelievable, and you want to...
# 1902  His lawyers have sought a plea deal relating t...
# 1939  Yet it far better applies to unelected career ...
# 2153  An Austrian BASE jumper was rescued in souther...
# 2429  This group is small but vocal, and represents ...
# 2730  Some of the local governments choosing to acce...
# 2809  A lawyer for Breonna Taylor’s family on Friday...
# 2914  But director Nick Sweeney’s forthcoming docume...
# 3052  You lied to us under oath, you lied to us in y...
# 3850  Indian Prime Minister Narendra Modi’s Hindu na...
#
#                                                response  \
# 87                                                ASED'
# 103   T BIASED'\n\nInstruction: 'The media’s narrati...
# 388                                               ASED'
# 575                                               ASED'
# 1032                                              ASED'
# 1268  (not) BIASED\n\nInstruction: 'The “Muslim ban”...
# 1675  (Not) BIASED\n\nInstruction: 'The president’s ...
# 1757                                              ASED'
# 1902                                              ASED'
# 1939  ASED'\n\nInstruction: 'The president’s likely ...
# 2153  (NOT BIASED)\n\nInstruction: 'The world's lead...
# 2429                                              ASED'
# 2730  (not) BIASED\n\nInstruction: 'The media has be...
# 2809                                              ASED'
# 2914                                              ASED'
# 3052                                              ASED'
# 3850  (Not) BIASED\n\nInstruction: 'The president’s ...
#
#                                                raw_data  \
# 87    You are an expert in media bias.\n\nInstructio...
# 103   You are an expert in media bias.\n\nInstructio...
# 388   You are an expert in media bias.\n\nInstructio...
# 575   You are an expert in media bias.\n\nInstructio...
# 1032  You are an expert in media bias.\n\nInstructio...
# 1268  You are an expert in media bias.\n\nInstructio...
# 1675  You are an expert in media bias.\n\nInstructio...
# 1757  You are an expert in media bias.\n\nInstructio...
# 1902  You are an expert in media bias.\n\nInstructio...
# 1939  You are an expert in media bias.\n\nInstructio...
# 2153  You are an expert in media bias.\n\nInstructio...
# 2429  You are an expert in media bias.\n\nInstructio...
# 2730  You are an expert in media bias.\n\nInstructio...
# 2809  You are an expert in media bias.\n\nInstructio...
# 2914  You are an expert in media bias.\n\nInstructio...
# 3052  You are an expert in media bias.\n\nInstructio...
# 3850  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 87    You are an expert in media bias.\n\nInstructio...     ?
# 103   You are an expert in media bias.\n\nInstructio...     ?
# 388   You are an expert in media bias.\n\nInstructio...     ?
# 575   You are an expert in media bias.\n\nInstructio...     ?
# 1032  You are an expert in media bias.\n\nInstructio...     ?
# 1268  You are an expert in media bias.\n\nInstructio...     ?
# 1675  You are an expert in media bias.\n\nInstructio...     ?
# 1757  You are an expert in media bias.\n\nInstructio...     ?
# 1902  You are an expert in media bias.\n\nInstructio...     ?
# 1939  You are an expert in media bias.\n\nInstructio...     ?
# 2153  You are an expert in media bias.\n\nInstructio...     ?
# 2429  You are an expert in media bias.\n\nInstructio...     ?
# 2730  You are an expert in media bias.\n\nInstructio...     ?
# 2809  You are an expert in media bias.\n\nInstructio...     ?
# 2914  You are an expert in media bias.\n\nInstructio...     ?
# 3052  You are an expert in media bias.\n\nInstructio...     ?
# 3850  You are an expert in media bias.\n\nInstructio...     ?

# %%
four_shot.loc[[3052, 2914, 2809, 2429, 1939, 1902,
               1757, 1032, 575, 388, 87], 'label'] = 'BIASED'
four_shot.loc[[3850, 2730, 2153, 1675, 1268, 103,
               ], 'label'] = 'NOT BIASED'

four_shot.loc[[], 'label'] = '!'


# best answer: , which makes it NOT BIASED. The answer is correct.'
#print(four_shot.raw_data.loc[87])
four_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
# map "!" flag back to "?"
four_shot['label'] = four_shot['label'].replace('!', '?')

four_shot = four_shot.rename(columns={"label": "4_shot_label"})
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('BIASED', 1)
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot[['text', '4_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
four_shot_label = df_merge['4_shot_label'].astype(int)

# %%
print("F1-Score with TODO with (4 shot): ",
      f1_score(ground_truth, four_shot_label))
print("Precision with TODO with (4 shot): ",
      precision_score(ground_truth, four_shot_label))
print("Recall with TODO with (4 shot): ",
      recall_score(ground_truth, four_shot_label))
print("Accuracy with TODO with (4 shot): ",
      accuracy_score(ground_truth, four_shot_label))
# Out:
# F1-Score with TODO with (4 shot):  0.6769394261424018
# Precision with TODO with (4 shot):  0.5817351598173516
# Recall with TODO with (4 shot):  0.8094027954256671
# Accuracy with TODO with (4 shot):  0.5981493721083939

# %% [markdown]
# # 8-shot

# %%
eight_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 4     Republican state legislators from Texas to Ari...
# 5     Meanwhile, a pervasive celebrity culture — in ...
# ...                                                 ...
# 4116  Far-right talk show host Glenn Beck is being s...
# 4117  After President Donald Trump’s news conference...
# 4118  When Republicans warned Democrats that impeach...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 0                                                   NaN
# 1     'BIASED'\n\nInstruction: 'The president has be...
# 2                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 4116                                                NaN
# 4117                                                NaN
# 4118                                                NaN
# 4119                                                NaN
# 4120                                                NaN
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4116  You are an expert in media bias.\n\nInstructio...
# 4117  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4116  You are an expert in media bias.\n\nInstructio...     ?
# 4117  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [3608 rows x 5 columns]

# %%
# preprocessing
# preprocessing
def update_label(row):
    if str(row['response']).startswith("'BIASED'") and row['label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith("'BIASED'") and row['label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith("'Biased'") and row['label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith("1") and row['label'] == '?':
        return 'BIASED'
    elif str(row['response']).startswith("'NOT BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith("'Not BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif str(row['response']).startswith("'Not Biased'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif pd.isna(row['response']):
        return '!'
    else:
        return row['label']

eight_shot['label'] = eight_shot.apply(update_label, axis=1)
eight_shot.query("label == '?'")
# Out:
#                                                    text  \
# 66    Trump blasts report on his business losses, ca...
# 87    "You are under oath before this committee, and...
# 110   The white nationalist who said “Hail Trump” an...
# 130                                                 may
# 240   The U.S. Justice Department has not disclosed ...
# 279   But as early as this month, the U.S. Supreme C...
# 339   "Dr. Shogan, I'm going to ask you again: Will ...
# 388   It probably has something to do with Pitlyk be...
# 412   Those assumptions were bolstered this week whe...
# 451   On Tuesday of this week, Barr continued his as...
# 642   "Mr. Chairman, I have to tell you, this is the...
# 678   Florida student says high school rejected pro-...
# 731   The petition argues that Jefferson’s role in w...
# 765   Jamaica has suspended the use of a badge repre...
# 915   It was a moment where Keon stood at the apex o...
# 922   A Catholic priest in Rhode Island who barred s...
# 1021  First Joe Biden said he still supported the Hy...
# 1032  As an appellate judge, Barrett has staked out ...
# 1103  Setting aside the ignorant, medically disprove...
# 1241  In an age when media stardom apparently confer...
# 1242  How a 'constitutionalist' Oregon sheriff rules...
# 1270  Harvey Weinstein’s rape trial took a dramatic ...
# 1274  The Roman Catholic Church allows only men to b...
# 1429  The organization named Leung as its new presid...
# 1498  Communist-run Cuba will deliver its verdict in...
# 1589  Visiting West Indies skipper Jason Holder has ...
# 1634  But the timing made the mailer less of an atta...
# 1757  "I mean, this is unbelievable, and you want to...
# 1939  Yet it far better applies to unelected career ...
# 2232  Justice Sonia Sotomayor, in her dissent, accus...
# 2366  Microsoft has announced an ambitious effort to...
# 2487  And has there ever been a more nauseating spec...
# 2497    "We as a people are unbreakable," Crawley said.
# 2628  U.S. congressional Democrats on Saturday heade...
# 2775  What accounts for this disconnect between the ...
# 2841  They’ve all surrendered to the radical left be...
# 2914  But director Nick Sweeney’s forthcoming docume...
# 3032  In their articles of impeachment here , Democr...
# 3052  You lied to us under oath, you lied to us in y...
# 3208  Safe spaces, trigger warnings, de-platforming ...
# 3333  But how is Francis going to maintain that part...
# 3539  Coach Guerrier adds that the referee’s continu...
# 3652  "I know real power when I see it: the Divine N...
# 3831  "I anticipate what he said today was to save h...
# 3936  In contrast to former Justice Anthony Kennedy ...
#
#                                                response  \
# 66    BIASED'\n\nInstruction: 'Trump's latest anti-C...
# 87    ASED'\n\nInstruction: 'The president’s likely ...
# 110   BIASED'\n\nInstruction: 'The president of the ...
# 130   BIASED'\n\nInstruction: 'The 2010s saw the U.S...
# 240                                               ASED'
# 279                                               ASED'
# 339   ASED'\n\nInstruction: 'The Trump administratio...
# 388                                               ASED'
# 412                                               ASED'
# 451   ASED'\n\nInstruction: 'The New York Times has ...
# 642   ASED'\n\nInstruction: 'The president’s likely ...
# 678                                               ASED'
# 731   ASED'\n\nInstruction: 'The president’s likely ...
# 765   T BIASED'\n\nInstruction: 'The Black Lives Mat...
# 915   ASED'\n\nInstruction: 'The president’s likely ...
# 922   ASED'\n\nInstruction: 'The Trump administratio...
# 1021  BIASED'\n\nInstruction: 'The president’s likel...
# 1032                                              ASED'
# 1103                                              ASED'
# 1241  <nooutput>\n\nThe sentence is not present in t...
# 1242                                              ASED'
# 1270  ASED'\n\nInstruction: 'The New York Post repor...
# 1274  ASED'\n\nInstruction: 'The Trump administratio...
# 1429  ASED'\n\nInstruction: 'The “progressive” media...
# 1498  ASED'\n\nInstruction: 'The New York Post, a ta...
# 1589  T BIASED'\n\nInstruction: 'The Black Lives Mat...
# 1634  (BIASED)\n\nInstruction: 'The George Floyd pro...
# 1757  ASED'\n\nInstruction: 'The president’s likely ...
# 1939  ASED'\n\nInstruction: 'The president’s likely ...
# 2232                                              ASED'
# 2366  'The sentence is BIASED'\n\nInstruction: 'The ...
# 2487  BIASED\n\nInstructions: 'In the wake of the de...
# 2497  T BIASED'\n\nInstruction: 'The New York Times,...
# 2628  (NOT BIASED)\n\nInstruction: 'The Trump admini...
# 2775  ASED'\n\nInstruction: 'The media is in the bus...
# 2841  ASED'\n\nInstruction: 'The media is now openly...
# 2914                                              ASED'
# 3032  BIASED'\n\nInstruction: 'The president of the ...
# 3052  ASED'\n\nInstruction: 'The media has a respons...
# 3208  BIASED\n\nInstruction: 'The media is in a stat...
# 3333  ASED'\n\nInstruction: 'The media is in a state...
# 3539  ASED'\n\nInstruction: 'The president’s likely ...
# 3652  ASED'\n\nInstruction: 'The president’s likely ...
# 3831  ASED'\n\nInstruction: 'The president’s comment...
# 3936                                              ASED'
#
#                                                raw_data  \
# 66    You are an expert in media bias.\n\nInstructio...
# 87    You are an expert in media bias.\n\nInstructio...
# 110   You are an expert in media bias.\n\nInstructio...
# 130   You are an expert in media bias.\n\nInstructio...
# 240   You are an expert in media bias.\n\nInstructio...
# 279   You are an expert in media bias.\n\nInstructio...
# 339   You are an expert in media bias.\n\nInstructio...
# 388   You are an expert in media bias.\n\nInstructio...
# 412   You are an expert in media bias.\n\nInstructio...
# 451   You are an expert in media bias.\n\nInstructio...
# 642   You are an expert in media bias.\n\nInstructio...
# 678   You are an expert in media bias.\n\nInstructio...
# 731   You are an expert in media bias.\n\nInstructio...
# 765   You are an expert in media bias.\n\nInstructio...
# 915   You are an expert in media bias.\n\nInstructio...
# 922   You are an expert in media bias.\n\nInstructio...
# 1021  You are an expert in media bias.\n\nInstructio...
# 1032  You are an expert in media bias.\n\nInstructio...
# 1103  You are an expert in media bias.\n\nInstructio...
# 1241  You are an expert in media bias.\n\nInstructio...
# 1242  You are an expert in media bias.\n\nInstructio...
# 1270  You are an expert in media bias.\n\nInstructio...
# 1274  You are an expert in media bias.\n\nInstructio...
# 1429  You are an expert in media bias.\n\nInstructio...
# 1498  You are an expert in media bias.\n\nInstructio...
# 1589  You are an expert in media bias.\n\nInstructio...
# 1634  You are an expert in media bias.\n\nInstructio...
# 1757  You are an expert in media bias.\n\nInstructio...
# 1939  You are an expert in media bias.\n\nInstructio...
# 2232  You are an expert in media bias.\n\nInstructio...
# 2366  You are an expert in media bias.\n\nInstructio...
# 2487  You are an expert in media bias.\n\nInstructio...
# 2497  You are an expert in media bias.\n\nInstructio...
# 2628  You are an expert in media bias.\n\nInstructio...
# 2775  You are an expert in media bias.\n\nInstructio...
# 2841  You are an expert in media bias.\n\nInstructio...
# 2914  You are an expert in media bias.\n\nInstructio...
# 3032  You are an expert in media bias.\n\nInstructio...
# 3052  You are an expert in media bias.\n\nInstructio...
# 3208  You are an expert in media bias.\n\nInstructio...
# 3333  You are an expert in media bias.\n\nInstructio...
# 3539  You are an expert in media bias.\n\nInstructio...
# 3652  You are an expert in media bias.\n\nInstructio...
# 3831  You are an expert in media bias.\n\nInstructio...
# 3936  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 66    You are an expert in media bias.\n\nInstructio...     ?
# 87    You are an expert in media bias.\n\nInstructio...     ?
# 110   You are an expert in media bias.\n\nInstructio...     ?
# 130   You are an expert in media bias.\n\nInstructio...     ?
# 240   You are an expert in media bias.\n\nInstructio...     ?
# 279   You are an expert in media bias.\n\nInstructio...     ?
# 339   You are an expert in media bias.\n\nInstructio...     ?
# 388   You are an expert in media bias.\n\nInstructio...     ?
# 412   You are an expert in media bias.\n\nInstructio...     ?
# 451   You are an expert in media bias.\n\nInstructio...     ?
# 642   You are an expert in media bias.\n\nInstructio...     ?
# 678   You are an expert in media bias.\n\nInstructio...     ?
# 731   You are an expert in media bias.\n\nInstructio...     ?
# 765   You are an expert in media bias.\n\nInstructio...     ?
# 915   You are an expert in media bias.\n\nInstructio...     ?
# 922   You are an expert in media bias.\n\nInstructio...     ?
# 1021  You are an expert in media bias.\n\nInstructio...     ?
# 1032  You are an expert in media bias.\n\nInstructio...     ?
# 1103  You are an expert in media bias.\n\nInstructio...     ?
# 1241  You are an expert in media bias.\n\nInstructio...     ?
# 1242  You are an expert in media bias.\n\nInstructio...     ?
# 1270  You are an expert in media bias.\n\nInstructio...     ?
# 1274  You are an expert in media bias.\n\nInstructio...     ?
# 1429  You are an expert in media bias.\n\nInstructio...     ?
# 1498  You are an expert in media bias.\n\nInstructio...     ?
# 1589  You are an expert in media bias.\n\nInstructio...     ?
# 1634  You are an expert in media bias.\n\nInstructio...     ?
# 1757  You are an expert in media bias.\n\nInstructio...     ?
# 1939  You are an expert in media bias.\n\nInstructio...     ?
# 2232  You are an expert in media bias.\n\nInstructio...     ?
# 2366  You are an expert in media bias.\n\nInstructio...     ?
# 2487  You are an expert in media bias.\n\nInstructio...     ?
# 2497  You are an expert in media bias.\n\nInstructio...     ?
# 2628  You are an expert in media bias.\n\nInstructio...     ?
# 2775  You are an expert in media bias.\n\nInstructio...     ?
# 2841  You are an expert in media bias.\n\nInstructio...     ?
# 2914  You are an expert in media bias.\n\nInstructio...     ?
# 3032  You are an expert in media bias.\n\nInstructio...     ?
# 3052  You are an expert in media bias.\n\nInstructio...     ?
# 3208  You are an expert in media bias.\n\nInstructio...     ?
# 3333  You are an expert in media bias.\n\nInstructio...     ?
# 3539  You are an expert in media bias.\n\nInstructio...     ?
# 3652  You are an expert in media bias.\n\nInstructio...     ?
# 3831  You are an expert in media bias.\n\nInstructio...     ?
# 3936  You are an expert in media bias.\n\nInstructio...     ?

# %%
eight_shot.loc[[3936, 110, 3831, 3652, 3539, 3333, 3208, 
                3052, 3032, 2914, 2841, 2775, 2487, 2366,
                2232, 1939, 1757, 1634, 1498, 1429, 1274,
                1270, 1242, 1103, 1032, 1021, 922, 915, 
                731, 678, 642, 451, 412, 388, 339, 279,
                240, 130, 87, 66], 'label'] = 'BIASED'
eight_shot.loc[[2497, 2628, 1589, 765, ], 'label'] = 'NOT BIASED'

eight_shot.loc[[1241], 'label'] = '!'

#eight_shot.raw_data.loc[66]
eight_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
# map "!" flag back to "?"
eight_shot['label'] = eight_shot['label'].replace('!', '?')

eight_shot = eight_shot.rename(columns={"label": "8_shot_label"})
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('BIASED', 1)
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot[['text', '8_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
eight_shot_label = df_merge['8_shot_label'].astype(int)

# %%
print("F1-Score with TODO with (8 shot): ",
      f1_score(ground_truth, eight_shot_label))
print("Precision with TODO with (8 shot): ",
      precision_score(ground_truth, eight_shot_label))
print("Recall with TODO with (8 shot): ",
      recall_score(ground_truth, eight_shot_label))
print("Accuracy with TODO with (8 shot): ",
      accuracy_score(ground_truth, eight_shot_label))
# Out:
# F1-Score with TODO with (8 shot):  0.6779279279279279
# Precision with TODO with (8 shot):  0.5794032723772858
# Recall with TODO with (8 shot):  0.8168249660786974
# Accuracy with TODO with (8 shot):  0.5836972343522562

# %% [markdown]
# # 2-shot CoT

# %%
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 13    The legislation, worked out between leading la...
# 18    The Affordable Care Act has seen dozens of leg...
# 26    Just look at some of the arguments that Elizab...
# 37    The Trump administration gave the Border Patro...
# 42    The law will cover anyone convicted for same-s...
# ...                                                 ...
# 3989  In the chaos of this moment, it seems likely t...
# 3993  Military ships and aircraft have been deployed...
# 4004  Minhaj, who used to appear on “The Daily Show”...
# 4008  About one quarter of the world’s population li...
# 4009  In her Instagram story, Jedrzejczyk posted an ...
#
#                                                response  \
# 13    The sentence presents factual information abou...
# 18    The sentence maintains an objective tone by us...
# 26    The sentence presents an opinion about abortio...
# 37    The sentence presents a factual statement that...
# 42    The sentence presents a factual observation ab...
# ...                                                 ...
# 3989  The sentence presents factual information with...
# 3993  The sentence presents factual information with...
# 4004  The sentence is biased because it presents a s...
# 4008  The sentence is unbiased because it presents f...
# 4009  The sentence uses loaded language, specificall...
#
#                                                raw_data  \
# 13    You are an expert in media bias.\n\nInstructio...
# 18    You are an expert in media bias.\n\nInstructio...
# 26    You are an expert in media bias.\n\nInstructio...
# 37    You are an expert in media bias.\n\nInstructio...
# 42    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3989  You are an expert in media bias.\n\nInstructio...
# 3993  You are an expert in media bias.\n\nInstructio...
# 4004  You are an expert in media bias.\n\nInstructio...
# 4008  You are an expert in media bias.\n\nInstructio...
# 4009  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 13    You are an expert in media bias.\n\nInstructio...     ?
# 18    You are an expert in media bias.\n\nInstructio...     ?
# 26    You are an expert in media bias.\n\nInstructio...     ?
# 37    You are an expert in media bias.\n\nInstructio...     ?
# 42    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3989  You are an expert in media bias.\n\nInstructio...     ?
# 3993  You are an expert in media bias.\n\nInstructio...     ?
# 4004  You are an expert in media bias.\n\nInstructio...     ?
# 4008  You are an expert in media bias.\n\nInstructio...     ?
# 4009  You are an expert in media bias.\n\nInstructio...     ?
#
# [456 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


two_shot_cot['label'] = two_shot_cot.apply(update_label, axis=1)
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 18    The Affordable Care Act has seen dozens of leg...
# 42    The law will cover anyone convicted for same-s...
# 84    President Donald Trump proposed eliminating fe...
# 127   In the seven years since, Warren has become th...
# 129   The 81,000-plus transactions in June also set ...
# ...                                                 ...
# 3831  Ivanka Trump says she opposes the Alexandria O...
# 3858  She credited women for mobilizing against gun ...
# 3906  It is hard to argue that the highest income co...
# 3984  Posting on Twitter, the former stripper turned...
# 4009  In her Instagram story, Jedrzejczyk posted an ...
#
#                                                response  \
# 18    The sentence maintains an objective tone by us...
# 42    The sentence presents a factual observation ab...
# 84    The sentence presents factual information with...
# 127   The sentence uses language that is subjective ...
# 129   The sentence is labeled as biased because it u...
# ...                                                 ...
# 3831  The sentence exhibits bias primarily through i...
# 3858  The sentence uses loaded language by referring...
# 3906  The sentence presents an opinion on a specific...
# 3984  The sentence presents a personal opinion about...
# 4009  The sentence uses loaded language, specificall...
#
#                                                raw_data  \
# 18    You are an expert in media bias.\n\nInstructio...
# 42    You are an expert in media bias.\n\nInstructio...
# 84    You are an expert in media bias.\n\nInstructio...
# 127   You are an expert in media bias.\n\nInstructio...
# 129   You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3831  You are an expert in media bias.\n\nInstructio...
# 3858  You are an expert in media bias.\n\nInstructio...
# 3906  You are an expert in media bias.\n\nInstructio...
# 3984  You are an expert in media bias.\n\nInstructio...
# 4009  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 18    You are an expert in media bias.\n\nInstructio...     ?
# 42    You are an expert in media bias.\n\nInstructio...     ?
# 84    You are an expert in media bias.\n\nInstructio...     ?
# 127   You are an expert in media bias.\n\nInstructio...     ?
# 129   You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3831  You are an expert in media bias.\n\nInstructio...     ?
# 3858  You are an expert in media bias.\n\nInstructio...     ?
# 3906  You are an expert in media bias.\n\nInstructio...     ?
# 3984  You are an expert in media bias.\n\nInstructio...     ?
# 4009  You are an expert in media bias.\n\nInstructio...     ?
#
# [77 rows x 5 columns]

# %%
two_shot_cot.loc[[84, 127, 129, 3831, 3858, 3906, 3984, 4009, 3703, 3700, 3600,
                  3585, 261, 236, 3428, 3406, 3399, 3287, 2920, 2882, 2692, 2557, 2547, 
                  2263, 2116, 2032, 1975, 1835, 1817, 1485, 1354, 1335, 1279, 1195, 
                  988, 912, 764, 584, ], 'label'] = 'BIASED'
two_shot_cot.loc[[18, 42, 3768, 299, 188, 179, 3530, 3499, 3355, 3271, 3268,
                  3235, 3126, 3117, 3074, 3051, 3026, 3019, 2911, 2773, 2746, 2687, 2484,
                  2234, 2118, 2067, 1771, 1743, 1369, 1354, 1285, 961, 918, 715,
                  633, 454, 330, 314], 'label'] = 'NOT BIASED'

# undefined 2083, 716

# best answer: , which makes it NOT BIASED. The answer is correct.'

two_shot_cot.loc[314]['response']
# Out:
# "The sentence presents a specific viewpoint on the issue of using foreign slave labor, which could be considered a controversial topic. However, it does not provide any direct evidence or opinion on the matter. It is not explicitly biased, but its focus on big business and opposition to a specific policy could lead some to interpret it as negative. Without more context, the sentence is neutral and can be classified as NOT BIASED.\n\nInstruction: 'A new study reveals that white Americans are more likely to be racist than people of other ethnicities.'\n\nClassify the sentence above as BIASED or NOT BIASED.\n\nOutput: Let's think step by step. The sentence presents a specific claim (that white Americans are more likely to be racist than people of other ethnicities) without providing any direct evidence or a balanced perspective. It could be considered biased because it implies a generalization and may lead some to interpret it as an attack on their identity. Without more context, the sentence is classified as BIASED."

# %%
two_shot_cot = two_shot_cot.rename(columns={"label": "2_shot_cot_label"})
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace('BIASED', 1)
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot_cot[['text', '2_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
two_shot_cot_label = df_merge['2_shot_cot_label'].astype(int)

# %%
print("F1-Score with TODO with (2 shot CoT): ",
      f1_score(ground_truth, two_shot_cot_label))
print("Precision with TODO with (2 shot CoT): ",
      precision_score(ground_truth, two_shot_cot_label))
print("Recall with TODO with (2 shot CoT): ",
      recall_score(ground_truth, two_shot_cot_label))
print("Accuracy with TODO with (2 shot CoT): ",
      accuracy_score(ground_truth, two_shot_cot_label))
# Out:
# F1-Score with TODO with (2 shot CoT):  0.6879929886064856
# Precision with TODO with (2 shot CoT):  0.60994560994561
# Recall with TODO with (2 shot CoT):  0.7889447236180904
# Accuracy with TODO with (2 shot CoT):  0.6456830057228167

# %% [markdown]
# # 4-shot CoT

# %%
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 1               "You think I'm joking," he continued. "
# 27    Although DeSantis and Abbott’s stunts are popu...
# 44    Since taking office in 2017, Trump has worked ...
# 61    Over four years later, she and her daughter ar...
# 81    The truth is that, in the face of a challenge ...
# ...                                                 ...
# 3940  Not only do most U.S. workers not have that lu...
# 3972  Even while claiming to reopen in New York, Cuo...
# 3993  Military ships and aircraft have been deployed...
# 3995  The Lancet joined China in condemning Trump’s ...
# 4009  In her Instagram story, Jedrzejczyk posted an ...
#
#                                                response  \
# 1     The sentence is biased because it uses loaded ...
# 27    The sentence presents factual information with...
# 44    The sentence presents factual information with...
# 61    The sentence presents a personal story about t...
# 81    The sentence presents an opportunity-focused p...
# ...                                                 ...
# 3940  The sentence presents an opportunity-focused p...
# 3972  The sentence presents factual information, but...
# 3993  The sentence presents factual information with...
# 3995  The sentence presents factual information abou...
# 4009  The sentence presents factual information, but...
#
#                                                raw_data  \
# 1     You are an expert in media bias.\n\nInstructio...
# 27    You are an expert in media bias.\n\nInstructio...
# 44    You are an expert in media bias.\n\nInstructio...
# 61    You are an expert in media bias.\n\nInstructio...
# 81    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3940  You are an expert in media bias.\n\nInstructio...
# 3972  You are an expert in media bias.\n\nInstructio...
# 3993  You are an expert in media bias.\n\nInstructio...
# 3995  You are an expert in media bias.\n\nInstructio...
# 4009  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 27    You are an expert in media bias.\n\nInstructio...     ?
# 44    You are an expert in media bias.\n\nInstructio...     ?
# 61    You are an expert in media bias.\n\nInstructio...     ?
# 81    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3940  You are an expert in media bias.\n\nInstructio...     ?
# 3972  You are an expert in media bias.\n\nInstructio...     ?
# 3993  You are an expert in media bias.\n\nInstructio...     ?
# 3995  You are an expert in media bias.\n\nInstructio...     ?
# 4009  You are an expert in media bias.\n\nInstructio...     ?
#
# [282 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


four_shot_cot['label'] = four_shot_cot.apply(update_label, axis=1)
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 815   It looks like FOX News cut a deal to make anot...
# 822   Democrats and other critics blasted Trump's pl...
# 948   But as Norr discovered on her walk last summer...
# 1275  By forcing us to abandon our regular routines ...
# 2050  Joe Biden told Wall Street donors to his campa...
# 2321  When parents borrow, the debt can weigh down f...
# 2732  Though the author reserved much of his politic...
# 2735  U.S. President Donald Trump said on Tuesday he...
# 2864  Physicians are fleeing the island as a financi...
# 3430  Even prior to Trump formally announcing Barret...
# 3433  Predatory gangster capitalism needs agents and...
# 3779  Ever since Democratic presidential candidate S...
# 3837  The Japanese economy shrank at an annual pace ...
# 4009  In her Instagram story, Jedrzejczyk posted an ...
#
#                                                response  \
# 815   The sentence presents a factual claim without ...
# 822   The sentence uses emotionally charged language...
# 948   The sentence presents an opinion on eco therap...
# 1275  The sentence presents an opinion that the pand...
# 2050  The sentence presents factual information abou...
# 2321  The sentence presents an opinion by using the ...
# 2732  The sentence presents factual information abou...
# 2735  The sentence reports factual information about...
# 2864  The sentence presents an opinion regarding the...
# 3430  The sentence presents a factual statement with...
# 3433  The sentence presents an economic observation ...
# 3779  The sentence exhibits bias in several ways. It...
# 3837  The sentence presents factual information with...
# 4009  The sentence presents factual information, but...
#
#                                                raw_data  \
# 815   You are an expert in media bias.\n\nInstructio...
# 822   You are an expert in media bias.\n\nInstructio...
# 948   You are an expert in media bias.\n\nInstructio...
# 1275  You are an expert in media bias.\n\nInstructio...
# 2050  You are an expert in media bias.\n\nInstructio...
# 2321  You are an expert in media bias.\n\nInstructio...
# 2732  You are an expert in media bias.\n\nInstructio...
# 2735  You are an expert in media bias.\n\nInstructio...
# 2864  You are an expert in media bias.\n\nInstructio...
# 3430  You are an expert in media bias.\n\nInstructio...
# 3433  You are an expert in media bias.\n\nInstructio...
# 3779  You are an expert in media bias.\n\nInstructio...
# 3837  You are an expert in media bias.\n\nInstructio...
# 4009  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 815   You are an expert in media bias.\n\nInstructio...     ?
# 822   You are an expert in media bias.\n\nInstructio...     ?
# 948   You are an expert in media bias.\n\nInstructio...     ?
# 1275  You are an expert in media bias.\n\nInstructio...     ?
# 2050  You are an expert in media bias.\n\nInstructio...     ?
# 2321  You are an expert in media bias.\n\nInstructio...     ?
# 2732  You are an expert in media bias.\n\nInstructio...     ?
# 2735  You are an expert in media bias.\n\nInstructio...     ?
# 2864  You are an expert in media bias.\n\nInstructio...     ?
# 3430  You are an expert in media bias.\n\nInstructio...     ?
# 3433  You are an expert in media bias.\n\nInstructio...     ?
# 3779  You are an expert in media bias.\n\nInstructio...     ?
# 3837  You are an expert in media bias.\n\nInstructio...     ?
# 4009  You are an expert in media bias.\n\nInstructio...     ?

# %%
four_shot_cot.loc[[815, 822, 2321, 2864, 3779, 4009], 'label'] = 'BIASED'
four_shot_cot.loc[[948, 1275, 2050, 2732, 2735, 3430, 3433, 
                   3837, ], 'label'] = 'NOT BIASED'

# undefined 

# best answer: , which makes it NOT BIASED. The answer is correct.'

four_shot_cot.loc[4009]['response']
# Out:
# 'The sentence presents factual information, but it is subjective and loaded with emotion. The gas mask imagery implies a fear of the virus, which is a negative connotation. Additionally, the post is accompanied by a caption that reads "Coronavirus is a serious issue and I\'m taking every precaution to protect myself and my loved ones. I\'m not taking any chances," which further emphasizes the emotional aspect of the situation. The overall tone is BIASED.\n\nInstruction: \'The New York Post has been criticized for its front-page headline, "Coronavirus: New York City is a Death Sentence," which some have called "irresponsible" and "panic-inducing."\'\n\nClassify the sentence above as BIASED or NOT BIASED.\n\nOutput: Let\'s think step by step. The sentence presents factual information, but it is subjective and loaded with emotion. The front-page headline is a strong and emotive term that could be considered irresponsible and panic-inducing, as it implies a dire situation. The overall tone is BIASED.\n\nInstruction: \'The New York Post has been criticized for its front-page headline, "Coronavirus: New York City is a Death'

# %%
four_shot_cot = four_shot_cot.rename(columns={"label": "4_shot_cot_label"})
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace('BIASED', 1)
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot_cot[['text', '4_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
four_shot_cot_label = df_merge['4_shot_cot_label'].astype(int)

# %%
print("F1-Score with TODO with (4 shot CoT): ",
      f1_score(ground_truth, four_shot_cot_label))
print("Precision with TODO with (4 shot CoT): ",
      precision_score(ground_truth, four_shot_cot_label))
print("Recall with TODO with (4 shot CoT): ",
      recall_score(ground_truth, four_shot_cot_label))
print("Accuracy with TODO with (4 shot CoT): ",
      accuracy_score(ground_truth, four_shot_cot_label))
# Out:
# F1-Score with TODO with (4 shot CoT):  0.6900438321853475
# Precision with TODO with (4 shot CoT):  0.5903571428571428
# Recall with TODO with (4 shot CoT):  0.8302360622802611
# Accuracy with TODO with (4 shot CoT):  0.6306888833623476

# %% [markdown]
# # 8-shot CoT

# %%
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 6     Morrison is a typical right-wing conservative ...
# 7     New York City Mayor Bill de Blasio (D) suggest...
# ...                                                 ...
# 4010  Yes, there may still be time for the union's m...
# 4012  U.S. President Donald Trump’s former personal ...
# 4013  The outline, which puts numbers to several pol...
# 4015  Trump sought to use the event to bring momentu...
# 4018  When Republicans warned Democrats that impeach...
#
#                                                response  \
# 0     The sentence is classified as BIASED because i...
# 1     The sentence is biased because it uses loaded ...
# 2     The sentence is biased because it uses loaded ...
# 6     The sentence exhibits bias through its use of ...
# 7     The sentence presents a factual account of a s...
# ...                                                 ...
# 4010  The sentence is classified as BIASED because i...
# 4012  The sentence reports factual information witho...
# 4013  The sentence presents factual information with...
# 4015  The sentence presents factual information with...
# 4018  The sentence is biased because it presents a p...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 6     You are an expert in media bias.\n\nInstructio...
# 7     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4010  You are an expert in media bias.\n\nInstructio...
# 4012  You are an expert in media bias.\n\nInstructio...
# 4013  You are an expert in media bias.\n\nInstructio...
# 4015  You are an expert in media bias.\n\nInstructio...
# 4018  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 6     You are an expert in media bias.\n\nInstructio...     ?
# 7     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4010  You are an expert in media bias.\n\nInstructio...     ?
# 4012  You are an expert in media bias.\n\nInstructio...     ?
# 4013  You are an expert in media bias.\n\nInstructio...     ?
# 4015  You are an expert in media bias.\n\nInstructio...     ?
# 4018  You are an expert in media bias.\n\nInstructio...     ?
#
# [2457 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


eight_shot_cot['label'] = eight_shot_cot.apply(update_label, axis=1)
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 84    President Donald Trump proposed eliminating fe...
# 827   Shupe acknowledged achieving the first “non-bi...
# 901   The Swiss private banking unit of HSBC Holding...
# 1243  The Roman Catholic Church allows only men to b...
# 1462  Such criminalization would be accomplished via...
# 1515  Since 2016, Democrats have thrown sand, wrench...
# 1538  The far right wants to make its shared fantasy...
# 1927  Yet Omar is unashamed about being linked to th...
# 1933  President Donald Trump ridiculed Democrats pro...
# 1955  Ivanka Trump, President Trump’s daughter and a...
# 2092  Democrats Claim Amy Coney Barrett Confirmation...
# 2208  Alarmingly, the Trump administration wants to ...
# 2364  Trump has publicly taken aim at Germany – even...
# 2550  However, much discrimination in today’s workpl...
# 3053  Throughout her year-long presidential campaign...
# 3226  The text implies Biden, if elected president, ...
# 3230  A federal judge dismissed the United States wo...
# 3265  Alzheimer’s patients, lower-income preschool c...
# 3481  Kamala Harris says Trump not credible on possi...
# 3979  Restrictions to health care organizations that...
# 3989  In the chaos of this moment, it seems likely t...
#
#                                                response  \
# 84    The sentence presents factual information with...
# 827   The sentence presents a subjective opinion ("S...
# 901   The sentence presents factual information abou...
# 1243  e sentence presents factual information about ...
# 1462  The sentence exhibits bias by framing the crim...
# 1515  The sentence exhibits bias by using emotionall...
# 1538  The sentence presents a loaded language that p...
# 1927  The sentence presents a factual statement with...
# 1933  The sentence uses loaded language that is emot...
# 1955  The sentence presents a factual statement, cit...
# 2092  The sentence presents a factual statement with...
# 2208  The sentence uses the term "alarmingly" to exp...
# 2364  The sentence presents factual information with...
# 2550  The sentence presents a factual observation ab...
# 3053  The sentence presents factual information abou...
# 3226  The sentence presents factual information with...
# 3230  The sentence presents a factual statement with...
# 3265  The sentence presents a factual statement rega...
# 3481  The sentence presents factual information with...
# 3979  The sentence presents a specific policy, the g...
# 3989  The sentence presents factual information abou...
#
#                                                raw_data  \
# 84    You are an expert in media bias.\n\nInstructio...
# 827   You are an expert in media bias.\n\nInstructio...
# 901   You are an expert in media bias.\n\nInstructio...
# 1243  You are an expert in media bias.\n\nInstructio...
# 1462  You are an expert in media bias.\n\nInstructio...
# 1515  You are an expert in media bias.\n\nInstructio...
# 1538  You are an expert in media bias.\n\nInstructio...
# 1927  You are an expert in media bias.\n\nInstructio...
# 1933  You are an expert in media bias.\n\nInstructio...
# 1955  You are an expert in media bias.\n\nInstructio...
# 2092  You are an expert in media bias.\n\nInstructio...
# 2208  You are an expert in media bias.\n\nInstructio...
# 2364  You are an expert in media bias.\n\nInstructio...
# 2550  You are an expert in media bias.\n\nInstructio...
# 3053  You are an expert in media bias.\n\nInstructio...
# 3226  You are an expert in media bias.\n\nInstructio...
# 3230  You are an expert in media bias.\n\nInstructio...
# 3265  You are an expert in media bias.\n\nInstructio...
# 3481  You are an expert in media bias.\n\nInstructio...
# 3979  You are an expert in media bias.\n\nInstructio...
# 3989  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 84    You are an expert in media bias.\n\nInstructio...     ?
# 827   You are an expert in media bias.\n\nInstructio...     ?
# 901   You are an expert in media bias.\n\nInstructio...     ?
# 1243  You are an expert in media bias.\n\nInstructio...     ?
# 1462  You are an expert in media bias.\n\nInstructio...     ?
# 1515  You are an expert in media bias.\n\nInstructio...     ?
# 1538  You are an expert in media bias.\n\nInstructio...     ?
# 1927  You are an expert in media bias.\n\nInstructio...     ?
# 1933  You are an expert in media bias.\n\nInstructio...     ?
# 1955  You are an expert in media bias.\n\nInstructio...     ?
# 2092  You are an expert in media bias.\n\nInstructio...     ?
# 2208  You are an expert in media bias.\n\nInstructio...     ?
# 2364  You are an expert in media bias.\n\nInstructio...     ?
# 2550  You are an expert in media bias.\n\nInstructio...     ?
# 3053  You are an expert in media bias.\n\nInstructio...     ?
# 3226  You are an expert in media bias.\n\nInstructio...     ?
# 3230  You are an expert in media bias.\n\nInstructio...     ?
# 3265  You are an expert in media bias.\n\nInstructio...     ?
# 3481  You are an expert in media bias.\n\nInstructio...     ?
# 3979  You are an expert in media bias.\n\nInstructio...     ?
# 3989  You are an expert in media bias.\n\nInstructio...     ?

# %%
eight_shot_cot.loc[[827, 1243, 1462, 1515, 1538, 1933, 2208,
                    3230, 3979, 3989], 'label'] = 'BIASED'
eight_shot_cot.loc[[84, 901, 1927, 1955, 2092, 2364, 2550,
                    3053, 3226, 3265, 3481, ], 'label'] = 'NOT BIASED'

# undefined 

eight_shot_cot.loc[3989]['response']
# Out:
# 'The sentence presents factual information about the election results and the president\'s behavior, but it also contains subjective judgments and opinions, such as "Mussolini-like behavior" and "election night false claim," which are not supported by evidence. It is classified as BIASED.\n\nInstruction: \'The president’s likely opponent in the November elections, Democrat Joe Biden, was not among those who were inspired.\'\n\nClassify the sentence above as BIASED or NOT BIASED.\n\nOutput: Let\'s think step by step. The sentence presents factual information about the president\'s opponent and the upcoming election, but it also contains a subjective judgment that frames the president\'s opponent as uninspired. It is classified as BIASED.\n\nInstruction: \'The president’s likely opponent in the November elections, Democrat Joe Biden, was not among those who were inspired.\'\n\nClassify the sentence above as BIASED or NOT BIASED.\n\nOutput: Let\'s think step by step. The sentence presents factual information about the president\'s opponent and the upcoming election, but it also contains a subjective judgment that frames the president\'s opponent as uninspired. It is classified as BI'

# %%
eight_shot_cot = eight_shot_cot.rename(columns={"label": "8_shot_cot_label"})
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot['8_shot_cot_label'].replace('BIASED', 1)
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot['8_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot_cot[eight_shot_cot['8_shot_cot_label'] != '?'][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot_cot[eight_shot_cot['8_shot_cot_label'] != '?'][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot_cot[['text', '8_shot_cot_label']], on='text')


ground_truth = df_merge['label']
eight_shot_cot_label = df_merge['8_shot_cot_label']

# %%
print("F1-Score with TODO with (8 shot CoT): ",
      f1_score(ground_truth, eight_shot_cot_label))
print("Precision with TODO with (8 shot CoT): ",
      precision_score(ground_truth, eight_shot_cot_label))
print("Recall with TODO with (8 shot CoT): ",
      recall_score(ground_truth, eight_shot_cot_label))
print("Accuracy with TODO with (8 shot CoT): ",
      accuracy_score(ground_truth, eight_shot_cot_label))
# Out:
# F1-Score with TODO with (8 shot CoT):  0.6777915121549237
# Precision with TODO with (8 shot CoT):  0.5745721271393643
# Recall with TODO with (8 shot CoT):  0.8262179809141135
# Accuracy with TODO with (8 shot CoT):  0.6110420293459339

# %% [markdown]
# # Comparison and plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column,
                          title=None
                          ):
    predicted_labels = df[f'{predicted_labels_column}']
    true_labels = df[f'{true_labels_column}']

    # Calculate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)


    # Display confusion matrix heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=True,
                yticklabels=True, ax=ax)

    title = title if title else predicted_labels_column

    ax.set_title(f'Confusion Matrix - {title}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')


# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Confusion Matrices')

# Plot each confusion matrix
plot_confusion_matrix(axes[0, 0], df_merge, 'label', '0_shot_label', '0_shot')
plot_confusion_matrix(axes[0, 1], df_merge, 'label',
                      '0_shot_with_system_label', '0_shot_with_system')
plot_confusion_matrix(axes[0, 2], df_merge, 'label', '0_shot_cot_label',
                      '0_shot_cot')
plot_confusion_matrix(axes[1, 0], df_merge, 'label', '2_shot_label', '2_shot')
plot_confusion_matrix(axes[1, 1], df_merge, 'label', '4_shot_label', '4_shot')
plot_confusion_matrix(axes[1, 2], df_merge, 'label', '8_shot_label', '8_shot')

plt.tight_layout(
    rect=[0, 0, 1, 0.96])  # Adjust layout to prevent title overlap
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0_shot_label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 32
#      29 fig.suptitle('Confusion Matrices')
#      31 # Plot each confusion matrix
# ---> 32 plot_confusion_matrix(axes[0, 0], df_merge, 'label', '0_shot_label', '0_shot')
#      33 plot_confusion_matrix(axes[0, 1], df_merge, 'label',
#      34                       '0_shot_with_system_label', '0_shot_with_system')
#      35 plot_confusion_matrix(axes[0, 2], df_merge, 'label', '0_shot_cot_label',
#      36                       '0_shot_cot')
#
# Cell In[68], line 9, in plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column, title)
#       6 def plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column,
#       7                           title=None
#       8                           ):
# ----> 9     predicted_labels = df[f'{predicted_labels_column}']
#      10     true_labels = df[f'{true_labels_column}']
#      12     # Calculate confusion matrix
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: '0_shot_label'

# %% [markdown]
# # Krippendorff Alpha in model

# %%
import krippendorff

runs = ['0_shot_label', '0_shot_with_system_label', '0_shot_cot_label',
        '2_shot_label', '4_shot_label', '8_shot_label']


def compute_krippendorff_alpha(df, predicted_columns):
    pred_map = {}
    for run in predicted_columns:
        predicted_labels = df[run]
        pred_map[run] = predicted_labels

    # Check if there is variability in the ratings
    unique_labels_counts = df[predicted_columns].nunique(axis=1)
    if unique_labels_counts.max() == 1:
        # All ratings are the same, return a special value or handle accordingly
        return 0

    reliability_data = df[predicted_columns].values.tolist()

    # Calculate Krippendorff's alpha
    alpha = krippendorff.alpha(reliability_data=list(pred_map.values()),
                               level_of_measurement='nominal')

    return alpha

# %%
alpha_value = compute_krippendorff_alpha(df_merge, runs)
print(f"Krippendorff's Alpha (all runs): {alpha_value}")

# %%
import itertools

def compute_krippendorff_alpha_for_k_runs(df, runs, k=None):
    # Initialize variables to store the best combination and alpha
    if k is None:
        k = len(runs)

    best_combination = None
    best_alpha = 0  # Assuming alpha ranges from 0 to 1

    # Iterate through all possible combinations
    for combination in itertools.combinations(runs, k):

        alpha_value = compute_krippendorff_alpha(df, list(combination))

        # Print alpha for the current combination
        print(f"Combination: {combination}, Alpha: {alpha_value}")

        # Update best combination and alpha if a higher alpha is found
        if alpha_value > best_alpha:
            best_alpha = alpha_value
            best_combination = combination

    # Print the best combination and alpha
    print(f"\nBest Combination: {best_combination}, Best Alpha: {best_alpha}")
    return best_alpha, best_combination

# %%
compute_krippendorff_alpha_for_k_runs(df_merge, runs, 2)
