# %% [markdown]
# # Eval the results of Llama 7b

# %%
import pandas as pd
from datasets import load_dataset
from sklearn.metrics import f1_score, precision_score, recall_score, \
    accuracy_score

import re
from typing import List, Tuple

import pandas as pd


def is_contained(inner_start, inner_end, outer_start, outer_end):
    return (
        outer_start <= inner_start <= outer_end
        and outer_start <= inner_end <= outer_end
        and (inner_start, inner_end) != (outer_start, outer_end)
    )


def find_all_occurrences_indices(
    sentence: str,
    label: str,
) -> List[Tuple[int, int]]:
    """
    Finds all occurrences of a label in a sentence and returns a list of tuples
    with the start and end indices of the occurrences.

    Args:
        sentence: The sentence to search in.
        label: The label to search for.

    Returns:
        A list of tuples with the start and end indices of the occurrences.
    """
    return [
        (int(match.start()), int(match.end()))
        for match in re.finditer(label, sentence)
    ]


def find_contained_labels(labels):
    """
    Finds all labels that are contained in other labels.

    Args:
        labels: A list of labels.

    Returns:
        A dictionary with the labels as keys and a list of labels that are
        contained in the key label as values.
    """
    return {
        label_1: [
            label2
            for label2 in labels
            if label_1 in label2 and label_1 != label2
        ]
        for label_1 in labels
    }


def find_labels_in_sentence(
    sentence: str,
    labels: List[str],
) -> List[List[Tuple[int, int]]]:
    """
    Finds all occurrences of the labels in a sentence and returns a list of
    lists with the occurrences of each label.

    Labels that are contained in other labels are not returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.

    Returns:
        A list of lists with the positional occurrence of each label.
    """
    if not labels:
        return []

    containable_map = find_contained_labels(labels)
    sentence_lower = sentence.lower()
    occurrences = [
        find_all_occurrences_indices(sentence_lower, label.lower())
        for label in labels
    ]
    label_occurrences = dict(zip(labels, occurrences))
    included_list = []
    for label, inner_pos in zip(labels, occurrences):
        contained = set()
        containing_labels = containable_map.get(label, set())

        for bigger_label in containing_labels:
            locations: List[Tuple[int, int]] = label_occurrences.get(
                bigger_label,
                list(),
            )

            for inner_start, inner_end in inner_pos:
                for outer_start, outer_end in locations:
                    if is_contained(
                        inner_start,
                        inner_end,
                        outer_start,
                        outer_end,
                    ):
                        contained.add((inner_start, inner_end))
        included_list.append(list(contained))

    return [
        list(set(pos) - set(included))
        for pos, included in zip(occurrences, included_list)
    ]


def find_label(
    sentence: str,
    labels: List[str],
    default_label: str = "?",
) -> str:
    """
    Search for given labels in the sentence and returns it if found. If only
    one label occur in the sentence, it will be returned. If no label or
    different labels occur in the sentence, '?' is returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.
        default_label: The label to return if no label or different labels
            occur in the sentence.

    Returns:
        The label that occurs in the sentence or '?' if no label occurs in the
        sentence.
    """
    occurrences = find_labels_in_sentence(sentence=sentence, labels=labels)
    non_empty_indices = [i for i, sublist in enumerate(occurrences) if sublist]
    return (
        labels[non_empty_indices[0]]
        if len(
            non_empty_indices,
        )
           == 1
        else default_label
    )


def _soft_parse(
    df: pd.DataFrame,
    in_col: str,
    parsed_col: str,
    labels: List[str] = None,
) -> pd.DataFrame:
    if labels is None:
        raise ValueError("Labels are not set!")

    df[parsed_col] = df[in_col].apply(
        lambda x: find_label(x, labels),
    )

# %%
# load
model = 'Llama-2-7b-chat-hf'

# load results
zero_shot = pd.read_csv(f"../zero-shot/data/{model}.csv")
zero_shot_with_system = pd.read_csv(
    f"../zero-shot-system_prompt/data/{model}.csv")
zero_shot_cot = pd.read_csv(f"../zero-shot-cot/data/{model}.csv")
two_shot = pd.read_csv(f"../2-shot/data/{model}.csv")
four_shot = pd.read_csv(f"../4-shot/data/{model}.csv")
eight_shot = pd.read_csv(f"../8-shot/data/{model}.csv")

two_shot_cot = pd.read_csv(f"../2-shot-CoT/data/{model}.csv")
four_shot_cot = pd.read_csv(f"../4-shot-CoT/data/{model}.csv")
eight_shot_cot = pd.read_csv(f"../8-shot-CoT/data/{model}.csv")

#load pool
pool = load_dataset('mediabiasgroup/BABE-icl-pool')['train'].to_pandas()

# exclude pool from model (if needed)
zero_shot = zero_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
zero_shot_with_system = zero_shot_with_system.merge(pool['text'], on='text',
                                                    how='left',
                                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
zero_shot_cot = zero_shot_cot.merge(pool['text'], on='text', how='left',
                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
two_shot = two_shot.merge(pool['text'], on='text', how='left',
                          indicator=True).query('_merge == "left_only"').drop(
    '_merge', axis=1)
four_shot = four_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot = eight_shot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
two_shot_cot = two_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
four_shot_cot = four_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot_cot = eight_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)


#load babe
dataset = load_dataset('mediabiasgroup/BABE-v4')
df_babe = pd.DataFrame(dataset['train'])

# df_merge = babe at begin
df_merge_all_runs = df_babe
df_merge_all_runs_with_errors = df_babe

def find_first_occurrence(string, instruction="Instruction:",
                          statement1="The answer is BIASED",
                          statement2="The answer is NOT BIASED"
                          ):
    index_instruction = string.find(instruction)
    index1 = string.find(statement1)
    index2 = string.find(statement2)

    if index1 == -1 and index2 == -1:
        return "Neither instruction nor statements found in the given string."
    elif index1 == -1 and index2 == -1:
        return "Neither statement found in the given string."
    elif index1 == -1:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"
    elif index2 == -1:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    elif index1 < index2:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    else:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"

# %% [markdown]
# # Zero shot

# %%
_soft_parse(zero_shot, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
zero_shot.query("label == '?'")
# Out:
#                                                    text  \
# 11    On Monday, the Supreme Court voted in an 8-1 d...
# 15    Facebook bans white nationalism from platform ...
# 25    Trump acknowledged there might be a resurgence...
# 44    Since taking office in 2017, Trump has worked ...
# 50    In a tweet, which he quickly deleted, the pres...
# ...                                                 ...
# 4075  But as many reminded the President, his horrif...
# 4084  Posting on Twitter, the former stripper turned...
# 4093  Military ships and aircraft have been deployed...
# 4109  In her Instagram story, Jedrzejczyk posted an ...
# 4115  Trump sought to use the event to bring momentu...
#
#                                                response  \
# 11    NOT BIASED\n\nExplanation:\nThe sentence does ...
# 15    NOT BIASED\n\nExplanation: The sentence simply...
# 25    NOT BIASED\n\nExplanation: The sentence simply...
# 44    NOT BIASED\n\nExplanation: The sentence simply...
# 50    NOT BIASED\n\nExplanation: The sentence does n...
# ...                                                 ...
# 4075  NOT BIASED\n\nExplanation: The sentence simply...
# 4084  NOT BIASED\n\nExplanation: The sentence does n...
# 4093  NOT BIASED\n\nExplanation:\nThe sentence provi...
# 4109  NOT BIASED\n\nExplanation: The sentence is not...
# 4115  NOT BIASED\n\nExplanation: The sentence simply...
#
#                                                raw_data  \
# 11    Instruction: 'On Monday, the Supreme Court vot...
# 15    Instruction: 'Facebook bans white nationalism ...
# 25    Instruction: 'Trump acknowledged there might b...
# 44    Instruction: 'Since taking office in 2017, Tru...
# 50    Instruction: 'In a tweet, which he quickly del...
# ...                                                 ...
# 4075  Instruction: 'But as many reminded the Preside...
# 4084  Instruction: 'Posting on Twitter, the former s...
# 4093  Instruction: 'Military ships and aircraft have...
# 4109  Instruction: 'In her Instagram story, Jedrzejc...
# 4115  Instruction: 'Trump sought to use the event to...
#
#                                                   query label
# 11    Instruction: 'On Monday, the Supreme Court vot...     ?
# 15    Instruction: 'Facebook bans white nationalism ...     ?
# 25    Instruction: 'Trump acknowledged there might b...     ?
# 44    Instruction: 'Since taking office in 2017, Tru...     ?
# 50    Instruction: 'In a tweet, which he quickly del...     ?
# ...                                                 ...   ...
# 4075  Instruction: 'But as many reminded the Preside...     ?
# 4084  Instruction: 'Posting on Twitter, the former s...     ?
# 4093  Instruction: 'Military ships and aircraft have...     ?
# 4109  Instruction: 'In her Instagram story, Jedrzejc...     ?
# 4115  Instruction: 'Trump sought to use the event to...     ?
#
# [235 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


zero_shot['label'] = zero_shot.apply(update_label, axis=1)
zero_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
zero_shot = zero_shot.rename(columns={"label": "0_shot_label"})
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('BIASED', 1)
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot[['text', '0_shot_label']], on='text')

ground_truth = df_merge['label']
zero_shot_label = df_merge['0_shot_label']

# %%
print("F1-Score with TODO: ", f1_score(ground_truth, zero_shot_label))
print("Precision with TODO: ",
      precision_score(ground_truth, zero_shot_label))
print("Recall with TODO: ",
      recall_score(ground_truth, zero_shot_label))
print("Accuracy with TODO: ",
      accuracy_score(ground_truth, zero_shot_label))
# Out:
# F1-Score with TODO:  0.6008412663272084
# Precision with TODO:  0.5372129849564529
# Recall with TODO:  0.6815670517327976
# Accuracy with TODO:  0.5516040785874161

# %% [markdown]
# # zero shot with system prompt

# %%
_soft_parse(zero_shot_with_system, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
zero_shot_with_system.query("label == '?'")
# Out:
#                                                    text  \
# 173   U.S. firearms makers will be able within days ...
# 185   NBC cited Center for Countering Digital Hate, ...
# 198   The accusations fueled the #MeToo movement, in...
# 440   Many Democratic voters have said they believe ...
# 481   A bipartisan group of lawmakers in Mississippi...
# 533   Wray did not explain the evidence that had inf...
# 663   Weinstein faces up to 28 years in California p...
# 904   Following his arrest on July 6, 2019, financie...
# 1064  Prosecutors have said the gunman targeted a To...
# 1097  Just steps from where Trump spoke, peaceful pr...
# 1200  The free health care for DACA illegal aliens p...
# 1359  Although duties set to kick in soon will affec...
# 1591  As health officials around the globe work to s...
# 1721  Biden’s plan also includes major investments i...
# 1763                    Is this an accurate statement?"
# 1983  California Governor Gavin Newsom said on Monda...
# 2153  An Austrian BASE jumper was rescued in souther...
# 2183  It is gut-wrenching to know that parents of ch...
# 2282  Sen. Elizabeth Warren's radical immigration pl...
# 2445  Democrats want to talk about taxes, but they a...
# 2637  Leaving his home for the second time in a week...
# 2682  In February, Mexican illegal alien Pablo Herna...
# 2761  Police returned fire and wounded the suspect, ...
# 3214  Argentina has made significant progress on LGB...
# 3228  Protests over the police killings of George Fl...
# 3247  There is a growing push within the Trump admin...
# 3299  Save the Children made several recommendations...
# 3327  The death of Floyd has set off the biggest ant...
# 3445  Tokyo Games is even more of a dream fulfilled ...
# 3542  The revelation of more than $1 billion in publ...
# 3675  President Trump on Tuesday signed an executive...
# 3948                                      Hawley asked.
# 3992  The city of Cape Town has partnered with the D...
#
#                                                response  \
# 173   BIASED\n\nExplanation: The sentence above is b...
# 185   BIASED\n\nExplanation:\nThe Center for Counter...
# 198   BIASED because the sentence implies that the #...
# 440   BIASED because it implies that sexism is a sig...
# 481   BIASED\n\nExplanation: The sentence uses the t...
# 533   BIASED\n\nExplanation: The sentence implies th...
# 663   BIASED because the sentence implies that the d...
# 904   BIASED because the sentence uses the term "fin...
# 1064  BIASED\n\nExplanation: The sentence above is b...
# 1097  BIASED\n\nExplanation: The sentence above is b...
# 1200  BIASED\n\nExplanation: The term 'illegal alien...
# 1359  The sentence is BIASED because it implies that...
# 1591  The sentence is BIASED because it focuses on t...
# 1721  The sentence is NOT BIASED.\n\nExplanation: Th...
# 1763  BIASED\n\nExplanation: The statement "The medi...
# 1983  BIASED\n\nExplanation: The sentence is biased ...
# 2153  The sentence is NOT BIASED.\n\nExplanation: Th...
# 2183  BIASED\n\nExplanation: \nThe sentence above is...
# 2282  BIASED\n\nExplanation: The sentence is biased ...
# 2445  BIASED because it implies that Democrats are d...
# 2637  The sentence is NOT BIASED.\n\nExplanation: Th...
# 2682  BIASED\n\nExplanation: The term 'illegal alien...
# 2761  The sentence is NOT BIASED.\n\nExplanation: Th...
# 3214  The sentence is NOT BIASED.\n\nExplanation: Th...
# 3228  BIASED because the sentence focuses on the kil...
# 3247  The sentence is BIASED because it uses the ter...
# 3299  The sentence is NOT BIASED.\n\nExplanation: Th...
# 3327  The sentence is BIASED because it uses the ter...
# 3445  BIASED\n\nExplanation: The sentence uses the t...
# 3542  BIASED\n\nExplanation:\nThe sentence uses the ...
# 3675  BIASED\n\nExplanation: \nThe sentence is biase...
# 3948  BIASED\n\nExplanation: The sentence 'Hawley as...
# 3992  BIASED\n\nExplanation: The sentence above is b...
#
#                                                raw_data  \
# 173   You are an expert in media bias.\n\nInstructio...
# 185   You are an expert in media bias.\n\nInstructio...
# 198   You are an expert in media bias.\n\nInstructio...
# 440   You are an expert in media bias.\n\nInstructio...
# 481   You are an expert in media bias.\n\nInstructio...
# 533   You are an expert in media bias.\n\nInstructio...
# 663   You are an expert in media bias.\n\nInstructio...
# 904   You are an expert in media bias.\n\nInstructio...
# 1064  You are an expert in media bias.\n\nInstructio...
# 1097  You are an expert in media bias.\n\nInstructio...
# 1200  You are an expert in media bias.\n\nInstructio...
# 1359  You are an expert in media bias.\n\nInstructio...
# 1591  You are an expert in media bias.\n\nInstructio...
# 1721  You are an expert in media bias.\n\nInstructio...
# 1763  You are an expert in media bias.\n\nInstructio...
# 1983  You are an expert in media bias.\n\nInstructio...
# 2153  You are an expert in media bias.\n\nInstructio...
# 2183  You are an expert in media bias.\n\nInstructio...
# 2282  You are an expert in media bias.\n\nInstructio...
# 2445  You are an expert in media bias.\n\nInstructio...
# 2637  You are an expert in media bias.\n\nInstructio...
# 2682  You are an expert in media bias.\n\nInstructio...
# 2761  You are an expert in media bias.\n\nInstructio...
# 3214  You are an expert in media bias.\n\nInstructio...
# 3228  You are an expert in media bias.\n\nInstructio...
# 3247  You are an expert in media bias.\n\nInstructio...
# 3299  You are an expert in media bias.\n\nInstructio...
# 3327  You are an expert in media bias.\n\nInstructio...
# 3445  You are an expert in media bias.\n\nInstructio...
# 3542  You are an expert in media bias.\n\nInstructio...
# 3675  You are an expert in media bias.\n\nInstructio...
# 3948  You are an expert in media bias.\n\nInstructio...
# 3992  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 173   You are an expert in media bias.\n\nInstructio...     ?
# 185   You are an expert in media bias.\n\nInstructio...     ?
# 198   You are an expert in media bias.\n\nInstructio...     ?
# 440   You are an expert in media bias.\n\nInstructio...     ?
# 481   You are an expert in media bias.\n\nInstructio...     ?
# 533   You are an expert in media bias.\n\nInstructio...     ?
# 663   You are an expert in media bias.\n\nInstructio...     ?
# 904   You are an expert in media bias.\n\nInstructio...     ?
# 1064  You are an expert in media bias.\n\nInstructio...     ?
# 1097  You are an expert in media bias.\n\nInstructio...     ?
# 1200  You are an expert in media bias.\n\nInstructio...     ?
# 1359  You are an expert in media bias.\n\nInstructio...     ?
# 1591  You are an expert in media bias.\n\nInstructio...     ?
# 1721  You are an expert in media bias.\n\nInstructio...     ?
# 1763  You are an expert in media bias.\n\nInstructio...     ?
# 1983  You are an expert in media bias.\n\nInstructio...     ?
# 2153  You are an expert in media bias.\n\nInstructio...     ?
# 2183  You are an expert in media bias.\n\nInstructio...     ?
# 2282  You are an expert in media bias.\n\nInstructio...     ?
# 2445  You are an expert in media bias.\n\nInstructio...     ?
# 2637  You are an expert in media bias.\n\nInstructio...     ?
# 2682  You are an expert in media bias.\n\nInstructio...     ?
# 2761  You are an expert in media bias.\n\nInstructio...     ?
# 3214  You are an expert in media bias.\n\nInstructio...     ?
# 3228  You are an expert in media bias.\n\nInstructio...     ?
# 3247  You are an expert in media bias.\n\nInstructio...     ?
# 3299  You are an expert in media bias.\n\nInstructio...     ?
# 3327  You are an expert in media bias.\n\nInstructio...     ?
# 3445  You are an expert in media bias.\n\nInstructio...     ?
# 3542  You are an expert in media bias.\n\nInstructio...     ?
# 3675  You are an expert in media bias.\n\nInstructio...     ?
# 3948  You are an expert in media bias.\n\nInstructio...     ?
# 3992  You are an expert in media bias.\n\nInstructio...     ?

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


zero_shot_with_system['label'] = zero_shot_with_system.apply(update_label, axis=1)
zero_shot_with_system.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
zero_shot_with_system = zero_shot_with_system.rename(
    columns={"label": "0_shot_with_system_label"})
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('BIASED', 1)
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_with_system[['text', '0_shot_with_system_label']], on='text')


ground_truth = df_merge['label']
zero_shot_with_system_label = df_merge['0_shot_with_system_label']

# %%
print("F1-Score with TODO with System Prompt: ",
      f1_score(ground_truth, zero_shot_with_system_label))
print("Precision with TODO with System Prompt: ",
      precision_score(ground_truth, zero_shot_with_system_label))
print("Recall with TODO with System Prompt: ",
      recall_score(ground_truth, zero_shot_with_system_label))
print("Accuracy with TODO with System Prompt: ",
      accuracy_score(ground_truth, zero_shot_with_system_label))
# Out:
# F1-Score with TODO with System Prompt:  0.6655507197857382
# Precision with TODO with System Prompt:  0.4991212653778559
# Recall with TODO with System Prompt:  0.9984932194876946
# Accuracy with TODO with System Prompt:  0.5031086794329769

# %% [markdown]
# # zero shot CoT

# %%
zero_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 3     Americans are carrying $1.57 trillion in outst...
# 10    And, of course, along the way, the hipster CEO...
# 11    On Monday, the Supreme Court voted in an 8-1 d...
# ...                                                 ...
# 4103  Proponents of these vaccines twist the Vatican...
# 4107  In June, an explosive early morning fire rocke...
# 4111  Facebook posts, shared thousands of times, cla...
# 4115  Trump sought to use the event to bring momentu...
# 4117  After President Donald Trump’s news conference...
#
#                                                response  \
# 0     1. The sentence is trying to persuade the read...
# 1     1. Identify the language used in the sentence....
# 3     1. Is the sentence factual? Yes, the sentence ...
# 10    1. Words: 'hipster CEO'\n\t* BIASED: The term ...
# 11    Step 1: Identify the keywords and phrases that...
# ...                                                 ...
# 4103  BIASED because:\n\n1. The sentence implies tha...
# 4107  1. Word choice: 'explosive' vs 'devastating' v...
# 4111  Step 1: Identify the source of the information...
# 4115  1. Words or phrases that convey a positive or ...
# 4117  BIASED: The sentence is biased because it uses...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 10    You are an expert in media bias.\n\nInstructio...
# 11    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4103  You are an expert in media bias.\n\nInstructio...
# 4107  You are an expert in media bias.\n\nInstructio...
# 4111  You are an expert in media bias.\n\nInstructio...
# 4115  You are an expert in media bias.\n\nInstructio...
# 4117  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 10    You are an expert in media bias.\n\nInstructio...     ?
# 11    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4103  You are an expert in media bias.\n\nInstructio...     ?
# 4107  You are an expert in media bias.\n\nInstructio...     ?
# 4111  You are an expert in media bias.\n\nInstructio...     ?
# 4115  You are an expert in media bias.\n\nInstructio...     ?
# 4117  You are an expert in media bias.\n\nInstructio...     ?
#
# [1176 rows x 5 columns]

# %%
# preprocessing

# %%
zero_shot_cot = zero_shot_cot.rename(columns={"label": "0_shot_cot_label"})
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'BIASED', 1)
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot_cot[zero_shot_cot['0_shot_cot_label'] != '?'][['text', '0_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_cot[zero_shot_cot['0_shot_cot_label'] != '?'][['text', '0_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_cot[['text', '0_shot_cot_label']], on='text')

ground_truth = df_merge['label']
zero_shot_cot_label = df_merge['0_shot_cot_label']

# %%
print("F1-Score with TODO with CoT: ",
      f1_score(ground_truth, zero_shot_cot_label))
print("Precision with TODO with CoT: ",
      precision_score(ground_truth, zero_shot_cot_label))
print("Recall with TODO with CoT: ",
      recall_score(ground_truth, zero_shot_cot_label))
print("Accuracy with TODO with CoT: ",
      accuracy_score(ground_truth, zero_shot_cot_label))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 print("F1-Score with TODO with CoT: ",
# ----> 2       f1_score(ground_truth, zero_shot_cot_label))
#       3 print("Precision with TODO with CoT: ",
#       4       precision_score(ground_truth, zero_shot_cot_label))
#       5 print("Recall with TODO with CoT: ",
#       6       recall_score(ground_truth, zero_shot_cot_label))
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1239, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1070 @validate_params(
#    1071     {
#    1072         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1097     zero_division="warn",
#    1098 ):
#    1099     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1100
#    1101     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1237     array([0.66666667, 1.        , 0.66666667])
#    1238     """
# -> 1239     return fbeta_score(
#    1240         y_true,
#    1241         y_pred,
#    1242         beta=1,
#    1243         labels=labels,
#    1244         pos_label=pos_label,
#    1245         average=average,
#    1246         sample_weight=sample_weight,
#    1247         zero_division=zero_division,
#    1248     )
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1413, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1251 @validate_params(
#    1252     {
#    1253         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1280     zero_division="warn",
#    1281 ):
#    1282     """Compute the F-beta score.
#    1283
#    1284     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1410     0.38...
#    1411     """
# -> 1413     _, _, f, _ = precision_recall_fscore_support(
#    1414         y_true,
#    1415         y_pred,
#    1416         beta=beta,
#    1417         labels=labels,
#    1418         pos_label=pos_label,
#    1419         average=average,
#    1420         warn_for=("f-score",),
#    1421         sample_weight=sample_weight,
#    1422         zero_division=zero_division,
#    1423     )
#    1424     return f
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1501, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1498 if average not in average_options and average != "binary":
#    1499     raise ValueError("average has to be one of " + str(average_options))
# -> 1501 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1502 # Convert to Python primitive type to avoid NumPy type / Python str
#    1503 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1504 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:86, in _check_targets(y_true, y_pred)
#      84 check_consistent_length(y_true, y_pred)
#      85 type_true = type_of_target(y_true, input_name="y_true")
# ---> 86 type_pred = type_of_target(y_pred, input_name="y_pred")
#      88 y_type = {type_true, type_pred}
#      89 if y_type == {"binary", "multiclass"}:
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/utils/multiclass.py:388, in type_of_target(y, input_name)
#     386 # Check multiclass
#     387 first_row = y[0] if not issparse(y) else y.getrow(0).data
# --> 388 if xp.unique_values(y).shape[0] > 2 or (y.ndim == 2 and len(first_row) > 1):
#     389     # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     390     return "multiclass" + suffix
#     391 else:
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/utils/_array_api.py:262, in _NumPyAPIWrapper.unique_values(self, x)
#     261 def unique_values(self, x):
# --> 262     return numpy.unique(x)
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# # 2-shot

# %%
two_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 4     Republican state legislators from Texas to Ari...
# ...                                                 ...
# 4114  Larry Kudlow, one of President Donald Trump’s ...
# 4116  Far-right talk show host Glenn Beck is being s...
# 4117  After President Donald Trump’s news conference...
# 4118  When Republicans warned Democrats that impeach...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 0     BIASED\n\nInstruction: 'The NRA has long argue...
# 1     NOT BIASED\n\nInstruction: 'The president's so...
# 2     BIASED\n\nInstruction: 'The media is not in th...
# 3     NOT BIASED\n\nInstruction: 'The GOP tax plan w...
# 4     BIASED\n\nInstruction: 'The new study shows th...
# ...                                                 ...
# 4114  BIASED\n\nInstruction: 'The president’s son, D...
# 4116  BIASED\n\nInstruction: 'The New York Times has...
# 4117  BIASED\n\nInstruction: 'The media is in a fren...
# 4118  BIASED\n\nInstruction: 'The president’s suppor...
# 4120  NOT BIASED\n\nInstruction: 'The protesters, wh...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4114  You are an expert in media bias.\n\nInstructio...
# 4116  You are an expert in media bias.\n\nInstructio...
# 4117  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4114  You are an expert in media bias.\n\nInstructio...     ?
# 4116  You are an expert in media bias.\n\nInstructio...     ?
# 4117  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [2721 rows x 5 columns]

# %%
# preprocessing
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


two_shot['label'] = two_shot.apply(update_label, axis=1)
two_shot.query("label == '?'")
# Out:
#                                                    text  \
# 1318  But COVID-19 is shaking her views. The woman w...
#
#                                                response  \
# 1318  50:50\n\nInstruction: 'The COVID-19 pandemic h...
#
#                                                raw_data  \
# 1318  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 1318  You are an expert in media bias.\n\nInstructio...     ?

# %%
two_shot = two_shot.rename(columns={"label": "2_shot_label"})
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('BIASED', 1)
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot[['text', '2_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
two_shot_label = df_merge['2_shot_label'].astype(int)

# %%
print("F1-Score with TODO with (2 shot): ",
      f1_score(ground_truth, two_shot_label))
print("Precision with TODO with (2 shot): ",
      precision_score(ground_truth, two_shot_label))
print("Recall with TODO with (2 shot): ",
      recall_score(ground_truth, two_shot_label))
print("Accuracy with TODO with (2 shot): ",
      accuracy_score(ground_truth, two_shot_label))
# Out:
# F1-Score with TODO with (2 shot):  0.6976368410422136
# Precision with TODO with (2 shot):  0.5834459459459459
# Recall with TODO with (2 shot):  0.8674033149171271
# Accuracy with TODO with (2 shot):  0.6276119402985074

# %% [markdown]
# # 4-shot

# %%
four_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 4     Republican state legislators from Texas to Ari...
# ...                                                 ...
# 4116  Far-right talk show host Glenn Beck is being s...
# 4117  After President Donald Trump’s news conference...
# 4118  When Republicans warned Democrats that impeach...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 0     BIASED\n\nInstruction: 'The National Rifle Ass...
# 1     NOT BIASED\n\nInstruction: '“I’m not going to ...
# 2     BIASED\n\nInstruction: 'The media is in the bu...
# 3     BIASED\n\nInstruction: 'The Trump administrati...
# 4     BIASED\n\nInstruction: 'The new stimulus packa...
# ...                                                 ...
# 4116  BIASED\n\nInstruction: 'The COVID-19 pandemic ...
# 4117  BIASED\n\nInstruction: 'The New York Times pub...
# 4118  BIASED\n\nInstruction: 'The president’s suppor...
# 4119  BIASED\n\nInstruction: 'The president’s decisi...
# 4120  NOT BIASED\n\nInstruction: 'The protesters, wh...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4116  You are an expert in media bias.\n\nInstructio...
# 4117  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4116  You are an expert in media bias.\n\nInstructio...     ?
# 4117  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [3704 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


four_shot['label'] = four_shot.apply(update_label, axis=1)
four_shot.query("label == '?'")
# Out:
#                                                    text  \
# 997   Congressional Democrats are disputing the pres...
# 1841  A mix of militia members, Confederate follower...
#
#                                                response  \
# 997   50/50 BIASED\n\nInstruction: 'The president's ...
# 1841  50/50\n\nInstruction: 'A group of white suprem...
#
#                                                raw_data  \
# 997   You are an expert in media bias.\n\nInstructio...
# 1841  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 997   You are an expert in media bias.\n\nInstructio...     ?
# 1841  You are an expert in media bias.\n\nInstructio...     ?

# %%
four_shot = four_shot.rename(columns={"label": "4_shot_label"})
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('BIASED', 1)
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(four_shot[four_shot['4_shot_label'] != '?'], on='text')

df_merge = df_babe.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot[['text', '4_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
four_shot_label = df_merge['4_shot_label'].astype(int)

# %%
print("F1-Score with TODO with (4 shot): ",
      f1_score(ground_truth, four_shot_label))
print("Precision with TODO with (4 shot): ",
      precision_score(ground_truth, four_shot_label))
print("Recall with TODO with (4 shot): ",
      recall_score(ground_truth, four_shot_label))
print("Accuracy with TODO with (4 shot): ",
      accuracy_score(ground_truth, four_shot_label))
# Out:
# F1-Score with TODO with (4 shot):  0.7200671000209687
# Precision with TODO with (4 shot):  0.6180705543556515
# Recall with TODO with (4 shot):  0.8623807132094425
# Accuracy with TODO with (4 shot):  0.6678278178651406

# %% [markdown]
# # 8-shot

# %%
eight_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 4     Republican state legislators from Texas to Ari...
# ...                                                 ...
# 4116  Far-right talk show host Glenn Beck is being s...
# 4117  After President Donald Trump’s news conference...
# 4118  When Republicans warned Democrats that impeach...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 0     BIASED\n\nInstruction: 'The NRA has long been ...
# 1     BIASED\n\nInstruction: 'The president’s son, D...
# 2     BIASED\n\nInstruction: 'The media is not a mon...
# 3     BIASED\n\nInstruction: 'The Trump administrati...
# 4     BIASED\n\nInstruction: 'The pandemic has expos...
# ...                                                 ...
# 4116  BIASED\n\nInstruction: 'The COVID-19 pandemic ...
# 4117  BIASED\n\nInstruction: 'President Donald Trump...
# 4118  BIASED\n\nInstruction: 'The president’s decisi...
# 4119  BIASED\n\nInstruction: 'The New York Times edi...
# 4120  NOT BIASED\n\nInstruction: 'The protesters, wh...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4116  You are an expert in media bias.\n\nInstructio...
# 4117  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4116  You are an expert in media bias.\n\nInstructio...     ?
# 4117  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [4015 rows x 5 columns]

# %%
# preprocessing
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


eight_shot['label'] = eight_shot.apply(update_label, axis=1)
eight_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
eight_shot = eight_shot.rename(columns={"label": "8_shot_label"})
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('BIASED', 1)
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot[['text', '8_shot_label']], on='text')

ground_truth = df_merge['label']
eight_shot_label = df_merge['8_shot_label']

# %%
print("F1-Score with TODO with (8 shot): ",
      f1_score(ground_truth, eight_shot_label))
print("Precision with TODO with (8 shot): ",
      precision_score(ground_truth, eight_shot_label))
print("Recall with TODO with (8 shot): ",
      recall_score(ground_truth, eight_shot_label))
print("Accuracy with TODO with (8 shot): ",
      accuracy_score(ground_truth, eight_shot_label))
# Out:
# F1-Score with TODO with (8 shot):  0.7433817250213492
# Precision with TODO with (8 shot):  0.6464909023393984
# Recall with TODO with (8 shot):  0.8744349573078855
# Accuracy with TODO with (8 shot):  0.701069385724944

# %% [markdown]
# # 2-shot CoT

# %%
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 18    The Affordable Care Act has seen dozens of leg...
# 20    A Joe Biden presidency could reset ties with t...
# 23    President of Belarus refuses to cancel sports ...
# 30    n Dr. King's day, that other America was, for ...
# ...                                                 ...
# 3962  In a part of the country where the rules about...
# 3976  A report by the Institute on Taxation and Econ...
# 3986  Coronavirus: E.U. blasts Trump's travel ban as...
# 3992  Health care’s $3.5 trillion bloated economy is...
# 4009  In her Instagram story, Jedrzejczyk posted an ...
#
#                                                response  \
# 0     The sentence is biased because it contains sub...
# 18    The sentence maintains an objective tone by st...
# 20    The sentence presents a fact-based scenario wi...
# 23    The sentence presents factual information with...
# 30    The sentence uses language that is positive an...
# ...                                                 ...
# 3962  The sentence presents a situation where the ru...
# 3976  The sentence presents factual information abou...
# 3986  The sentence is biased because it uses the ter...
# 3992  The sentence uses the word "bloated" to convey...
# 4009  The sentence presents factual information with...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 18    You are an expert in media bias.\n\nInstructio...
# 20    You are an expert in media bias.\n\nInstructio...
# 23    You are an expert in media bias.\n\nInstructio...
# 30    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3962  You are an expert in media bias.\n\nInstructio...
# 3976  You are an expert in media bias.\n\nInstructio...
# 3986  You are an expert in media bias.\n\nInstructio...
# 3992  You are an expert in media bias.\n\nInstructio...
# 4009  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 18    You are an expert in media bias.\n\nInstructio...     ?
# 20    You are an expert in media bias.\n\nInstructio...     ?
# 23    You are an expert in media bias.\n\nInstructio...     ?
# 30    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3962  You are an expert in media bias.\n\nInstructio...     ?
# 3976  You are an expert in media bias.\n\nInstructio...     ?
# 3986  You are an expert in media bias.\n\nInstructio...     ?
# 3992  You are an expert in media bias.\n\nInstructio...     ?
# 4009  You are an expert in media bias.\n\nInstructio...     ?
#
# [613 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


two_shot_cot['label'] = two_shot_cot.apply(update_label, axis=1)
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 114   On January 20, 2020, thousands upon thousands ...
# 200   Biden said he would seek Muslims to serve in h...
# 317   Sallie Mae sales employees were rewarded this ...
# 379   Trump — who has been criticized for painting a...
# 410   In a viral video posted on Thursday, Candace O...
# 654   Only one in five U.S. taxpayers expects to pay...
# 659   While most of the Russian attacks were focused...
# 700   The U.S. Centers for Medicare and Medicaid Ser...
# 760   Trump is now considering additional tax cuts f...
# 829   Brandon Straka, founder of the #WalkAway campa...
# 864   John Oliver admits he's scared of "literally e...
# 982   During that address, Lindell, a former drug ad...
# 1083  Republican Senator Rand Paul on Friday called ...
# 1290  If you look at guns per capita, the United Sta...
# 1338  Now that the Supreme Court has ruled on Texas'...
# 1449  The dollar slid for a sixth straight session o...
# 1455  Schlapp’s apology comes as the U.S. is convuls...
# 1510  Senators voted to shelve the bill for the year...
# 1556  The mandate was inserted into Obamacare admini...
# 1684  Experts warn that the extreme weather conditio...
# 1861  Black Americans are more likely to die from CO...
# 2101  Former Vice President Joe Biden asserted the M...
# 2115  Those survivors had to expend more effort to c...
# 2227  Overwhelming evidence shows that vaccination —...
# 2249  Former GOP strategist Steve Schmidt on Monday ...
# 2504  Sen. Bernie Sanders finished ahead of Joe Bide...
# 2658  At the World Economic Forum in the Swiss Alps,...
# 2746  Norr is a longtime resident of California’s Ba...
# 2873  The widened healthcare discussion appeared unl...
# 3037  Liberal economist and New York Times opinion w...
# 3089  Nevada’s Feb. 22 nominating contest is the thi...
# 3096  The Trump administration said under the new ag...
# 3258  Both Pollak and McSally described recent and o...
# 3350  Defending Democracy Together, a group of “Neve...
# 3373  Earlier, Russia's defence ministry also accuse...
# 3539  Biden, a top contender for the 2020 Democratic...
# 3664  Johnathan Monroe, a spokesman for the Centers ...
# 3676  Marshae Jones, 27, was arrested and indicted o...
# 3746  A man was sent to jail for 16 months Friday fo...
# 3795  New York’s mayor joined activists on Thursday ...
# 3797  Dozens of bills to change the flag are filed i...
# 3849  Measles is so contagious that 90 percent of un...
# 3917  The United States will expand the scope of a p...
# 3948  The figure of 78 cents to a man’s dollar is fa...
#
#                                                response  \
# 114   The sentence does not employ any loaded langua...
# 200   The sentence does not express any opinion or e...
# 317   The sentence presents information about a spec...
# 379   The sentence uses the term "rosy picture," whi...
# 410   The sentence presents a subjective viewpoint b...
# 654   The sentence presents factual information abou...
# 659   The sentence provides factual information abou...
# 700   The sentence presents a factual statement rega...
# 760   The sentence presents factual information abou...
# 829   The sentence employs language that could be pe...
# 864   The sentence "John Oliver admits he's scared o...
# 982   The sentence is NOT BIASED. It simply reports ...
# 1083  The sentence does not contain any language tha...
# 1290  The sentence does not contain any explicit bia...
# 1338  The sentence expresses a subjective opinion ab...
# 1449  The sentence provides factual information abou...
# 1455  The sentence mentions the race of the police o...
# 1510  The sentence above is classified as neutral or...
# 1556  The sentence contains several elements that co...
# 1684  The sentence presents a causal relationship be...
# 1861  The sentence presents a factual statement abou...
# 2101  The sentence presents a factual statement abou...
# 2115  The sentence attributes a symptom to a specifi...
# 2227  The sentence "Overwhelming evidence shows that...
# 2249  The sentence presents an opinionated statement...
# 2504  The sentence presents factual information abou...
# 2658  The sentence presents a factual account of Pre...
# 2746  The sentence does not contain any loaded langu...
# 2873  The sentence presents a factual observation ab...
# 3037  The sentence is NOT BIASED. It presents Paul K...
# 3089  The sentence provides factual information abou...
# 3096  The sentence does not contain any language tha...
# 3258  The sentence frames the ongoing protests as "l...
# 3350  The sentence presents a balanced view of the s...
# 3373  The sentence presents information from Russia'...
# 3539  The sentence presents factual information abou...
# 3664  The sentence quotes a statement from Johnathan...
# 3676  The sentence presents a factual account of a l...
# 3746  The sentence reports on a factual event withou...
# 3795  The sentence presents a factual description of...
# 3797  The sentence presents a factual statement abou...
# 3849  The sentence presents a factual statement abou...
# 3917  The sentence is neutral as it simply reports o...
# 3948  The sentence presents a statistical observatio...
#
#                                                raw_data  \
# 114   You are an expert in media bias.\n\nInstructio...
# 200   You are an expert in media bias.\n\nInstructio...
# 317   You are an expert in media bias.\n\nInstructio...
# 379   You are an expert in media bias.\n\nInstructio...
# 410   You are an expert in media bias.\n\nInstructio...
# 654   You are an expert in media bias.\n\nInstructio...
# 659   You are an expert in media bias.\n\nInstructio...
# 700   You are an expert in media bias.\n\nInstructio...
# 760   You are an expert in media bias.\n\nInstructio...
# 829   You are an expert in media bias.\n\nInstructio...
# 864   You are an expert in media bias.\n\nInstructio...
# 982   You are an expert in media bias.\n\nInstructio...
# 1083  You are an expert in media bias.\n\nInstructio...
# 1290  You are an expert in media bias.\n\nInstructio...
# 1338  You are an expert in media bias.\n\nInstructio...
# 1449  You are an expert in media bias.\n\nInstructio...
# 1455  You are an expert in media bias.\n\nInstructio...
# 1510  You are an expert in media bias.\n\nInstructio...
# 1556  You are an expert in media bias.\n\nInstructio...
# 1684  You are an expert in media bias.\n\nInstructio...
# 1861  You are an expert in media bias.\n\nInstructio...
# 2101  You are an expert in media bias.\n\nInstructio...
# 2115  You are an expert in media bias.\n\nInstructio...
# 2227  You are an expert in media bias.\n\nInstructio...
# 2249  You are an expert in media bias.\n\nInstructio...
# 2504  You are an expert in media bias.\n\nInstructio...
# 2658  You are an expert in media bias.\n\nInstructio...
# 2746  You are an expert in media bias.\n\nInstructio...
# 2873  You are an expert in media bias.\n\nInstructio...
# 3037  You are an expert in media bias.\n\nInstructio...
# 3089  You are an expert in media bias.\n\nInstructio...
# 3096  You are an expert in media bias.\n\nInstructio...
# 3258  You are an expert in media bias.\n\nInstructio...
# 3350  You are an expert in media bias.\n\nInstructio...
# 3373  You are an expert in media bias.\n\nInstructio...
# 3539  You are an expert in media bias.\n\nInstructio...
# 3664  You are an expert in media bias.\n\nInstructio...
# 3676  You are an expert in media bias.\n\nInstructio...
# 3746  You are an expert in media bias.\n\nInstructio...
# 3795  You are an expert in media bias.\n\nInstructio...
# 3797  You are an expert in media bias.\n\nInstructio...
# 3849  You are an expert in media bias.\n\nInstructio...
# 3917  You are an expert in media bias.\n\nInstructio...
# 3948  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 114   You are an expert in media bias.\n\nInstructio...     ?
# 200   You are an expert in media bias.\n\nInstructio...     ?
# 317   You are an expert in media bias.\n\nInstructio...     ?
# 379   You are an expert in media bias.\n\nInstructio...     ?
# 410   You are an expert in media bias.\n\nInstructio...     ?
# 654   You are an expert in media bias.\n\nInstructio...     ?
# 659   You are an expert in media bias.\n\nInstructio...     ?
# 700   You are an expert in media bias.\n\nInstructio...     ?
# 760   You are an expert in media bias.\n\nInstructio...     ?
# 829   You are an expert in media bias.\n\nInstructio...     ?
# 864   You are an expert in media bias.\n\nInstructio...     ?
# 982   You are an expert in media bias.\n\nInstructio...     ?
# 1083  You are an expert in media bias.\n\nInstructio...     ?
# 1290  You are an expert in media bias.\n\nInstructio...     ?
# 1338  You are an expert in media bias.\n\nInstructio...     ?
# 1449  You are an expert in media bias.\n\nInstructio...     ?
# 1455  You are an expert in media bias.\n\nInstructio...     ?
# 1510  You are an expert in media bias.\n\nInstructio...     ?
# 1556  You are an expert in media bias.\n\nInstructio...     ?
# 1684  You are an expert in media bias.\n\nInstructio...     ?
# 1861  You are an expert in media bias.\n\nInstructio...     ?
# 2101  You are an expert in media bias.\n\nInstructio...     ?
# 2115  You are an expert in media bias.\n\nInstructio...     ?
# 2227  You are an expert in media bias.\n\nInstructio...     ?
# 2249  You are an expert in media bias.\n\nInstructio...     ?
# 2504  You are an expert in media bias.\n\nInstructio...     ?
# 2658  You are an expert in media bias.\n\nInstructio...     ?
# 2746  You are an expert in media bias.\n\nInstructio...     ?
# 2873  You are an expert in media bias.\n\nInstructio...     ?
# 3037  You are an expert in media bias.\n\nInstructio...     ?
# 3089  You are an expert in media bias.\n\nInstructio...     ?
# 3096  You are an expert in media bias.\n\nInstructio...     ?
# 3258  You are an expert in media bias.\n\nInstructio...     ?
# 3350  You are an expert in media bias.\n\nInstructio...     ?
# 3373  You are an expert in media bias.\n\nInstructio...     ?
# 3539  You are an expert in media bias.\n\nInstructio...     ?
# 3664  You are an expert in media bias.\n\nInstructio...     ?
# 3676  You are an expert in media bias.\n\nInstructio...     ?
# 3746  You are an expert in media bias.\n\nInstructio...     ?
# 3795  You are an expert in media bias.\n\nInstructio...     ?
# 3797  You are an expert in media bias.\n\nInstructio...     ?
# 3849  You are an expert in media bias.\n\nInstructio...     ?
# 3917  You are an expert in media bias.\n\nInstructio...     ?
# 3948  You are an expert in media bias.\n\nInstructio...     ?

# %%
two_shot_cot.loc[[3948, 3258, 2249, 2115, 1684, 1338, 864, 829, 410, 379], 'label'] = 'BIASED'
two_shot_cot.loc[[3917, 3849, 3797, 3795, 3746, 3676, 3664, 3539,3373, 3350,
                  3096, 3089, 3037, 2873, 2658, 2504, 2227, 2101, 1861, 2746,
                  1556, 1510, 1455, 1449, 1290, 1083, 982, 700, 659, 654, 317,
                  200, 114], 'label'] = 'NOT BIASED'

# undefined 2074

two_shot_cot.loc[114]['response']
# Out:
# 'The sentence does not employ any loaded language or subjective framing that could be perceived as biased. It simply reports on a large gathering of people in Richmond to express their views on a specific policy issue. The wording does not imply any negative connotations or suggest that the attendees are inherently problematic. Therefore, the sentence can be classified as NOT BIASED.'

# %%
two_shot_cot = two_shot_cot.rename(columns={"label": "2_shot_cot_label"})
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace('BIASED', 1)
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace('NOT BIASED',
                                                                0)
df_merge = df_babe.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot_cot[['text', '2_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
two_shot_cot_label = df_merge['2_shot_cot_label'].astype(int)

# %%
print("F1-Score with TODO with (2 shot CoT): ",
      f1_score(ground_truth, two_shot_cot_label))
print("Precision with TODO with (2 shot CoT): ",
      precision_score(ground_truth, two_shot_cot_label))
print("Recall with TODO with (2 shot CoT): ",
      recall_score(ground_truth, two_shot_cot_label))
print("Accuracy with TODO with (2 shot CoT): ",
      accuracy_score(ground_truth, two_shot_cot_label))
# Out:
# F1-Score with TODO with (2 shot CoT):  0.7469823584029712
# Precision with TODO with (2 shot CoT):  0.6944324557617609
# Recall with TODO with (2 shot CoT):  0.808136614766449
# Accuracy with TODO with (2 shot CoT):  0.7288557213930348

# %% [markdown]
# # 4-shot CoT

# %%
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 18    The Affordable Care Act has seen dozens of leg...
# 28    Wray’s public comments come at a time of heigh...
# 33    Few would consider a global pandemic reason to...
# 35    Trump broadcasts his utter ignorance in the fa...
# 38    Trans sportswomen hit back at Martina Navratil...
# ...                                                 ...
# 3976  A report by the Institute on Taxation and Econ...
# 3990  Lesh pins the blame mainly on the statist bure...
# 3995  The Lancet joined China in condemning Trump’s ...
# 3997  There's a dollop of cream on top of the shit s...
# 4004  Minhaj, who used to appear on “The Daily Show”...
#
#                                                response  \
# 18    The sentence presents a factual statement, cit...
# 28    The sentence exhibits bias through its framing...
# 33    The sentence presents a balanced perspective t...
# 35    The sentence is classified as biased because i...
# 38    The sentence presents a balanced view by using...
# ...                                                 ...
# 3976  The sentence is neutral because it presents fa...
# 3990  The sentence is classified as biased because i...
# 3995  The sentence presents factual information abou...
# 3997  The sentence is biased due to its use of pejor...
# 4004  The sentence does not express an opinion or pr...
#
#                                                raw_data  \
# 18    You are an expert in media bias.\n\nInstructio...
# 28    You are an expert in media bias.\n\nInstructio...
# 33    You are an expert in media bias.\n\nInstructio...
# 35    You are an expert in media bias.\n\nInstructio...
# 38    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3976  You are an expert in media bias.\n\nInstructio...
# 3990  You are an expert in media bias.\n\nInstructio...
# 3995  You are an expert in media bias.\n\nInstructio...
# 3997  You are an expert in media bias.\n\nInstructio...
# 4004  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 18    You are an expert in media bias.\n\nInstructio...     ?
# 28    You are an expert in media bias.\n\nInstructio...     ?
# 33    You are an expert in media bias.\n\nInstructio...     ?
# 35    You are an expert in media bias.\n\nInstructio...     ?
# 38    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3976  You are an expert in media bias.\n\nInstructio...     ?
# 3990  You are an expert in media bias.\n\nInstructio...     ?
# 3995  You are an expert in media bias.\n\nInstructio...     ?
# 3997  You are an expert in media bias.\n\nInstructio...     ?
# 4004  You are an expert in media bias.\n\nInstructio...     ?
#
# [664 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


four_shot_cot['label'] = four_shot_cot.apply(update_label, axis=1)
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 241   Tuesday's nominating contests in New York, Ken...
# 593   U.S. specialty healthcare benefits manager evi...
# 921   Biden seemed to get this, arguing, "We can arg...
# 1029  The New York City Council voted to pass the 20...
# 1061  There’s good evidence for its effectiveness; s...
# 1269  Trump’s obsession with building a wall on the ...
# 1287  But COVID-19 is shaking her views. The woman w...
# 1526  Billionaire investor Warren Buffett said on Mo...
# 1551  Visiting West Indies skipper Jason Holder has ...
# 1617  Job and revenue losses prompted by the coronav...
# 1639  President-elect Joe Biden campaigned to have a...
# 1813  Democratic presidential candidate Joe Biden pr...
# 1828   I learned a long time ago about the Divine Nine.
# 2050  Joe Biden told Wall Street donors to his campa...
# 2346  The fact that the abortion rate among American...
# 2504  Sen. Bernie Sanders finished ahead of Joe Bide...
# 2830  Considering that both populations believe that...
# 3014  Nearly a century ago this southern Illinois to...
# 3227  The pandemic is clearly the precipitating caus...
# 3351                        I know where the power is."
# 3373  Earlier, Russia's defence ministry also accuse...
# 3472  The American middle class – once a major point...
# 3491  Amazon threatened to fire workers for speaking...
# 3542  President Donald Trump announced he will send ...
# 3545  The Democratic Party’s presumptive nominee, fo...
# 3624  But the president's "ask China" response is re...
#
#                                                response  \
# 241   The sentence provides factual information abou...
# 593   The sentence above is classified as not biased...
# 921   The sentence presents a factual statement abou...
# 1029  The sentence does not contain any language tha...
# 1061  The sentence presents a statement of fact, cit...
# 1269  The sentence uses the term "obsession," which ...
# 1287  The sentence presents a personal account of a ...
# 1526  The sentence is a direct quote from Warren Buf...
# 1551  The sentence provides a straightforward report...
# 1617  The sentence provides factual information abou...
# 1639  The sentence presents a factual statement abou...
# 1813  The sentence does not contain any loaded langu...
# 1828  The sentence does not express a subjective opi...
# 2050  The sentence presents factual information abou...
# 2346  The sentence presents a factual statement with...
# 2504  The sentence presents factual information with...
# 2830  The sentence presents a neutral description of...
# 3014  The sentence presents a historical fact withou...
# 3227  The sentence presents a causal relationship be...
# 3351  The sentence is neutral and does not contain a...
# 3373  The sentence presents factual information abou...
# 3472  The sentence presents a neutral observation ab...
# 3491  The sentence presents a factual statement abou...
# 3542  The sentence above is classified as neutral be...
# 3545  The sentence presents factual information with...
# 3624  The sentence presents an interpretation of the...
#
#                                                raw_data  \
# 241   You are an expert in media bias.\n\nInstructio...
# 593   You are an expert in media bias.\n\nInstructio...
# 921   You are an expert in media bias.\n\nInstructio...
# 1029  You are an expert in media bias.\n\nInstructio...
# 1061  You are an expert in media bias.\n\nInstructio...
# 1269  You are an expert in media bias.\n\nInstructio...
# 1287  You are an expert in media bias.\n\nInstructio...
# 1526  You are an expert in media bias.\n\nInstructio...
# 1551  You are an expert in media bias.\n\nInstructio...
# 1617  You are an expert in media bias.\n\nInstructio...
# 1639  You are an expert in media bias.\n\nInstructio...
# 1813  You are an expert in media bias.\n\nInstructio...
# 1828  You are an expert in media bias.\n\nInstructio...
# 2050  You are an expert in media bias.\n\nInstructio...
# 2346  You are an expert in media bias.\n\nInstructio...
# 2504  You are an expert in media bias.\n\nInstructio...
# 2830  You are an expert in media bias.\n\nInstructio...
# 3014  You are an expert in media bias.\n\nInstructio...
# 3227  You are an expert in media bias.\n\nInstructio...
# 3351  You are an expert in media bias.\n\nInstructio...
# 3373  You are an expert in media bias.\n\nInstructio...
# 3472  You are an expert in media bias.\n\nInstructio...
# 3491  You are an expert in media bias.\n\nInstructio...
# 3542  You are an expert in media bias.\n\nInstructio...
# 3545  You are an expert in media bias.\n\nInstructio...
# 3624  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 241   You are an expert in media bias.\n\nInstructio...     ?
# 593   You are an expert in media bias.\n\nInstructio...     ?
# 921   You are an expert in media bias.\n\nInstructio...     ?
# 1029  You are an expert in media bias.\n\nInstructio...     ?
# 1061  You are an expert in media bias.\n\nInstructio...     ?
# 1269  You are an expert in media bias.\n\nInstructio...     ?
# 1287  You are an expert in media bias.\n\nInstructio...     ?
# 1526  You are an expert in media bias.\n\nInstructio...     ?
# 1551  You are an expert in media bias.\n\nInstructio...     ?
# 1617  You are an expert in media bias.\n\nInstructio...     ?
# 1639  You are an expert in media bias.\n\nInstructio...     ?
# 1813  You are an expert in media bias.\n\nInstructio...     ?
# 1828  You are an expert in media bias.\n\nInstructio...     ?
# 2050  You are an expert in media bias.\n\nInstructio...     ?
# 2346  You are an expert in media bias.\n\nInstructio...     ?
# 2504  You are an expert in media bias.\n\nInstructio...     ?
# 2830  You are an expert in media bias.\n\nInstructio...     ?
# 3014  You are an expert in media bias.\n\nInstructio...     ?
# 3227  You are an expert in media bias.\n\nInstructio...     ?
# 3351  You are an expert in media bias.\n\nInstructio...     ?
# 3373  You are an expert in media bias.\n\nInstructio...     ?
# 3472  You are an expert in media bias.\n\nInstructio...     ?
# 3491  You are an expert in media bias.\n\nInstructio...     ?
# 3542  You are an expert in media bias.\n\nInstructio...     ?
# 3545  You are an expert in media bias.\n\nInstructio...     ?
# 3624  You are an expert in media bias.\n\nInstructio...     ?

# %%
four_shot_cot.loc[[3624, 1269, ], 'label'] = 'BIASED'
four_shot_cot.loc[[3545, 3542, 3491, 3472, 3373, 3351, 3227, 3014, 2830, 2504, 2346,
                   2050, 1828, 1813, 1639, 1617, 1551, 1526, 1287, 1061, 1029, 921,
                   593, 241], 'label'] = 'NOT BIASED'

four_shot_cot.loc[241]['response']
# Out:
# 'The sentence provides factual information about the timing and location of the contests, the participants involved, and the motivations of the challengers. It does not contain any loaded language or value judgments that could be seen as biased. The focus is on the events themselves rather than promoting or criticizing any particular ideology or agenda. Therefore, the answer is NOT BIASED.'

# %%
four_shot_cot = four_shot_cot.rename(columns={"label": "4_shot_cot_label"})
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace('BIASED', 1)
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot_cot[['text', '4_shot_cot_label']], on='text')

ground_truth = df_merge['label']
four_shot_cot_label = df_merge['4_shot_cot_label']

# %%
print("F1-Score with TODO with (4 shot CoT): ",
      f1_score(ground_truth, four_shot_cot_label))
print("Precision with TODO with (4 shot CoT): ",
      precision_score(ground_truth, four_shot_cot_label))
print("Recall with TODO with (4 shot CoT): ",
      recall_score(ground_truth, four_shot_cot_label))
print("Accuracy with TODO with (4 shot CoT): ",
      accuracy_score(ground_truth, four_shot_cot_label))
# Out:
# F1-Score with TODO with (4 shot CoT):  0.7598130841121494
# Precision with TODO with (4 shot CoT):  0.7103538663171691
# Recall with TODO with (4 shot CoT):  0.8166750376695128
# Accuracy with TODO with (4 shot CoT):  0.7443422034319821

# %% [markdown]
# # 8-shot CoT

# %%
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 6     Morrison is a typical right-wing conservative ...
# 7     New York City Mayor Bill de Blasio (D) suggest...
# 8     The plastics industry, recently on its back fo...
# ...                                                 ...
# 4011  Facebook posts, shared thousands of times, cla...
# 4012  U.S. President Donald Trump’s former personal ...
# 4014  Larry Kudlow, one of President Donald Trump’s ...
# 4016  Far-right talk show host Glenn Beck is being s...
# 4019  Sen. Tom Cotton (R-AR) says it “makes absolute...
#
#                                                response  \
# 2     The sentence is biased because it uses pejorat...
# 3     The sentence presents a factual statement rega...
# 6     The sentence exhibits bias through its use of ...
# 7     The sentence presents a factual statement abou...
# 8     The sentence is biased because it uses the phr...
# ...                                                 ...
# 4011  The sentence presents a claim without providin...
# 4012  The sentence presents a factual statement abou...
# 4014  The sentence is biased as it uses a loaded ter...
# 4016  The sentence is biased because it uses pejorat...
# 4019  The sentence is biased because it uses languag...
#
#                                                raw_data  \
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 6     You are an expert in media bias.\n\nInstructio...
# 7     You are an expert in media bias.\n\nInstructio...
# 8     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4011  You are an expert in media bias.\n\nInstructio...
# 4012  You are an expert in media bias.\n\nInstructio...
# 4014  You are an expert in media bias.\n\nInstructio...
# 4016  You are an expert in media bias.\n\nInstructio...
# 4019  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 6     You are an expert in media bias.\n\nInstructio...     ?
# 7     You are an expert in media bias.\n\nInstructio...     ?
# 8     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4011  You are an expert in media bias.\n\nInstructio...     ?
# 4012  You are an expert in media bias.\n\nInstructio...     ?
# 4014  You are an expert in media bias.\n\nInstructio...     ?
# 4016  You are an expert in media bias.\n\nInstructio...     ?
# 4019  You are an expert in media bias.\n\nInstructio...     ?
#
# [1809 rows x 5 columns]

# %%
# preprocessing
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


eight_shot_cot['label'] = eight_shot_cot.apply(update_label, axis=1)
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 114   On January 20, 2020, thousands upon thousands ...
# 128                                                 may
# 301   Police in Milwaukee on Thursday identified the...
# 371   Russia has replenished its forces with hundred...
# 478   Sen. Bernie Sanders, I-Vt., went after Pete Bu...
# 914   The Guardian ran a sympathetic feature in Octo...
# 1074  U.S. President Donald Trump said on Wednesday ...
# 1311  President Donald Trump took another step Thurs...
# 1760  One of three officers involved in the shooting...
# 1772  Carlson warned if Trump was unsuccessful in ef...
# 2027  Other European countries have also said they w...
# 2316  An initiative to build bridges between the Gre...
# 2434  Conservative Republican Senator Ted Cruz favor...
# 2544  In the wake of the El Paso shooting, in which ...
# 2647  The movement to ban or limit the use of natura...
# 2668  After days of mounting pressure, the top socce...
# 2728  Hawley recalled during Tuesday’s hearing that ...
# 2739  The Grammy-winner condemned those smearing eve...
# 2756  As banks leave low-income communities and jack...
# 2906  Reuters was not able to verify battlefield rep...
# 2980  The German Federal State of Baden-Wuerttemberg...
# 3081  Trump's comments came during a mega-rally in t...
# 3099  Hungarian Prime Minister Viktor Orban, a staun...
# 3473  In Washington, three key issues seemed to galv...
# 3479  But the announcement Monday further clarifies ...
# 3521  Biden, the former vice president making his th...
# 3657  Despite Portman’s insistence that she has trie...
# 3787  The Europeans have set up a complicated barter...
#
#                                                response  \
# 114   The sentence is neutral as it simply states a ...
# 128   The sentence is neutral and does not convey an...
# 301   The sentence is factual and does not contain a...
# 371   The sentence is neutral as it provides factual...
# 478   The sentence is neutral and does not express a...
# 914   The sentence is factual and reports on a news ...
# 1074  The sentence presents a statement made by Pres...
# 1311  The sentence presents a factual statement abou...
# 1760  The sentence above is classified as unbiased b...
# 1772  The sentence presents a statement made by Tuck...
# 2027  The sentence is factual and does not express a...
# 2316  The sentence provides factual information with...
# 2434  The sentence is neutral and factual. It descri...
# 2544  The sentence is factual and does not express a...
# 2647  The sentence presents a factual report on a mo...
# 2668  The sentence presents a straightforward report...
# 2728  The sentence is neutral as it simply reports o...
# 2739  The sentence displays bias through the use of ...
# 2756  The sentence presents a situation where banks ...
# 2906  The sentence "Reuters was not able to verify b...
# 2980  The sentence is factual, reporting on a legal ...
# 3081  The sentence contains subjective language that...
# 3099  The sentence uses the term "staunch anti-immig...
# 3473  The sentence presents a factual account of the...
# 3479  The sentence is neutral and factual, providing...
# 3521  The sentence presents a factual statement abou...
# 3657  The sentence presents a factual observation ab...
# 3787  The sentence presents a factual description of...
#
#                                                raw_data  \
# 114   You are an expert in media bias.\n\nInstructio...
# 128   You are an expert in media bias.\n\nInstructio...
# 301   You are an expert in media bias.\n\nInstructio...
# 371   You are an expert in media bias.\n\nInstructio...
# 478   You are an expert in media bias.\n\nInstructio...
# 914   You are an expert in media bias.\n\nInstructio...
# 1074  You are an expert in media bias.\n\nInstructio...
# 1311  You are an expert in media bias.\n\nInstructio...
# 1760  You are an expert in media bias.\n\nInstructio...
# 1772  You are an expert in media bias.\n\nInstructio...
# 2027  You are an expert in media bias.\n\nInstructio...
# 2316  You are an expert in media bias.\n\nInstructio...
# 2434  You are an expert in media bias.\n\nInstructio...
# 2544  You are an expert in media bias.\n\nInstructio...
# 2647  You are an expert in media bias.\n\nInstructio...
# 2668  You are an expert in media bias.\n\nInstructio...
# 2728  You are an expert in media bias.\n\nInstructio...
# 2739  You are an expert in media bias.\n\nInstructio...
# 2756  You are an expert in media bias.\n\nInstructio...
# 2906  You are an expert in media bias.\n\nInstructio...
# 2980  You are an expert in media bias.\n\nInstructio...
# 3081  You are an expert in media bias.\n\nInstructio...
# 3099  You are an expert in media bias.\n\nInstructio...
# 3473  You are an expert in media bias.\n\nInstructio...
# 3479  You are an expert in media bias.\n\nInstructio...
# 3521  You are an expert in media bias.\n\nInstructio...
# 3657  You are an expert in media bias.\n\nInstructio...
# 3787  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 114   You are an expert in media bias.\n\nInstructio...     ?
# 128   You are an expert in media bias.\n\nInstructio...     ?
# 301   You are an expert in media bias.\n\nInstructio...     ?
# 371   You are an expert in media bias.\n\nInstructio...     ?
# 478   You are an expert in media bias.\n\nInstructio...     ?
# 914   You are an expert in media bias.\n\nInstructio...     ?
# 1074  You are an expert in media bias.\n\nInstructio...     ?
# 1311  You are an expert in media bias.\n\nInstructio...     ?
# 1760  You are an expert in media bias.\n\nInstructio...     ?
# 1772  You are an expert in media bias.\n\nInstructio...     ?
# 2027  You are an expert in media bias.\n\nInstructio...     ?
# 2316  You are an expert in media bias.\n\nInstructio...     ?
# 2434  You are an expert in media bias.\n\nInstructio...     ?
# 2544  You are an expert in media bias.\n\nInstructio...     ?
# 2647  You are an expert in media bias.\n\nInstructio...     ?
# 2668  You are an expert in media bias.\n\nInstructio...     ?
# 2728  You are an expert in media bias.\n\nInstructio...     ?
# 2739  You are an expert in media bias.\n\nInstructio...     ?
# 2756  You are an expert in media bias.\n\nInstructio...     ?
# 2906  You are an expert in media bias.\n\nInstructio...     ?
# 2980  You are an expert in media bias.\n\nInstructio...     ?
# 3081  You are an expert in media bias.\n\nInstructio...     ?
# 3099  You are an expert in media bias.\n\nInstructio...     ?
# 3473  You are an expert in media bias.\n\nInstructio...     ?
# 3479  You are an expert in media bias.\n\nInstructio...     ?
# 3521  You are an expert in media bias.\n\nInstructio...     ?
# 3657  You are an expert in media bias.\n\nInstructio...     ?
# 3787  You are an expert in media bias.\n\nInstructio...     ?

# %%
eight_shot_cot.loc[[3099, 3081, 2756, 2739, ], 'label'] = 'BIASED'
eight_shot_cot.loc[[3787, 3657, 3521, 3479, 3473, 2980, 2906, 2728,
                    2668, 2647, 2544, 2434, 2316, 2027, 1772, 1760,
                    1311, 1074, 914, 478, 371, 371, 301, 128, 114,], 'label'] = 'NOT BIASED'

# undefined

eight_shot_cot.loc[114]['response']
# Out:
# 'The sentence is neutral as it simply states a factual observation about the number of people involved in the event without expressing an opinion or taking a side. It does not employ any loaded language or emotive phrasing that could be perceived as biased. Therefore, the answer is NOT BIASED.'

# %%
eight_shot_cot = eight_shot_cot.rename(columns={"label": "8_shot_cot_label"})
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot['8_shot_cot_label'].replace('BIASED', 1)
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot['8_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot_cot[eight_shot_cot['8_shot_cot_label'] != '?'][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot_cot[eight_shot_cot['8_shot_cot_label'] != '?'][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot_cot[['text', '8_shot_cot_label']], on='text')


ground_truth = df_merge['label']
eight_shot_cot_label = df_merge['8_shot_cot_label']

# %%
print("F1-Score with TODO with (8 shot CoT): ",
      f1_score(ground_truth, eight_shot_cot_label))
print("Precision with TODO with (8 shot CoT): ",
      precision_score(ground_truth, eight_shot_cot_label))
print("Recall with TODO with (8 shot CoT): ",
      recall_score(ground_truth, eight_shot_cot_label))
print("Accuracy with TODO with (8 shot CoT): ",
      accuracy_score(ground_truth, eight_shot_cot_label))
# Out:
# F1-Score with TODO with (8 shot CoT):  0.7594035165813487
# Precision with TODO with (8 shot CoT):  0.6818545163868905
# Recall with TODO with (8 shot CoT):  0.8568558513309894
# Accuracy with TODO with (8 shot CoT):  0.7311614026361601

# %% [markdown]
# # Comparison and plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column,
                          title=None
                          ):
    predicted_labels = df[f'{predicted_labels_column}']
    true_labels = df[f'{true_labels_column}']

    # Calculate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)


    # Display confusion matrix heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=True,
                yticklabels=True, ax=ax)

    title = title if title else predicted_labels_column

    ax.set_title(f'Confusion Matrix - {title}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')


# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Confusion Matrices')

# Plot each confusion matrix
plot_confusion_matrix(axes[0, 0], df_merge, 'label', '0_shot_label', '0_shot')
plot_confusion_matrix(axes[0, 1], df_merge, 'label',
                      '0_shot_with_system_label', '0_shot_with_system')
plot_confusion_matrix(axes[0, 2], df_merge, 'label', '0_shot_cot_label',
                      '0_shot_cot')
plot_confusion_matrix(axes[1, 0], df_merge, 'label', '2_shot_label', '2_shot')
plot_confusion_matrix(axes[1, 1], df_merge, 'label', '4_shot_label', '4_shot')
plot_confusion_matrix(axes[1, 2], df_merge, 'label', '8_shot_label', '8_shot')

plt.tight_layout(
    rect=[0, 0, 1, 0.96])  # Adjust layout to prevent title overlap
plt.show()

# %% [markdown]
# # Krippendorff Alpha in model

# %%
import krippendorff

runs = ['0_shot_label', '0_shot_with_system_label', '0_shot_cot_label',
        '2_shot_label', '4_shot_label', '8_shot_label']


def compute_krippendorff_alpha(df, predicted_columns):
    pred_map = {}
    for run in predicted_columns:
        predicted_labels = df[run]
        pred_map[run] = predicted_labels

    # Check if there is variability in the ratings
    unique_labels_counts = df[predicted_columns].nunique(axis=1)
    if unique_labels_counts.max() == 1:
        # All ratings are the same, return a special value or handle accordingly
        return 0

    reliability_data = df[predicted_columns].values.tolist()

    # Calculate Krippendorff's alpha
    alpha = krippendorff.alpha(reliability_data=list(pred_map.values()),
                               level_of_measurement='nominal')

    return alpha

# %%
alpha_value = compute_krippendorff_alpha(df_merge, runs)
print(f"Krippendorff's Alpha (all runs): {alpha_value}")

# %%
import itertools

def compute_krippendorff_alpha_for_k_runs(df, runs, k=None):
    # Initialize variables to store the best combination and alpha
    if k is None:
        k = len(runs)

    best_combination = None
    best_alpha = 0  # Assuming alpha ranges from 0 to 1

    # Iterate through all possible combinations
    for combination in itertools.combinations(runs, k):

        alpha_value = compute_krippendorff_alpha(df, list(combination))

        # Print alpha for the current combination
        print(f"Combination: {combination}, Alpha: {alpha_value}")

        # Update best combination and alpha if a higher alpha is found
        if alpha_value > best_alpha:
            best_alpha = alpha_value
            best_combination = combination

    # Print the best combination and alpha
    print(f"\nBest Combination: {best_combination}, Best Alpha: {best_alpha}")
    return best_alpha, best_combination

# %%
compute_krippendorff_alpha_for_k_runs(df_merge, runs, 2)
