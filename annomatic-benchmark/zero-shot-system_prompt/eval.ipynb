# %%
import pandas as pd
from datasets import load_dataset
from sklearn.metrics import f1_score, precision_score, recall_score, \
    accuracy_score

import re
from typing import List, Tuple

import pandas as pd


def is_contained(inner_start, inner_end, outer_start, outer_end):
    return (
        outer_start <= inner_start <= outer_end
        and outer_start <= inner_end <= outer_end
        and (inner_start, inner_end) != (outer_start, outer_end)
    )


def find_all_occurrences_indices(
    sentence: str,
    label: str,
) -> List[Tuple[int, int]]:
    """
    Finds all occurrences of a label in a sentence and returns a list of tuples
    with the start and end indices of the occurrences.

    Args:
        sentence: The sentence to search in.
        label: The label to search for.

    Returns:
        A list of tuples with the start and end indices of the occurrences.
    """
    return [
        (int(match.start()), int(match.end()))
        for match in re.finditer(label, sentence)
    ]


def find_contained_labels(labels):
    """
    Finds all labels that are contained in other labels.

    Args:
        labels: A list of labels.

    Returns:
        A dictionary with the labels as keys and a list of labels that are
        contained in the key label as values.
    """
    return {
        label_1: [
            label2
            for label2 in labels
            if label_1 in label2 and label_1 != label2
        ]
        for label_1 in labels
    }


def find_labels_in_sentence(
    sentence: str,
    labels: List[str],
) -> List[List[Tuple[int, int]]]:
    """
    Finds all occurrences of the labels in a sentence and returns a list of
    lists with the occurrences of each label.

    Labels that are contained in other labels are not returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.

    Returns:
        A list of lists with the positional occurrence of each label.
    """
    if not labels:
        return []

    containable_map = find_contained_labels(labels)
    sentence_lower = sentence.lower()
    occurrences = [
        find_all_occurrences_indices(sentence_lower, label.lower())
        for label in labels
    ]
    label_occurrences = dict(zip(labels, occurrences))
    included_list = []
    for label, inner_pos in zip(labels, occurrences):
        contained = set()
        containing_labels = containable_map.get(label, set())

        for bigger_label in containing_labels:
            locations: List[Tuple[int, int]] = label_occurrences.get(
                bigger_label,
                list(),
            )

            for inner_start, inner_end in inner_pos:
                for outer_start, outer_end in locations:
                    if is_contained(
                        inner_start,
                        inner_end,
                        outer_start,
                        outer_end,
                    ):
                        contained.add((inner_start, inner_end))
        included_list.append(list(contained))

    return [
        list(set(pos) - set(included))
        for pos, included in zip(occurrences, included_list)
    ]


def find_label(
    sentence: str,
    labels: List[str],
    default_label: str = "?",
) -> str:
    """
    Search for given labels in the sentence and returns it if found. If only
    one label occur in the sentence, it will be returned. If no label or
    different labels occur in the sentence, '?' is returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.
        default_label: The label to return if no label or different labels
            occur in the sentence.

    Returns:
        The label that occurs in the sentence or '?' if no label occurs in the
        sentence.
    """
    occurrences = find_labels_in_sentence(sentence=sentence, labels=labels)
    non_empty_indices = [i for i, sublist in enumerate(occurrences) if sublist]
    return (
        labels[non_empty_indices[0]]
        if len(
            non_empty_indices,
        )
           == 1
        else default_label
    )


def _soft_parse(
    df: pd.DataFrame,
    in_col: str,
    parsed_col: str,
    labels: List[str] = None,
) -> pd.DataFrame:
    if labels is None:
        raise ValueError("Labels are not set!")

    df[parsed_col] = df[in_col].apply(
        lambda x: find_label(x, labels),
    )

# %%
# load

# load results
df_falcon_7b = pd.read_csv(f"./data/falcon-7b-instruct.csv")
df_flan_ul2 = pd.read_csv(f"./data/flan-ul2.csv")
df_flan_t5_base = pd.read_csv("./data/flan-t5-base.csv")
df_flan_t5_large = pd.read_csv("./data/flan-t5-large.csv")
df_flan_t5_xl = pd.read_csv("./data/flan-t5-xl.csv")
df_openai_gpt_3_5_turbo = pd.read_csv('./data/gpt-3.5-turbo.csv')
df_openai_gpt_4_turbo = pd.read_csv(f"./data/gpt-4.csv")
df_Llama_2_7b = pd.read_csv(f"./data/Llama-2-7b-chat-hf.csv")
df_Llama_2_13b = pd.read_csv(f"./data/Llama-2-13b-chat-hf.csv")
df_mistral_7b = pd.read_csv(f"./data/Mistral-7B-Instruct-v0.1.csv")
df_mixtral_8x7b = pd.read_csv(f"./data/Mixtral-8x7B-Instruct-v0.1.csv")
df_openchat_3_5 = pd.read_csv(f"./data/openchat_3.5.csv")
df_zephyr_7b_beta = pd.read_csv(f"./data/zephyr-7b-beta.csv")

#load pool
pool = load_dataset('mediabiasgroup/BABE-icl-pool')['train'].to_pandas()

# exclude pool from model (if needed)
df_falcon_7b = df_falcon_7b.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_flan_ul2 = df_flan_ul2.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_openai_gpt_3_5_turbo = df_openai_gpt_3_5_turbo.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_openai_gpt_4_turbo = df_openai_gpt_4_turbo.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_Llama_2_7b = df_Llama_2_7b.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_Llama_2_13b = df_Llama_2_13b.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_mistral_7b = df_mistral_7b.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_mixtral_8x7b = df_mixtral_8x7b.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_openchat_3_5 = df_openchat_3_5.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
df_zephyr_7b_beta = df_zephyr_7b_beta.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)



#load babe
dataset = load_dataset('mediabiasgroup/BABE-v4')
df_babe = pd.DataFrame(dataset['train'])

# df_merge_all_runs = only contains the elements legal in all annotations
df_merge_all_runs = df_babe

# df_merge_all_runs_with_errors = only contains the elements legal in all annotations
df_merge_all_runs_with_errors = df_babe


def find_first_occurrence(string, instruction="Instruction:",
                          statement1="The answer is BIASED",
                          statement2="The answer is NOT BIASED"
                          ):
    index_instruction = string.find(instruction)
    index1 = string.find(statement1)
    index2 = string.find(statement2)

    if index1 == -1 and index2 == -1:
        return "Neither instruction nor statements found in the given string."
    elif index1 == -1 and index2 == -1:
        return "Neither statement found in the given string."
    elif index1 == -1:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"
    elif index2 == -1:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    elif index1 < index2:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    else:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"

# %% [markdown]
# # Falcon 7B

# %%
_soft_parse(df_falcon_7b, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_falcon_7b.query("label == '?'")
# Out:
#                                                    text  \
# 20    A Joe Biden presidency could reset ties with t...
# 95    The head of the World Health Organization said...
# 196   With radical feminists and extremist trans act...
# 297   This is why Donald Trump is awake at 2:30 a.m....
# 383   While the stupid Democrats who vote for Democr...
# ...                                                 ...
# 3658  acked by Virginia’s first Democratic-controlle...
# 3837  It amazes me that even intelligent people – in...
# 3845  The movement’s hysteric leader proceeded to hu...
# 3851  A leading economist who vouched for Democratic...
# 4084  Posting on Twitter, the former stripper turned...
#
#                                                response  \
# 20    'NOT BIASED'\n\nExplanation: The sentence pres...
# 95    'NOT BIASED'\n\nExplanation: The sentence does...
# 196   'NOT BIASED'\n\nExplanation: The sentence port...
# 297   'NOT BIASED'\n\nExplanation: The sentence pres...
# 383   'NOT BIASED'\n\nExplanation: The sentence cont...
# ...                                                 ...
# 3658  'NOT BIASED'\n\nExplanation: The sentence pres...
# 3837  'NOT BIASED'\n\nExplanation: The sentence is n...
# 3845  'Hysteric' (BIASED), 'leader' (NOT BIASED),'mo...
# 3851  'NOT BIASED'\n\nExplanation: The sentence pres...
# 4084  'NOT BIASED'\n\nExplanation: The sentence is n...
#
#                                                raw_data  \
# 20    You are an expert in media bias.\n\nInstructio...
# 95    You are an expert in media bias.\n\nInstructio...
# 196   You are an expert in media bias.\n\nInstructio...
# 297   You are an expert in media bias.\n\nInstructio...
# 383   You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3658  You are an expert in media bias.\n\nInstructio...
# 3837  You are an expert in media bias.\n\nInstructio...
# 3845  You are an expert in media bias.\n\nInstructio...
# 3851  You are an expert in media bias.\n\nInstructio...
# 4084  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 20    You are an expert in media bias.\n\nInstructio...     ?
# 95    You are an expert in media bias.\n\nInstructio...     ?
# 196   You are an expert in media bias.\n\nInstructio...     ?
# 297   You are an expert in media bias.\n\nInstructio...     ?
# 383   You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3658  You are an expert in media bias.\n\nInstructio...     ?
# 3837  You are an expert in media bias.\n\nInstructio...     ?
# 3845  You are an expert in media bias.\n\nInstructio...     ?
# 3851  You are an expert in media bias.\n\nInstructio...     ?
# 4084  You are an expert in media bias.\n\nInstructio...     ?
#
# [82 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith("'BIASED'") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("'Biased'") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("1") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("'NOT BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith("'Not BIASED'") and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith("'Not Biased'") and row[
        'label'] == '?':
        return 'NOT BIASED'

    else:
        return row['label']


df_falcon_7b['label'] = df_falcon_7b.apply(update_label, axis=1)
df_falcon_7b.query("label == '?'")
# Out:
#                                                    text  \
# 2062  'Pandemic Apprentice': Deprived of rallies to ...
# 3845  The movement’s hysteric leader proceeded to hu...
#
#                                                response  \
# 2062  'Pandemic Apprentice': Deprived of rallies to ...
# 3845  'Hysteric' (BIASED), 'leader' (NOT BIASED),'mo...
#
#                                                raw_data  \
# 2062  You are an expert in media bias.\n\nInstructio...
# 3845  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 2062  You are an expert in media bias.\n\nInstructio...     ?
# 3845  You are an expert in media bias.\n\nInstructio...     ?

# %%
# preprocessing

df_falcon_7b['label'] = df_falcon_7b.apply(update_label, axis=1)
df_falcon_7b.query("label == '?'")
# Out:
#                                                    text  \
# 2062  'Pandemic Apprentice': Deprived of rallies to ...
# 3845  The movement’s hysteric leader proceeded to hu...
#
#                                                response  \
# 2062  'Pandemic Apprentice': Deprived of rallies to ...
# 3845  'Hysteric' (BIASED), 'leader' (NOT BIASED),'mo...
#
#                                                raw_data  \
# 2062  You are an expert in media bias.\n\nInstructio...
# 3845  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 2062  You are an expert in media bias.\n\nInstructio...     ?
# 3845  You are an expert in media bias.\n\nInstructio...     ?

# %%
df_falcon_7b = df_falcon_7b.rename(columns={"label": "falcon_7b_label"})
df_falcon_7b['falcon_7b_label'] = df_falcon_7b['falcon_7b_label'].replace('BIASED', 1)
df_falcon_7b['falcon_7b_label'] = df_falcon_7b['falcon_7b_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(df_falcon_7b[df_falcon_7b['falcon_7b_label'] != '?'][['text', 'falcon_7b_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_falcon_7b[df_falcon_7b['falcon_7b_label'] != '?'][['text', 'falcon_7b_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_falcon_7b[['text', 'falcon_7b_label']], on='text')

ground_truth = df_merge['label'].astype(int)
falcon_7b_label = df_merge['falcon_7b_label'].astype(int)

# %%
print("F1-Score with Falcon 7b with (0 shot + Sys. Prompt): ",
      f1_score(ground_truth, falcon_7b_label))
print("Precision with Falcon 7b with (0 shot + Sys. Prompt): ",
      precision_score(ground_truth, falcon_7b_label))
print("Recall with Falcon 7b with (0 shot + Sys. Prompt): ",
      recall_score(ground_truth, falcon_7b_label))
print("Accuracy with Falcon 7b with (0 shot + Sys. Prompt): ",
      accuracy_score(ground_truth, falcon_7b_label))
# Out:
# F1-Score with Falcon 7b with (0 shot + Sys. Prompt):  0.5074925074925075
# Precision with Falcon 7b with (0 shot + Sys. Prompt):  0.5042183622828784
# Recall with Falcon 7b with (0 shot + Sys. Prompt):  0.5108094519859225
# Accuracy with Falcon 7b with (0 shot + Sys. Prompt):  0.5093306792734511

# %% [markdown]
# # Flan UL2

# %%
_soft_parse(df_flan_ul2, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_flan_ul2.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_flan_ul2 = df_flan_ul2.rename(columns={"label": "flan_ul2_label"})
df_flan_ul2['flan_ul2_label'] = df_flan_ul2['flan_ul2_label'].replace('BIASED', 1)
df_flan_ul2['flan_ul2_label'] = df_flan_ul2['flan_ul2_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_flan_ul2[df_flan_ul2['flan_ul2_label'] != '?'][['text', 'flan_ul2_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_flan_ul2[df_flan_ul2['flan_ul2_label'] != '?'][['text', 'flan_ul2_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_flan_ul2[['text', 'flan_ul2_label']], on='text')

ground_truth = df_merge['label'].astype(int)
flan_ul2_label = df_merge['flan_ul2_label'].astype(int)

# %%
print("F1-Score with Flan UL2 (0 Shot + Sys Prompt): ", f1_score(ground_truth, flan_ul2_label))
print("Precision with Flan UL2 (0 Shot + Sys Prompt): ", precision_score(ground_truth, flan_ul2_label))
print("Recall with Flan UL2 (0 Shot + Sys Prompt): ", recall_score(ground_truth, flan_ul2_label))
print("Accuracy with Flan UL2 (0 Shot + Sys Prompt): ",  accuracy_score(ground_truth, flan_ul2_label))
# Out:
# F1-Score with Flan UL2 (0 Shot + Sys Prompt):  0.7203867848509267
# Precision with Flan UL2 (0 Shot + Sys Prompt):  0.7742494226327945
# Recall with Flan UL2 (0 Shot + Sys Prompt):  0.6735308890005023
# Accuracy with Flan UL2 (0 Shot + Sys Prompt):  0.7411091768216862

# %% [markdown]
# # Flan T5 base

# %%
_soft_parse(df_flan_t5_base, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_flan_t5_base.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_flan_t5_base = df_flan_t5_base.rename(columns={"label": "flan_t5_base_label"})
df_flan_t5_base['flan_t5_base_label'] = df_flan_t5_base['flan_t5_base_label'].replace('BIASED', 1)
df_flan_t5_base['flan_t5_base_label'] = df_flan_t5_base['flan_t5_base_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_flan_t5_base[df_flan_t5_base['flan_t5_base_label'] != '?'][['text', 'flan_t5_base_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_flan_t5_base[df_flan_t5_base['flan_t5_base_label'] != '?'][['text', 'flan_t5_base_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_flan_t5_base[['text', 'flan_t5_base_label']], on='text')

ground_truth = df_merge['label'].astype(int)
flan_t5_base_label = df_merge['flan_t5_base_label'].astype(int)

# %%
print("F1-Score with Flan T5 base (0 shot): ", f1_score(ground_truth, flan_t5_base_label))
print("Precision with Flan T5 base (0 shot): ", precision_score(ground_truth, flan_t5_base_label))
print("Recall with Flan T5 base (0 shot): ", recall_score(ground_truth, flan_t5_base_label))
print("Accuracy with Flan T5 base (0 shot): ",  accuracy_score(ground_truth, flan_t5_base_label))
# Out:
# F1-Score with Flan T5 base (0 shot):  0.6609257265877286
# Precision with Flan T5 base (0 shot):  0.5213699405604302
# Recall with Flan T5 base (0 shot):  0.9024987751102401
# Accuracy with Flan T5 base (0 shot):  0.5413734530453773

# %% [markdown]
# # Flan T5 large

# %%
_soft_parse(df_flan_t5_large, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_flan_t5_large.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_flan_t5_large = df_flan_t5_large.rename(columns={"label": "flan_t5_large_label"})
df_flan_t5_large['flan_t5_large_label'] = df_flan_t5_large['flan_t5_large_label'].replace('BIASED', 1)
df_flan_t5_large['flan_t5_large_label'] = df_flan_t5_large['flan_t5_large_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_flan_t5_large[df_flan_t5_large['flan_t5_large_label'] != '?'][['text', 'flan_t5_large_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_flan_t5_large[df_flan_t5_large['flan_t5_large_label'] != '?'][['text', 'flan_t5_large_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_flan_t5_large[['text', 'flan_t5_large_label']], on='text')

ground_truth = df_merge['label'].astype(int)
flan_t5_large_label = df_merge['flan_t5_large_label'].astype(int)

# %%
print("F1-Score with Flan T5 Large (0 shot + Sys Prompt): ", f1_score(ground_truth, flan_t5_large_label))
print("Precision with Flan T5 Large (0 shot + Sys Prompt): ", precision_score(ground_truth, flan_t5_large_label))
print("Recall with Flan T5 Large (0 shot + Sys Prompt): ", recall_score(ground_truth, flan_t5_large_label))
print("Accuracy with Flan T5 Large (0 shot + Sys Prompt): ",  accuracy_score(ground_truth, flan_t5_large_label))
# Out:
# F1-Score with Flan T5 Large (0 shot + Sys Prompt):  0.6692776327241079
# Precision with Flan T5 Large (0 shot + Sys Prompt):  0.6019569471624266
# Recall with Flan T5 Large (0 shot + Sys Prompt):  0.7535521803037727
# Accuracy with Flan T5 Large (0 shot + Sys Prompt):  0.631157486047076

# %% [markdown]
# # Flan T5 Xl

# %%
_soft_parse(df_flan_t5_xl, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_flan_t5_xl.query("label == '?'")
# Out:
#                                                    text  response  raw_data  \
# 1705  Tennessee has an annual sales tax-free holiday...  Not bias  Not bias
#
#                                                   query label
# 1705  You are an expert in media bias.\n\nInstructio...     ?

# %%
df_flan_t5_xl.loc[[1705], 'label'] = 'NOT BIASED'

# %%
df_flan_t5_xl = df_flan_t5_xl.rename(columns={"label": "flan_t5_xl_label"})
df_flan_t5_xl['flan_t5_xl_label'] = df_flan_t5_xl['flan_t5_xl_label'].replace('BIASED', 1)
df_flan_t5_xl['flan_t5_xl_label'] = df_flan_t5_xl['flan_t5_xl_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_flan_t5_xl[df_flan_t5_xl['flan_t5_xl_label'] != '?'][['text', 'flan_t5_xl_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_flan_t5_xl[df_flan_t5_xl['flan_t5_xl_label'] != '?'][['text', 'flan_t5_xl_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_flan_t5_xl[['text', 'flan_t5_xl_label']], on='text')

ground_truth = df_merge['label'].astype(int)
flan_t5_xl_label = df_merge['flan_t5_xl_label'].astype(int)

# %%
print("F1-Score with Flan T5 xl (0 Shot + Sys Prompt): ", f1_score(ground_truth, flan_t5_xl_label))
print("Precision with Flan T5 xl (0 Shot + Sys Prompt): ", precision_score(ground_truth, flan_t5_xl_label))
print("Recall with Flan T5 xl (0 Shot + Sys Prompt): ", recall_score(ground_truth, flan_t5_xl_label))
print("Accuracy with Flan T5 xl (0 Shot + Sys Prompt): ",  accuracy_score(ground_truth, flan_t5_xl_label))
# Out:
# F1-Score with Flan T5 xl (0 Shot + Sys Prompt):  0.5226896323285856
# Precision with Flan T5 xl (0 Shot + Sys Prompt):  0.8067484662576687
# Recall with Flan T5 xl (0 Shot + Sys Prompt):  0.3865752082312592
# Accuracy with Flan T5 xl (0 Shot + Sys Prompt):  0.6503275903906819

# %% [markdown]
# # GPT-3.5-turbo

# %%
_soft_parse(df_openai_gpt_3_5_turbo, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_openai_gpt_3_5_turbo.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_openai_gpt_3_5_turbo = df_openai_gpt_3_5_turbo.rename(columns={"label": "gpt_3_5_label"})
df_openai_gpt_3_5_turbo['gpt_3_5_label'] = df_openai_gpt_3_5_turbo['gpt_3_5_label'].replace(
    'BIASED', 1)
df_openai_gpt_3_5_turbo['gpt_3_5_label'] = df_openai_gpt_3_5_turbo['gpt_3_5_label'].replace(
    'NOT BIASED',
    0)

df_merge = df_babe.merge(df_openai_gpt_3_5_turbo[df_openai_gpt_3_5_turbo['gpt_3_5_label'] != '?'][['text', 'gpt_3_5_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_openai_gpt_3_5_turbo[df_openai_gpt_3_5_turbo['gpt_3_5_label'] != '?'][['text', 'gpt_3_5_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_openai_gpt_3_5_turbo[['text', 'gpt_3_5_label']], on='text')


ground_truth = df_merge['label'].astype(int)
gpt_3_5_label = df_merge['gpt_3_5_label'].astype(int)

# %%
print("F1-Score with GPT 3.5 Turbo with (0 Shot + Sys Prompt): ",
      f1_score(ground_truth, gpt_3_5_label))
print("Precision with GPT 3.5 Turbo with (0 Shot + Sys Prompt): ",
      precision_score(ground_truth, gpt_3_5_label))
print("Recall with GPT 3.5 Turbo with (0 Shot + Sys Prompt): ",
      recall_score(ground_truth, gpt_3_5_label))
print("Accuracy with GPT 3.5 Turbo with (0 Shot + Sys Prompt): ",
      accuracy_score(ground_truth, gpt_3_5_label))
# Out:
# F1-Score with GPT 3.5 Turbo with (0 Shot + Sys Prompt):  0.7418086500655307
# Precision with GPT 3.5 Turbo with (0 Shot + Sys Prompt):  0.7757675438596491
# Recall with GPT 3.5 Turbo with (0 Shot + Sys Prompt):  0.7106981416373681
# Accuracy with GPT 3.5 Turbo with (0 Shot + Sys Prompt):  0.7550360606814225

# %% [markdown]
# # GPT 4 - turbo

# %%
_soft_parse(df_openai_gpt_4_turbo, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_openai_gpt_4_turbo.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_openai_gpt_4_turbo = df_openai_gpt_4_turbo.rename(columns={"label": "gpt_4_label"})
df_openai_gpt_4_turbo['gpt_4_label'] = df_openai_gpt_4_turbo['gpt_4_label'].replace(
    'BIASED', 1)
df_openai_gpt_4_turbo['gpt_4_label'] = df_openai_gpt_4_turbo['gpt_4_label'].replace(
    'NOT BIASED',
    0)

df_merge = df_babe.merge(df_openai_gpt_4_turbo[df_openai_gpt_4_turbo['gpt_4_label'] != '?'][['text', 'gpt_4_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_openai_gpt_4_turbo[df_openai_gpt_4_turbo['gpt_4_label'] != '?'][['text', 'gpt_4_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_openai_gpt_4_turbo[['text', 'gpt_4_label']], on='text')


ground_truth = df_merge['label'].astype(int)
gpt_4_label = df_merge['gpt_4_label'].astype(int)

# %%
print("F1-Score with GPT 4 turbo with (0 Shot + Sys Prompt): ",
      f1_score(ground_truth, gpt_4_label))
print("Precision with GPT 4 turbo with (0 Shot + Sys Prompt): ",
      precision_score(ground_truth, gpt_4_label))
print("Recall with GPT 4 turbo with (0 Shot + Sys Prompt): ",
      recall_score(ground_truth, gpt_4_label))
print("Accuracy with GPT 4 turbo with (0 Shot + Sys Prompt): ",
      accuracy_score(ground_truth, gpt_4_label))
# Out:
# F1-Score with GPT 4 turbo with (0 Shot + Sys Prompt):  0.780759493670886
# Precision with GPT 4 turbo with (0 Shot + Sys Prompt):  0.7871362940275651
# Recall with GPT 4 turbo with (0 Shot + Sys Prompt):  0.7744851833249623
# Accuracy with GPT 4 turbo with (0 Shot + Sys Prompt):  0.7846306888833623

# %% [markdown]
# # Llama-2-7b-chat-hf

# %%
_soft_parse(df_Llama_2_7b, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_Llama_2_7b.query("label == '?'")
# Out:
#                                                    text  \
# 173   U.S. firearms makers will be able within days ...
# 185   NBC cited Center for Countering Digital Hate, ...
# 198   The accusations fueled the #MeToo movement, in...
# 440   Many Democratic voters have said they believe ...
# 481   A bipartisan group of lawmakers in Mississippi...
# 533   Wray did not explain the evidence that had inf...
# 663   Weinstein faces up to 28 years in California p...
# 904   Following his arrest on July 6, 2019, financie...
# 1064  Prosecutors have said the gunman targeted a To...
# 1097  Just steps from where Trump spoke, peaceful pr...
# 1200  The free health care for DACA illegal aliens p...
# 1359  Although duties set to kick in soon will affec...
# 1591  As health officials around the globe work to s...
# 1721  Biden’s plan also includes major investments i...
# 1763                    Is this an accurate statement?"
# 1983  California Governor Gavin Newsom said on Monda...
# 2153  An Austrian BASE jumper was rescued in souther...
# 2183  It is gut-wrenching to know that parents of ch...
# 2282  Sen. Elizabeth Warren's radical immigration pl...
# 2445  Democrats want to talk about taxes, but they a...
# 2637  Leaving his home for the second time in a week...
# 2682  In February, Mexican illegal alien Pablo Herna...
# 2761  Police returned fire and wounded the suspect, ...
# 3214  Argentina has made significant progress on LGB...
# 3228  Protests over the police killings of George Fl...
# 3247  There is a growing push within the Trump admin...
# 3299  Save the Children made several recommendations...
# 3327  The death of Floyd has set off the biggest ant...
# 3445  Tokyo Games is even more of a dream fulfilled ...
# 3542  The revelation of more than $1 billion in publ...
# 3675  President Trump on Tuesday signed an executive...
# 3948                                      Hawley asked.
# 3992  The city of Cape Town has partnered with the D...
#
#                                                response  \
# 173   BIASED\n\nExplanation: The sentence above is b...
# 185   BIASED\n\nExplanation:\nThe Center for Counter...
# 198   BIASED because the sentence implies that the #...
# 440   BIASED because it implies that sexism is a sig...
# 481   BIASED\n\nExplanation: The sentence uses the t...
# 533   BIASED\n\nExplanation: The sentence implies th...
# 663   BIASED because the sentence implies that the d...
# 904   BIASED because the sentence uses the term "fin...
# 1064  BIASED\n\nExplanation: The sentence above is b...
# 1097  BIASED\n\nExplanation: The sentence above is b...
# 1200  BIASED\n\nExplanation: The term 'illegal alien...
# 1359  The sentence is BIASED because it implies that...
# 1591  The sentence is BIASED because it focuses on t...
# 1721  The sentence is NOT BIASED.\n\nExplanation: Th...
# 1763  BIASED\n\nExplanation: The statement "The medi...
# 1983  BIASED\n\nExplanation: The sentence is biased ...
# 2153  The sentence is NOT BIASED.\n\nExplanation: Th...
# 2183  BIASED\n\nExplanation: \nThe sentence above is...
# 2282  BIASED\n\nExplanation: The sentence is biased ...
# 2445  BIASED because it implies that Democrats are d...
# 2637  The sentence is NOT BIASED.\n\nExplanation: Th...
# 2682  BIASED\n\nExplanation: The term 'illegal alien...
# 2761  The sentence is NOT BIASED.\n\nExplanation: Th...
# 3214  The sentence is NOT BIASED.\n\nExplanation: Th...
# 3228  BIASED because the sentence focuses on the kil...
# 3247  The sentence is BIASED because it uses the ter...
# 3299  The sentence is NOT BIASED.\n\nExplanation: Th...
# 3327  The sentence is BIASED because it uses the ter...
# 3445  BIASED\n\nExplanation: The sentence uses the t...
# 3542  BIASED\n\nExplanation:\nThe sentence uses the ...
# 3675  BIASED\n\nExplanation: \nThe sentence is biase...
# 3948  BIASED\n\nExplanation: The sentence 'Hawley as...
# 3992  BIASED\n\nExplanation: The sentence above is b...
#
#                                                raw_data  \
# 173   You are an expert in media bias.\n\nInstructio...
# 185   You are an expert in media bias.\n\nInstructio...
# 198   You are an expert in media bias.\n\nInstructio...
# 440   You are an expert in media bias.\n\nInstructio...
# 481   You are an expert in media bias.\n\nInstructio...
# 533   You are an expert in media bias.\n\nInstructio...
# 663   You are an expert in media bias.\n\nInstructio...
# 904   You are an expert in media bias.\n\nInstructio...
# 1064  You are an expert in media bias.\n\nInstructio...
# 1097  You are an expert in media bias.\n\nInstructio...
# 1200  You are an expert in media bias.\n\nInstructio...
# 1359  You are an expert in media bias.\n\nInstructio...
# 1591  You are an expert in media bias.\n\nInstructio...
# 1721  You are an expert in media bias.\n\nInstructio...
# 1763  You are an expert in media bias.\n\nInstructio...
# 1983  You are an expert in media bias.\n\nInstructio...
# 2153  You are an expert in media bias.\n\nInstructio...
# 2183  You are an expert in media bias.\n\nInstructio...
# 2282  You are an expert in media bias.\n\nInstructio...
# 2445  You are an expert in media bias.\n\nInstructio...
# 2637  You are an expert in media bias.\n\nInstructio...
# 2682  You are an expert in media bias.\n\nInstructio...
# 2761  You are an expert in media bias.\n\nInstructio...
# 3214  You are an expert in media bias.\n\nInstructio...
# 3228  You are an expert in media bias.\n\nInstructio...
# 3247  You are an expert in media bias.\n\nInstructio...
# 3299  You are an expert in media bias.\n\nInstructio...
# 3327  You are an expert in media bias.\n\nInstructio...
# 3445  You are an expert in media bias.\n\nInstructio...
# 3542  You are an expert in media bias.\n\nInstructio...
# 3675  You are an expert in media bias.\n\nInstructio...
# 3948  You are an expert in media bias.\n\nInstructio...
# 3992  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 173   You are an expert in media bias.\n\nInstructio...     ?
# 185   You are an expert in media bias.\n\nInstructio...     ?
# 198   You are an expert in media bias.\n\nInstructio...     ?
# 440   You are an expert in media bias.\n\nInstructio...     ?
# 481   You are an expert in media bias.\n\nInstructio...     ?
# 533   You are an expert in media bias.\n\nInstructio...     ?
# 663   You are an expert in media bias.\n\nInstructio...     ?
# 904   You are an expert in media bias.\n\nInstructio...     ?
# 1064  You are an expert in media bias.\n\nInstructio...     ?
# 1097  You are an expert in media bias.\n\nInstructio...     ?
# 1200  You are an expert in media bias.\n\nInstructio...     ?
# 1359  You are an expert in media bias.\n\nInstructio...     ?
# 1591  You are an expert in media bias.\n\nInstructio...     ?
# 1721  You are an expert in media bias.\n\nInstructio...     ?
# 1763  You are an expert in media bias.\n\nInstructio...     ?
# 1983  You are an expert in media bias.\n\nInstructio...     ?
# 2153  You are an expert in media bias.\n\nInstructio...     ?
# 2183  You are an expert in media bias.\n\nInstructio...     ?
# 2282  You are an expert in media bias.\n\nInstructio...     ?
# 2445  You are an expert in media bias.\n\nInstructio...     ?
# 2637  You are an expert in media bias.\n\nInstructio...     ?
# 2682  You are an expert in media bias.\n\nInstructio...     ?
# 2761  You are an expert in media bias.\n\nInstructio...     ?
# 3214  You are an expert in media bias.\n\nInstructio...     ?
# 3228  You are an expert in media bias.\n\nInstructio...     ?
# 3247  You are an expert in media bias.\n\nInstructio...     ?
# 3299  You are an expert in media bias.\n\nInstructio...     ?
# 3327  You are an expert in media bias.\n\nInstructio...     ?
# 3445  You are an expert in media bias.\n\nInstructio...     ?
# 3542  You are an expert in media bias.\n\nInstructio...     ?
# 3675  You are an expert in media bias.\n\nInstructio...     ?
# 3948  You are an expert in media bias.\n\nInstructio...     ?
# 3992  You are an expert in media bias.\n\nInstructio...     ?

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


df_Llama_2_7b['label'] = df_Llama_2_7b.apply(update_label, axis=1)
df_Llama_2_7b.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_Llama_2_7b = df_Llama_2_7b.rename(columns={"label": "llama_7b_label"})
df_Llama_2_7b['llama_7b_label'] = df_Llama_2_7b['llama_7b_label'].replace('BIASED', 1)
df_Llama_2_7b['llama_7b_label'] = df_Llama_2_7b['llama_7b_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_Llama_2_7b[df_Llama_2_7b['llama_7b_label'] != '?'][['text', 'llama_7b_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_Llama_2_7b[df_Llama_2_7b['llama_7b_label'] != '?'][['text', 'llama_7b_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_Llama_2_7b[['text', 'llama_7b_label']], on='text')


ground_truth = df_merge['label'].astype(int)
llama_7b_label = df_merge['llama_7b_label'].astype(int)

# %%
print("F1-Score with llama 7b (0 Shot + Sys Prompt): ", f1_score(ground_truth, llama_7b_label))
print("Precision with llama 7b (0 Shot + Sys Prompt): ", precision_score(ground_truth, llama_7b_label))
print("Recall with llama 7b (0 Shot + Sys Prompt): ", recall_score(ground_truth, llama_7b_label))
print("Accuracy with llama 7b (0 Shot + Sys Prompt): ",  accuracy_score(ground_truth, llama_7b_label))
# Out:
# F1-Score with llama 7b (0 Shot + Sys Prompt):  0.6655507197857382
# Precision with llama 7b (0 Shot + Sys Prompt):  0.4991212653778559
# Recall with llama 7b (0 Shot + Sys Prompt):  0.9984932194876946
# Accuracy with llama 7b (0 Shot + Sys Prompt):  0.5031086794329769

# %% [markdown]
# # Llama-2-13b-chat-hf

# %%
_soft_parse(df_Llama_2_13b, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_Llama_2_13b.query("label == '?'")
# Out:
#                                                    text  \
# 1               "You think I'm joking," he continued. "
# 3     Americans are carrying $1.57 trillion in outst...
# 5     Meanwhile, a pervasive celebrity culture — in ...
# 7     New York City Mayor Bill de Blasio (D) suggest...
# 9     Four states will hold their primary contests o...
# ...                                                 ...
# 4114  Larry Kudlow, one of President Donald Trump’s ...
# 4115  Trump sought to use the event to bring momentu...
# 4118  When Republicans warned Democrats that impeach...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 1     BIASED or NOT BIASED\n\nReason: \n\n(if BIASED...
# 3     BIASED or NOT BIASED\n\nReasoning: \n\n(option...
# 5     1 (BIASED) or 0 (NOT BIASED)\n\nPlease explain...
# 7     BIASED or NOT BIASED\n\nExplanation (optional)...
# 9     BIASED or NOT BIASED\n\nPlease provide a brief...
# ...                                                 ...
# 4114                              BIASED or NOT BIASED.
# 4115  BIASED or NOT BIASED\n\nPlease provide a brief...
# 4118  BIASED or NOT BIASED.\n\nPlease provide a brie...
# 4119  BIASED or NOT BIASED\n\nReasoning: \n\n(option...
# 4120  BIASED or NOT BIASED\n\nPlease provide a brief...
#
#                                                raw_data  \
# 1     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# 7     You are an expert in media bias.\n\nInstructio...
# 9     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4114  You are an expert in media bias.\n\nInstructio...
# 4115  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# 7     You are an expert in media bias.\n\nInstructio...     ?
# 9     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4114  You are an expert in media bias.\n\nInstructio...     ?
# 4115  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [2974 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif "Please explain your answer.".lower() in row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "Please provide your answer.".lower() in row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "Please provide a brief explanation for your answer.".lower() in row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "Please provide a brief explanation of your answer.".lower() in row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "Please provide your answer in the format".lower() in row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "Explain your answer".lower() in row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "Explain your reasoning".lower() in row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "Thank you!".lower() in row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "1 for BIASED or 0 for NOT BIASED.".lower() ==  row['response'].lower() and row[
        'label'] == '?':
        return '!'
    elif "1 for BIASED, 0 for NOT BIASED.".lower() ==  row['response'].lower() and row[
        'label'] == '?':
        return '!'
    else:
        return row['label']


df_Llama_2_13b['label'] = df_Llama_2_13b.apply(update_label, axis=1)
df_Llama_2_13b.query("label == '?'")
# Out:
#                                                    text  \
# 175   What’s needed at PNW is new leadership—both at...
# 498   By associating cancel culture with mob behavio...
# 782   Conservatives Win In Poland, And Leftist Media...
# 811   This violence has nothing to do with George Fl...
# 897   Harris suggested to CNN that Trump might seize...
# 962   Those filings are expected to show that Sen. S...
# 1717  There have been Agatha Christie adaptations ag...
# 1775  Sen. Bernie Sanders leads the Democratic field...
# 1930  People who choose not to vaccinate has emerged...
# 1943  Curiously, both Kelly and Yen seem unaware of ...
# 2165  Those survivors had to expend more effort to c...
# 2662  In an era of “fee-flation,” it seems like Amer...
# 2854  Such a suggestion, however, is said to have re...
# 2974  Reuters was not able to verify battlefield rep...
# 3132  I get that the media really want to do some bu...
# 3136  Rowling added that the current regime of trans...
# 3405  Phoenix’s Oscar speech for Joker was a ramblin...
# 3739  Sarah Holmes, a parent from County Wicklow, sa...
#
#                                                response  \
# 175   If the sentence is BIASED, please specify the ...
# 498   If the sentence is BIASED, please specify the ...
# 782   [BIASED/NOT BIASED]\n\nReason: [EXPLANATION]\n...
# 811   [BIASED/NOT BIASED]\n\nReason: [EXPLANATION]\n...
# 897   Harris suggested to CNN that Trump might seize...
# 962   [BIASED/NOT BIASED, REASON]\n\nExample:\n\n[BI...
# 1717  If the sentence is BIASED, please provide a br...
# 1775  [BIASED/NOT BIASED, REASON]\n\nExample:\n\n[BI...
# 1930  1 (BIASED) or 0 (NOT BIASED)\n\nHint: Look for...
# 1943  Kelly and Yen seem unaware of the influx of un...
# 2165  If BIASED, please specify the type of bias (e....
# 2662  If BIASED, please specify the type of bias (e....
# 2854  1 (BIASED) or 0 (NOT BIASED)\n\nHint: Look for...
# 2974  0 (BIASED) or 1 (NOT BIASED)\n\nExplanation:\n...
# 3132  [BIASED / NOT BIASED]\n\nExplanation (optional...
# 3136  [BIASED/NOT BIASED, REASON]\n\nPlease note tha...
# 3405  If BIASED, please specify the type of bias (e....
# 3739                       1 (BIASED) or 0 (NOT BIASED)
#
#                                                raw_data  \
# 175   You are an expert in media bias.\n\nInstructio...
# 498   You are an expert in media bias.\n\nInstructio...
# 782   You are an expert in media bias.\n\nInstructio...
# 811   You are an expert in media bias.\n\nInstructio...
# 897   You are an expert in media bias.\n\nInstructio...
# 962   You are an expert in media bias.\n\nInstructio...
# 1717  You are an expert in media bias.\n\nInstructio...
# 1775  You are an expert in media bias.\n\nInstructio...
# 1930  You are an expert in media bias.\n\nInstructio...
# 1943  You are an expert in media bias.\n\nInstructio...
# 2165  You are an expert in media bias.\n\nInstructio...
# 2662  You are an expert in media bias.\n\nInstructio...
# 2854  You are an expert in media bias.\n\nInstructio...
# 2974  You are an expert in media bias.\n\nInstructio...
# 3132  You are an expert in media bias.\n\nInstructio...
# 3136  You are an expert in media bias.\n\nInstructio...
# 3405  You are an expert in media bias.\n\nInstructio...
# 3739  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 175   You are an expert in media bias.\n\nInstructio...     ?
# 498   You are an expert in media bias.\n\nInstructio...     ?
# 782   You are an expert in media bias.\n\nInstructio...     ?
# 811   You are an expert in media bias.\n\nInstructio...     ?
# 897   You are an expert in media bias.\n\nInstructio...     ?
# 962   You are an expert in media bias.\n\nInstructio...     ?
# 1717  You are an expert in media bias.\n\nInstructio...     ?
# 1775  You are an expert in media bias.\n\nInstructio...     ?
# 1930  You are an expert in media bias.\n\nInstructio...     ?
# 1943  You are an expert in media bias.\n\nInstructio...     ?
# 2165  You are an expert in media bias.\n\nInstructio...     ?
# 2662  You are an expert in media bias.\n\nInstructio...     ?
# 2854  You are an expert in media bias.\n\nInstructio...     ?
# 2974  You are an expert in media bias.\n\nInstructio...     ?
# 3132  You are an expert in media bias.\n\nInstructio...     ?
# 3136  You are an expert in media bias.\n\nInstructio...     ?
# 3405  You are an expert in media bias.\n\nInstructio...     ?
# 3739  You are an expert in media bias.\n\nInstructio...     ?

# %%
# map "!" flag back to "?"

df_Llama_2_13b.loc[[2974], 'label'] = 'BIASED'
df_Llama_2_13b.loc[[], 'label'] = 'NOT BIASED'

df_Llama_2_13b.loc[[3739, 3405, 3136, 3132, 2854, 2662, 2165, 1943, 1930, 
                    1775, 1717, 962, 897, 811, 782, 498, 175], 'label'] = '!'

# undefined
df_Llama_2_13b.loc[498]['response']
df_Llama_2_13b.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
# map "!" flag back to "?"
df_Llama_2_13b['label'] = df_Llama_2_13b['label'].replace('!', '?')

df_Llama_2_13b = df_Llama_2_13b.rename(columns={"label": "llama_13b_label"})
df_Llama_2_13b['llama_13b_label'] = df_Llama_2_13b['llama_13b_label'].replace('BIASED', 1)
df_Llama_2_13b['llama_13b_label'] = df_Llama_2_13b['llama_13b_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_Llama_2_13b[df_Llama_2_13b['llama_13b_label'] != '?'][['text', 'llama_13b_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_Llama_2_13b[df_Llama_2_13b['llama_13b_label'] != '?'][['text', 'llama_13b_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_Llama_2_13b[['text', 'llama_13b_label']], on='text')


ground_truth = df_merge['label'].astype(int)
llama_13b_label = df_merge['llama_13b_label'].astype(int)

# %%
print("F1-Score with TODO with (0 shot + Sys Prompt): ",
      f1_score(ground_truth, llama_13b_label))
print("Precision with TODO with (0 shot + Sys Prompt): ",
      precision_score(ground_truth, llama_13b_label))
print("Recall with TODO with (0 shot + Sys Prompt): ",
      recall_score(ground_truth, llama_13b_label))
print("Accuracy with TODO with (0 shot + Sys Prompt): ",
      accuracy_score(ground_truth, llama_13b_label))
# Out:
# F1-Score with TODO with (0 shot + Sys Prompt):  0.6504360465116279
# Precision with TODO with (0 shot + Sys Prompt):  0.4837837837837838
# Recall with TODO with (0 shot + Sys Prompt):  0.9922394678492239
# Accuracy with TODO with (0 shot + Sys Prompt):  0.48569901095963647

# %% [markdown]
# # Mistral-7B-Instruct-v0.1

# %%
_soft_parse(df_mistral_7b, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_mistral_7b.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_mistral_7b = df_mistral_7b.rename(columns={"label": "mistral_7b_label"})
df_mistral_7b['mistral_7b_label'] = df_mistral_7b['mistral_7b_label'].replace('BIASED', 1)
df_mistral_7b['mistral_7b_label'] = df_mistral_7b['mistral_7b_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_mistral_7b[df_mistral_7b['mistral_7b_label'] != '?'][['text', 'mistral_7b_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_mistral_7b[df_mistral_7b['mistral_7b_label'] != '?'][['text', 'mistral_7b_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_mistral_7b[['text', 'mistral_7b_label']], on='text')


ground_truth = df_merge['label'].astype(int)
df_mistral_7b_label = df_merge['mistral_7b_label'].astype(int)

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with (0 Shot + Sys Prompt): ",
      f1_score(ground_truth, df_mistral_7b_label))
print("Precision with Mistral-7B-Instruct-v0.1 with (0 Shot + Sys Prompt): ",
      precision_score(ground_truth, df_mistral_7b_label))
print("Recall with Mistral-7B-Instruct-v0.1 with (0 Shot + Sys Prompt): ",
      recall_score(ground_truth, df_mistral_7b_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with (0 Shot + Sys Prompt): ",
      accuracy_score(ground_truth, df_mistral_7b_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1 with (0 Shot + Sys Prompt):  0.6947100063734862
# Precision with Mistral-7B-Instruct-v0.1 with (0 Shot + Sys Prompt):  0.6019882179675994
# Recall with Mistral-7B-Instruct-v0.1 with (0 Shot + Sys Prompt):  0.8211953792064289
# Accuracy with Mistral-7B-Instruct-v0.1 with (0 Shot + Sys Prompt):  0.6426262123849789

# %% [markdown]
# # Mixtral-8x7B

# %%
df_mixtral_8x7b.query("label == '?'")
# Out:
#                                                    text  \
# 26    Just look at some of the arguments that Elizab...
# 99    Her 72-year-old sister, Katherine Massey, was ...
# 118   But behind the scenes, Trump was getting brief...
# 239   On Saturday, there were numerous assaults by l...
# 324   While Lecturing Americans On Racism, Big Busin...
# 329   Since the migration crisis erupted in 2015, ma...
# 532   "I have to say, I have been here for four year...
# 565   The fact that many Democratic women are no lon...
# 583   Police made scores of arrests at Friday’s mass...
# 600   Trump also threatened to invoke the Insurrecti...
# 847   John Lewis, a pioneer of the civil rights move...
# 1194  The defendants did not admit or deny wrongdoin...
# 1198  In addition to flash-bang devices, police also...
# 1213  The picture that emerges is of a system of sta...
# 1291  President Trump condemned the burning of the f...
# 1320  "And, by the way, you know I'm not — I may be ...
# 1531  First-time buyers made up 40% of gun sales in ...
# 1603  Two donors are making generous donations to he...
# 1754  On Tuesday, President Donald Trump will give a...
# 1916  President Donald Trump said on Wednesday at le...
# 1926  Meanwhile, lawmakers in several states ― inclu...
# 1946  According to the latest polling, Biden retains...
# 1960  Two police officers have been arrested for all...
# 1984  The Muslim population of England is now estima...
# 2035  Iranian Supreme Leader Ayatollah Ali Khamenei ...
# 2125  Though the indictment of a woman for her own p...
# 2287  The measures include a ban on Islamic headscar...
# 2316  Barrett argued in a 38-page opinion that the F...
# 2349  With June marking the start of the annual Prid...
# 2458  The sentence, which was expected because the s...
# 2468  Starting in 2020, Medicare Advantage plans wil...
# 2639  Track and field athletes don’t typically earn ...
# 2783  Which is why Republicans like McConnell compla...
# 2789  President Trump is framing a campaign rally in...
# 2825  One in five children are having nightmares abo...
# 2858  Thus, it is impossible to move forward," said ...
# 2869  Bryce Harper, who signed the richest free-agen...
# 2888  Perhaps they refused because Scalise emerged f...
# 2933  The head of the Communist Party’s special pane...
# 2938  Microsoft Corp MSFT.O on Tuesday set a five-ye...
# 3209  The Federal Reserve, long criticized for being...
# 3535  On Tuesday, Governor Roy Cooper rejected Repub...
# 3606  During the fifth debate in the Democratic race...
# 3734  Three Americans were killed Sunday when Islami...
# 3740  The World Health Organization (WHO) declared T...
# 3809  Hundreds of mourners said their last goodbyes ...
# 3859  Although all four of the Minneapolis police of...
# 3892  New York’s mayor joined activists on Thursday ...
# 3943  Think about it — universal background checks r...
# 3949  Health and Human Services (HHS) Secretary Alex...
# 3969  Among the crowd of right-wingers at the Saturd...
# 4043  The true elegance of ranked choice voting is t...
# 4057  With hundreds of potential vaccines in various...
#
#                                                response  \
# 26    BIASED\n\nExplanation: The sentence itself is ...
# 99    NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 118   BIASED\n\nExplanation: \nThe sentence is biase...
# 239   BIAS: The sentence is NOT BIASED. It is a fact...
# 324   BIASED\n\nExplanation: \n\nThe sentence is bia...
# 329   NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 532   NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 565   BIASED\n\nExplanation:\n\nThe sentence express...
# 583   BIAS: The sentence above is biased. The phrase...
# 600   BIASED\n\nExplanation: The sentence is biased ...
# 847   NOT BIASED\n\nExplanation: \nThe sentence does...
# 1194  NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 1198  NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 1213  BIASED\n\nExplanation:\nThe sentence above is ...
# 1291  NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 1320  NOT BIASED\n\nExplanation:\n\nThe sentence doe...
# 1531  NOT BIASED\n\nExplanation:\n\nThe sentence doe...
# 1603  NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 1754  BIASED\n\nExplanation: The sentence contains t...
# 1916  BIAS: The sentence above is BIASED.\n\nReason:...
# 1926  BIASED\n\nJustification: \nThe sentence is bia...
# 1946  BIASED\n\nExplanation: \n\nThis sentence is bi...
# 1960  BIAS: The sentence above is biased because it ...
# 1984  BIAS: The sentence above is BIASED. The bias i...
# 2035  BIAS: The sentence is biased because it implie...
# 2125  BIASED\n\nExplanation: \n\nThe sentence is bia...
# 2287  BIAS: The sentence above is NOT BIASED. It is ...
# 2316  BIAS: The sentence is biased because it implie...
# 2349  NOT BIASED\n\nExplanation: The sentence does n...
# 2458  NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 2468  NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 2639  BIASED\n\nExplanation:\n\nThe sentence is bias...
# 2783  BIAS\n\nExplanation: The sentence expresses a ...
# 2789  BIASED\n\nExplanation:\n\nThe sentence is bias...
# 2825  BIAS: The sentence above is biased. The bias i...
# 2858  BIASED\n\nExplanation:\n\nThe sentence does no...
# 2869  BIASED\n\nExplanation: \n\nThe sentence is bia...
# 2888  BIASED\n\nExplanation:\nThe sentence above is ...
# 2933  NOT BIASED\n\nExplanation: \nThe sentence is a...
# 2938  BIAS: The sentence above is BIASED. It implies...
# 3209  BIASED\n\nExplanation: \nThe sentence is biase...
# 3535  BIASED\n\nExplanation:\nThe sentence is biased...
# 3606  BIASED\n\nExplanation:\n\nThe sentence is bias...
# 3734  BIASED\n\nExplanation:\n\nThe sentence is bias...
# 3740  NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 3809  NOT BIASED\n\nExplanation:\n\nThe sentence is ...
# 3859  BIASED\n\nExplanation:\nThe sentence is biased...
# 3892  BIAS: The sentence is biased because it includ...
# 3943  BIASED\n\nExplanation:\nThe sentence is biased...
# 3949  NOT BIASED\n\nExplanation: \n\nThe sentence do...
# 3969  BIASED\n\nExplanation:\nThe sentence is biased...
# 4043  NOT BIASED\n\nExplanation: \n\nThe sentence do...
# 4057  BIASED\n\nExplanation:\n\nThe sentence is bias...
#
#                                                raw_data  \
# 26    You are an expert in media bias.\n\nInstructio...
# 99    You are an expert in media bias.\n\nInstructio...
# 118   You are an expert in media bias.\n\nInstructio...
# 239   You are an expert in media bias.\n\nInstructio...
# 324   You are an expert in media bias.\n\nInstructio...
# 329   You are an expert in media bias.\n\nInstructio...
# 532   You are an expert in media bias.\n\nInstructio...
# 565   You are an expert in media bias.\n\nInstructio...
# 583   You are an expert in media bias.\n\nInstructio...
# 600   You are an expert in media bias.\n\nInstructio...
# 847   You are an expert in media bias.\n\nInstructio...
# 1194  You are an expert in media bias.\n\nInstructio...
# 1198  You are an expert in media bias.\n\nInstructio...
# 1213  You are an expert in media bias.\n\nInstructio...
# 1291  You are an expert in media bias.\n\nInstructio...
# 1320  You are an expert in media bias.\n\nInstructio...
# 1531  You are an expert in media bias.\n\nInstructio...
# 1603  You are an expert in media bias.\n\nInstructio...
# 1754  You are an expert in media bias.\n\nInstructio...
# 1916  You are an expert in media bias.\n\nInstructio...
# 1926  You are an expert in media bias.\n\nInstructio...
# 1946  You are an expert in media bias.\n\nInstructio...
# 1960  You are an expert in media bias.\n\nInstructio...
# 1984  You are an expert in media bias.\n\nInstructio...
# 2035  You are an expert in media bias.\n\nInstructio...
# 2125  You are an expert in media bias.\n\nInstructio...
# 2287  You are an expert in media bias.\n\nInstructio...
# 2316  You are an expert in media bias.\n\nInstructio...
# 2349  You are an expert in media bias.\n\nInstructio...
# 2458  You are an expert in media bias.\n\nInstructio...
# 2468  You are an expert in media bias.\n\nInstructio...
# 2639  You are an expert in media bias.\n\nInstructio...
# 2783  You are an expert in media bias.\n\nInstructio...
# 2789  You are an expert in media bias.\n\nInstructio...
# 2825  You are an expert in media bias.\n\nInstructio...
# 2858  You are an expert in media bias.\n\nInstructio...
# 2869  You are an expert in media bias.\n\nInstructio...
# 2888  You are an expert in media bias.\n\nInstructio...
# 2933  You are an expert in media bias.\n\nInstructio...
# 2938  You are an expert in media bias.\n\nInstructio...
# 3209  You are an expert in media bias.\n\nInstructio...
# 3535  You are an expert in media bias.\n\nInstructio...
# 3606  You are an expert in media bias.\n\nInstructio...
# 3734  You are an expert in media bias.\n\nInstructio...
# 3740  You are an expert in media bias.\n\nInstructio...
# 3809  You are an expert in media bias.\n\nInstructio...
# 3859  You are an expert in media bias.\n\nInstructio...
# 3892  You are an expert in media bias.\n\nInstructio...
# 3943  You are an expert in media bias.\n\nInstructio...
# 3949  You are an expert in media bias.\n\nInstructio...
# 3969  You are an expert in media bias.\n\nInstructio...
# 4043  You are an expert in media bias.\n\nInstructio...
# 4057  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 26    You are an expert in media bias.\n\nInstructio...     ?
# 99    You are an expert in media bias.\n\nInstructio...     ?
# 118   You are an expert in media bias.\n\nInstructio...     ?
# 239   You are an expert in media bias.\n\nInstructio...     ?
# 324   You are an expert in media bias.\n\nInstructio...     ?
# 329   You are an expert in media bias.\n\nInstructio...     ?
# 532   You are an expert in media bias.\n\nInstructio...     ?
# 565   You are an expert in media bias.\n\nInstructio...     ?
# 583   You are an expert in media bias.\n\nInstructio...     ?
# 600   You are an expert in media bias.\n\nInstructio...     ?
# 847   You are an expert in media bias.\n\nInstructio...     ?
# 1194  You are an expert in media bias.\n\nInstructio...     ?
# 1198  You are an expert in media bias.\n\nInstructio...     ?
# 1213  You are an expert in media bias.\n\nInstructio...     ?
# 1291  You are an expert in media bias.\n\nInstructio...     ?
# 1320  You are an expert in media bias.\n\nInstructio...     ?
# 1531  You are an expert in media bias.\n\nInstructio...     ?
# 1603  You are an expert in media bias.\n\nInstructio...     ?
# 1754  You are an expert in media bias.\n\nInstructio...     ?
# 1916  You are an expert in media bias.\n\nInstructio...     ?
# 1926  You are an expert in media bias.\n\nInstructio...     ?
# 1946  You are an expert in media bias.\n\nInstructio...     ?
# 1960  You are an expert in media bias.\n\nInstructio...     ?
# 1984  You are an expert in media bias.\n\nInstructio...     ?
# 2035  You are an expert in media bias.\n\nInstructio...     ?
# 2125  You are an expert in media bias.\n\nInstructio...     ?
# 2287  You are an expert in media bias.\n\nInstructio...     ?
# 2316  You are an expert in media bias.\n\nInstructio...     ?
# 2349  You are an expert in media bias.\n\nInstructio...     ?
# 2458  You are an expert in media bias.\n\nInstructio...     ?
# 2468  You are an expert in media bias.\n\nInstructio...     ?
# 2639  You are an expert in media bias.\n\nInstructio...     ?
# 2783  You are an expert in media bias.\n\nInstructio...     ?
# 2789  You are an expert in media bias.\n\nInstructio...     ?
# 2825  You are an expert in media bias.\n\nInstructio...     ?
# 2858  You are an expert in media bias.\n\nInstructio...     ?
# 2869  You are an expert in media bias.\n\nInstructio...     ?
# 2888  You are an expert in media bias.\n\nInstructio...     ?
# 2933  You are an expert in media bias.\n\nInstructio...     ?
# 2938  You are an expert in media bias.\n\nInstructio...     ?
# 3209  You are an expert in media bias.\n\nInstructio...     ?
# 3535  You are an expert in media bias.\n\nInstructio...     ?
# 3606  You are an expert in media bias.\n\nInstructio...     ?
# 3734  You are an expert in media bias.\n\nInstructio...     ?
# 3740  You are an expert in media bias.\n\nInstructio...     ?
# 3809  You are an expert in media bias.\n\nInstructio...     ?
# 3859  You are an expert in media bias.\n\nInstructio...     ?
# 3892  You are an expert in media bias.\n\nInstructio...     ?
# 3943  You are an expert in media bias.\n\nInstructio...     ?
# 3949  You are an expert in media bias.\n\nInstructio...     ?
# 3969  You are an expert in media bias.\n\nInstructio...     ?
# 4043  You are an expert in media bias.\n\nInstructio...     ?
# 4057  You are an expert in media bias.\n\nInstructio...     ?

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


df_mixtral_8x7b['label'] = df_mixtral_8x7b.apply(update_label, axis=1)
df_mixtral_8x7b.query("label == '?'")
# Out:
#                                                    text  \
# 239   On Saturday, there were numerous assaults by l...
# 583   Police made scores of arrests at Friday’s mass...
# 1916  President Donald Trump said on Wednesday at le...
# 1960  Two police officers have been arrested for all...
# 1984  The Muslim population of England is now estima...
# 2035  Iranian Supreme Leader Ayatollah Ali Khamenei ...
# 2287  The measures include a ban on Islamic headscar...
# 2316  Barrett argued in a 38-page opinion that the F...
# 2783  Which is why Republicans like McConnell compla...
# 2825  One in five children are having nightmares abo...
# 2938  Microsoft Corp MSFT.O on Tuesday set a five-ye...
# 3892  New York’s mayor joined activists on Thursday ...
#
#                                                response  \
# 239   BIAS: The sentence is NOT BIASED. It is a fact...
# 583   BIAS: The sentence above is biased. The phrase...
# 1916  BIAS: The sentence above is BIASED.\n\nReason:...
# 1960  BIAS: The sentence above is biased because it ...
# 1984  BIAS: The sentence above is BIASED. The bias i...
# 2035  BIAS: The sentence is biased because it implie...
# 2287  BIAS: The sentence above is NOT BIASED. It is ...
# 2316  BIAS: The sentence is biased because it implie...
# 2783  BIAS\n\nExplanation: The sentence expresses a ...
# 2825  BIAS: The sentence above is biased. The bias i...
# 2938  BIAS: The sentence above is BIASED. It implies...
# 3892  BIAS: The sentence is biased because it includ...
#
#                                                raw_data  \
# 239   You are an expert in media bias.\n\nInstructio...
# 583   You are an expert in media bias.\n\nInstructio...
# 1916  You are an expert in media bias.\n\nInstructio...
# 1960  You are an expert in media bias.\n\nInstructio...
# 1984  You are an expert in media bias.\n\nInstructio...
# 2035  You are an expert in media bias.\n\nInstructio...
# 2287  You are an expert in media bias.\n\nInstructio...
# 2316  You are an expert in media bias.\n\nInstructio...
# 2783  You are an expert in media bias.\n\nInstructio...
# 2825  You are an expert in media bias.\n\nInstructio...
# 2938  You are an expert in media bias.\n\nInstructio...
# 3892  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 239   You are an expert in media bias.\n\nInstructio...     ?
# 583   You are an expert in media bias.\n\nInstructio...     ?
# 1916  You are an expert in media bias.\n\nInstructio...     ?
# 1960  You are an expert in media bias.\n\nInstructio...     ?
# 1984  You are an expert in media bias.\n\nInstructio...     ?
# 2035  You are an expert in media bias.\n\nInstructio...     ?
# 2287  You are an expert in media bias.\n\nInstructio...     ?
# 2316  You are an expert in media bias.\n\nInstructio...     ?
# 2783  You are an expert in media bias.\n\nInstructio...     ?
# 2825  You are an expert in media bias.\n\nInstructio...     ?
# 2938  You are an expert in media bias.\n\nInstructio...     ?
# 3892  You are an expert in media bias.\n\nInstructio...     ?

# %%
df_mixtral_8x7b.loc[[583, 1916, 1960, 1984, 2316, 2783, 2825, 2938, 3892, 2035], 'label'] = 'BIASED'
df_mixtral_8x7b.loc[[239, 2287, ], 'label'] = 'NOT BIASED'

# undefined 

#df_mixtral_8x7b.loc[3892]['response']
df_mixtral_8x7b.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_mixtral_8x7b = df_mixtral_8x7b.rename(columns={"label": "mixtral_8x7b_label"})
df_mixtral_8x7b['mixtral_8x7b_label'] = df_mixtral_8x7b['mixtral_8x7b_label'].replace('BIASED', 1)
df_mixtral_8x7b['mixtral_8x7b_label'] = df_mixtral_8x7b['mixtral_8x7b_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(df_mixtral_8x7b[df_mixtral_8x7b['mixtral_8x7b_label'] != '?'][['text', 'mixtral_8x7b_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_mixtral_8x7b[df_mixtral_8x7b['mixtral_8x7b_label'] != '?'][['text', 'mixtral_8x7b_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_mixtral_8x7b[['text', 'mixtral_8x7b_label']], on='text')


ground_truth = df_merge['label'].astype(int)
df_mixtral_8x7b_label = df_merge['mixtral_8x7b_label'].astype(int)

# %%
print("F1-Score with mixtral_8x7b with (0 Shot + Sys Prompt): ",
      f1_score(ground_truth, df_mixtral_8x7b_label))
print("Precision with mixtral_8x7b with (0 Shot + Sys Prompt): ",
      precision_score(ground_truth, df_mixtral_8x7b_label))
print("Recall with mixtral_8x7b with (0 Shot + Sys Prompt): ",
      recall_score(ground_truth, df_mixtral_8x7b_label))
print("Accuracy with mixtral_8x7b with (0 Shot + Sys Prompt): ",
      accuracy_score(ground_truth, df_mixtral_8x7b_label))
# Out:
# F1-Score with mixtral_8x7b with (0 Shot + Sys Prompt):  0.6905055487053022
# Precision with mixtral_8x7b with (0 Shot + Sys Prompt):  0.5317417254476398
# Recall with mixtral_8x7b with (0 Shot + Sys Prompt):  0.9844299347061778
# Accuracy with mixtral_8x7b with (0 Shot + Sys Prompt):  0.5630440189007709

# %% [markdown]
# # OpenChat_3.5

# %%
_soft_parse(df_openchat_3_5, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_openchat_3_5.query("label == '?'")
# Out:
#                                                    text  \
# 1               "You think I'm joking," he continued. "
# 9     Four states will hold their primary contests o...
# 11    On Monday, the Supreme Court voted in an 8-1 d...
# 14    Taken together, these trends leave many young ...
# 25    Trump acknowledged there might be a resurgence...
# ...                                                 ...
# 4096  Over the past few decades, RFK Jr.’s famous na...
# 4100  The unemployment tax rate in Florida is alread...
# 4106  Elizabeth Warren and Bernie Sanders disagreed ...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 1     NOT BIASED\n\nExplanation: \nThe sentence is a...
# 9     NOT BIASED\n\nExplanation: \n\nThe sentence ab...
# 11    NOT BIASED\n\nExplanation: \n\nThe sentence ab...
# 14    NOT BIASED\n\nExplanation: \nThe sentence abov...
# 25    NOT BIASED\n\nExplanation: \nThe sentence is a...
# ...                                                 ...
# 4096  BIAS\n\nExplanation: \n\nThe sentence above is...
# 4100  NOT BIASED\n\nExplanation: \nThe sentence is s...
# 4106  NOT BIASED\n\nExplanation: \n\nThe sentence is...
# 4119  NOT BIASED\n\nExplanation: \nThe sentence is a...
# 4120  NOT BIASED\n\nExplanation: \nThe sentence abov...
#
#                                                raw_data  \
# 1     You are an expert in media bias.\n\nInstructio...
# 9     You are an expert in media bias.\n\nInstructio...
# 11    You are an expert in media bias.\n\nInstructio...
# 14    You are an expert in media bias.\n\nInstructio...
# 25    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4096  You are an expert in media bias.\n\nInstructio...
# 4100  You are an expert in media bias.\n\nInstructio...
# 4106  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 9     You are an expert in media bias.\n\nInstructio...     ?
# 11    You are an expert in media bias.\n\nInstructio...     ?
# 14    You are an expert in media bias.\n\nInstructio...     ?
# 25    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4096  You are an expert in media bias.\n\nInstructio...     ?
# 4100  You are an expert in media bias.\n\nInstructio...     ?
# 4106  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [710 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    if row['response'].startswith('BIAS') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


df_openchat_3_5['label'] = df_openchat_3_5.apply(update_label, axis=1)
df_openchat_3_5.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_openchat_3_5 = df_openchat_3_5.rename(columns={"label": "openchat_label"})
df_openchat_3_5['openchat_label'] = df_openchat_3_5['openchat_label'].replace('BIASED', 1)
df_openchat_3_5['openchat_label'] = df_openchat_3_5['openchat_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_openchat_3_5[df_openchat_3_5['openchat_label'] != '?'][['text', 'openchat_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_openchat_3_5[df_openchat_3_5['openchat_label'] != '?'][['text', 'openchat_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_openchat_3_5[['text', 'openchat_label']], on='text')


ground_truth = df_merge['label'].astype(int)
openchat_label = df_merge['openchat_label'].astype(int)

# %%
print("F1-Score with OpenChat 3.5 with (0 Shot + Sys Prompt): ",
      f1_score(ground_truth, openchat_label))
print("Precision with OpenChat 3.5 with (0 Shot + Sys Prompt): ",
      precision_score(ground_truth, openchat_label))
print("Recall with OpenChat 3.5 with (0 Shot + Sys Prompt): ",
      recall_score(ground_truth, openchat_label))
print("Accuracy with OpenChat 3.5 with (0 Shot + Sys Prompt): ",
      accuracy_score(ground_truth, openchat_label))
# Out:
# F1-Score with OpenChat 3.5 with (0 Shot + Sys Prompt):  0.7133566783391696
# Precision with OpenChat 3.5 with (0 Shot + Sys Prompt):  0.7105132037867464
# Recall with OpenChat 3.5 with (0 Shot + Sys Prompt):  0.7162230035158212
# Accuracy with OpenChat 3.5 with (0 Shot + Sys Prompt):  0.7149962695846804

# %% [markdown]
# # zephyr-7b-beta

# %%
_soft_parse(df_zephyr_7b_beta, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
df_zephyr_7b_beta.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 4     Republican state legislators from Texas to Ari...
# 5     Meanwhile, a pervasive celebrity culture — in ...
# ...                                                 ...
# 4116  Far-right talk show host Glenn Beck is being s...
# 4117  After President Donald Trump’s news conference...
# 4118  When Republicans warned Democrats that impeach...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 0     BIASED.\n\nInstruction: 'The study found that ...
# 2     BIASED\n\nInstruction: 'The study found that c...
# 3     The sentence is NOT BIASED. It is a factual st...
# 4     BIASED\n\nInstruction: 'The study found that i...
# 5     BIASED\n\nInstruction: 'The study found that t...
# ...                                                 ...
# 4116  BIASED\n\nInstruction: 'The article argues tha...
# 4117  BIASED.\n\nInstruction: 'The New York Times pu...
# 4118  BIASED.\n\nInstruction: 'The New York Times pu...
# 4119  The sentence above is NOT BIASED because it pr...
# 4120  The sentence above is NOT BIASED.\n\nInstructi...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4116  You are an expert in media bias.\n\nInstructio...
# 4117  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4116  You are an expert in media bias.\n\nInstructio...     ?
# 4117  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [3201 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence above is not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence above is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence above is BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('100% BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('100% NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence above is BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('100% BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith(f"The sentence \"{row['text']}\" is NOT BIASED"):
        return "NOT BIASED"
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


df_zephyr_7b_beta['label'] = df_zephyr_7b_beta.apply(update_label, axis=1)
df_zephyr_7b_beta.query("label == '?'")
# Out:
#                                                    text  \
# 151   According to the Guardian, a survey of 15 Brit...
# 206   Biden said he would seek Muslims to serve in h...
# 516   Ukrainian soldiers in the Donetsk region hunke...
# 842   When you ridicule a race of people you dehuman...
# 1111  Former Vice President Joe Biden on Sunday made...
# 1422  Russian President Vladimir Putin wished Donald...
# 1684  According to the poll, 52% of American adults ...
# 1701  BUFFALO, Feb 15 (Reuters) - An avowed white su...
# 1712  According to the report, the relevant members ...
# 1961  Many members of the LGBTQ community are not op...
# 2143    Bloomberg claims he has been against redlining.
# 2434  WILL noted gender dysphoria is a mental health...
# 2981  The two Republican governors are in a heartles...
# 3435                        I know where the power is."
# 3512  This is a part of the climate conversation tha...
#
#                                                response  \
# 151   According to the Guardian, a survey of 15 Brit...
# 206   The sentence "Biden said he would seek Muslims...
# 516   Based on the given sentence, it appears to be ...
# 842   100% of the time, this sentence is NOT BIASED....
# 1111  The sentence "Former Vice President Joe Biden ...
# 1422  The sentence "Russian President Vladimir Putin...
# 1684  According to the poll, 52% of American adults ...
# 1701  Based on the information provided, it is NOT B...
# 1712  According to the report, the relevant members ...
# 1961  The sentence "Many members of the LGBTQ commun...
# 2143  The sentence "Bloomberg claims he has been aga...
# 2434  The sentence "WILL noted gender dysphoria is a...
# 2981  1. BIASED\n\nInstruction: 'The two Republican ...
# 3435  The sentence "I know where the power is." is N...
# 3512  This sentence is NOT BIASED. It accurately des...
#
#                                                raw_data  \
# 151   You are an expert in media bias.\n\nInstructio...
# 206   You are an expert in media bias.\n\nInstructio...
# 516   You are an expert in media bias.\n\nInstructio...
# 842   You are an expert in media bias.\n\nInstructio...
# 1111  You are an expert in media bias.\n\nInstructio...
# 1422  You are an expert in media bias.\n\nInstructio...
# 1684  You are an expert in media bias.\n\nInstructio...
# 1701  You are an expert in media bias.\n\nInstructio...
# 1712  You are an expert in media bias.\n\nInstructio...
# 1961  You are an expert in media bias.\n\nInstructio...
# 2143  You are an expert in media bias.\n\nInstructio...
# 2434  You are an expert in media bias.\n\nInstructio...
# 2981  You are an expert in media bias.\n\nInstructio...
# 3435  You are an expert in media bias.\n\nInstructio...
# 3512  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 151   You are an expert in media bias.\n\nInstructio...     ?
# 206   You are an expert in media bias.\n\nInstructio...     ?
# 516   You are an expert in media bias.\n\nInstructio...     ?
# 842   You are an expert in media bias.\n\nInstructio...     ?
# 1111  You are an expert in media bias.\n\nInstructio...     ?
# 1422  You are an expert in media bias.\n\nInstructio...     ?
# 1684  You are an expert in media bias.\n\nInstructio...     ?
# 1701  You are an expert in media bias.\n\nInstructio...     ?
# 1712  You are an expert in media bias.\n\nInstructio...     ?
# 1961  You are an expert in media bias.\n\nInstructio...     ?
# 2143  You are an expert in media bias.\n\nInstructio...     ?
# 2434  You are an expert in media bias.\n\nInstructio...     ?
# 2981  You are an expert in media bias.\n\nInstructio...     ?
# 3435  You are an expert in media bias.\n\nInstructio...     ?
# 3512  You are an expert in media bias.\n\nInstructio...     ?

# %%
df_zephyr_7b_beta.loc[[151, 206, 516, 842, 1111, 1422,1684, 1701, 1712, 1961,2143, 2434, 2470, 3435, 3512], 'label'] = 'NOT BIASED'
df_zephyr_7b_beta.loc[[2981], 'label'] = 'BIASED'
df_zephyr_7b_beta.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
df_zephyr_7b_beta = df_zephyr_7b_beta.rename(columns={"label": "zephyr_label"})
df_zephyr_7b_beta['zephyr_label'] = df_zephyr_7b_beta['zephyr_label'].replace('BIASED', 1)
df_zephyr_7b_beta['zephyr_label'] = df_zephyr_7b_beta['zephyr_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(df_zephyr_7b_beta[df_zephyr_7b_beta['zephyr_label'] != '?'][['text', 'zephyr_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(df_zephyr_7b_beta[df_zephyr_7b_beta['zephyr_label'] != '?'][['text', 'zephyr_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(df_zephyr_7b_beta[['text', 'zephyr_label']], on='text')

ground_truth = df_merge['label'].astype(int)
zephyr_label = df_merge['zephyr_label'].astype(int)

# %%
print("F1-Score with zephyr beta (0 Shot + Sys Prompt): ", f1_score(ground_truth, zephyr_label))
print("Precision with zephyr beta (0 Shot + Sys Prompt): ", precision_score(ground_truth, zephyr_label))
print("Recall with zephyr beta (0 Shot + Sys Prompt): ", recall_score(ground_truth, zephyr_label))
print("Accuracy with zephyr beta (0 Shot + Sys Prompt): ",  accuracy_score(ground_truth, zephyr_label))
# Out:
# F1-Score with zephyr beta (0 Shot + Sys Prompt):  0.7124496451179743
# Precision with zephyr beta (0 Shot + Sys Prompt):  0.5763500931098696
# Recall with zephyr beta (0 Shot + Sys Prompt):  0.9326971371170266
# Accuracy with zephyr beta (0 Shot + Sys Prompt):  0.6272071623974136

# %%
# safe the file 
df_merge_all_runs_with_errors.to_csv("./all_runs_with_errors", index=False)

# %% [markdown]
# # Comparison and plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column,
                          title=None
                          ):
    predicted_labels = df[f'{predicted_labels_column}'].astype(int)
    true_labels = df[f'{true_labels_column}'].astype(int)

    # Calculate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)


    # Display confusion matrix heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=True,
                yticklabels=True, ax=ax)

    title = title if title else predicted_labels_column

    ax.set_title(f'Confusion Matrix - {title}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')


# Create subplots
fig, axes = plt.subplots(4, 3, figsize=(18, 12))
fig.suptitle('Confusion Matrices 4 Shot CoT')


#df_falcon_7b = pd.read_csv(f"./data/falcon-7b-instruct.csv")
#df_flan_ul2 = pd.read_csv(f"./data/flan-ul2.csv")
#df_openai_gpt_3_5_turbo = pd.read_csv('/home/sinix/PycharmProjects/Annomatic_Benchmark/4-shot-CoT/data/gpt-3.5-turbo.csv')
#df_openai_gpt_4_turbo = pd.read_csv(f"./data/gpt-4-1106-preview.csv")
#df_Llama_2_7b = pd.read_csv(f"./data/Llama-2-7b-chat-hf.csv")
#df_Llama_2_13b = pd.read_csv(f"./data/Llama-2-13b-chat-hf.csv")
#df_mistral_7b = pd.read_csv(f"./data/Mistral-7B-Instruct-v0.1.csv")
#df_mixtral_8x7b = pd.read_csv(f"./data/Mixtral-8x7B-Instruct-v0.1.csv")
#df_openchat_3_5 = pd.read_csv(f"./data/openchat_3.5.csv")
#df_zephyr_7b_beta = pd.read_csv(f"./data/zephyr-7b-beta.csv")


# Plot each confusion matrix
plot_confusion_matrix(axes[0, 0], df_merge_all_runs, 'label', 'falcon_7b_label', 'falcon-7b-instruct')
plot_confusion_matrix(axes[0, 1], df_merge_all_runs, 'label', 'flan_ul2_label', 'flan_ul2')
plot_confusion_matrix(axes[0, 2], df_merge_all_runs, 'label', 'gpt_3_5_label', 'gpt_3_5-turbo')
plot_confusion_matrix(axes[1, 0], df_merge_all_runs, 'label', 'gpt_4_label', 'gpt_4-turbo')
plot_confusion_matrix(axes[1, 1], df_merge_all_runs, 'label', 'llama_7b_label', 'llama_7b')
plot_confusion_matrix(axes[1, 2], df_merge_all_runs, 'label', 'llama_13b_label', 'llama_13b')
plot_confusion_matrix(axes[2, 0], df_merge_all_runs, 'label', 'mistral_7b_label', 'mistral_7b_label')
plot_confusion_matrix(axes[2, 1], df_merge_all_runs, 'label', 'mixtral_8x7b_label', 'mixtral_8x7b_label')
plot_confusion_matrix(axes[2, 2], df_merge_all_runs, 'label', 'openchat_label', 'openchat_label')
plot_confusion_matrix(axes[3, 0], df_merge_all_runs, 'label', 'zephyr_label', 'zephyr_label')




plt.tight_layout(
    rect=[0, 0, 1, 0.96])  # Adjust layout to prevent title overlap
plt.show()

# %% [markdown]
# # Krippendorff Alpha in 4-shot CoT

# %%
from krippendorff import alpha
import numpy as np

runs = ['falcon_7b_label', 'flan_ul2_label',
       'gpt_3_5_label', 'gpt_4_label', 'llama_7b_label', 'llama_13b_label',
       'mistral_7b_label', 'mixtral_8x7b_label', 'openchat_label',
       'zephyr_label']


def compute_krippendorff_alpha(dataframe, columns, missing_data='?'):
    """
    Compute Krippendorff's alpha for inter-rater reliability.

    Parameters:
    - dataframe: pd.DataFrame, the DataFrame containing the data.
    - columns: list, the list of column names to calculate alpha for.

    Returns:
    - alpha_value: float, Krippendorff's alpha value.
    """
    # Extract the relevant columns from the DataFrame
    data_subset = dataframe[columns]
    data_subset = data_subset.replace(missing_data, np.nan)

    # Ensure that the data is in a format suitable for krippendorff
    data_list = np.array([data_subset[col].tolist() for col in columns])

    # Calculate Krippendorff's alpha
    alpha_value = alpha(reliability_data=data_list)

    return alpha_value

# %%
alpha_value_with_errors = compute_krippendorff_alpha(df_merge_all_runs_with_errors, runs)
alpha_value_without_errors = compute_krippendorff_alpha(df_merge_all_runs, runs)

print(f"Krippendorff's Alpha (all runs with invalid data): {alpha_value_with_errors}")
print(f"Krippendorff's Alpha (all runs without invalid data): {alpha_value_without_errors}")
# Out:
# Krippendorff's Alpha (all runs with invalid data): 0.18160843951997885
# Krippendorff's Alpha (all runs without invalid data): 0.18030194822567602

# %%
import itertools

def compute_krippendorff_alpha_for_k_runs(df, runs, k=None):
    # Initialize variables to store the best combination and alpha
    if k is None:
        k = len(runs)

    best_combination = None
    best_alpha = 0  # Assuming alpha ranges from 0 to 1

    # Iterate through all possible combinations
    for combination in itertools.combinations(runs, k):

        alpha_value = compute_krippendorff_alpha(df, list(combination))

        # Print alpha for the current combination
        print(f"Combination: {combination}, Alpha: {alpha_value}")

        # Update best combination and alpha if a higher alpha is found
        if alpha_value > best_alpha:
            best_alpha = alpha_value
            best_combination = combination

    # Print the best combination and alpha
    print(f"\nBest Combination: {best_combination}, Best Alpha: {best_alpha}")
    return best_alpha, best_combination

# %%
compute_krippendorff_alpha_for_k_runs(df_merge_all_runs, runs, 3)
# Out:
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'gpt_3_5_label'), Alpha: 0.19555889261177806
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'gpt_4_label'), Alpha: 0.1982135461034198
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'llama_7b_label'), Alpha: -0.13976935961860582
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'llama_13b_label'), Alpha: -0.14572131744630945
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'mistral_7b_label'), Alpha: 0.08851171944777614
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'mixtral_8x7b_label'), Alpha: -0.05422686055026671
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'openchat_label'), Alpha: 0.16548950404538532
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'zephyr_label'), Alpha: 0.043052029661297175
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'gpt_4_label'), Alpha: 0.2657567949848245
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'llama_7b_label'), Alpha: -0.09858655509437919
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'llama_13b_label'), Alpha: -0.10459150421458152
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'mistral_7b_label'), Alpha: 0.151973971495024
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'mixtral_8x7b_label'), Alpha: -0.006456211256377742
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'openchat_label'), Alpha: 0.2208456707266171
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'zephyr_label'), Alpha: 0.0997408947487346
# Combination: ('falcon_7b_label', 'gpt_4_label', 'llama_7b_label'), Alpha: -0.09776767118482743
# Combination: ('falcon_7b_label', 'gpt_4_label', 'llama_13b_label'), Alpha: -0.10420363391063336
# Combination: ('falcon_7b_label', 'gpt_4_label', 'mistral_7b_label'), Alpha: 0.14007833894198685
# Combination: ('falcon_7b_label', 'gpt_4_label', 'mixtral_8x7b_label'), Alpha: -0.0036248768079996108
# Combination: ('falcon_7b_label', 'gpt_4_label', 'openchat_label'), Alpha: 0.22124112743038993
# Combination: ('falcon_7b_label', 'gpt_4_label', 'zephyr_label'), Alpha: 0.09844608895250517
# Combination: ('falcon_7b_label', 'llama_7b_label', 'llama_13b_label'), Alpha: -0.17687557106109209
# Combination: ('falcon_7b_label', 'llama_7b_label', 'mistral_7b_label'), Alpha: -0.07537130538884207
# Combination: ('falcon_7b_label', 'llama_7b_label', 'mixtral_8x7b_label'), Alpha: -0.10923594033460993
# Combination: ('falcon_7b_label', 'llama_7b_label', 'openchat_label'), Alpha: -0.09658759552266516
# Combination: ('falcon_7b_label', 'llama_7b_label', 'zephyr_label'), Alpha: -0.07513860838493747
# Combination: ('falcon_7b_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: -0.08452109053497936
# Combination: ('falcon_7b_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: -0.12539498920292824
# Combination: ('falcon_7b_label', 'llama_13b_label', 'openchat_label'), Alpha: -0.10425227670637516
# Combination: ('falcon_7b_label', 'llama_13b_label', 'zephyr_label'), Alpha: -0.0851151891296662
# Combination: ('falcon_7b_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.02887757283561876
# Combination: ('falcon_7b_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.15180853361992785
# Combination: ('falcon_7b_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.1378750656385045
# Combination: ('falcon_7b_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: -0.0006249161799529723
# Combination: ('falcon_7b_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.048604340717853356
# Combination: ('falcon_7b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.11244073037717583
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'gpt_4_label'), Alpha: 0.6240946308535136
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'llama_7b_label'), Alpha: 0.06366993788386532
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'llama_13b_label'), Alpha: 0.059181020841658216
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'mistral_7b_label'), Alpha: 0.41370096537933854
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'mixtral_8x7b_label'), Alpha: 0.18312217853502255
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'openchat_label'), Alpha: 0.549520116739629
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'zephyr_label'), Alpha: 0.3341010650562414
# Combination: ('flan_ul2_label', 'gpt_4_label', 'llama_7b_label'), Alpha: 0.08049963529340831
# Combination: ('flan_ul2_label', 'gpt_4_label', 'llama_13b_label'), Alpha: 0.0756114096762257
# Combination: ('flan_ul2_label', 'gpt_4_label', 'mistral_7b_label'), Alpha: 0.41518726622213187
# Combination: ('flan_ul2_label', 'gpt_4_label', 'mixtral_8x7b_label'), Alpha: 0.20118125597300918
# Combination: ('flan_ul2_label', 'gpt_4_label', 'openchat_label'), Alpha: 0.5617410572545161
# Combination: ('flan_ul2_label', 'gpt_4_label', 'zephyr_label'), Alpha: 0.34714097332906135
# Combination: ('flan_ul2_label', 'llama_7b_label', 'llama_13b_label'), Alpha: -0.21303292377678096
# Combination: ('flan_ul2_label', 'llama_7b_label', 'mistral_7b_label'), Alpha: 0.016335247888795257
# Combination: ('flan_ul2_label', 'llama_7b_label', 'mixtral_8x7b_label'), Alpha: -0.10565210161837024
# Combination: ('flan_ul2_label', 'llama_7b_label', 'openchat_label'), Alpha: 0.053253284761718644
# Combination: ('flan_ul2_label', 'llama_7b_label', 'zephyr_label'), Alpha: -0.011311962934001718
# Combination: ('flan_ul2_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: 0.009186320630023004
# Combination: ('flan_ul2_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: -0.1183382298638247
# Combination: ('flan_ul2_label', 'llama_13b_label', 'openchat_label'), Alpha: 0.04721604509197397
# Combination: ('flan_ul2_label', 'llama_13b_label', 'zephyr_label'), Alpha: -0.018903799053914927
# Combination: ('flan_ul2_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.14808445751286425
# Combination: ('flan_ul2_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.39913857516571594
# Combination: ('flan_ul2_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.30137970566492045
# Combination: ('flan_ul2_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: 0.17619626102743569
# Combination: ('flan_ul2_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.14002651157865176
# Combination: ('flan_ul2_label', 'openchat_label', 'zephyr_label'), Alpha: 0.3333096388507475
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'llama_7b_label'), Alpha: 0.12887778485373647
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'llama_13b_label'), Alpha: 0.12394459732097529
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'mistral_7b_label'), Alpha: 0.4838212618610346
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'mixtral_8x7b_label'), Alpha: 0.2557429590026762
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'openchat_label'), Alpha: 0.6208488708701763
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'zephyr_label'), Alpha: 0.40991402252800824
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'llama_13b_label'), Alpha: -0.19651198992242525
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'mistral_7b_label'), Alpha: 0.06307752747666362
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'mixtral_8x7b_label'), Alpha: -0.07735879672409607
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'openchat_label'), Alpha: 0.0883809652348978
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'zephyr_label'), Alpha: 0.0290552275240461
# Combination: ('gpt_3_5_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: 0.05579908083428908
# Combination: ('gpt_3_5_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: -0.09043327120187095
# Combination: ('gpt_3_5_label', 'llama_13b_label', 'openchat_label'), Alpha: 0.08228959501385236
# Combination: ('gpt_3_5_label', 'llama_13b_label', 'zephyr_label'), Alpha: 0.02127837028160584
# Combination: ('gpt_3_5_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.2018788970930483
# Combination: ('gpt_3_5_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.45573446186311206
# Combination: ('gpt_3_5_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.3637655445349751
# Combination: ('gpt_3_5_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: 0.21799609310535584
# Combination: ('gpt_3_5_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.18890936036589323
# Combination: ('gpt_3_5_label', 'openchat_label', 'zephyr_label'), Alpha: 0.38385774159733566
# Combination: ('gpt_4_label', 'llama_7b_label', 'llama_13b_label'), Alpha: -0.1815217017647881
# Combination: ('gpt_4_label', 'llama_7b_label', 'mistral_7b_label'), Alpha: 0.06386000634455768
# Combination: ('gpt_4_label', 'llama_7b_label', 'mixtral_8x7b_label'), Alpha: -0.057581542288386744
# Combination: ('gpt_4_label', 'llama_7b_label', 'openchat_label'), Alpha: 0.1033104869498781
# Combination: ('gpt_4_label', 'llama_7b_label', 'zephyr_label'), Alpha: 0.04332399180901758
# Combination: ('gpt_4_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: 0.0560502891000807
# Combination: ('gpt_4_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: -0.0715969354564654
# Combination: ('gpt_4_label', 'llama_13b_label', 'openchat_label'), Alpha: 0.09677741388027439
# Combination: ('gpt_4_label', 'llama_13b_label', 'zephyr_label'), Alpha: 0.03490119394696234
# Combination: ('gpt_4_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.20561156345911513
# Combination: ('gpt_4_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.45552922559208386
# Combination: ('gpt_4_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.36348034395900286
# Combination: ('gpt_4_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: 0.23443713780354913
# Combination: ('gpt_4_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.20661255227944908
# Combination: ('gpt_4_label', 'openchat_label', 'zephyr_label'), Alpha: 0.3953927007546201
# Combination: ('llama_7b_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: -0.08299717587094424
# Combination: ('llama_7b_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: 0.04290504401637596
# Combination: ('llama_7b_label', 'llama_13b_label', 'openchat_label'), Alpha: -0.17404968900267614
# Combination: ('llama_7b_label', 'llama_13b_label', 'zephyr_label'), Alpha: -0.016318893770697507
# Combination: ('llama_7b_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.07698341151397292
# Combination: ('llama_7b_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.08650838786672888
# Combination: ('llama_7b_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.18343683047580617
# Combination: ('llama_7b_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: -0.04449452851711855
# Combination: ('llama_7b_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.20549326916267507
# Combination: ('llama_7b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.0707345741815788
# Combination: ('llama_13b_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.05467360151667566
# Combination: ('llama_13b_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.07728220110624384
# Combination: ('llama_13b_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.1700316892808753
# Combination: ('llama_13b_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: -0.06048010302673079
# Combination: ('llama_13b_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.17511526930958587
# Combination: ('llama_13b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.06069405320813781
# Combination: ('mistral_7b_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: 0.22973843812890493
# Combination: ('mistral_7b_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.3662412279572095
# Combination: ('mistral_7b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.3982644130081582
# Combination: ('mixtral_8x7b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.2358221507095638
#
# Best Combination: ('flan_ul2_label', 'gpt_3_5_label', 'gpt_4_label'), Best Alpha: 0.6240946308535136
# (0.6240946308535136, ('flan_ul2_label', 'gpt_3_5_label', 'gpt_4_label'))

# %%
compute_krippendorff_alpha_for_k_runs(df_merge_all_runs_with_errors, runs, 3)
# Out:
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'gpt_3_5_label'), Alpha: 0.19446097015166863
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'gpt_4_label'), Alpha: 0.19980541415264563
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'llama_7b_label'), Alpha: -0.1386863799384861
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'llama_13b_label'), Alpha: -0.13734947614208237
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'mistral_7b_label'), Alpha: 0.08799682386953589
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'mixtral_8x7b_label'), Alpha: -0.056304077881102366
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'openchat_label'), Alpha: 0.1638864607955839
# Combination: ('falcon_7b_label', 'flan_ul2_label', 'zephyr_label'), Alpha: 0.04026100550558487
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'gpt_4_label'), Alpha: 0.2627077658463497
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'llama_7b_label'), Alpha: -0.10134136338195776
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'llama_13b_label'), Alpha: -0.0955257467148376
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'mistral_7b_label'), Alpha: 0.1485918004157728
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'mixtral_8x7b_label'), Alpha: -0.013320677108052514
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'openchat_label'), Alpha: 0.21631172196871762
# Combination: ('falcon_7b_label', 'gpt_3_5_label', 'zephyr_label'), Alpha: 0.09306613794080165
# Combination: ('falcon_7b_label', 'gpt_4_label', 'llama_7b_label'), Alpha: -0.09758813270451494
# Combination: ('falcon_7b_label', 'gpt_4_label', 'llama_13b_label'), Alpha: -0.09555538821726683
# Combination: ('falcon_7b_label', 'gpt_4_label', 'mistral_7b_label'), Alpha: 0.13809171159181555
# Combination: ('falcon_7b_label', 'gpt_4_label', 'mixtral_8x7b_label'), Alpha: -0.007037327737643206
# Combination: ('falcon_7b_label', 'gpt_4_label', 'openchat_label'), Alpha: 0.2169925157736341
# Combination: ('falcon_7b_label', 'gpt_4_label', 'zephyr_label'), Alpha: 0.09330923254725854
# Combination: ('falcon_7b_label', 'llama_7b_label', 'llama_13b_label'), Alpha: -0.18671428389664335
# Combination: ('falcon_7b_label', 'llama_7b_label', 'mistral_7b_label'), Alpha: -0.07799084117752053
# Combination: ('falcon_7b_label', 'llama_7b_label', 'mixtral_8x7b_label'), Alpha: -0.11751716027043546
# Combination: ('falcon_7b_label', 'llama_7b_label', 'openchat_label'), Alpha: -0.09908932656734515
# Combination: ('falcon_7b_label', 'llama_7b_label', 'zephyr_label'), Alpha: -0.08288533031585077
# Combination: ('falcon_7b_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: -0.07902738974168289
# Combination: ('falcon_7b_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: -0.13778021634185578
# Combination: ('falcon_7b_label', 'llama_13b_label', 'openchat_label'), Alpha: -0.09485423509260937
# Combination: ('falcon_7b_label', 'llama_13b_label', 'zephyr_label'), Alpha: -0.09197062530613054
# Combination: ('falcon_7b_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.021722672751958827
# Combination: ('falcon_7b_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.14794732246978748
# Combination: ('falcon_7b_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.13031660812531654
# Combination: ('falcon_7b_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: -0.00748834885448435
# Combination: ('falcon_7b_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.0365050123973345
# Combination: ('falcon_7b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.10416666905482797
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'gpt_4_label'), Alpha: 0.6269059614723216
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'llama_7b_label'), Alpha: 0.07200248070481485
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'llama_13b_label'), Alpha: 0.0849987055493816
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'mistral_7b_label'), Alpha: 0.4168447080092613
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'mixtral_8x7b_label'), Alpha: 0.18846605751865408
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'openchat_label'), Alpha: 0.5503373663905751
# Combination: ('flan_ul2_label', 'gpt_3_5_label', 'zephyr_label'), Alpha: 0.339012772414956
# Combination: ('flan_ul2_label', 'gpt_4_label', 'llama_7b_label'), Alpha: 0.0918006272106926
# Combination: ('flan_ul2_label', 'gpt_4_label', 'llama_13b_label'), Alpha: 0.10168492473123047
# Combination: ('flan_ul2_label', 'gpt_4_label', 'mistral_7b_label'), Alpha: 0.4195007273029918
# Combination: ('flan_ul2_label', 'gpt_4_label', 'mixtral_8x7b_label'), Alpha: 0.21002439726987088
# Combination: ('flan_ul2_label', 'gpt_4_label', 'openchat_label'), Alpha: 0.562322359494394
# Combination: ('flan_ul2_label', 'gpt_4_label', 'zephyr_label'), Alpha: 0.3535664198168921
# Combination: ('flan_ul2_label', 'llama_7b_label', 'llama_13b_label'), Alpha: -0.21230084970791285
# Combination: ('flan_ul2_label', 'llama_7b_label', 'mistral_7b_label'), Alpha: 0.022321258288976575
# Combination: ('flan_ul2_label', 'llama_7b_label', 'mixtral_8x7b_label'), Alpha: -0.09941714562552328
# Combination: ('flan_ul2_label', 'llama_7b_label', 'openchat_label'), Alpha: 0.059759074271859225
# Combination: ('flan_ul2_label', 'llama_7b_label', 'zephyr_label'), Alpha: -0.004696700032379875
# Combination: ('flan_ul2_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: 0.02181249362718185
# Combination: ('flan_ul2_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: -0.11519304742037573
# Combination: ('flan_ul2_label', 'llama_13b_label', 'openchat_label'), Alpha: 0.06845133544108417
# Combination: ('flan_ul2_label', 'llama_13b_label', 'zephyr_label'), Alpha: -0.008144066004573514
# Combination: ('flan_ul2_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.15154378714936623
# Combination: ('flan_ul2_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.4002260795963717
# Combination: ('flan_ul2_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.3044384645360003
# Combination: ('flan_ul2_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: 0.1796880984634327
# Combination: ('flan_ul2_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.14474206349206353
# Combination: ('flan_ul2_label', 'openchat_label', 'zephyr_label'), Alpha: 0.3350026363492046
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'llama_7b_label'), Alpha: 0.1357564234424763
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'llama_13b_label'), Alpha: 0.15050113590805825
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'mistral_7b_label'), Alpha: 0.48496948432812037
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'mixtral_8x7b_label'), Alpha: 0.2593203555103658
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'openchat_label'), Alpha: 0.6184200897175081
# Combination: ('gpt_3_5_label', 'gpt_4_label', 'zephyr_label'), Alpha: 0.412071251145527
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'llama_13b_label'), Alpha: -0.19900386044285567
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'mistral_7b_label'), Alpha: 0.0665083048792533
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'mixtral_8x7b_label'), Alpha: -0.07631935224849284
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'openchat_label'), Alpha: 0.09212628539406109
# Combination: ('gpt_3_5_label', 'llama_7b_label', 'zephyr_label'), Alpha: 0.03174594598975122
# Combination: ('gpt_3_5_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: 0.07178519657248406
# Combination: ('gpt_3_5_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: -0.09182224326538058
# Combination: ('gpt_3_5_label', 'llama_13b_label', 'openchat_label'), Alpha: 0.10628174320678663
# Combination: ('gpt_3_5_label', 'llama_13b_label', 'zephyr_label'), Alpha: 0.03168092045050608
# Combination: ('gpt_3_5_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.2016795402184357
# Combination: ('gpt_3_5_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.45523814914259175
# Combination: ('gpt_3_5_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.3640998740667861
# Combination: ('gpt_3_5_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: 0.21780488642812912
# Combination: ('gpt_3_5_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.18843783869047315
# Combination: ('gpt_3_5_label', 'openchat_label', 'zephyr_label'), Alpha: 0.382828105309302
# Combination: ('gpt_4_label', 'llama_7b_label', 'llama_13b_label'), Alpha: -0.18028193057366848
# Combination: ('gpt_4_label', 'llama_7b_label', 'mistral_7b_label'), Alpha: 0.06877015951905807
# Combination: ('gpt_4_label', 'llama_7b_label', 'mixtral_8x7b_label'), Alpha: -0.05214982993647044
# Combination: ('gpt_4_label', 'llama_7b_label', 'openchat_label'), Alpha: 0.1073978968867707
# Combination: ('gpt_4_label', 'llama_7b_label', 'zephyr_label'), Alpha: 0.04789584873183583
# Combination: ('gpt_4_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: 0.06873407609838145
# Combination: ('gpt_4_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: -0.06788888786473835
# Combination: ('gpt_4_label', 'llama_13b_label', 'openchat_label'), Alpha: 0.1156291948631919
# Combination: ('gpt_4_label', 'llama_13b_label', 'zephyr_label'), Alpha: 0.044097113445246805
# Combination: ('gpt_4_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.20775033372186513
# Combination: ('gpt_4_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.45385965373860526
# Combination: ('gpt_4_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.3642490560931183
# Combination: ('gpt_4_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: 0.23524719541733985
# Combination: ('gpt_4_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.20917287920377525
# Combination: ('gpt_4_label', 'openchat_label', 'zephyr_label'), Alpha: 0.39348361228828677
# Combination: ('llama_7b_label', 'llama_13b_label', 'mistral_7b_label'), Alpha: -0.08387533928062219
# Combination: ('llama_7b_label', 'llama_13b_label', 'mixtral_8x7b_label'), Alpha: 0.04627890997767892
# Combination: ('llama_7b_label', 'llama_13b_label', 'openchat_label'), Alpha: -0.1763892319821787
# Combination: ('llama_7b_label', 'llama_13b_label', 'zephyr_label'), Alpha: -0.016433288527237133
# Combination: ('llama_7b_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.07662800993685881
# Combination: ('llama_7b_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.0883145244231156
# Combination: ('llama_7b_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.184355003971148
# Combination: ('llama_7b_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: -0.044482195050945084
# Combination: ('llama_7b_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.20621435552980316
# Combination: ('llama_7b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.07043730647030944
# Combination: ('llama_13b_label', 'mistral_7b_label', 'mixtral_8x7b_label'), Alpha: 0.0564110439960942
# Combination: ('llama_13b_label', 'mistral_7b_label', 'openchat_label'), Alpha: 0.09161974299395637
# Combination: ('llama_13b_label', 'mistral_7b_label', 'zephyr_label'), Alpha: 0.1821819323375663
# Combination: ('llama_13b_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: -0.06172655057380494
# Combination: ('llama_13b_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.18330220467892555
# Combination: ('llama_13b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.06792093320796011
# Combination: ('mistral_7b_label', 'mixtral_8x7b_label', 'openchat_label'), Alpha: 0.22783379785114388
# Combination: ('mistral_7b_label', 'mixtral_8x7b_label', 'zephyr_label'), Alpha: 0.3648586610554385
# Combination: ('mistral_7b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.3953794160985967
# Combination: ('mixtral_8x7b_label', 'openchat_label', 'zephyr_label'), Alpha: 0.2323827821847022
#
# Best Combination: ('flan_ul2_label', 'gpt_3_5_label', 'gpt_4_label'), Best Alpha: 0.6269059614723216
# (0.6269059614723216, ('flan_ul2_label', 'gpt_3_5_label', 'gpt_4_label'))

# %%
df_merge_all_runs.shape
# Out:
# (3740, 21)

# %%
df_merge_all_runs.query("gpt_4_label != mixtral_8x7b_label").shape
# Out:
# (1659, 21)
