# %% [markdown]
# # Eval the results of Mistral-7B-Instruct-v0.1

# %%
import pandas as pd
from datasets import load_dataset
from sklearn.metrics import f1_score, precision_score, recall_score, \
    accuracy_score

import re
from typing import List, Tuple

import pandas as pd


def is_contained(inner_start, inner_end, outer_start, outer_end):
    return (
        outer_start <= inner_start <= outer_end
        and outer_start <= inner_end <= outer_end
        and (inner_start, inner_end) != (outer_start, outer_end)
    )


def find_all_occurrences_indices(
    sentence: str,
    label: str,
) -> List[Tuple[int, int]]:
    """
    Finds all occurrences of a label in a sentence and returns a list of tuples
    with the start and end indices of the occurrences.

    Args:
        sentence: The sentence to search in.
        label: The label to search for.

    Returns:
        A list of tuples with the start and end indices of the occurrences.
    """
    return [
        (int(match.start()), int(match.end()))
        for match in re.finditer(label, sentence)
    ]


def find_contained_labels(labels):
    """
    Finds all labels that are contained in other labels.

    Args:
        labels: A list of labels.

    Returns:
        A dictionary with the labels as keys and a list of labels that are
        contained in the key label as values.
    """
    return {
        label_1: [
            label2
            for label2 in labels
            if label_1 in label2 and label_1 != label2
        ]
        for label_1 in labels
    }


def find_labels_in_sentence(
    sentence: str,
    labels: List[str],
) -> List[List[Tuple[int, int]]]:
    """
    Finds all occurrences of the labels in a sentence and returns a list of
    lists with the occurrences of each label.

    Labels that are contained in other labels are not returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.

    Returns:
        A list of lists with the positional occurrence of each label.
    """
    if not labels:
        return []

    containable_map = find_contained_labels(labels)
    sentence_lower = sentence.lower()
    occurrences = [
        find_all_occurrences_indices(sentence_lower, label.lower())
        for label in labels
    ]
    label_occurrences = dict(zip(labels, occurrences))
    included_list = []
    for label, inner_pos in zip(labels, occurrences):
        contained = set()
        containing_labels = containable_map.get(label, set())

        for bigger_label in containing_labels:
            locations: List[Tuple[int, int]] = label_occurrences.get(
                bigger_label,
                list(),
            )

            for inner_start, inner_end in inner_pos:
                for outer_start, outer_end in locations:
                    if is_contained(
                        inner_start,
                        inner_end,
                        outer_start,
                        outer_end,
                    ):
                        contained.add((inner_start, inner_end))
        included_list.append(list(contained))

    return [
        list(set(pos) - set(included))
        for pos, included in zip(occurrences, included_list)
    ]


def find_label(
    sentence: str,
    labels: List[str],
    default_label: str = "?",
) -> str:
    """
    Search for given labels in the sentence and returns it if found. If only
    one label occur in the sentence, it will be returned. If no label or
    different labels occur in the sentence, '?' is returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.
        default_label: The label to return if no label or different labels
            occur in the sentence.

    Returns:
        The label that occurs in the sentence or '?' if no label occurs in the
        sentence.
    """
    occurrences = find_labels_in_sentence(sentence=sentence, labels=labels)
    non_empty_indices = [i for i, sublist in enumerate(occurrences) if sublist]
    return (
        labels[non_empty_indices[0]]
        if len(
            non_empty_indices,
        )
           == 1
        else default_label
    )


def _soft_parse(
    df: pd.DataFrame,
    in_col: str,
    parsed_col: str,
    labels: List[str] = None,
) -> pd.DataFrame:
    if labels is None:
        raise ValueError("Labels are not set!")

    df[parsed_col] = df[in_col].apply(
        lambda x: find_label(x, labels),
    )

def find_first_occurrence(string, instruction="Instruction:",
                          statement1="The answer is BIASED",
                          statement2="The answer is NOT BIASED"
                          ):
    index_instruction = string.find(instruction)
    index1 = string.find(statement1)
    index2 = string.find(statement2)

    if index1 == -1 and index2 == -1:
        return "Neither instruction nor statements found in the given string."
    elif index1 == -1 and index2 == -1:
        return "Neither statement found in the given string."
    elif index1 == -1:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"
    elif index2 == -1:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    elif index1 < index2:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    else:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"

# %%
# load
model = 'Mistral-7B-Instruct-v0.1'

# load results
zero_shot = pd.read_csv(f"../zero-shot/data/{model}.csv")
zero_shot_with_system = pd.read_csv(
    f"../zero-shot-system_prompt/data/{model}.csv")
zero_shot_cot = pd.read_csv(f"../zero-shot-cot/data/{model}.csv")
two_shot = pd.read_csv(f"../2-shot/data/{model}.csv")
four_shot = pd.read_csv(f"../4-shot/data/{model}.csv")
eight_shot = pd.read_csv(f"../8-shot/data/{model}.csv")

two_shot_cot = pd.read_csv(f"../2-shot-CoT/data/{model}.csv")
four_shot_cot = pd.read_csv(f"../4-shot-CoT/data/{model}.csv")
eight_shot_cot = pd.read_csv(f"../8-shot-CoT/data/{model}.csv")

#load pool
pool = load_dataset('mediabiasgroup/BABE-icl-pool')['train'].to_pandas()

# exclude pool from model (if needed)
zero_shot = zero_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
zero_shot_with_system = zero_shot_with_system.merge(pool['text'], on='text',
                                                    how='left',
                                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
zero_shot_cot = zero_shot_cot.merge(pool['text'], on='text', how='left',
                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
two_shot = two_shot.merge(pool['text'], on='text', how='left',
                          indicator=True).query('_merge == "left_only"').drop(
    '_merge', axis=1)
four_shot = four_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot = eight_shot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
two_shot_cot = two_shot_cot.merge(pool['text'], on='text', how='left',
                                  indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
four_shot_cot = four_shot_cot.merge(pool['text'], on='text', how='left',
                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot_cot = eight_shot_cot.merge(pool['text'], on='text', how='left',
                                      indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)

#load babe
dataset = load_dataset('mediabiasgroup/BABE-v4')
df_babe = pd.DataFrame(dataset['train'])

# df_merge = babe at begin
df_merge_all_runs = df_babe
df_merge_all_runs_with_errors = df_babe

# %% [markdown]
# # Zero shot

# %%
_soft_parse(zero_shot, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
zero_shot.query("label == '?'")
# Out:
#                                                    text response  \
# 1072  The photograph of Katie Bouman sitting in fron...  BIASSED
# 2156  Girls and women do not have the same access to...     BIAS
# 3156  But rather than appreciate the fact that Asian...  BIASSED
#
#                                                raw_data  \
# 1072  Instruction: 'The photograph of Katie Bouman s...
# 2156  Instruction: 'Girls and women do not have the ...
# 3156  Instruction: 'But rather than appreciate the f...
#
#                                                   query label
# 1072  Instruction: 'The photograph of Katie Bouman s...     ?
# 2156  Instruction: 'Girls and women do not have the ...     ?
# 3156  Instruction: 'But rather than appreciate the f...     ?

# %%
# preprocessing
zero_shot.loc[[1072, 2156, 3156], 'label'] = 'BIASED'

# %%
zero_shot = zero_shot.rename(columns={"label": "0_shot_label"})
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('BIASED', 1)
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('NOT BIASED', 0)


df_merge = df_babe.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot[['text', '0_shot_label']], on='text')


ground_truth = df_merge['label']
zero_shot_label = df_merge['0_shot_label']

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1: ",
      f1_score(ground_truth, zero_shot_label))
print("Precision with Mistral-7B-Instruct-v0.1: ",
      precision_score(ground_truth, zero_shot_label))
print("Recall with Mistral-7B-Instruct-v0.1: ",
      recall_score(ground_truth, zero_shot_label))
print("Accuracy with Mistral-7B-Instruct-v0.1: ",
      accuracy_score(ground_truth, zero_shot_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1:  0.691905459108973
# Precision with Mistral-7B-Instruct-v0.1:  0.592831541218638
# Recall with Mistral-7B-Instruct-v0.1:  0.8307383224510296
# Accuracy with Mistral-7B-Instruct-v0.1:  0.6336732156180055

# %% [markdown]
# # zero shot with system prompt

# %%
_soft_parse(zero_shot_with_system, 'response', 'label',
            ['BIASED', 'NOT BIASED'])
zero_shot_with_system.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
zero_shot_with_system = zero_shot_with_system.rename(
    columns={"label": "0_shot_with_system_label"})
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('BIASED', 1)
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('NOT BIASED', 0)



df_merge = df_babe.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_with_system[['text', '0_shot_with_system_label']], on='text')



ground_truth = df_merge['label']
zero_shot_with_system_label = df_merge['0_shot_with_system_label']

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with System Prompt: ",
      f1_score(ground_truth, zero_shot_with_system_label))
print("Precision with Mistral-7B-Instruct-v0.1 with System Prompt: ",
      precision_score(ground_truth, zero_shot_with_system_label))
print("Recall with Mistral-7B-Instruct-v0.1 with System Prompt: ",
      recall_score(ground_truth, zero_shot_with_system_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with System Prompt: ",
      accuracy_score(ground_truth, zero_shot_with_system_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1 with System Prompt:  0.6947100063734862
# Precision with Mistral-7B-Instruct-v0.1 with System Prompt:  0.6019882179675994
# Recall with Mistral-7B-Instruct-v0.1 with System Prompt:  0.8211953792064289
# Accuracy with Mistral-7B-Instruct-v0.1 with System Prompt:  0.6426262123849789

# %% [markdown]
# # zero shot CoT

# %%
zero_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 4     Republican state legislators from Texas to Ari...
# 5     Meanwhile, a pervasive celebrity culture — in ...
# 24    Disney’s executives stopped advertising on Tuc...
# 29      They’d be standing aside and waving them on in.
# 30    n Dr. King's day, that other America was, for ...
# ...                                                 ...
# 4100  The unemployment tax rate in Florida is alread...
# 4106  Elizabeth Warren and Bernie Sanders disagreed ...
# 4109  In her Instagram story, Jedrzejczyk posted an ...
# 4112  U.S. President Donald Trump’s former personal ...
# 4118  When Republicans warned Democrats that impeach...
#
#                                                response  \
# 4     The sentence is a statement of fact, so it is ...
# 5     The sentence is making a statement about the s...
# 24    The sentence is about Disney stopping advertis...
# 29    The sentence is describing a hypothetical situ...
# 30    1. The sentence mentions Dr. King, which could...
# ...                                                 ...
# 4100  First, we need to identify the source of the i...
# 4106  The sentence is reporting a disagreement betwe...
# 4109  First, we need to identify the potential biase...
# 4112  First, we need to identify the source of the i...
# 4118  First, we need to identify the author's point ...
#
#                                                raw_data  \
# 4     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# 24    You are an expert in media bias.\n\nInstructio...
# 29    You are an expert in media bias.\n\nInstructio...
# 30    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4100  You are an expert in media bias.\n\nInstructio...
# 4106  You are an expert in media bias.\n\nInstructio...
# 4109  You are an expert in media bias.\n\nInstructio...
# 4112  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 4     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# 24    You are an expert in media bias.\n\nInstructio...     ?
# 29    You are an expert in media bias.\n\nInstructio...     ?
# 30    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4100  You are an expert in media bias.\n\nInstructio...     ?
# 4106  You are an expert in media bias.\n\nInstructio...     ?
# 4109  You are an expert in media bias.\n\nInstructio...     ?
# 4112  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
#
# [829 rows x 5 columns]

# %%
# preprocessing
# redo

# %%
zero_shot_cot = zero_shot_cot.rename(columns={"label": "0_shot_cot_label"})
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'BIASED', 1)
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot_cot[zero_shot_cot['0_shot_cot_label'] != '?'][['text', '0_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_cot[zero_shot_cot['0_shot_cot_label'] != '?'][['text', '0_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_cot[['text', '0_shot_cot_label']], on='text')


ground_truth = df_merge['label']
zero_shot_cot_label = df_merge['0_shot_cot_label']

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with CoT: ",
      f1_score(ground_truth, zero_shot_cot_label))
print("Precision with Mistral-7B-Instruct-v0.1 with CoT: ",
      precision_score(ground_truth, zero_shot_cot_label))
print("Recall with Mistral-7B-Instruct-v0.1 with CoT: ",
      recall_score(ground_truth, zero_shot_cot_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with CoT: ",
      accuracy_score(ground_truth, zero_shot_cot_label))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 print("F1-Score with Mistral-7B-Instruct-v0.1 with CoT: ",
# ----> 2       f1_score(ground_truth, zero_shot_cot_label))
#       3 print("Precision with Mistral-7B-Instruct-v0.1 with CoT: ",
#       4       precision_score(ground_truth, zero_shot_cot_label))
#       5 print("Recall with Mistral-7B-Instruct-v0.1 with CoT: ",
#       6       recall_score(ground_truth, zero_shot_cot_label))
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1239, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1070 @validate_params(
#    1071     {
#    1072         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1097     zero_division="warn",
#    1098 ):
#    1099     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1100
#    1101     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1237     array([0.66666667, 1.        , 0.66666667])
#    1238     """
# -> 1239     return fbeta_score(
#    1240         y_true,
#    1241         y_pred,
#    1242         beta=1,
#    1243         labels=labels,
#    1244         pos_label=pos_label,
#    1245         average=average,
#    1246         sample_weight=sample_weight,
#    1247         zero_division=zero_division,
#    1248     )
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1413, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1251 @validate_params(
#    1252     {
#    1253         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1280     zero_division="warn",
#    1281 ):
#    1282     """Compute the F-beta score.
#    1283
#    1284     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1410     0.38...
#    1411     """
# -> 1413     _, _, f, _ = precision_recall_fscore_support(
#    1414         y_true,
#    1415         y_pred,
#    1416         beta=beta,
#    1417         labels=labels,
#    1418         pos_label=pos_label,
#    1419         average=average,
#    1420         warn_for=("f-score",),
#    1421         sample_weight=sample_weight,
#    1422         zero_division=zero_division,
#    1423     )
#    1424     return f
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1501, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1498 if average not in average_options and average != "binary":
#    1499     raise ValueError("average has to be one of " + str(average_options))
# -> 1501 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1502 # Convert to Python primitive type to avoid NumPy type / Python str
#    1503 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1504 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:93, in _check_targets(y_true, y_pred)
#      90     y_type = {"multiclass"}
#      92 if len(y_type) > 1:
# ---> 93     raise ValueError(
#      94         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95             type_true, type_pred
#      96         )
#      97     )
#      99 # We can't have more than one value on y_type => The set is no more needed
#     100 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and unknown targets

# %% [markdown]
# # 2-shot

# %%
two_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 4     Republican state legislators from Texas to Ari...
# 5     Meanwhile, a pervasive celebrity culture — in ...
# ...                                                 ...
# 4115  Trump sought to use the event to bring momentu...
# 4116  Far-right talk show host Glenn Beck is being s...
# 4118  When Republicans warned Democrats that impeach...
# 4119  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4120  The march then continued to the United States ...
#
#                                                response  \
# 0     NOT BIASED\n\nInstruction: 'The gun lobby is t...
# 1     NOT BIASED\n\nInstruction: 'The article was bi...
# 2     Instruction: 'The left is not interested in pe...
# 4     BIASED\n\nInstruction: 'The COVID-19 pandemic ...
# 5     Instruction: 'The media has been accused of se...
# ...                                                 ...
# 4115  NOT BIASED\n\nInstruction: 'President Trump's ...
# 4116  BIASED\n\nInstruction: 'The media is biased ag...
# 4118  Instruction: 'The president’s decision to run ...
# 4119  NOT BIASED\n\nInstruction: 'The New York Times...
# 4120  Instruction: 'The march then continued to the ...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 4     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4115  You are an expert in media bias.\n\nInstructio...
# 4116  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
# 4119  You are an expert in media bias.\n\nInstructio...
# 4120  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 4     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4115  You are an expert in media bias.\n\nInstructio...     ?
# 4116  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
# 4119  You are an expert in media bias.\n\nInstructio...     ?
# 4120  You are an expert in media bias.\n\nInstructio...     ?
#
# [2361 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Instruction:') and row[
        'label'] == '?':
        return '!'
    else:
        return row['label']


two_shot['label'] = two_shot.apply(update_label, axis=1)
two_shot.query("label == '?'")
# Out:
#                                                    text  \
# 30    n Dr. King's day, that other America was, for ...
# 2820  Christian white people in our country is borin...
# 3305  Federal agents fired tear gas canisters at Bla...
# 3769  Marshae Jones, 27, was arrested and indicted o...
#
#                                                response  \
# 30    2010, few Americans could predict that the com...
# 2820  The sentence is offensive and contains hate sp...
# 3305  50% BIASED, 50% NOT BIASED\n\nInstruction: 'Th...
# 3769  The sentence is ambiguous and could be interpr...
#
#                                                raw_data  \
# 30    You are an expert in media bias.\n\nInstructio...
# 2820  You are an expert in media bias.\n\nInstructio...
# 3305  You are an expert in media bias.\n\nInstructio...
# 3769  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 30    You are an expert in media bias.\n\nInstructio...     ?
# 2820  You are an expert in media bias.\n\nInstructio...     ?
# 3305  You are an expert in media bias.\n\nInstructio...     ?
# 3769  You are an expert in media bias.\n\nInstructio...     ?

# %%
# Map back '!' flag to '?'
two_shot['label'] = two_shot['label'].replace('!', '?')

two_shot = two_shot.rename(columns={"label": "2_shot_label"})
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('BIASED', 1)
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot[['text', '2_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
two_shot_label = df_merge['2_shot_label'].astype(int)

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with (2 shot): ",
      f1_score(ground_truth, two_shot_label))
print("Precision with Mistral-7B-Instruct-v0.1 with (2 shot): ",
      precision_score(ground_truth, two_shot_label))
print("Recall with Mistral-7B-Instruct-v0.1 with (2 shot): ",
      recall_score(ground_truth, two_shot_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with (2 shot): ",
      accuracy_score(ground_truth, two_shot_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1 with (2 shot):  0.5245755138516532
# Precision with Mistral-7B-Instruct-v0.1 with (2 shot):  0.7733860342555995
# Recall with Mistral-7B-Instruct-v0.1 with (2 shot):  0.3968897903989182
# Accuracy with Mistral-7B-Instruct-v0.1 with (2 shot):  0.6623294192319898

# %% [markdown]
# # 4-shot

# %%
four_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 3     Americans are carrying $1.57 trillion in outst...
# 5     Meanwhile, a pervasive celebrity culture — in ...
# 15    Facebook bans white nationalism from platform ...
# 18    The Affordable Care Act has seen dozens of leg...
# ...                                                 ...
# 4102  The president can’t handle criticism. Or facts...
# 4103  Proponents of these vaccines twist the Vatican...
# 4104  Minhaj, who used to appear on “The Daily Show”...
# 4114  Larry Kudlow, one of President Donald Trump’s ...
# 4118  When Republicans warned Democrats that impeach...
#
#                                                response  \
# 0     NOT BIASED\n\nInstruction: 'The gun-grabbers a...
# 3     Instruction: 'The American middle class is fal...
# 5     Instruction: 'The media is biased because it o...
# 15    Instruction: 'The media is biased against cons...
# 18    NOT BIASED\n\nInstruction: 'The Affordable Car...
# ...                                                 ...
# 4102  Instruction: 'The president’s likely opponent ...
# 4103  BIASED\n\nInstruction: 'The Vatican has not is...
# 4104  NOT BIASED\n\nInstruction: 'The American middl...
# 4114  NOT BIASED\n\nInstruction: 'The coronavirus pa...
# 4118  Instruction: 'The president’s latest executive...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 5     You are an expert in media bias.\n\nInstructio...
# 15    You are an expert in media bias.\n\nInstructio...
# 18    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4102  You are an expert in media bias.\n\nInstructio...
# 4103  You are an expert in media bias.\n\nInstructio...
# 4104  You are an expert in media bias.\n\nInstructio...
# 4114  You are an expert in media bias.\n\nInstructio...
# 4118  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 5     You are an expert in media bias.\n\nInstructio...     ?
# 15    You are an expert in media bias.\n\nInstructio...     ?
# 18    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4102  You are an expert in media bias.\n\nInstructio...     ?
# 4103  You are an expert in media bias.\n\nInstructio...     ?
# 4104  You are an expert in media bias.\n\nInstructio...     ?
# 4114  You are an expert in media bias.\n\nInstructio...     ?
# 4118  You are an expert in media bias.\n\nInstructio...     ?
#
# [1151 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Instruction:') and row[
        'label'] == '?':
        return '!'
    else:
        return row['label']


four_shot['label'] = four_shot.apply(update_label, axis=1)
four_shot.query("label == '?'")
# Out:
#                                                    text  \
# 1318  But COVID-19 is shaking her views. The woman w...
# 2549  Police identified the shooter as Anthony Ferri...
# 3305  Federal agents fired tear gas canisters at Bla...
# 3683  In certain ways, 2020 feels a lot like 1968. F...
#
#                                                response  \
# 1318                                              50:50
# 2549  50% BIASED, 50% NOT BIASED\n\nInstruction: 'Th...
# 3305  50% BIASED, 50% NOT BIASED\n\nExplanation: The...
# 3683  2020 feels a lot like 1968. Federal troops and...
#
#                                                raw_data  \
# 1318  You are an expert in media bias.\n\nInstructio...
# 2549  You are an expert in media bias.\n\nInstructio...
# 3305  You are an expert in media bias.\n\nInstructio...
# 3683  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 1318  You are an expert in media bias.\n\nInstructio...     ?
# 2549  You are an expert in media bias.\n\nInstructio...     ?
# 3305  You are an expert in media bias.\n\nInstructio...     ?
# 3683  You are an expert in media bias.\n\nInstructio...     ?

# %%
# Map back '!' flag to '?'
four_shot['label'] = four_shot['label'].replace('!', '?')

four_shot = four_shot.rename(columns={"label": "4_shot_label"})
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('BIASED', 1)
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot[['text', '4_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
four_shot_label = df_merge['4_shot_label'].astype(int)

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with (4 shot): ",
      f1_score(ground_truth, four_shot_label))
print("Precision with Mistral-7B-Instruct-v0.1 with (4 shot): ",
      precision_score(ground_truth, four_shot_label))
print("Recall with Mistral-7B-Instruct-v0.1 with (4 shot): ",
      recall_score(ground_truth, four_shot_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with (4 shot): ",
      accuracy_score(ground_truth, four_shot_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1 with (4 shot):  0.6153319644079398
# Precision with Mistral-7B-Instruct-v0.1 with (4 shot):  0.7906772207563765
# Recall with Mistral-7B-Instruct-v0.1 with (4 shot):  0.503641456582633
# Accuracy with Mistral-7B-Instruct-v0.1 with (4 shot):  0.6941496598639456

# %% [markdown]
# # 8-shot

# %%
eight_shot.query("label == '?'")
# Out:
#                                                    text  \
# 0     But instead of closing loopholes that allow cr...
# 1               "You think I'm joking," he continued. "
# 2     Yes, the rich are rich and want to stay that w...
# 3     Americans are carrying $1.57 trillion in outst...
# 6     Morrison is a typical right-wing conservative ...
# ...                                                 ...
# 4094  Instead of that, we’re in this amazing moment ...
# 4101  Leftist media and the technocratic elite who r...
# 4102  The president can’t handle criticism. Or facts...
# 4106  Elizabeth Warren and Bernie Sanders disagreed ...
# 4112  U.S. President Donald Trump’s former personal ...
#
#                                                response  \
# 0     NOT BIASED\n\nInstruction: 'The gun-grabbers a...
# 1     NOT BIASED\n\nInstruction: 'The president’s li...
# 2     Classify the sentence above as BIASED or NOT B...
# 3     NOT BIASED\n\nInstruction: 'The American middl...
# 6     Classification: BIASED\n\nInstruction: 'The Am...
# ...                                                 ...
# 4094  Classify the sentence above as BIASED or NOT B...
# 4101  BIASED\n\nInstruction: 'The media is biased ag...
# 4102  Classification: BIASED\n\nInstruction: 'The pr...
# 4106  NOT BIASED\n\nInstruction: 'The president’s sp...
# 4112  NOT BIASED\n\nInstruction: 'President Donald T...
#
#                                                raw_data  \
# 0     You are an expert in media bias.\n\nInstructio...
# 1     You are an expert in media bias.\n\nInstructio...
# 2     You are an expert in media bias.\n\nInstructio...
# 3     You are an expert in media bias.\n\nInstructio...
# 6     You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 4094  You are an expert in media bias.\n\nInstructio...
# 4101  You are an expert in media bias.\n\nInstructio...
# 4102  You are an expert in media bias.\n\nInstructio...
# 4106  You are an expert in media bias.\n\nInstructio...
# 4112  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 0     You are an expert in media bias.\n\nInstructio...     ?
# 1     You are an expert in media bias.\n\nInstructio...     ?
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 3     You are an expert in media bias.\n\nInstructio...     ?
# 6     You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 4094  You are an expert in media bias.\n\nInstructio...     ?
# 4101  You are an expert in media bias.\n\nInstructio...     ?
# 4102  You are an expert in media bias.\n\nInstructio...     ?
# 4106  You are an expert in media bias.\n\nInstructio...     ?
# 4112  You are an expert in media bias.\n\nInstructio...     ?
#
# [1603 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith(
        'Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and \
        row[
            'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith(
        'Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and \
        row[
            'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Output: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Output: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('Instruction:') and row[
        'label'] == '?':
        return '!'
    else:
        return row['label']


eight_shot['label'] = eight_shot.apply(update_label, axis=1)
eight_shot.query("label == '?'")
# Out:
#                                                    text  \
# 1318  But COVID-19 is shaking her views. The woman w...
# 3305  Federal agents fired tear gas canisters at Bla...
# 3683  In certain ways, 2020 feels a lot like 1968. F...
#
#                                                response  \
# 1318                                              50:50
# 3305  50/50\n\nInstruction: 'The Black Lives Matter ...
# 3683  2020 feels a lot like 1968. Federal troops and...
#
#                                                raw_data  \
# 1318  You are an expert in media bias.\n\nInstructio...
# 3305  You are an expert in media bias.\n\nInstructio...
# 3683  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 1318  You are an expert in media bias.\n\nInstructio...     ?
# 3305  You are an expert in media bias.\n\nInstructio...     ?
# 3683  You are an expert in media bias.\n\nInstructio...     ?

# %%
# Map back '!' flag to '?'
eight_shot['label'] = eight_shot['label'].replace('!', '?')

eight_shot = eight_shot.rename(columns={"label": "8_shot_label"})
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('BIASED', 1)
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot[['text', '8_shot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
eight_shot_label = df_merge['8_shot_label'].astype(int)

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with (8 shot): ",
      f1_score(ground_truth, eight_shot_label))
print("Precision with Mistral-7B-Instruct-v0.1 with (8 shot): ",
      precision_score(ground_truth, eight_shot_label))
print("Recall with Mistral-7B-Instruct-v0.1 with (8 shot): ",
      recall_score(ground_truth, eight_shot_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with (8 shot): ",
      accuracy_score(ground_truth, eight_shot_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1 with (8 shot):  0.6576332429990966
# Precision with Mistral-7B-Instruct-v0.1 with (8 shot):  0.7941818181818182
# Recall with Mistral-7B-Instruct-v0.1 with (8 shot):  0.5611510791366906
# Accuracy with Mistral-7B-Instruct-v0.1 with (8 shot):  0.7110546378653113

# %% [markdown]
# # 2-shot CoT

# %%
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 2     Yes, the rich are rich and want to stay that w...
# 13    The legislation, worked out between leading la...
# 20    A Joe Biden presidency could reset ties with t...
# 26    Just look at some of the arguments that Elizab...
# 33    Few would consider a global pandemic reason to...
# ...                                                 ...
# 3984  Posting on Twitter, the former stripper turned...
# 3987  Wall Street surged on Thursday as investors we...
# 3993  Military ships and aircraft have been deployed...
# 4006  Elizabeth Warren and Bernie Sanders disagreed ...
# 4007  In June, an explosive early morning fire rocke...
#
#                                                response  \
# 2     The statement is biased because it presents a ...
# 13    The sentence presents a factual account of a l...
# 20    The sentence presents a fact-based scenario wi...
# 26    The sentence presents a fact about Elizabeth S...
# 33    The sentence presents a balanced viewpoint, ac...
# ...                                                 ...
# 3984  The sentence presents a statement from a perso...
# 3987  The sentence presents a balanced view of event...
# 3993  The sentence presents factual information with...
# 4006  The sentence presents a factual account of a d...
# 4007  The sentence presents a factual account of an ...
#
#                                                raw_data  \
# 2     You are an expert in media bias.\n\nInstructio...
# 13    You are an expert in media bias.\n\nInstructio...
# 20    You are an expert in media bias.\n\nInstructio...
# 26    You are an expert in media bias.\n\nInstructio...
# 33    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3984  You are an expert in media bias.\n\nInstructio...
# 3987  You are an expert in media bias.\n\nInstructio...
# 3993  You are an expert in media bias.\n\nInstructio...
# 4006  You are an expert in media bias.\n\nInstructio...
# 4007  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 2     You are an expert in media bias.\n\nInstructio...     ?
# 13    You are an expert in media bias.\n\nInstructio...     ?
# 20    You are an expert in media bias.\n\nInstructio...     ?
# 26    You are an expert in media bias.\n\nInstructio...     ?
# 33    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3984  You are an expert in media bias.\n\nInstructio...     ?
# 3987  You are an expert in media bias.\n\nInstructio...     ?
# 3993  You are an expert in media bias.\n\nInstructio...     ?
# 4006  You are an expert in media bias.\n\nInstructio...     ?
# 4007  You are an expert in media bias.\n\nInstructio...     ?
#
# [540 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('The sentence is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The statement is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence above is classified as biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is labeled as biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as biased') and \
        row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('This sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith(
        'The sentence is considered not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence presents factual') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence presents a factual statement') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']



two_shot_cot['label'] = two_shot_cot.apply(update_label, axis=1)
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 133   Ukraine's eastern front line resembles "a grin...
# 639   But the Camp Fire of 2018 was something differ...
# 1465  And most egregiously, in what will surely be v...
# 1506  Defense lawyer Damon Cheronis asked one group ...
# 1710  Former Vice President Joe Biden continues to m...
# 1757  Immigration Voice claims to be an independent ...
# 2627  Students will also be required to sign a pact ...
# 2770  Nevertheless, the media jihad continues, and t...
# 2871  Microsoft Corp MSFT.O on Tuesday set a five-ye...
# 3366  Democratic U.S. Rep. David Cicilline of Rhode ...
# 3409  While the major baseball leagues won’t be affe...
# 3473  In Washington, three key issues seemed to galv...
# 3514  The governor of Minnesota declared a state of ...
# 3722  Joe Biden can count among his many celebrity a...
# 3771  In an act of blunt-force plutocratic thuggery,...
# 3858  She credited women for mobilizing against gun ...
#
#                                                response  \
# 133   The sentence presents a statement from Colin K...
# 639   The sentence presents a personal experience of...
# 1465  The sentence contains multiple elements of bia...
# 1506  The sentence presents a hypothetical scenario ...
# 1710  The sentence presents a statement from Joe Bid...
# 1757  The sentence presents a statement of fact abou...
# 2627  The sentence presents a clear statement of the...
# 2770  The sentence contains several elements that su...
# 2871  The sentence presents a fact about Microsoft's...
# 3366  The sentence presents a factual account of a s...
# 3409  The sentence presents a statement that is fact...
# 3473  The sentence presents a factual observation ab...
# 3514  The sentence presents a factual account of eve...
# 3722  The sentence contains multiple statements abou...
# 3771  The sentence uses strong, emotionally charged ...
# 3858  The sentence expresses a positive bias towards...
#
#                                                raw_data  \
# 133   You are an expert in media bias.\n\nInstructio...
# 639   You are an expert in media bias.\n\nInstructio...
# 1465  You are an expert in media bias.\n\nInstructio...
# 1506  You are an expert in media bias.\n\nInstructio...
# 1710  You are an expert in media bias.\n\nInstructio...
# 1757  You are an expert in media bias.\n\nInstructio...
# 2627  You are an expert in media bias.\n\nInstructio...
# 2770  You are an expert in media bias.\n\nInstructio...
# 2871  You are an expert in media bias.\n\nInstructio...
# 3366  You are an expert in media bias.\n\nInstructio...
# 3409  You are an expert in media bias.\n\nInstructio...
# 3473  You are an expert in media bias.\n\nInstructio...
# 3514  You are an expert in media bias.\n\nInstructio...
# 3722  You are an expert in media bias.\n\nInstructio...
# 3771  You are an expert in media bias.\n\nInstructio...
# 3858  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 133   You are an expert in media bias.\n\nInstructio...     ?
# 639   You are an expert in media bias.\n\nInstructio...     ?
# 1465  You are an expert in media bias.\n\nInstructio...     ?
# 1506  You are an expert in media bias.\n\nInstructio...     ?
# 1710  You are an expert in media bias.\n\nInstructio...     ?
# 1757  You are an expert in media bias.\n\nInstructio...     ?
# 2627  You are an expert in media bias.\n\nInstructio...     ?
# 2770  You are an expert in media bias.\n\nInstructio...     ?
# 2871  You are an expert in media bias.\n\nInstructio...     ?
# 3366  You are an expert in media bias.\n\nInstructio...     ?
# 3409  You are an expert in media bias.\n\nInstructio...     ?
# 3473  You are an expert in media bias.\n\nInstructio...     ?
# 3514  You are an expert in media bias.\n\nInstructio...     ?
# 3722  You are an expert in media bias.\n\nInstructio...     ?
# 3771  You are an expert in media bias.\n\nInstructio...     ?
# 3858  You are an expert in media bias.\n\nInstructio...     ?

# %%
two_shot_cot.loc[[13, 43, 3858, 1465], 'label'] = 'BIASED'
two_shot_cot.loc[[20, 26, 33, 42, 68, 78, 93, 3514, 3409, 2871, 2627, 1757, 639, 133], 'label'] = 'NOT BIASED'

# undetermable 3771 but tends to bias
# undetermable 3722, 3473, 3366, 2770, 1710, 1506

two_shot_cot.loc[133]['response']
# Out:
# 'The sentence presents a statement from Colin Kahl, a high-ranking official in the Biden administration, which is a fact. However, the use of the phrase "a grinding slog" to describe the situation in Ukraine is somewhat subjective and could be interpreted as an opinion rather than an objective assessment. While it\'s not necessarily biased, it does add a layer of interpretation that might not be necessary to convey the same information. The sentence is therefore NOT BIASED but could be improved for clarity.'

# %%
two_shot_cot = two_shot_cot.rename(columns={"label": "2_shot_cot_label"})
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace(
    'BIASED', 1)
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace(
    'NOT BIASED',
    0)

df_merge = df_babe.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot_cot[['text', '2_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
two_shot_cot_label = df_merge['2_shot_cot_label'].astype(int)

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with (2 shot CoT): ",
      f1_score(ground_truth, two_shot_cot_label))
print("Precision with Mistral-7B-Instruct-v0.1 with (2 shot CoT): ",
      precision_score(ground_truth, two_shot_cot_label))
print("Recall with Mistral-7B-Instruct-v0.1 with (2 shot CoT): ",
      recall_score(ground_truth, two_shot_cot_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with (2 shot CoT): ",
      accuracy_score(ground_truth, two_shot_cot_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1 with (2 shot CoT):  0.7327868852459015
# Precision with Mistral-7B-Instruct-v0.1 with (2 shot CoT):  0.6176165803108808
# Recall with Mistral-7B-Instruct-v0.1 with (2 shot CoT):  0.9007556675062972
# Accuracy with Mistral-7B-Instruct-v0.1 with (2 shot CoT):  0.6751370204285002

# %% [markdown]
# # 4-shot CoT

# %%
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 25    Trump acknowledged there might be a resurgence...
# 33    Few would consider a global pandemic reason to...
# 35    Trump broadcasts his utter ignorance in the fa...
# 87    IKEA said then that the basis of the company’s...
# 114   On January 20, 2020, thousands upon thousands ...
# ...                                                 ...
# 3977  Thursday’s announcement was the latest move by...
# 3988  Democrats and Republicans have long conflated ...
# 3993  Military ships and aircraft have been deployed...
# 4002  The president can’t handle criticism. Or facts...
# 4008  About one quarter of the world’s population li...
#
#                                                response  \
# 25    The sentence presents a statement made by Pres...
# 33    The sentence presents a balanced perspective, ...
# 35    The sentence is biased because it uses loaded ...
# 87    The sentence is not biased because it presents...
# 114   The sentence is biased because it employs load...
# ...                                                 ...
# 3977  The sentence is biased because it uses languag...
# 3988  The sentence is biased because it uses the ter...
# 3993  The sentence is not biased because it presents...
# 4002  The sentence above is classified as biased bec...
# 4008  The sentence is NOT BIASED. It presents a fact...
#
#                                                raw_data  \
# 25    You are an expert in media bias.\n\nInstructio...
# 33    You are an expert in media bias.\n\nInstructio...
# 35    You are an expert in media bias.\n\nInstructio...
# 87    You are an expert in media bias.\n\nInstructio...
# 114   You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3977  You are an expert in media bias.\n\nInstructio...
# 3988  You are an expert in media bias.\n\nInstructio...
# 3993  You are an expert in media bias.\n\nInstructio...
# 4002  You are an expert in media bias.\n\nInstructio...
# 4008  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 25    You are an expert in media bias.\n\nInstructio...     ?
# 33    You are an expert in media bias.\n\nInstructio...     ?
# 35    You are an expert in media bias.\n\nInstructio...     ?
# 87    You are an expert in media bias.\n\nInstructio...     ?
# 114   You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3977  You are an expert in media bias.\n\nInstructio...     ?
# 3988  You are an expert in media bias.\n\nInstructio...     ?
# 3993  You are an expert in media bias.\n\nInstructio...     ?
# 4002  You are an expert in media bias.\n\nInstructio...     ?
# 4008  You are an expert in media bias.\n\nInstructio...     ?
#
# [297 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('The sentence is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The statement is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is labeled as biased') and \
        row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as biased') and \
        row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as BIASED') and \
        row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith(
        'The sentence above is classified as biased') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('This sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith(
        'The sentence is considered not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith(
        'The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith(
        'The sentence is classified as not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is unbiased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is NOT biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is factual and neutral') and \
        row[
            'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith(
        'The sentence is neutral and presents factual information') and \
        row[
            'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is factual') and \
        row[
            'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is factual') and \
        row[
            'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


four_shot_cot['label'] = four_shot_cot.apply(update_label, axis=1)
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 25    Trump acknowledged there might be a resurgence...
# 33    Few would consider a global pandemic reason to...
# 159   In one Senate committee, a bipartisan effort w...
# 244   Working-class Americans, like those who make u...
# 355   U.S. intelligence assessments and experts have...
# ...                                                 ...
# 3801  A fifth of U.S. trans people reported discrimi...
# 3837  The Japanese economy shrank at an annual pace ...
# 3859  U.S. President Donald Trump on Friday signed a...
# 3907  Black Americans enrolled in Medicare were arou...
# 3940  Not only do most U.S. workers not have that lu...
#
#                                                response  \
# 25    The sentence presents a statement made by Pres...
# 33    The sentence presents a balanced perspective, ...
# 159   The sentence presents a balanced and objective...
# 244   The sentence presents a statement that can be ...
# 355   The sentence presents a factual assertion base...
# ...                                                 ...
# 3801  The sentence presents a factual statement base...
# 3837  The sentence presents a factual observation ab...
# 3859  The sentence presents factual information abou...
# 3907  The sentence presents a factual statement base...
# 3940  The sentence presents a factual observation ab...
#
#                                                raw_data  \
# 25    You are an expert in media bias.\n\nInstructio...
# 33    You are an expert in media bias.\n\nInstructio...
# 159   You are an expert in media bias.\n\nInstructio...
# 244   You are an expert in media bias.\n\nInstructio...
# 355   You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3801  You are an expert in media bias.\n\nInstructio...
# 3837  You are an expert in media bias.\n\nInstructio...
# 3859  You are an expert in media bias.\n\nInstructio...
# 3907  You are an expert in media bias.\n\nInstructio...
# 3940  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 25    You are an expert in media bias.\n\nInstructio...     ?
# 33    You are an expert in media bias.\n\nInstructio...     ?
# 159   You are an expert in media bias.\n\nInstructio...     ?
# 244   You are an expert in media bias.\n\nInstructio...     ?
# 355   You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3801  You are an expert in media bias.\n\nInstructio...     ?
# 3837  You are an expert in media bias.\n\nInstructio...     ?
# 3859  You are an expert in media bias.\n\nInstructio...     ?
# 3907  You are an expert in media bias.\n\nInstructio...     ?
# 3940  You are an expert in media bias.\n\nInstructio...     ?
#
# [94 rows x 5 columns]

# %%
four_shot_cot.loc[
    [25, 33, 159, 244, 355, 418, 440, 493, 639, 678, 760, 770, 808,
     865, 901, 908, 925, 999, 1099, 1107, 1153, 1228, 1233,
     1283, 1380, 1424, 1435, 1461, 1472, 1516, 1520, 1532,
     1627, 1641, 1732, 1789, 1835, 1860, 1940, 1979, 1985, 2025, 2046, 2074,
     2151, 2226, 2251, 2319, 2341, 2359, 2484, 2534, 2610, 2644, 2658, 2660,
     2732, 2742, 2798, 2835, 2902, 2922, 2953, 2954, 3126, 3143, 3182,
     3281, 3318, 3348, 3361, 3426, 3443, 3557, 3560, 3565, 3582, 3601,
     3623, 3694, 3711, 3755, 3795, 3801, 3837, 3859, 3907, 3940], 'label'] = 'NOT BIASED'

four_shot_cot.loc[[635, 692, 1451, 1559, 2181, 2970], 'label'] = 'BIASED'

# undecideable 2860

four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 2860  “You know, there’s over 100 million people wit...
#
#                                                response  \
# 2860  The sentence contains a statement from a perso...
#
#                                                raw_data  \
# 2860  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 2860  You are an expert in media bias.\n\nInstructio...     ?

# %%
four_shot_cot = four_shot_cot.rename(columns={"label": "4_shot_cot_label"})
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace(
    'BIASED', 1)
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace(
    'NOT BIASED',
    0)
    
df_merge = df_babe.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot_cot[['text', '4_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
four_shot_cot_label = df_merge['4_shot_cot_label'].astype(int)

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with (4 shot CoT): ",
      f1_score(ground_truth, four_shot_cot_label))
print("Precision with Mistral-7B-Instruct-v0.1 with (4 shot CoT): ",
      precision_score(ground_truth, four_shot_cot_label))
print("Recall with Mistral-7B-Instruct-v0.1 with (4 shot CoT): ",
      recall_score(ground_truth, four_shot_cot_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with (4 shot CoT): ",
      accuracy_score(ground_truth, four_shot_cot_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1 with (4 shot CoT):  0.7340137471360133
# Precision with Mistral-7B-Instruct-v0.1 with (4 shot CoT):  0.6268231945926717
# Recall with Mistral-7B-Instruct-v0.1 with (4 shot CoT):  0.8854271356783919
# Accuracy with Mistral-7B-Instruct-v0.1 with (4 shot CoT):  0.6823383084577115

# %% [markdown]
# # 8-shot CoT

# %%
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 5     Meanwhile, a pervasive celebrity culture — in ...
# 11    On Monday, the Supreme Court voted in an 8-1 d...
# 21    Donald Trump signed an executive order for thi...
# 24    Disney’s executives stopped advertising on Tuc...
# 25    Trump acknowledged there might be a resurgence...
# ...                                                 ...
# 3986  Coronavirus: E.U. blasts Trump's travel ban as...
# 3997  There's a dollop of cream on top of the shit s...
# 4012  U.S. President Donald Trump’s former personal ...
# 4014  Larry Kudlow, one of President Donald Trump’s ...
# 4020  The march then continued to the United States ...
#
#                                                response  \
# 5     The sentence is biased because it implies a ne...
# 11    The sentence is biased because it uses languag...
# 21    The sentence presents factual information with...
# 24    The sentence is biased due to its use of loade...
# 25    The sentence presents an objective statement o...
# ...                                                 ...
# 3986  The sentence is biased because it employs emot...
# 3997  The sentence is biased due to its use of emoti...
# 4012  The sentence reports a statement made by Micha...
# 4014  The sentence is biased because it employs load...
# 4020  The sentence presents the facts of the event w...
#
#                                                raw_data  \
# 5     You are an expert in media bias.\n\nInstructio...
# 11    You are an expert in media bias.\n\nInstructio...
# 21    You are an expert in media bias.\n\nInstructio...
# 24    You are an expert in media bias.\n\nInstructio...
# 25    You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3986  You are an expert in media bias.\n\nInstructio...
# 3997  You are an expert in media bias.\n\nInstructio...
# 4012  You are an expert in media bias.\n\nInstructio...
# 4014  You are an expert in media bias.\n\nInstructio...
# 4020  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 5     You are an expert in media bias.\n\nInstructio...     ?
# 11    You are an expert in media bias.\n\nInstructio...     ?
# 21    You are an expert in media bias.\n\nInstructio...     ?
# 24    You are an expert in media bias.\n\nInstructio...     ?
# 25    You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3986  You are an expert in media bias.\n\nInstructio...     ?
# 3997  You are an expert in media bias.\n\nInstructio...     ?
# 4012  You are an expert in media bias.\n\nInstructio...     ?
# 4014  You are an expert in media bias.\n\nInstructio...     ?
# 4020  You are an expert in media bias.\n\nInstructio...     ?
#
# [576 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('The sentence is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The statement is biased') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is labeled as biased') and \
        row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as biased') and \
        row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is classified as BIASED') and \
        row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith(
        'The sentence above is classified as biased') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('This sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith(
        'The sentence is considered not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith(
        'The sentence is classified as NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith(
        'The sentence is classified as not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is unbiased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is NOT biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is factual and neutral') and \
        row[
            'label'] == '?':
        return 'NOT BIASED'
    return row['label']


eight_shot_cot['label'] = eight_shot_cot.apply(update_label, axis=1)
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 21    Donald Trump signed an executive order for thi...
# 25    Trump acknowledged there might be a resurgence...
# 41    U.S. President Donald Trump pledged on Wednesd...
# 97    Her 72-year-old sister, Katherine Massey, was ...
# 100   Eight years later, the Democratic Party has ha...
# ...                                                 ...
# 3832  A gunman opened fire at the Molson Coors Bever...
# 3833  So far, there have been no arrests linked to t...
# 3941  The Trump administration on Thursday scrapped ...
# 4012  U.S. President Donald Trump’s former personal ...
# 4020  The march then continued to the United States ...
#
#                                                response  \
# 21    The sentence presents factual information with...
# 25    The sentence presents an objective statement o...
# 41    The sentence presents a statement by President...
# 97    The sentence is factual and does not contain a...
# 100   The sentence presents factual information with...
# ...                                                 ...
# 3832  The sentence is factual and devoid of any edit...
# 3833  The sentence is factual and unbiased, simply s...
# 3941  The sentence presents a factual account of a p...
# 4012  The sentence reports a statement made by Micha...
# 4020  The sentence presents the facts of the event w...
#
#                                                raw_data  \
# 21    You are an expert in media bias.\n\nInstructio...
# 25    You are an expert in media bias.\n\nInstructio...
# 41    You are an expert in media bias.\n\nInstructio...
# 97    You are an expert in media bias.\n\nInstructio...
# 100   You are an expert in media bias.\n\nInstructio...
# ...                                                 ...
# 3832  You are an expert in media bias.\n\nInstructio...
# 3833  You are an expert in media bias.\n\nInstructio...
# 3941  You are an expert in media bias.\n\nInstructio...
# 4012  You are an expert in media bias.\n\nInstructio...
# 4020  You are an expert in media bias.\n\nInstructio...
#
#                                                   query label
# 21    You are an expert in media bias.\n\nInstructio...     ?
# 25    You are an expert in media bias.\n\nInstructio...     ?
# 41    You are an expert in media bias.\n\nInstructio...     ?
# 97    You are an expert in media bias.\n\nInstructio...     ?
# 100   You are an expert in media bias.\n\nInstructio...     ?
# ...                                                 ...   ...
# 3832  You are an expert in media bias.\n\nInstructio...     ?
# 3833  You are an expert in media bias.\n\nInstructio...     ?
# 3941  You are an expert in media bias.\n\nInstructio...     ?
# 4012  You are an expert in media bias.\n\nInstructio...     ?
# 4020  You are an expert in media bias.\n\nInstructio...     ?
#
# [101 rows x 5 columns]

# %%
eight_shot_cot.loc[
    [21, 25, 41, 97, 100, 133, 136, 139, 167, 235, 286, 294, 333, 355, 386,
     408, 454, 516, 557, 595, 620, 623, 637, 658, 696, 782, 848, 901, 931,
     943, 960, 995, 1008, 1042, 1193, 1285, 1313, 1332, 1378, 1401,
     1414, 1448, 1488, 1495, 1526, 1542, 1579, 1583, 1650,
     1665, 1699, 1710, 1758, 1779, 1810, 1880, 1938, 1981,
     2019, 2050, 2081, 2126, 2302, 2351, 2382, 2383, 2509,
     2539, 2683, 2697, 2702, 2736, 2840, 2902, 2927,
     2932, 2954, 2976, 2996, 3024, 1789, 3050, 3024, 3073, 3128,
     3281, 3284, 3299, 3328, 3440, 3493, 3516, 3544, 3748,
     3783, 3809, 3832, 3833, 3941, 4012, 4020], 'label'] = 'NOT BIASED'
eight_shot_cot.loc[[644, 1521, 2899, 3147, 1656], 'label'] = 'BIASED'

# undecideable 1656 -> contains BIASED subset so it should be biased

# %%
eight_shot_cot = eight_shot_cot.rename(columns={"label": "8_shot_cot_label"})
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot[
    '8_shot_cot_label'].replace('BIASED', 1)
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot[
    '8_shot_cot_label'].replace('NOT BIASED',
                                0)
                                
df_merge = df_babe.merge(eight_shot_cot[['text', '8_shot_cot_label']][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot_cot[['text', '8_shot_cot_label']][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot_cot[['text', '8_shot_cot_label']], on='text')

ground_truth = df_merge['label']
eight_shot_cot_label = df_merge['8_shot_cot_label']

# %%
print("F1-Score with Mistral-7B-Instruct-v0.1 with (8 shot CoT): ",
      f1_score(ground_truth, eight_shot_cot_label))
print("Precision with Mistral-7B-Instruct-v0.1 with (8 shot CoT): ",
      precision_score(ground_truth, eight_shot_cot_label))
print("Recall with Mistral-7B-Instruct-v0.1 with (8 shot CoT): ",
      recall_score(ground_truth, eight_shot_cot_label))
print("Accuracy with Mistral-7B-Instruct-v0.1 with (8 shot CoT): ",
      accuracy_score(ground_truth, eight_shot_cot_label))
# Out:
# F1-Score with Mistral-7B-Instruct-v0.1 with (8 shot CoT):  0.7554083885209713
# Precision with Mistral-7B-Instruct-v0.1 with (8 shot CoT):  0.6738873572272548
# Recall with Mistral-7B-Instruct-v0.1 with (8 shot CoT):  0.8593671521848317
# Accuracy with Mistral-7B-Instruct-v0.1 with (8 shot CoT):  0.7244466550609301

# %% [markdown]
# # Comparison and plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column,
                          title=None
                          ):
    predicted_labels = df[f'{predicted_labels_column}']
    true_labels = df[f'{true_labels_column}']

    # Calculate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Display confusion matrix heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=True,
                yticklabels=True, ax=ax)

    title = title if title else predicted_labels_column

    ax.set_title(f'Confusion Matrix - {title}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')


# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Confusion Matrices')

# Plot each confusion matrix
plot_confusion_matrix(axes[0, 0], df_merge_all_runs, 'label', '0_shot_label', '0_shot')
plot_confusion_matrix(axes[0, 1], df_merge_all_runs, 'label',
                      '0_shot_with_system_label', '0_shot_with_system')
plot_confusion_matrix(axes[0, 2], df_merge_all_runs, 'label', '0_shot_cot_label',
                      '0_shot_cot')
plot_confusion_matrix(axes[1, 0], df_merge_all_runs, 'label', '2_shot_label', '2_shot')
plot_confusion_matrix(axes[1, 1], df_merge_all_runs, 'label', '4_shot_label', '4_shot')
plot_confusion_matrix(axes[1, 2], df_merge_all_runs, 'label', '8_shot_label', '8_shot')

plt.tight_layout(
    rect=[0, 0, 1, 0.96])  # Adjust layout to prevent title overlap
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0_shot_cot_label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 34
#      31 plot_confusion_matrix(axes[0, 0], df_merge_all_runs, 'label', '0_shot_label', '0_shot')
#      32 plot_confusion_matrix(axes[0, 1], df_merge_all_runs, 'label',
#      33                       '0_shot_with_system_label', '0_shot_with_system')
# ---> 34 plot_confusion_matrix(axes[0, 2], df_merge_all_runs, 'label', '0_shot_cot_label',
#      35                       '0_shot_cot')
#      36 plot_confusion_matrix(axes[1, 0], df_merge_all_runs, 'label', '2_shot_label', '2_shot')
#      37 plot_confusion_matrix(axes[1, 1], df_merge_all_runs, 'label', '4_shot_label', '4_shot')
#
# Cell In[52], line 9, in plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column, title)
#       6 def plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column,
#       7                           title=None
#       8                           ):
# ----> 9     predicted_labels = df[f'{predicted_labels_column}']
#      10     true_labels = df[f'{true_labels_column}']
#      12     # Calculate confusion matrix
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/PycharmProjects/Annomatic_Benchmark/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: '0_shot_cot_label'

# %% [markdown]
# # Krippendorff Alpha in model

# %%
import krippendorff

runs = ['0_shot_label', '0_shot_with_system_label', '0_shot_cot_label',
        '2_shot_label', '4_shot_label', '8_shot_label']


def compute_krippendorff_alpha(df, predicted_columns):
    pred_map = {}
    for run in predicted_columns:
        predicted_labels = df[run]
        pred_map[run] = predicted_labels

    # Check if there is variability in the ratings
    unique_labels_counts = df[predicted_columns].nunique(axis=1)
    if unique_labels_counts.max() == 1:
        # All ratings are the same, return a special value or handle accordingly
        return 0

    reliability_data = df[predicted_columns].values.tolist()

    # Calculate Krippendorff's alpha
    alpha = krippendorff.alpha(reliability_data=list(pred_map.values()),
                               level_of_measurement='nominal')

    return alpha

# %%
alpha_value = compute_krippendorff_alpha(df_merge, runs)
print(f"Krippendorff's Alpha (all runs): {alpha_value}")

# %%
import itertools


def compute_krippendorff_alpha_for_k_runs(df, runs, k=None):
    # Initialize variables to store the best combination and alpha
    if k is None:
        k = len(runs)

    best_combination = None
    best_alpha = 0  # Assuming alpha ranges from 0 to 1

    # Iterate through all possible combinations
    for combination in itertools.combinations(runs, k):

        alpha_value = compute_krippendorff_alpha(df, list(combination))

        # Print alpha for the current combination
        print(f"Combination: {combination}, Alpha: {alpha_value}")

        # Update best combination and alpha if a higher alpha is found
        if alpha_value > best_alpha:
            best_alpha = alpha_value
            best_combination = combination

    # Print the best combination and alpha
    print(f"\nBest Combination: {best_combination}, Best Alpha: {best_alpha}")
    return best_alpha, best_combination

# %%
compute_krippendorff_alpha_for_k_runs(df_merge, runs, 2)
