# %% [markdown]
# # Eval the results of GPT 4 turbo

# %%
import pandas as pd
from datasets import load_dataset
from sklearn.metrics import f1_score, precision_score, recall_score, \
    accuracy_score

import re
from typing import List, Tuple

import pandas as pd


def is_contained(inner_start, inner_end, outer_start, outer_end):
    return (
        outer_start <= inner_start <= outer_end
        and outer_start <= inner_end <= outer_end
        and (inner_start, inner_end) != (outer_start, outer_end)
    )


def find_all_occurrences_indices(
    sentence: str,
    label: str,
) -> List[Tuple[int, int]]:
    """
    Finds all occurrences of a label in a sentence and returns a list of tuples
    with the start and end indices of the occurrences.

    Args:
        sentence: The sentence to search in.
        label: The label to search for.

    Returns:
        A list of tuples with the start and end indices of the occurrences.
    """
    return [
        (int(match.start()), int(match.end()))
        for match in re.finditer(label, sentence)
    ]


def find_contained_labels(labels):
    """
    Finds all labels that are contained in other labels.

    Args:
        labels: A list of labels.

    Returns:
        A dictionary with the labels as keys and a list of labels that are
        contained in the key label as values.
    """
    return {
        label_1: [
            label2
            for label2 in labels
            if label_1 in label2 and label_1 != label2
        ]
        for label_1 in labels
    }


def find_labels_in_sentence(
    sentence: str,
    labels: List[str],
) -> List[List[Tuple[int, int]]]:
    """
    Finds all occurrences of the labels in a sentence and returns a list of
    lists with the occurrences of each label.

    Labels that are contained in other labels are not returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.

    Returns:
        A list of lists with the positional occurrence of each label.
    """
    if not labels:
        return []

    containable_map = find_contained_labels(labels)
    sentence_lower = sentence.lower()
    occurrences = [
        find_all_occurrences_indices(sentence_lower, label.lower())
        for label in labels
    ]
    label_occurrences = dict(zip(labels, occurrences))
    included_list = []
    for label, inner_pos in zip(labels, occurrences):
        contained = set()
        containing_labels = containable_map.get(label, set())

        for bigger_label in containing_labels:
            locations: List[Tuple[int, int]] = label_occurrences.get(
                bigger_label,
                list(),
            )

            for inner_start, inner_end in inner_pos:
                for outer_start, outer_end in locations:
                    if is_contained(
                        inner_start,
                        inner_end,
                        outer_start,
                        outer_end,
                    ):
                        contained.add((inner_start, inner_end))
        included_list.append(list(contained))

    return [
        list(set(pos) - set(included))
        for pos, included in zip(occurrences, included_list)
    ]


def find_label(
    sentence: str,
    labels: List[str],
    default_label: str = "?",
) -> str:
    """
    Search for given labels in the sentence and returns it if found. If only
    one label occur in the sentence, it will be returned. If no label or
    different labels occur in the sentence, '?' is returned.

    Args:
        sentence: The sentence to search in.
        labels: The labels to search for.
        default_label: The label to return if no label or different labels
            occur in the sentence.

    Returns:
        The label that occurs in the sentence or '?' if no label occurs in the
        sentence.
    """
    occurrences = find_labels_in_sentence(sentence=sentence, labels=labels)
    non_empty_indices = [i for i, sublist in enumerate(occurrences) if sublist]
    return (
        labels[non_empty_indices[0]]
        if len(
            non_empty_indices,
        )
           == 1
        else default_label
    )


def _soft_parse(
    df: pd.DataFrame,
    in_col: str,
    parsed_col: str,
    labels: List[str] = None,
) -> pd.DataFrame:
    if labels is None:
        raise ValueError("Labels are not set!")

    df[parsed_col] = df[in_col].apply(
        lambda x: find_label(x, labels),
    )

# %%
# load
model = 'gpt-4-1106-preview'

# load results
# TODO maybe rerun zeroshot and system zero
zero_shot = pd.read_csv(f"../zero-shot/data/gpt-4.csv")
zero_shot_with_system = pd.read_csv(
    f"../zero-shot-system_prompt/data/gpt-4.csv")
#zero_shot_cot = pd.read_csv(f"../zero-shot-cot/data/{model}.csv")
two_shot = pd.read_csv(f"../2-shot/data/{model}.csv")
four_shot = pd.read_csv(f"../4-shot/data/{model}.csv")
eight_shot = pd.read_csv(f"../8-shot/data/{model}.csv")

two_shot_cot = pd.read_csv(f"../2-shot-CoT/data/{model}.csv")
four_shot_cot = pd.read_csv(f"../4-shot-CoT/data/{model}.csv")
eight_shot_cot = pd.read_csv(f"../8-shot-CoT/data/{model}.csv")

#load pool
pool = load_dataset('mediabiasgroup/BABE-icl-pool')['train'].to_pandas()

# exclude pool from model (if needed)
zero_shot = zero_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
zero_shot_with_system = zero_shot_with_system.merge(pool['text'], on='text',
                                                    how='left',
                                                    indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
#zero_shot_cot = zero_shot_cot.merge(pool['text'], on='text', how='left',
#                                    indicator=True).query(
#    '_merge == "left_only"').drop('_merge', axis=1)
two_shot = two_shot.merge(pool['text'], on='text', how='left',
                          indicator=True).query('_merge == "left_only"').drop(
    '_merge', axis=1)
four_shot = four_shot.merge(pool['text'], on='text', how='left',
                            indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot = eight_shot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
two_shot_cot = two_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
four_shot_cot = four_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)
eight_shot_cot = eight_shot_cot.merge(pool['text'], on='text', how='left',
                              indicator=True).query(
    '_merge == "left_only"').drop('_merge', axis=1)


#load babe
dataset = load_dataset('mediabiasgroup/BABE-v4')
df_babe = pd.DataFrame(dataset['train'])

# df_merge = babe at begin
df_merge_all_runs = df_babe
df_merge_all_runs_with_errors = df_babe
def find_first_occurrence(string, instruction="Instruction:",
                          statement1="The answer is BIASED",
                          statement2="The answer is NOT BIASED"
                          ):
    index_instruction = string.find(instruction)
    index1 = string.find(statement1)
    index2 = string.find(statement2)

    if index1 == -1 and index2 == -1:
        return "Neither instruction nor statements found in the given string."
    elif index1 == -1 and index2 == -1:
        return "Neither statement found in the given string."
    elif index1 == -1:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"
    elif index2 == -1:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    elif index1 < index2:
        if index_instruction == -1 or index1 < index_instruction:
            return f"{statement1}"
        else:
            return "After Instruction"
    else:
        if index_instruction == -1 or index2 < index_instruction:
            return f"{statement2}"
        else:
            return "After Instruction"

# %% [markdown]
# # Zero shot

# %%
#_soft_parse(zero_shot, 'response', 'label',
#            ['BIASED', 'NOT BIASED'])
zero_shot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, label, raw_data, query]
# Index: []

# %%
# preprocessing

# %%
zero_shot = zero_shot.rename(columns={"label": "0_shot_label"})
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('BIASED', 1)
zero_shot['0_shot_label'] = zero_shot['0_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot[zero_shot['0_shot_label'] != '?'][['text', '0_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot[['text', '0_shot_label']], on='text')

ground_truth = df_merge['label']
zero_shot_label = df_merge['0_shot_label']

# %%
print("F1-Score with GPT 4 turbo: ", f1_score(ground_truth, zero_shot_label))
print("Precision with GPT 4 turbo: ",
      precision_score(ground_truth, zero_shot_label))
print("Recall with GPT 4 turbo: ",
      recall_score(ground_truth, zero_shot_label))
print("Accuracy with GPT 4 turbo: ",
      accuracy_score(ground_truth, zero_shot_label))
# Out:
# F1-Score with GPT 4 turbo:  0.7739199575934269
# Precision with GPT 4 turbo:  0.819304152637486
# Recall with GPT 4 turbo:  0.7332998493219488
# Accuracy with GPT 4 turbo:  0.7878637154936583

# %% [markdown]
# # zero shot with system prompt

# %%
zero_shot_with_system.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
zero_shot_with_system = zero_shot_with_system.rename(
    columns={"label": "0_shot_with_system_label"})
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('BIASED', 1)
zero_shot_with_system['0_shot_with_system_label'] = zero_shot_with_system[
    '0_shot_with_system_label'].replace('NOT BIASED', 0)
df_merge = df_babe.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(zero_shot_with_system[zero_shot_with_system['0_shot_with_system_label'] != '?'][['text', '0_shot_with_system_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(zero_shot_with_system[['text', '0_shot_with_system_label']], on='text')

ground_truth = df_merge['label']
zero_shot_with_system_label = df_merge['0_shot_with_system_label']

# %%
print("F1-Score with GPT 4 turbo with System Prompt: ",
      f1_score(ground_truth, zero_shot_with_system_label))
print("Precision with GPT 4 turbo with System Prompt: ",
      precision_score(ground_truth, zero_shot_with_system_label))
print("Recall with GPT 4 turbo with System Prompt: ",
      recall_score(ground_truth, zero_shot_with_system_label))
print("Accuracy with GPT 4 turbo with System Prompt: ",
      accuracy_score(ground_truth, zero_shot_with_system_label))
# Out:
# F1-Score with GPT 4 turbo with System Prompt:  0.780759493670886
# Precision with GPT 4 turbo with System Prompt:  0.7871362940275651
# Recall with GPT 4 turbo with System Prompt:  0.7744851833249623
# Accuracy with GPT 4 turbo with System Prompt:  0.7846306888833623

# %% [markdown]
# # zero shot CoT

# %%
zero_shot_cot.query("label == '?'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 zero_shot_cot.query("label == '?'")
#
# NameError: name 'zero_shot_cot' is not defined

# %%
# preprocessing
# Out:
# Running cells with 'Python 3.11.1 64-bit ('3.11.1')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sinix/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
zero_shot_cot = zero_shot_cot.rename(columns={"label": "0_shot_cot_label"})
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'BIASED', 1)
zero_shot_cot['0_shot_cot_label'] = zero_shot_cot['0_shot_cot_label'].replace(
    'NOT BIASED', 0)

df_merge = pd.merge(df_merge, zero_shot_cot[['text', '0_shot_cot_label']],
                    on='text')
ground_truth = df_merge['label']
zero_shot_cot_label = df_merge['0_shot_cot_label']
# Out:
# Running cells with 'Python 3.11.1 64-bit ('3.11.1')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sinix/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
print("F1-Score with GPT 4 turbo with CoT: ",
      f1_score(ground_truth, zero_shot_cot_label))
print("Precision with GPT 4 turbo with CoT: ",
      precision_score(ground_truth, zero_shot_cot_label))
print("Recall with GPT 4 turbo with CoT: ",
      recall_score(ground_truth, zero_shot_cot_label))
print("Accuracy with GPT 4 turbo with CoT: ",
      accuracy_score(ground_truth, zero_shot_cot_label))
# Out:
# Running cells with 'Python 3.11.1 64-bit ('3.11.1')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sinix/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# # 2-shot

# %%
two_shot.query("label == '?'")
# Out:
#                                                    text  \
# 46    But research like Clayton’s and Jyoti’s is an ...
# 353   The number of women behind the camera on Holly...
# 438   In February, Breitbart News’s John Binder repo...
# 533                         Never, and I've seen a lot.
# 627   "Mr. Chairman, I have to tell you, this is the...
# 631   Until recently, there seemed to be no broader ...
# 661   Donald Trump announced at the time that the En...
# 920   Republican senators returned to Washington on ...
# 989   Trump pledged to ban the devices soon after a ...
# 991   “The FBI has for quite some time now assessed ...
# 1075  Just steps from where Trump spoke, peaceful pr...
# 1128  A Republican group opposed to President Donald...
# 1166  Even a relaxing walk through her local park ca...
# 1265  A family-run network of pro-gun groups is behi...
# 1357  Alabama has the most restrictive abortion law ...
# 1732  But the decline in carbon emissions caused by ...
# 1734  President Donald Trump asserted without eviden...
# 1825           And then that child will be taken away.”
# 1826  When their first caretaker is not the biologic...
# 1900  President Donald Trump used the occasion to ag...
# 1937  Thousands are marching, including some white n...
# 2076  The ADL report represents a sobering warning a...
# 2174  Trump supporter grabs spotlight at Sanders eve...
# 2215  Sure, the coronavirus pandemic is racing throu...
# 2225  It is worth noting that in eight of the top te...
# 2319  Britain will ban the sale of new petrol, diese...
# 2371  On Tuesday, the former Iranian reformist vice-...
# 2546  U.S. immigration officials on Monday deported ...
# 2561  A poll released Tuesday finds 75 percent of Am...
# 2705  The protesters also chanted the name of George...
# 2792  The doctor explained that two medicines that w...
# 2840  Those areas have been plagued for years by gun...
# 2877  The Jerusalem Post reports: Nearly 50% of Pale...
# 2983                             And they aren’t alone.
# 2991                   are guaranteed to vote for them.
# 3018                     Everything will be Ukraine..."
# 3134  “This new wording, I would worry, does leave i...
# 3184  I shot and killed people because they were Bla...
# 3363  And crises are bad for people’s mental health,...
# 3409  While the major baseball leagues won’t be affe...
# 3803  Democrats took the first step to repeal Presid...
# 3903  The man behind a petition drive to recall a Ca...
#
#                                                response  \
# 46    NOT BIASED\n\nThe sentence presents a viewpoin...
# 353   BIASED\n\nInstruction: 'The number of women be...
# 438   NOT BIASED\n\nThe sentence appears to be a fac...
# 533   NOT BIASED\n\nThe sentence "Never, and I've se...
# 627   NOT BIASED\n\nThe sentence is a direct quote f...
# 631   NOT BIASED\n\nThe sentence provides an observa...
# 661   NOT BIASED\n\nThe sentence provides factual in...
# 920   BIASED\n\nThe use of the word "seethed" convey...
# 989   BIASED\n\nThe sentence contains a factual stat...
# 991   BIASED\n\nThe sentence contains a quote from F...
# 1075  BIASED\n\nThe sentence uses the term "peaceful...
# 1128  NOT BIASED\n\nThe sentence reports on the acti...
# 1166  NOT BIASED\n\nThe sentence describes a persona...
# 1265  NOT BIASED\n\nThe sentence presents a finding ...
# 1357  BIASED\n\nThe sentence presents a factual stat...
# 1732  NOT BIASED\n\nThe sentence presents a potentia...
# 1734  NOT BIASED\n\nThe sentence presents a factual ...
# 1825  The sentence provided, "And then that child wi...
# 1826  NOT BIASED\n\nThe sentence presents a statemen...
# 1900  NOT BIASED\n\nThe sentence is a straightforwar...
# 1937  BIASED\n\nThe sentence attributes the actions ...
# 2076  NOT BIASED\n\nThe sentence appears to be a str...
# 2174  BIASED\n\nThe sentence "Trump supporter grabs ...
# 2215  NOT BIASED\n\nThe sentence uses a metaphor to ...
# 2225  NOT BIASED\n\nThe sentence appears to present ...
# 2319  NOT BIASED\n\nInstruction: 'This prohibition i...
# 2371  NOT BIASED\n\nThe sentence reports a statement...
# 2546  NOT BIASED\n\nThe sentence appears to be a str...
# 2561  NOT BIASED\n\nThe sentence presents a statisti...
# 2705  BIASED\n\nThe use of "allegedly" could be seen...
# 2792  BIASED\n\nThe use of the term "halt her pregna...
# 2840  NOT BIASED\n\nThe sentence is stating a fact a...
# 2877  NOT BIASED\n\nThe sentence presents a factual ...
# 2983  BIASED\n\nThe sentence "And they aren’t alone....
# 2991  The provided sentence fragment 'are guaranteed...
# 3018  NOT BIASED\n\nThe sentence "Everything will be...
# 3134  NOT BIASED\n\nThe sentence presents a quote fr...
# 3184  NOT BIASED\n\nThe sentence appears to be a dir...
# 3363  NOT BIASED\n\nThe sentence presents a statemen...
# 3409  NOT BIASED\n\nThe sentence presents a potentia...
# 3803  NOT BIASED\n\nThe sentence appears to be a fac...
# 3903  BIASED\n\nThe use of the word "shoving" may no...
#
#                                                raw_data  \
# 46    {\n  "id": "chatcmpl-8UtY0GCNJSr0souklVOkWAbYs...
# 353   {\n  "id": "chatcmpl-8UtjEWmc90IorY72U54AOjuDg...
# 438   {\n  "id": "chatcmpl-8Utnn9jev5zREHaq9z683amnB...
# 533   {\n  "id": "chatcmpl-8Utr8OnY5nW5OuWKkqtErm86t...
# 627   {\n  "id": "chatcmpl-8Utv81laujOGno4URomfWv8ep...
# 631   {\n  "id": "chatcmpl-8UtvJpwZ2yAdBT8fOAsF0vfU9...
# 661   {\n  "id": "chatcmpl-8Utwpuu028xmIs1W7qyaVpQCS...
# 920   {\n  "id": "chatcmpl-8Uu8f73VtVqFxlHkPtQdNpADQ...
# 989   {\n  "id": "chatcmpl-8UuBlStNB1Au9bcPcQU2PdFKs...
# 991   {\n  "id": "chatcmpl-8UuBvb15IammoQIt23id0kEL2...
# 1075  {\n  "id": "chatcmpl-8UuF4TIELFbMQ5AQKNi1DGCDn...
# 1128  {\n  "id": "chatcmpl-8UuGkWNUIaAWGncfclsGGxnig...
# 1166  {\n  "id": "chatcmpl-8UuHyp2bDZV5EakSgnuPvHd8x...
# 1265  {\n  "id": "chatcmpl-8UuLmdbWk0MVEGSvOaTrFb2x7...
# 1357  {\n  "id": "chatcmpl-8UuPhOYI35WzWxem6aLjxCKy9...
# 1732  {\n  "id": "chatcmpl-8UucvaKUGkDM8UarpdBS76GIu...
# 1734  {\n  "id": "chatcmpl-8UuczJPTgsh2lhAF6cjhi59bw...
# 1825  {\n  "id": "chatcmpl-8UuhCKKi1JNTlMLGDetjWvrSg...
# 1826  {\n  "id": "chatcmpl-8UuhKcwKoqapbJM7qmVr1exJS...
# 1900  {\n  "id": "chatcmpl-8UukPoTFAdmop7Ex421b7CKeq...
# 1937  {\n  "id": "chatcmpl-8UulvvYJ2CMugZZigdke5nR8L...
# 2076  {\n  "id": "chatcmpl-8Uut7B0nu55hSFFLiiYlCuJ00...
# 2174  {\n  "id": "chatcmpl-8Uuy0lJad8cqqE8FaQzmLhi0E...
# 2215  {\n  "id": "chatcmpl-8UuzQhS73milIxsYeGMfKsvTk...
# 2225  {\n  "id": "chatcmpl-8UuzqwklYM4BdjOGMbnDG9Okv...
# 2319  {\n  "id": "chatcmpl-8Uv3uBCKQLTUiNHvnJ4htLDgf...
# 2371  {\n  "id": "chatcmpl-8Uv6FwBxblf0ciz9252Rj1bHT...
# 2546  {\n  "id": "chatcmpl-8UvCuWy7UL6vsIE5KZZ4VgeES...
# 2561  {\n  "id": "chatcmpl-8UvDZSUYo1qzDmxRdL3orRiYy...
# 2705  {\n  "id": "chatcmpl-8UvKHVTiZmKb9DfXR5FF4dqoz...
# 2792  {\n  "id": "chatcmpl-8UvPbBU9ryfcCqGdQROyXotXH...
# 2840  {\n  "id": "chatcmpl-8UvRsBnSQI4uQvmTc8zjINNxi...
# 2877  {\n  "id": "chatcmpl-8UvTQzgD893hJ4cNJ8WESJ9wM...
# 2983  {\n  "id": "chatcmpl-8UvXXWEXgy53LMoEaCJCd98qQ...
# 2991  {\n  "id": "chatcmpl-8UvYFRpAyjyqwTP5iTPImdrMc...
# 3018  {\n  "id": "chatcmpl-8UvZM1vQnkDVIW5dyCmYaXiHz...
# 3134  {\n  "id": "chatcmpl-8UvdTs4rE3ztZRKJNjVmVbXSu...
# 3184  {\n  "id": "chatcmpl-8UvfbuQ3oXSGEjVu7aP4lUysA...
# 3363  {\n  "id": "chatcmpl-8Uvn4N7O0uJQeUyh3ciRx79j4...
# 3409  {\n  "id": "chatcmpl-8Uvp1EZvSsKbzF7jCMFCAixZ4...
# 3803  {\n  "id": "chatcmpl-8Uw4sn7Yxa1JjFcLSkulFCIEY...
# 3903  {\n  "id": "chatcmpl-8Uw8nwbFH65mYjvecPOTCkYuF...
#
#                                                   query label
# 46    [{'role': 'system', 'content': 'You are an exp...     ?
# 353   [{'role': 'system', 'content': 'You are an exp...     ?
# 438   [{'role': 'system', 'content': 'You are an exp...     ?
# 533   [{'role': 'system', 'content': 'You are an exp...     ?
# 627   [{'role': 'system', 'content': 'You are an exp...     ?
# 631   [{'role': 'system', 'content': 'You are an exp...     ?
# 661   [{'role': 'system', 'content': 'You are an exp...     ?
# 920   [{'role': 'system', 'content': 'You are an exp...     ?
# 989   [{'role': 'system', 'content': 'You are an exp...     ?
# 991   [{'role': 'system', 'content': 'You are an exp...     ?
# 1075  [{'role': 'system', 'content': 'You are an exp...     ?
# 1128  [{'role': 'system', 'content': 'You are an exp...     ?
# 1166  [{'role': 'system', 'content': 'You are an exp...     ?
# 1265  [{'role': 'system', 'content': 'You are an exp...     ?
# 1357  [{'role': 'system', 'content': 'You are an exp...     ?
# 1732  [{'role': 'system', 'content': 'You are an exp...     ?
# 1734  [{'role': 'system', 'content': 'You are an exp...     ?
# 1825  [{'role': 'system', 'content': 'You are an exp...     ?
# 1826  [{'role': 'system', 'content': 'You are an exp...     ?
# 1900  [{'role': 'system', 'content': 'You are an exp...     ?
# 1937  [{'role': 'system', 'content': 'You are an exp...     ?
# 2076  [{'role': 'system', 'content': 'You are an exp...     ?
# 2174  [{'role': 'system', 'content': 'You are an exp...     ?
# 2215  [{'role': 'system', 'content': 'You are an exp...     ?
# 2225  [{'role': 'system', 'content': 'You are an exp...     ?
# 2319  [{'role': 'system', 'content': 'You are an exp...     ?
# 2371  [{'role': 'system', 'content': 'You are an exp...     ?
# 2546  [{'role': 'system', 'content': 'You are an exp...     ?
# 2561  [{'role': 'system', 'content': 'You are an exp...     ?
# 2705  [{'role': 'system', 'content': 'You are an exp...     ?
# 2792  [{'role': 'system', 'content': 'You are an exp...     ?
# 2840  [{'role': 'system', 'content': 'You are an exp...     ?
# 2877  [{'role': 'system', 'content': 'You are an exp...     ?
# 2983  [{'role': 'system', 'content': 'You are an exp...     ?
# 2991  [{'role': 'system', 'content': 'You are an exp...     ?
# 3018  [{'role': 'system', 'content': 'You are an exp...     ?
# 3134  [{'role': 'system', 'content': 'You are an exp...     ?
# 3184  [{'role': 'system', 'content': 'You are an exp...     ?
# 3363  [{'role': 'system', 'content': 'You are an exp...     ?
# 3409  [{'role': 'system', 'content': 'You are an exp...     ?
# 3803  [{'role': 'system', 'content': 'You are an exp...     ?
# 3903  [{'role': 'system', 'content': 'You are an exp...     ?

# %%
def update_label(row):
    if row['response'].startswith("BIASED") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("NOT BIASED") and row['label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


two_shot['label'] = two_shot.apply(update_label, axis=1)
two_shot.query("label == '?'")
# Out:
#                                           text  \
# 1825  And then that child will be taken away.”
# 2991          are guaranteed to vote for them.
#
#                                                response  \
# 1825  The sentence provided, "And then that child wi...
# 2991  The provided sentence fragment 'are guaranteed...
#
#                                                raw_data  \
# 1825  {\n  "id": "chatcmpl-8UuhCKKi1JNTlMLGDetjWvrSg...
# 2991  {\n  "id": "chatcmpl-8UvYFRpAyjyqwTP5iTPImdrMc...
#
#                                                   query label
# 1825  [{'role': 'system', 'content': 'You are an exp...     ?
# 2991  [{'role': 'system', 'content': 'You are an exp...     ?

# %%
# TODO maybe rerun
two_shot.loc[[1825, 2991], 'label'] = 'NOT BIASED'

# %%
two_shot = two_shot.rename(columns={"label": "2_shot_label"})
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('BIASED', 1)
two_shot['2_shot_label'] = two_shot['2_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot[two_shot['2_shot_label'] != '?'][['text', '2_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot[['text', '2_shot_label']], on='text')

ground_truth = df_merge['label']
two_shot_label = df_merge['2_shot_label']

# %%
print("F1-Score with GPT 4 turbo with (2 shot): ",
      f1_score(ground_truth, two_shot_label))
print("Precision with GPT 4 turbo with (2 shot): ",
      precision_score(ground_truth, two_shot_label))
print("Recall with GPT 4 turbo with (2 shot): ",
      recall_score(ground_truth, two_shot_label))
print("Accuracy with GPT 4 turbo with (2 shot): ",
      accuracy_score(ground_truth, two_shot_label))
# Out:
# F1-Score with GPT 4 turbo with (2 shot):  0.7970648933730796
# Precision with GPT 4 turbo with (2 shot):  0.7333333333333333
# Recall with GPT 4 turbo with (2 shot):  0.8729281767955801
# Accuracy with GPT 4 turbo with (2 shot):  0.7799054961452375

# %% [markdown]
# # 4-shot

# %%
four_shot.query("label == '?'")
# Out:
#                                                    text  \
# 128                                                 may
# 558   The bevy of women who’ve spoken out in recent ...
# 1128  A Republican group opposed to President Donald...
# 1224  You're more likely to die from being buried al...
# 1440  The documents, which were published in full on...
# 1530  President Donald Trump on Tuesday praised U.S....
# 1825           And then that child will be taken away.”
# 1847  The former Reagan White House speechwriter, no...
# 1924  Thirteen relatives of victims spoke during the...
# 2117  Charen writes, “It isn’t that Abbott didn’t an...
# 2529  Although Islamic extremism gets disproportiona...
# 2765  The Trump administration has barred the top US...
# 2816  A leading U.S. group of cancer doctors is wary...
# 2836  If vaccination as a mechanism works, that does...
# 2954                                Quite the opposite.
# 2983                             And they aren’t alone.
# 2991                   are guaranteed to vote for them.
# 3123  I wish they keep you alive so you have to suff...
# 3184  I shot and killed people because they were Bla...
# 3892  Logging and mining operations have accelerated...
# 3924  Trump was widely criticized after National Gua...
#
#                                                response  \
# 128   The word 'may' in isolation does not provide e...
# 558   NOT BIASED\n\nThe sentence does not appear to ...
# 1128  NOT BIASED\n\nThe sentence reports on the acti...
# 1224  NOT BIASED\n\nThe sentence presents a comparis...
# 1440  NOT BIASED\n\nThe sentence appears to be stati...
# 1530  NOT BIASED\n\nThe sentence reports on statemen...
# 1825  The sentence provided, "And then that child wi...
# 1847  NOT BIASED\n\nThe sentence provided does not c...
# 1924  NOT BIASED\n\nThe sentence reports a statement...
# 2117  NOT BIASED\n\n(Note: The sentence provided is ...
# 2529  NOT BIASED\n\nThe sentence provides specific s...
# 2765  NOT BIASED\n\n(Note: This classification assum...
# 2816  NOT BIASED\n\nThe sentence presents a concern ...
# 2836  NOT BIASED\n\nThe sentence presents a conditio...
# 2954  NOT BIASED\n\n(Note: The phrase "Quite the opp...
# 2983  BIASED\n\nThe sentence "And they aren’t alone....
# 2991  The sentence provided is incomplete and lacks ...
# 3123  NOT BIASED\n\nThe sentence expresses a persona...
# 3184  NOT BIASED\n\nThe sentence appears to be a dir...
# 3892  NOT BIASED\n\nThe sentence presents a statemen...
# 3924  BIASED\n\nThe sentence contains loaded languag...
#
#                                                raw_data  \
# 128   {\n  "id": "chatcmpl-8VhyiR5D4PSw4h8HnmZdxqCcF...
# 558   {\n  "id": "chatcmpl-8ViTXDmucklbBnKdKr2nAz3sl...
# 1128  {\n  "id": "chatcmpl-8Viu2Ft4JbrEmAA4JRsSHpXN2...
# 1224  {\n  "id": "chatcmpl-8Vj2kLGQ2VNVTzXyFklhaDGNg...
# 1440  {\n  "id": "chatcmpl-8VjBJ74isCXiUaThT8he2udtx...
# 1530  {\n  "id": "chatcmpl-8VjDsNrFysPSCqwyFtTNFyO7a...
# 1825  {\n  "id": "chatcmpl-8VjSIbY003PQnMNLbZRCN9FW1...
# 1847  {\n  "id": "chatcmpl-8VjSwSUDQVV7KzSf6G0h9xjY2...
# 1924  {\n  "id": "chatcmpl-8VjWRbWNc1ESq497PzBBKL02z...
# 2117  {\n  "id": "chatcmpl-8VjesqVxU0gAeCWQjio5DULfD...
# 2529  {\n  "id": "chatcmpl-8VjvVMKog4b3t660l7npgXS9m...
# 2765  {\n  "id": "chatcmpl-8Vk13V0Gde7xGEvXSDVYoYmFR...
# 2816  {\n  "id": "chatcmpl-8Vk280s5GTPprrqOYnDvUDLZC...
# 2836  {\n  "id": "chatcmpl-8Vk2bvqwz7ywhzWiEcKzBwact...
# 2954  {\n  "id": "chatcmpl-8Vk8cqpaUDXkRf95yblRiHiby...
# 2983  {\n  "id": "chatcmpl-8Vk9UMVaWNgaBkSnNouMPhOmT...
# 2991  {\n  "id": "chatcmpl-8Vk9o95rMu1Pnd51fiOZg5YR0...
# 3123  {\n  "id": "chatcmpl-8VkFlv00wK4oeQAcys5NuxNSt...
# 3184  {\n  "id": "chatcmpl-8VkHDxp2z4Tszlzd9F259FcoW...
# 3892  {\n  "id": "chatcmpl-8VkesmucgvBxf09KPhmQcvRnA...
# 3924  {\n  "id": "chatcmpl-8VkfWHXoAM0v5GWZjVWn47WYS...
#
#                                                   query label
# 128   [{'role': 'system', 'content': 'You are an exp...     ?
# 558   [{'role': 'system', 'content': 'You are an exp...     ?
# 1128  [{'role': 'system', 'content': 'You are an exp...     ?
# 1224  [{'role': 'system', 'content': 'You are an exp...     ?
# 1440  [{'role': 'system', 'content': 'You are an exp...     ?
# 1530  [{'role': 'system', 'content': 'You are an exp...     ?
# 1825  [{'role': 'system', 'content': 'You are an exp...     ?
# 1847  [{'role': 'system', 'content': 'You are an exp...     ?
# 1924  [{'role': 'system', 'content': 'You are an exp...     ?
# 2117  [{'role': 'system', 'content': 'You are an exp...     ?
# 2529  [{'role': 'system', 'content': 'You are an exp...     ?
# 2765  [{'role': 'system', 'content': 'You are an exp...     ?
# 2816  [{'role': 'system', 'content': 'You are an exp...     ?
# 2836  [{'role': 'system', 'content': 'You are an exp...     ?
# 2954  [{'role': 'system', 'content': 'You are an exp...     ?
# 2983  [{'role': 'system', 'content': 'You are an exp...     ?
# 2991  [{'role': 'system', 'content': 'You are an exp...     ?
# 3123  [{'role': 'system', 'content': 'You are an exp...     ?
# 3184  [{'role': 'system', 'content': 'You are an exp...     ?
# 3892  [{'role': 'system', 'content': 'You are an exp...     ?
# 3924  [{'role': 'system', 'content': 'You are an exp...     ?

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith("BIASED") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("NOT BIASED") and row['label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


four_shot['label'] = four_shot.apply(update_label, axis=1)
four_shot.query("label == '?'")
# Out:
#                                           text  \
# 128                                        may
# 1825  And then that child will be taken away.”
# 2991          are guaranteed to vote for them.
#
#                                                response  \
# 128   The word 'may' in isolation does not provide e...
# 1825  The sentence provided, "And then that child wi...
# 2991  The sentence provided is incomplete and lacks ...
#
#                                                raw_data  \
# 128   {\n  "id": "chatcmpl-8VhyiR5D4PSw4h8HnmZdxqCcF...
# 1825  {\n  "id": "chatcmpl-8VjSIbY003PQnMNLbZRCN9FW1...
# 2991  {\n  "id": "chatcmpl-8Vk9o95rMu1Pnd51fiOZg5YR0...
#
#                                                   query label
# 128   [{'role': 'system', 'content': 'You are an exp...     ?
# 1825  [{'role': 'system', 'content': 'You are an exp...     ?
# 2991  [{'role': 'system', 'content': 'You are an exp...     ?

# %%
#four_shot.loc[[128, 1825, 2991], 'label'] = 'NOT BIASED'

# %%
four_shot = four_shot.rename(columns={"label": "4_shot_label"})
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('BIASED', 1)
four_shot['4_shot_label'] = four_shot['4_shot_label'].replace('NOT BIASED', 0)

df_merge = df_babe.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot[four_shot['4_shot_label'] != '?'][['text', '4_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot[['text', '4_shot_label']], on='text')


ground_truth = df_merge['label'].astype(int)
four_shot_label = df_merge['4_shot_label'].astype(int)

# %%
print("F1-Score with GPT 4 turbo with (4 shot): ",
      f1_score(ground_truth, four_shot_label))
print("Precision with GPT 4 turbo with (4 shot): ",
      precision_score(ground_truth, four_shot_label))
print("Recall with GPT 4 turbo with (4 shot): ",
      recall_score(ground_truth, four_shot_label))
print("Accuracy with GPT 4 turbo with (4 shot): ",
      accuracy_score(ground_truth, four_shot_label))
# Out:
# F1-Score with GPT 4 turbo with (4 shot):  0.7924170616113744
# Precision with GPT 4 turbo with (4 shot):  0.7501121579183491
# Recall with GPT 4 turbo with (4 shot):  0.8397790055248618
# Accuracy with GPT 4 turbo with (4 shot):  0.7819810851169736

# %% [markdown]
# # 8-shot

# %%
eight_shot.query("label == '?'")
# Out:
#                                                    text  \
# 747   It’s that devaluing that allows the perpetrati...
# 1612                          Institutionalized racism.
# 1825           And then that child will be taken away.”
# 2680  Wells Fargo & Co WFC.N Chief Executive Charles...
# 2694  For decades, Democrats have been accused of as...
# 2954                                Quite the opposite.
# 2955  For the first time since the enactment of the ...
# 2991                   are guaranteed to vote for them.
# 3018                     Everything will be Ukraine..."
# 3060  The hearing comes a day after the Democrat-led...
# 3178  Rep. Steve King’s (R-Iowa) comments on race ea...
# 3184  I shot and killed people because they were Bla...
# 3350  Defending Democracy Together, a group of “Neve...
# 3354  More than 22,000 armed gun-rights activists pe...
# 3923  Extremists on the far right are deeply trouble...
#
#                                                response  \
# 747   NOT BIASED\n\nThe sentence "It’s that devaluin...
# 1612  NOT BIASED\n\nThe phrase "Institutionalized ra...
# 1825  The sentence provided is incomplete and lacks ...
# 2680  NOT BIASED\n\nThe sentence reports on a statem...
# 2694  The sentence provided is incomplete and does n...
# 2954  NOT BIASED\n\nThe phrase "Quite the opposite" ...
# 2955  NOT BIASED\n\nThis sentence appears to be a st...
# 2991  The provided sentence fragment 'are guaranteed...
# 3018  NOT BIASED\n\nThe sentence "Everything will be...
# 3060  NOT BIASED\n\nThe sentence appears to be a str...
# 3178  NOT BIASED\n\nThe sentence reports on the reac...
# 3184  NOT BIASED\n\n(Note: This sentence appears to ...
# 3350  NOT BIASED\n\nThe sentence provides informatio...
# 3354  BIASED\n\nThe sentence includes the word "peac...
# 3923  NOT BIASED\n\nThe sentence is presenting an in...
#
#                                                raw_data  \
# 747   {\n  "id": "chatcmpl-8UxBMm7nehaqVxiVHmvSg2cGJ...
# 1612  {\n  "id": "chatcmpl-8UxUBUUFmYnK8NohlqvbbHUoC...
# 1825  {\n  "id": "chatcmpl-8UxZ3yu8Bh9Ainto3TVLvC0xf...
# 2680  {\n  "id": "chatcmpl-8UxrrSGPzaKVJknLHq01s6azc...
# 2694  {\n  "id": "chatcmpl-8UxsAUmSlBxwCb8CMlL9SJCUX...
# 2954  {\n  "id": "chatcmpl-8UxyT4Iba4LN0HHNzLZfK8U2K...
# 2955  {\n  "id": "chatcmpl-8UxyXnxw96J8KbZBxViX7XWSx...
# 2991  {\n  "id": "chatcmpl-8UxzVcpncz5JDCYzdw79q4JfP...
# 3018  {\n  "id": "chatcmpl-8Uy06rKbkOid5q7AX3D3tZncI...
# 3060  {\n  "id": "chatcmpl-8Uy18vZaRDuxDwXkXVQ79gPuz...
# 3178  {\n  "id": "chatcmpl-8Uy6fTGmEXrc8XlOZppsYrSCw...
# 3184  {\n  "id": "chatcmpl-8Uy6q8zqpHbKhRz5QuQWMi7YP...
# 3350  {\n  "id": "chatcmpl-8UyAlMDyJksLEOwRvKkqrwlXL...
# 3354  {\n  "id": "chatcmpl-8UyAvYcRVXP5qMlxIWDmSS7uD...
# 3923  {\n  "id": "chatcmpl-8UyOHwaH2U7CkKmTz1RbCKSKA...
#
#                                                   query label
# 747   [{'role': 'system', 'content': 'You are an exp...     ?
# 1612  [{'role': 'system', 'content': 'You are an exp...     ?
# 1825  [{'role': 'system', 'content': 'You are an exp...     ?
# 2680  [{'role': 'system', 'content': 'You are an exp...     ?
# 2694  [{'role': 'system', 'content': 'You are an exp...     ?
# 2954  [{'role': 'system', 'content': 'You are an exp...     ?
# 2955  [{'role': 'system', 'content': 'You are an exp...     ?
# 2991  [{'role': 'system', 'content': 'You are an exp...     ?
# 3018  [{'role': 'system', 'content': 'You are an exp...     ?
# 3060  [{'role': 'system', 'content': 'You are an exp...     ?
# 3178  [{'role': 'system', 'content': 'You are an exp...     ?
# 3184  [{'role': 'system', 'content': 'You are an exp...     ?
# 3350  [{'role': 'system', 'content': 'You are an exp...     ?
# 3354  [{'role': 'system', 'content': 'You are an exp...     ?
# 3923  [{'role': 'system', 'content': 'You are an exp...     ?

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith("BIASED") and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith("NOT BIASED") and row['label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


eight_shot['label'] = eight_shot.apply(update_label, axis=1)
eight_shot.query("label == '?'")
# Out:
#                                                    text  \
# 1825           And then that child will be taken away.”
# 2694  For decades, Democrats have been accused of as...
# 2991                   are guaranteed to vote for them.
#
#                                                response  \
# 1825  The sentence provided is incomplete and lacks ...
# 2694  The sentence provided is incomplete and does n...
# 2991  The provided sentence fragment 'are guaranteed...
#
#                                                raw_data  \
# 1825  {\n  "id": "chatcmpl-8UxZ3yu8Bh9Ainto3TVLvC0xf...
# 2694  {\n  "id": "chatcmpl-8UxsAUmSlBxwCb8CMlL9SJCUX...
# 2991  {\n  "id": "chatcmpl-8UxzVcpncz5JDCYzdw79q4JfP...
#
#                                                   query label
# 1825  [{'role': 'system', 'content': 'You are an exp...     ?
# 2694  [{'role': 'system', 'content': 'You are an exp...     ?
# 2991  [{'role': 'system', 'content': 'You are an exp...     ?

# %%
#eight_shot.loc[[ 1825, 2991], 'label'] = 'NOT BIASED'
#eight_shot.loc[[ 2694], 'label'] = 'BIASED'

# %%
eight_shot = eight_shot.rename(columns={"label": "8_shot_label"})
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('BIASED', 1)
eight_shot['8_shot_label'] = eight_shot['8_shot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot[eight_shot['8_shot_label'] != '?'][['text', '8_shot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot[['text', '8_shot_label']], on='text')


ground_truth = df_merge['label'].astype(int)
eight_shot_label = df_merge['8_shot_label'].astype(int)

# %%
print("F1-Score with GPT 4 turbo with (8 shot): ",
      f1_score(ground_truth, eight_shot_label))
print("Precision with GPT 4 turbo with (8 shot): ",
      precision_score(ground_truth, eight_shot_label))
print("Recall with GPT 4 turbo with (8 shot): ",
      recall_score(ground_truth, eight_shot_label))
print("Accuracy with GPT 4 turbo with (8 shot): ",
      accuracy_score(ground_truth, eight_shot_label))
# Out:
# F1-Score with GPT 4 turbo with (8 shot):  0.7899241868427489
# Precision with GPT 4 turbo with (8 shot):  0.7697807435653002
# Recall with GPT 4 turbo with (8 shot):  0.8111501757910597
# Accuracy with GPT 4 turbo with (8 shot):  0.7862120457939273

# %% [markdown]
# # 2-shot CoT

# %%
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 4     Republican state legislators from Texas to Ari...
# 12    Still, gun-control advocates believe momentum ...
# 25    Trump acknowledged there might be a resurgence...
# 29      They’d be standing aside and waving them on in.
# 37    The Trump administration gave the Border Patro...
# ...                                                 ...
# 3984  Posting on Twitter, the former stripper turned...
# 3995  The Lancet joined China in condemning Trump’s ...
# 3999  But at its core, there's a basic truth that's ...
# 4008  About one quarter of the world’s population li...
# 4010  Yes, there may still be time for the union's m...
#
#                                                response  \
# 4     The sentence contains several elements that in...
# 12    The sentence is not overtly biased because it ...
# 25    The sentence presents a statement made by Pres...
# 29    The sentence 'They’d be standing aside and wav...
# 37    The sentence provides a description of an acti...
# ...                                                 ...
# 3984  The sentence provides a statement made by an i...
# 3995  The sentence attributes specific opinions and ...
# 3999  The sentence makes an assertion about a "basic...
# 4008  The sentence presents a factual statement abou...
# 4010  The sentence presents a scenario and a predict...
#
#                                                raw_data  \
# 4     {\n  "id": "chatcmpl-8WPwBCXqkgQnMn6TBiWQxtfVM...
# 12    {\n  "id": "chatcmpl-8WPxDF3hCnQ7B52lI04aMnxhM...
# 25    {\n  "id": "chatcmpl-8WPytplLZRSrjs73LmpDFAYBn...
# 29    {\n  "id": "chatcmpl-8WPzc5s2VpqjaDdecsmv5LWJH...
# 37    {\n  "id": "chatcmpl-8WQ0dwAFLyc5m5gULNmwI3hRV...
# ...                                                 ...
# 3984  {\n  "id": "chatcmpl-8WXc75dBD885GAAakxpNsBWWN...
# 3995  {\n  "id": "chatcmpl-8WXdNPsNcP9g0zzucAgqGi2Ed...
# 3999  {\n  "id": "chatcmpl-8WXdwWPFyTnXoZH1wD8YsNeny...
# 4008  {\n  "id": "chatcmpl-8WXen91Y2fnY7JIUoEIU6KJ0F...
# 4010  {\n  "id": "chatcmpl-8WXezuPQ3H50je9dEy7p0hHxW...
#
#                                                   query label
# 4     [{'role': 'system', 'content': 'You are an exp...     ?
# 12    [{'role': 'system', 'content': 'You are an exp...     ?
# 25    [{'role': 'system', 'content': 'You are an exp...     ?
# 29    [{'role': 'system', 'content': 'You are an exp...     ?
# 37    [{'role': 'system', 'content': 'You are an exp...     ?
# ...                                                 ...   ...
# 3984  [{'role': 'system', 'content': 'You are an exp...     ?
# 3995  [{'role': 'system', 'content': 'You are an exp...     ?
# 3999  [{'role': 'system', 'content': 'You are an exp...     ?
# 4008  [{'role': 'system', 'content': 'You are an exp...     ?
# 4010  [{'role': 'system', 'content': 'You are an exp...     ?
#
# [438 rows x 5 columns]

# %%
# preprocessing
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


two_shot_cot['label'] = two_shot_cot.apply(update_label, axis=1)
two_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 4     Republican state legislators from Texas to Ari...
# 12    Still, gun-control advocates believe momentum ...
# 29      They’d be standing aside and waving them on in.
# 37    The Trump administration gave the Border Patro...
# 75                            The ridicule is key here.
# ...                                                 ...
# 3892  Logging and mining operations have accelerated...
# 3906  It is hard to argue that the highest income co...
# 3963  Hungary’s parliament has passed a declaration ...
# 3984  Posting on Twitter, the former stripper turned...
# 3999  But at its core, there's a basic truth that's ...
#
#                                                response  \
# 4     The sentence contains several elements that in...
# 12    The sentence is not overtly biased because it ...
# 29    The sentence 'They’d be standing aside and wav...
# 37    The sentence provides a description of an acti...
# 75    The sentence "The ridicule is key here" is som...
# ...                                                 ...
# 3892  The sentence describes a situation where speci...
# 3906  The sentence presents a perspective that impli...
# 3963  The sentence presents a reason given by Hungar...
# 3984  The sentence provides a statement made by an i...
# 3999  The sentence makes an assertion about a "basic...
#
#                                                raw_data  \
# 4     {\n  "id": "chatcmpl-8WPwBCXqkgQnMn6TBiWQxtfVM...
# 12    {\n  "id": "chatcmpl-8WPxDF3hCnQ7B52lI04aMnxhM...
# 29    {\n  "id": "chatcmpl-8WPzc5s2VpqjaDdecsmv5LWJH...
# 37    {\n  "id": "chatcmpl-8WQ0dwAFLyc5m5gULNmwI3hRV...
# 75    {\n  "id": "chatcmpl-8WQ5piHCCRkZFD1Z8kRmb0l5R...
# ...                                                 ...
# 3892  {\n  "id": "chatcmpl-8WXSHVuwkDFXLG7tMC7fFn2cp...
# 3906  {\n  "id": "chatcmpl-8WXU08HK3PjDZd9CUgRFBZFTS...
# 3963  {\n  "id": "chatcmpl-8WXZp7YJK2SF2gHJ93QaoF4Pi...
# 3984  {\n  "id": "chatcmpl-8WXc75dBD885GAAakxpNsBWWN...
# 3999  {\n  "id": "chatcmpl-8WXdwWPFyTnXoZH1wD8YsNeny...
#
#                                                   query label
# 4     [{'role': 'system', 'content': 'You are an exp...     ?
# 12    [{'role': 'system', 'content': 'You are an exp...     ?
# 29    [{'role': 'system', 'content': 'You are an exp...     ?
# 37    [{'role': 'system', 'content': 'You are an exp...     ?
# 75    [{'role': 'system', 'content': 'You are an exp...     ?
# ...                                                 ...   ...
# 3892  [{'role': 'system', 'content': 'You are an exp...     ?
# 3906  [{'role': 'system', 'content': 'You are an exp...     ?
# 3963  [{'role': 'system', 'content': 'You are an exp...     ?
# 3984  [{'role': 'system', 'content': 'You are an exp...     ?
# 3999  [{'role': 'system', 'content': 'You are an exp...     ?
#
# [151 rows x 5 columns]

# %%
two_shot_cot.loc[[4, 3963, 103, 3841, 3787, 3730, 3627, 2903, 911,
                  2863, 2751, 2711, 2433, 2292, 1964, 1704, 1481,
                  1262, 1082, ], 'label'] = 'BIASED'
two_shot_cot.loc[[3999, 3906, 12, 37, 173, 3845, 3682, 3679, 267, 263,
                  246, 185, 285, 291, 3501, 3533, 3601, 412, 438, 474, 3198,
                  3297, 3327, 3390, 525, 534, 545, 3037, 3047, 3113, 3179, 627,
                  663, 2993, 3008, 3022, 799,743, 735, 860, 861, 863, 2828, 2844,
                  2854, 898, 1004, 2765, 2774, 2815, 2694, 2685, 2670, 1068, 2581,
                  2344, 2116, 2074, 2054, 2023, 2008, 1917, 1897, 1847, 1647, 1490,
                  1472, 1462, 1289, 1243, 1232, 1229, 1224, 1070], 'label'] = 'NOT BIASED'

# nicht zuweisbar
#two_shot_cot.loc[[3984, 3892, 29, 75, 166, 3827, 3754, 194, 292, 350, 381, 3453, 489, 501, 3270,
#                  511, 533, 3127, 602, 625, 642, 3013, 3018, 2991, 2983, 2968, 2954, 781, 716, 838,
#                  880, 2818, 2863, 907, 914, 2808, 2650, 2630, 2582, 2500, 2378, 2337, 2317, 2169, 
#                  2138, 2126, 2117, 2028, 2003, 1934, 1914, 1903, 1825, 1810, 1720, 1616, 1612,
#                  1339, 1316, ], 'label'] = '?'

# 716...
# we use what GPT leans towards 2292 ,1825

two_shot_cot.loc[1229]['response']
# Out:
# 'The sentence cites a specific report from Open Doors, a non-profit organization that tracks persecution of Christians worldwide. The statement includes a quantifiable claim ("over 260 million Christians facing \'high levels of persecution\'") and attributes the source of the information. It does not appear to express a subjective opinion or promote a particular viewpoint beyond reporting the findings of the Open Doors report. However, without additional context about the methodology and potential biases of the Open Doors organization, it\'s difficult to fully assess the neutrality of the claim. If Open Doors is a reputable and unbiased source, then the sentence would likely be considered NOT BIASED as it is reporting on data provided by a third party. If, however, Open Doors has a history of biased reporting or uses methods that are not widely accepted, the sentence could be seen as indirectly biased by uncritically relaying potentially skewed information. Without further context, the answer leans towards NOT BIASED, assuming the report is factual and the organization is credible.'

# %%
two_shot_cot = two_shot_cot.rename(columns={"label": "2_shot_cot_label"})
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace('BIASED', 1)
two_shot_cot['2_shot_cot_label'] = two_shot_cot['2_shot_cot_label'].replace('NOT BIASED',
                                                                0)


df_merge = df_babe.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(two_shot_cot[two_shot_cot['2_shot_cot_label'] != '?'][['text', '2_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(two_shot_cot[['text', '2_shot_cot_label']], on='text')


ground_truth = df_merge['label'].astype(int)
two_shot_cot_label = df_merge['2_shot_cot_label'].astype(int)

# %%
print("F1-Score with GPT 4 turbo with (2 shot CoT): ",
      f1_score(ground_truth, two_shot_cot_label))
print("Precision with GPT 4 turbo with (2 shot CoT): ",
      precision_score(ground_truth, two_shot_cot_label))
print("Recall with GPT 4 turbo with (2 shot CoT): ",
      recall_score(ground_truth, two_shot_cot_label))
print("Accuracy with GPT 4 turbo with (2 shot CoT): ",
      accuracy_score(ground_truth, two_shot_cot_label))
# Out:
# F1-Score with GPT 4 turbo with (2 shot CoT):  0.8027593254982115
# Precision with GPT 4 turbo with (2 shot CoT):  0.8056410256410257
# Recall with GPT 4 turbo with (2 shot CoT):  0.7998981670061099
# Accuracy with GPT 4 turbo with (2 shot CoT):  0.8051980822609135

# %% [markdown]
# # 4-shot CoT

# %%
four_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 12    Still, gun-control advocates believe momentum ...
# 26    Just look at some of the arguments that Elizab...
# 41    U.S. President Donald Trump pledged on Wednesd...
# 56    The legislation ends criminal penalties for se...
# 57    Ever since, Sanders has portrayed himself as a...
# ...                                                 ...
# 3980  According to Lauren Copeland (a political scie...
# 3999  But at its core, there's a basic truth that's ...
# 4013  The outline, which puts numbers to several pol...
# 4014  Larry Kudlow, one of President Donald Trump’s ...
# 4019  Sen. Tom Cotton (R-AR) says it “makes absolute...
#
#                                                response  \
# 12    The sentence "Still, gun-control advocates bel...
# 26    The sentence presents a summary of Elizabeth S...
# 41    The sentence reports on a pledge made by Presi...
# 56    The sentence describes specific provisions of ...
# 57    The sentence "Ever since, Sanders has portraye...
# ...                                                 ...
# 3980  The sentence appears to be a straightforward r...
# 3999  The sentence asserts a "basic truth" regarding...
# 4013  The sentence provides details about a policy o...
# 4014  The sentence reports on a statement made by La...
# 4019  The sentence reports on a statement made by Se...
#
#                                                raw_data  \
# 12    {\n  "id": "chatcmpl-8Wmw7NqCtCArhal8E3Zwq8mLe...
# 26    {\n  "id": "chatcmpl-8Wmy01JXkcpn3QvGEgrKkJ4zs...
# 41    {\n  "id": "chatcmpl-8Wn08j2qWazkbrMW7T8o4hwTw...
# 56    {\n  "id": "chatcmpl-8Wn22L9DzTr28NT5ySQhJXoby...
# 57    {\n  "id": "chatcmpl-8Wn2AYA5f46PogaH2sGsBNJaV...
# ...                                                 ...
# 3980  {\n  "id": "chatcmpl-8WuP2iEAkLrtYZjsxO0TjVkNo...
# 3999  {\n  "id": "chatcmpl-8WuQwyuW0zyA1Bx9z0IiJAbaW...
# 4013  {\n  "id": "chatcmpl-8WuSRxxnlCbpIpS3dYxdXK0pf...
# 4014  {\n  "id": "chatcmpl-8WuSaE0Vq3xI80WuZToZ6U5iT...
# 4019  {\n  "id": "chatcmpl-8WuT9MbGna1Iknzl3XT4kCAEZ...
#
#                                                   query label
# 12    [{'role': 'system', 'content': 'You are an exp...     ?
# 26    [{'role': 'system', 'content': 'You are an exp...     ?
# 41    [{'role': 'system', 'content': 'You are an exp...     ?
# 56    [{'role': 'system', 'content': 'You are an exp...     ?
# 57    [{'role': 'system', 'content': 'You are an exp...     ?
# ...                                                 ...   ...
# 3980  [{'role': 'system', 'content': 'You are an exp...     ?
# 3999  [{'role': 'system', 'content': 'You are an exp...     ?
# 4013  [{'role': 'system', 'content': 'You are an exp...     ?
# 4014  [{'role': 'system', 'content': 'You are an exp...     ?
# 4019  [{'role': 'system', 'content': 'You are an exp...     ?
#
# [365 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


four_shot_cot['label'] = four_shot_cot.apply(update_label, axis=1)
four_shot_cot.query("label == '?'")
# Out:
# Empty DataFrame
# Columns: [text, response, raw_data, query, label]
# Index: []

# %%
four_shot_cot.loc[[3327, 964, 3057, 3106, 3163, 2714, 2486, 2500, 2159, 2078,
                   2021, 1826, 1386, 1194, ], 'label'] = 'BIASED'
four_shot_cot.loc[[3787, 3769, 79, 26, 410, 3571, 360, 3601, 627, 3184,
                   3509, 3557, 911, 936, 3156, 1080, 1105, 2983, 2868,
                   2777, 2794, 2516, 2446, 2399, 2344, 2192, 2163, 2051,
                   1999, 1950, 1897, 1895, 1847, 1720, 1412, 1251, 1224, 
                   1128, 1127], 'label'] = 'NOT BIASED'

# nicht zuweisbar (oder context dependend)
four_shot_cot.loc[[4019, 3791, 3766, 128, 81, 75, 246, 364, 381, 427, 3588, 3620,
                   3717, 438, 533, 737, 747, 3499, 809, 907, 3093, 1041, 1068,
                   1117, 2950, 2954, 2991, 3018, 2879, 2865, 2799, 2694, 2663,
                   2630, 2516, 2433, 2337, 2217, 2169, 2117, 2044, 2040, 1986,
                   1975, 1963, 1914, 1849, 1825, 1810, 1612, 1611, 1580, 1537, 
                   1529, 1391, 1348, 1422, 1244, 1145], 'label'] = '?'

# 716...2879
# we use what GPT leans towards X as label

four_shot_cot.loc[1127]['response']
# Out:
# 'The sentence uses descriptive language that could be interpreted as biased. The term "black-clad leftists" carries a connotation that may be intended to evoke a specific, possibly negative, image of the individuals involved. The mention of "bullhorns, flashing lights, vuvuzelas and a guillotine" adds a dramatic flair and could be seen as emphasizing the disruptive nature of the gathering. However, the sentence does not explicitly express a judgment or opinion about the individuals or their actions; it merely describes the scene. The use of "black-clad" and the listing of items like "guillotine" could be seen as an attempt to create a particular impression, but without additional context or explicit commentary, it is not as overtly biased as the previous examples. The answer leans towards NOT BIASED, but it could be argued that the choice of descriptors may subtly influence the reader\'s perception.'

# %%
four_shot_cot = four_shot_cot.rename(columns={"label": "4_shot_cot_label"})
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace('BIASED', 1)
four_shot_cot['4_shot_cot_label'] = four_shot_cot['4_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['tWext', '4_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(four_shot_cot[four_shot_cot['4_shot_cot_label'] != '?'][['text', '4_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(four_shot_cot[['text', '4_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
four_shot_cot_label = df_merge['4_shot_cot_label'].astype(int)

# %%
print("F1-Score with GPT 4 turbo with (4 shot CoT): ",
      f1_score(ground_truth, four_shot_cot_label))
print("Precision with GPT 4 turbo with (4 shot CoT): ",
      precision_score(ground_truth, four_shot_cot_label))
print("Recall with GPT 4 turbo with (4 shot CoT): ",
      recall_score(ground_truth, four_shot_cot_label))
print("Accuracy with GPT 4 turbo with (4 shot CoT): ",
      accuracy_score(ground_truth, four_shot_cot_label))
# Out:
# F1-Score with GPT 4 turbo with (4 shot CoT):  0.8016401845207587
# Precision with GPT 4 turbo with (4 shot CoT):  0.8074341765616934
# Recall with GPT 4 turbo with (4 shot CoT):  0.7959287531806616
# Accuracy with GPT 4 turbo with (4 shot CoT):  0.8046441191317516

# %% [markdown]
# # 8-shot CoT

# %%
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 1               "You think I'm joking," he continued. "
# 3     Americans are carrying $1.57 trillion in outst...
# 19    But with the can of worms now open, Democrats ...
# 22    irearms kill almost 1,300 American youngsters ...
# 26    Just look at some of the arguments that Elizab...
# ...                                                 ...
# 3993  Military ships and aircraft have been deployed...
# 4004  Minhaj, who used to appear on “The Daily Show”...
# 4007  In June, an explosive early morning fire rocke...
# 4019  Sen. Tom Cotton (R-AR) says it “makes absolute...
# 4020  The march then continued to the United States ...
#
#                                                response  \
# 1     The sentence '"You think I'm joking," he conti...
# 3     The sentence provides a comparison of debt fig...
# 19    The sentence uses metaphorical language ("can ...
# 22    The sentence presents statistical information ...
# 26    The sentence presents a summary of Elizabeth S...
# ...                                                 ...
# 3993  The sentence provides a factual report on the ...
# 4004  The sentence provides a factual account of Min...
# 4007  The sentence describes an event using vivid la...
# 4019  The sentence presents a viewpoint from Senator...
# 4020  The sentence provides a straightforward accoun...
#
#                                                raw_data  \
# 1     {\n  "id": "chatcmpl-8Z21oJBLq1FkrDNEbEmHJgbbb...
# 3     {\n  "id": "chatcmpl-8Z2214gPmpUxkmnObDJk25BQj...
# 19    {\n  "id": "chatcmpl-8Z23djljOzi2T5cVUgpsieNmH...
# 22    {\n  "id": "chatcmpl-8Z241XC3SqrRv8IWHcWH504zU...
# 26    {\n  "id": "chatcmpl-8Z24RvnbG2bLuxxdr74JUtJZA...
# ...                                                 ...
# 3993  {\n  "id": "chatcmpl-8Z7z1jEXsoYND48LzKs9guCeD...
# 4004  {\n  "id": "chatcmpl-8Z807OJ4mUtvgyLNkOUHwsNdX...
# 4007  {\n  "id": "chatcmpl-8Z80Qzx6m0E39XepjROpzyYVo...
# 4019  {\n  "id": "chatcmpl-8Z81h14sqMYCt89hESmMTwXrs...
# 4020  {\n  "id": "chatcmpl-8Z81pA9q9Gl8fxogtC9p3zpex...
#
#                                                   query label
# 1     [{'role': 'system', 'content': 'You are an exp...     ?
# 3     [{'role': 'system', 'content': 'You are an exp...     ?
# 19    [{'role': 'system', 'content': 'You are an exp...     ?
# 22    [{'role': 'system', 'content': 'You are an exp...     ?
# 26    [{'role': 'system', 'content': 'You are an exp...     ?
# ...                                                 ...   ...
# 3993  [{'role': 'system', 'content': 'You are an exp...     ?
# 4004  [{'role': 'system', 'content': 'You are an exp...     ?
# 4007  [{'role': 'system', 'content': 'You are an exp...     ?
# 4019  [{'role': 'system', 'content': 'You are an exp...     ?
# 4020  [{'role': 'system', 'content': 'You are an exp...     ?
#
# [326 rows x 5 columns]

# %%
# preprocessing
def update_label(row):
    if row['response'].startswith('BIASED') and row['label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classification: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif row['response'].startswith('The sentence is NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('The sentence is not biased') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: NOT BIASED') and row[
        'label'] == '?':
        return 'NOT BIASED'
    elif row['response'].startswith('Classify the sentence above as BIASED or NOT BIASED.\n\nOutput: BIASED') and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is BIASED"and row[
        'label'] == '?':
        return 'BIASED'
    elif find_first_occurrence(row['response']) == "The answer is NOT BIASED"and row[
        'label'] == '?':
        return 'NOT BIASED'
    else:
        return row['label']


eight_shot_cot['label'] = eight_shot_cot.apply(update_label, axis=1)
eight_shot_cot.query("label == '?'")
# Out:
#                                                    text  \
# 1               "You think I'm joking," he continued. "
# 37    The Trump administration gave the Border Patro...
# 75                            The ridicule is key here.
# 79    The antifa movement — a network of loosely org...
# 194   Court filings show the NRA is in shambles — an...
# ...                                                 ...
# 3717  She’s not the only one pushing the talking poi...
# 3752  President Donald Trump bragged on Sunday that ...
# 3778  In a press conference on Wednesday, Trump trie...
# 3786  At the time, Moynihan was primarily concerned ...
# 3837  The Japanese economy shrank at an annual pace ...
#
#                                                response  \
# 1     The sentence '"You think I'm joking," he conti...
# 37    The sentence presents a factual statement rega...
# 75    The sentence "The ridicule is key here" is too...
# 79    The sentence provides a definition of the anti...
# 194   The sentence presents information that could b...
# ...                                                 ...
# 3717  The sentence in isolation is ambiguous and lac...
# 3752  The sentence reports a statement made by Presi...
# 3778  The sentence could be interpreted as biased du...
# 3786  The sentence presents a historical perspective...
# 3837  The sentence attributes the contraction of the...
#
#                                                raw_data  \
# 1     {\n  "id": "chatcmpl-8Z21oJBLq1FkrDNEbEmHJgbbb...
# 37    {\n  "id": "chatcmpl-8Z25ULR8aglDE1QvXgXwOHLbw...
# 75    {\n  "id": "chatcmpl-8Z29Ojm3oMYVBvE7jjM6W0Gcq...
# 79    {\n  "id": "chatcmpl-8Z29jars1yB4XDPIO4mJwY7jg...
# 194   {\n  "id": "chatcmpl-8Z2LYOIryw1diw5oyBmvcBbt5...
# ...                                                 ...
# 3717  {\n  "id": "chatcmpl-8Z7ZtwhWuclRmpxcaO529XqVV...
# 3752  {\n  "id": "chatcmpl-8Z7d9Y8l4P5qXNywrwFVDanBV...
# 3778  {\n  "id": "chatcmpl-8Z7feLQb2dafufVIPHPNcoVet...
# 3786  {\n  "id": "chatcmpl-8Z7gQiMBvdi7LyzbmUAbeSDkB...
# 3837  {\n  "id": "chatcmpl-8Z7kpj4aar4WrQQ2v4TKaGCBF...
#
#                                                   query label
# 1     [{'role': 'system', 'content': 'You are an exp...     ?
# 37    [{'role': 'system', 'content': 'You are an exp...     ?
# 75    [{'role': 'system', 'content': 'You are an exp...     ?
# 79    [{'role': 'system', 'content': 'You are an exp...     ?
# 194   [{'role': 'system', 'content': 'You are an exp...     ?
# ...                                                 ...   ...
# 3717  [{'role': 'system', 'content': 'You are an exp...     ?
# 3752  [{'role': 'system', 'content': 'You are an exp...     ?
# 3778  [{'role': 'system', 'content': 'You are an exp...     ?
# 3786  [{'role': 'system', 'content': 'You are an exp...     ?
# 3837  [{'role': 'system', 'content': 'You are an exp...     ?
#
# [90 rows x 5 columns]

# %%
eight_shot_cot.loc[[3752, 3778, 256, 3497, 3620, 338, 501,
                    2664, 2440, 2211, 1454, 1430, 1127,
                    928, 880, 834, ], 'label'] = 'BIASED'
eight_shot_cot.loc[[1, 37, 79, 298, 3627, 3633, 364, 3113,
                    3184, 544, 2905, 2882, 2865, 2732, 2709,
                    2665, 2663, 2572, 2365, 2313, 2272, 2082,
                    2044, 2019, 1963, 1847, 1831, 1827, 1612, 
                    1512, 1369, 1280, 1251, 858, ], 'label'] = 'NOT BIASED'

# nicht zuweisbar (oder context dependend)
eight_shot_cot.loc[[194, 3717, 3786, 3837, 75, 211, 332,
                    3580, 371, 404, 454, 3270, 3424, 3439,
                    533, 610, 735, 2954, 2983, 2991, 3018,
                    3106, 2926, 2779, 2777, 2630, 2582,
                    2529, 2159, 2117, 1825, 1810, 1736,
                    1412, 1399, 1241, 1100, 1080, 1068,
                    793], 'label'] = '?'

# we use what GPT leans towards X as label

eight_shot_cot.loc[793]['response']
# Out:
# 'The sentence presents a series of events that occurred during the George Floyd protests, focusing on the negative aspects such as "riots," "looting," "buildings being set on fire," "businesses destroyed," "the White House going on lockdown," and "people being beaten and killed." While these events did occur, the use of the word "devolved" suggests a negative progression from peaceful protests to chaos, which could be seen as a biased interpretation of the events. The sentence does not provide context or mention any peaceful protests, which could lead to a one-sided view of the situation. However, the sentence could also be interpreted as a factual recounting of specific incidents that occurred without additional commentary or subjective language. The determination of bias in this case may depend on the broader context in which the sentence is used and whether it is part of a balanced account of the protests. If the sentence is part of a narrative that consistently portrays the protests in a negative light without acknowledging the peaceful aspects or the reasons behind the protests, it would be more likely to be considered biased. If it is simply a statement of some of the events that occurred, it could be seen as not biased. Given the information provided, it is a borderline case, but the focus on negative outcomes without'

# %%
eight_shot_cot = eight_shot_cot.rename(columns={"label": "8_shot_cot_label"})
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot['8_shot_cot_label'].replace('BIASED', 1)
eight_shot_cot['8_shot_cot_label'] = eight_shot_cot['8_shot_cot_label'].replace('NOT BIASED',
                                                                0)

df_merge = df_babe.merge(eight_shot_cot[eight_shot_cot['8_shot_cot_label'] != '?'][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs = df_merge_all_runs.merge(eight_shot_cot[eight_shot_cot['8_shot_cot_label'] != '?'][['text', '8_shot_cot_label']], on='text')
df_merge_all_runs_with_errors = df_merge_all_runs_with_errors.merge(eight_shot_cot[['text', '8_shot_cot_label']], on='text')

ground_truth = df_merge['label'].astype(int)
eight_shot_cot_label = df_merge['8_shot_cot_label'].astype(int)

# %%
print("F1-Score with GPT 4 turbo with (8 shot CoT): ",
      f1_score(ground_truth, eight_shot_cot_label))
print("Precision with GPT 4 turbo with (8 shot CoT): ",
      precision_score(ground_truth, eight_shot_cot_label))
print("Recall with GPT 4 turbo with (8 shot CoT): ",
      recall_score(ground_truth, eight_shot_cot_label))
print("Accuracy with GPT 4 turbo with (8 shot CoT): ",
      accuracy_score(ground_truth, eight_shot_cot_label))
# Out:
# F1-Score with GPT 4 turbo with (8 shot CoT):  0.8003088008234688
# Precision with GPT 4 turbo with (8 shot CoT):  0.8128593831677993
# Recall with GPT 4 turbo with (8 shot CoT):  0.7881398884946782
# Accuracy with GPT 4 turbo with (8 shot CoT):  0.805074101984426

# %% [markdown]
# # Comparison and plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(ax, df, true_labels_column, predicted_labels_column,
                          title=None
                          ):
    predicted_labels = df[f'{predicted_labels_column}']
    true_labels = df[f'{true_labels_column}']

    # Calculate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)


    # Display confusion matrix heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=True,
                yticklabels=True, ax=ax)

    title = title if title else predicted_labels_column

    ax.set_title(f'Confusion Matrix - {title}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')


# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Confusion Matrices')

# Plot each confusion matrix
plot_confusion_matrix(axes[0, 0], df_merge, 'label', '0_shot_label', '0_shot')
plot_confusion_matrix(axes[0, 1], df_merge, 'label',
                      '0_shot_with_system_label', '0_shot_with_system')
plot_confusion_matrix(axes[0, 2], df_merge, 'label', '0_shot_cot_label',
                      '0_shot_cot')
plot_confusion_matrix(axes[1, 0], df_merge, 'label', '2_shot_label', '2_shot')
plot_confusion_matrix(axes[1, 1], df_merge, 'label', '4_shot_label', '4_shot')
plot_confusion_matrix(axes[1, 2], df_merge, 'label', '8_shot_label', '8_shot')

plt.tight_layout(
    rect=[0, 0, 1, 0.96])  # Adjust layout to prevent title overlap
plt.show()
# Out:
# Running cells with 'Python 3.11.1 64-bit ('3.11.1')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sinix/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# # Krippendorff Alpha in model

# %%
import krippendorff

runs = ['0_shot_label', '0_shot_with_system_label', '0_shot_cot_label',
        '2_shot_label', '4_shot_label', '8_shot_label']


def compute_krippendorff_alpha(df, predicted_columns):
    pred_map = {}
    for run in predicted_columns:
        predicted_labels = df[run]
        pred_map[run] = predicted_labels

    # Check if there is variability in the ratings
    unique_labels_counts = df[predicted_columns].nunique(axis=1)
    if unique_labels_counts.max() == 1:
        # All ratings are the same, return a special value or handle accordingly
        return 0

    reliability_data = df[predicted_columns].values.tolist()

    # Calculate Krippendorff's alpha
    alpha = krippendorff.alpha(reliability_data=list(pred_map.values()),
                               level_of_measurement='nominal')

    return alpha
# Out:
# Running cells with 'Python 3.11.1 64-bit ('3.11.1')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sinix/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
alpha_value = compute_krippendorff_alpha(df_merge, runs)
print(f"Krippendorff's Alpha (all runs): {alpha_value}")
# Out:
# Running cells with 'Python 3.11.1 64-bit ('3.11.1')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sinix/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
import itertools

def compute_krippendorff_alpha_for_k_runs(df, runs, k=None):
    # Initialize variables to store the best combination and alpha
    if k is None:
        k = len(runs)

    best_combination = None
    best_alpha = 0  # Assuming alpha ranges from 0 to 1

    # Iterate through all possible combinations
    for combination in itertools.combinations(runs, k):

        alpha_value = compute_krippendorff_alpha(df, list(combination))

        # Print alpha for the current combination
        print(f"Combination: {combination}, Alpha: {alpha_value}")

        # Update best combination and alpha if a higher alpha is found
        if alpha_value > best_alpha:
            best_alpha = alpha_value
            best_combination = combination

    # Print the best combination and alpha
    print(f"\nBest Combination: {best_combination}, Best Alpha: {best_alpha}")
    return best_alpha, best_combination
# Out:
# Running cells with 'Python 3.11.1 64-bit ('3.11.1')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sinix/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
compute_krippendorff_alpha_for_k_runs(df_merge, runs, 2)
# Out:
# Running cells with 'Python 3.11.1 64-bit ('3.11.1')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sinix/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'
